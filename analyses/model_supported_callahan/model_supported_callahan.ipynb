# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))


import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import os
import pandas as pd
import seaborn as sb
import statistics as st

from Bio import SeqIO

sb.set()
pd.set_option("display.max_rows", None)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Evaluation of model-supported clustering methods implemented in GeFaST on Callahan data
#
# The following notebook describes the steps and results of the evaluation.

# %%
# Initial files and directories:
#
# model_supported_callahan
# |- data
# |  |- balanced
# |  |  \- BalancedRefSeqs.fasta  # provided reference sequences of 'balanced' data set
# |  |
# |  \- hmp
# |     \- HMP_MOCK.fasta  # provided reference sequences of 'hmp' data set
# |
# |- evaluation # will contain the evaluation plots and tables
# |
# |- outputs # will contain the cluster and metric outputs
# |
# |- tasks  # task files for the different runs of GeFaST
# |
# |- base_as.conf  # common base configuration of runs in 'as' mode
# |- base_cons.conf  # common base configuration of runs in 'cons' mode
# \- base_lev.conf  # common base configuration of runs in 'lev' mode

# %% [markdown]
# The provided reference sequences are part of the [Supplementary Software](https://static-content.springer.com/esm/art%3A10.1038%2Fnmeth.3869/MediaObjects/41592_2016_BFnmeth3869_MOESM270_ESM.zip) of the DADA2 paper.

# %% [markdown]
# ## Analysis workflow
#
# The data sets are preprocessed as described in Callahan et al., *DADA2: High-resolution sample inference from Illumina amplicon data* (https://doi.org/10.1038/nmeth.3869),
# except that the minimum sequence abundance is set to 1 (not 2) for the sake of a fair comparison with other data sets and tools.
#
# The taxonomic assignment is obtained by merging (using `USEARCH -fastq_mergepairs`) and dereplicating (using `USEARCH -derep_fulllength`) the reads,
# and matching them with the respective reference sequences (using `VSEARCH --usearch_global`).
#
# GeFaST is executed in different modes (`as`, `lev`, `cons`), with different clusterers (`classic`, `cons-classic`, `cons-swarmer`) and with different cluster refiners (`classic`, `cons-lsa`, `cons-lsr`, `cons-lss`).
#
# The different runs are usually referred to by an abbreviation hinting at the mode, clusterer and refiner: `<mode/clusterer>__<refinement>`, e.g. `as__nf` and `lev_dada2-c__lsa1`.
#
# Values of `<mode/clusterer>`:
#
# | Abbreviation | Description |
# | --: | :-- |
# | as          | alignment-score mode with `classic` clusterer |
# | as_dada2-c  | alignment-score mode with `cons-classic` clusterer |
# | dada2-s     | consistency mode with `cons-swarmer` clusterer |
# | lev         | Levenshtein mode with `classic` clusterer |
# | lev_dada2-c | Levenshtein mode with `cons-classic` clusterer |
#
# Values of `<refinement>`:
#
# | Abbreviation | Description |
# | --:  | :-- |
# | nf   | no refinement |
# | f1   | fastidious refinement with `classic` refiner, incremented refinement threshold (+1 for `lev` / `lev_cons`, +20 for `as` / `as_cons`) |
# | 2f   | fastidious refinement with `classic` refiner, doubled refinement threshold doubled |
# | lsa1 | consistency-based refinement with `cons-lsa` refiner (option 1) |
# | lsa2 | consistency-based refinement with `cons-lsa` refiner (option 2) |
# | lsa3 | consistency-based refinement with `cons-lsa` refiner (option 3) |
# | lsa4 | consistency-based refinement with `cons-lsa` refiner (option 4) |
# | lsr1 | consistency-based refinement with `cons-lsr` refiner (option 1) |
# | lsr2 | consistency-based refinement with `cons-lsr` refiner (option 2) |
# | lsr3 | consistency-based refinement with `cons-lsr` refiner (option 3) |
# | lsr4 | consistency-based refinement with `cons-lsr` refiner (option 4) |
# | lss  | consistency-based refinement with `cons-lss` refiner |

# %% [markdown]
# ## Commands
#
# The following commands prepare and cluster the data sets. The results are evaluated below.
#
# In order to execute the workflow as provided here, the `tools` subdirectory of the overall repository should contain the USEARCH binaries `usearch8.0.1623_i86linux32` and `usearch10.0.240_i86linux32`, but the paths can be adjusted.
# In addition, VSEARCH is expected to be accessible through the `vsearch` command.
#
# IMPORTANT: The commands are not intended to be executed from this notebook. They should be executed from the root directory of the overall repository.

# %%
# %%bash
#
# TOOLS_DIR=tools
# ANALYSIS_DIR=analyses/model_supported_callahan
# DATA_DIR=${ANALYSIS_DIR}/data
# OUTPUT_DIR=${ANALYSIS_DIR}/outputs
#
# USEARCH8_PATH=${TOOLS_DIR}/usearch8.0.1623_i86linux32 # adjust to your system
# USEARCH10_PATH=${TOOLS_DIR}/usearch10.0.240_i86linux32 # adjust to your system
#
# GEFAST=${TOOLS_DIR}/GeFaST/build/GeFaST # adjust to your system
#
# RUNS=( as__nf as__2f as__f1 as__lsa1 as__lsa2 as__lsa3 as__lsa4 as__lsr1 as__lsr2 as__lsr3 as__lsr4 as__lss as_dada2-c__nf as_dada2-c__2f as_dada2-c__f1 as_dada2-c__lsa1 as_dada2-c__lsa2 as_dada2-c__lsa3 as_dada2-c__lsa4 as_dada2-c__lsr1 as_dada2-c__lsr2 as_dada2-c__lsr3 as_dada2-c__lsr4 as_dada2-c__lss dada2-s__nf dada2-s__lsa1 dada2-s__lsa2 dada2-s__lsa3 dada2-s__lsa4 dada2-s__lsr1 dada2-s__lsr2 dada2-s__lsr3 dada2-s__lsr4 dada2-s__lss lev__nf lev__2f lev__f1 lev__lsa1 lev__lsa2 lev__lsa3 lev__lsa4 lev__lsr1 lev__lsr2 lev__lsr3 lev__lsr4 lev__lss lev_dada2-c__nf lev_dada2-c__2f lev_dada2-c__f1 lev_dada2-c__lsa1 lev_dada2-c__lsa2 lev_dada2-c__lsa3 lev_dada2-c__lsa4 lev_dada2-c__lsr1 lev_dada2-c__lsr2 lev_dada2-c__lsr3 lev_dada2-c__lsr4 lev_dada2-c__lss )
#
# ## balanced
# python -m scripts.analyses.analysis_callahan reference balanced ${DATA_DIR}/balanced/BalancedRefSeqs.fasta ${DATA_DIR}/balanced/callahan.fasta
#
# # paired
# python -m scripts.analyses.analysis_callahan prepare balanced ${DATA_DIR}/balanced --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/balanced/ERR777695_pfmd.fastq ${DATA_DIR}/balanced/callahan.fasta ${DATA_DIR}/balanced/bp_callahan_0.97.tax 0.97
#
# READS=bp:${DATA_DIR}/balanced/ERR777695_pfmd.fastq
# TAX=callahan:${DATA_DIR}/balanced/bp_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/balanced_paired/${R} --tax_files ${TAX} --gefast ${GEFAST}
#     for F in ${OUTPUT_DIR}/balanced_paired/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/balanced_paired/${R}/${R}_${F##*/}; done
# done
#
#
# # single
# python -m scripts.analyses.analysis_callahan prepare balanced ${DATA_DIR}/balanced --single --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/balanced/ERR777695_1_sfd.fastq ${DATA_DIR}/balanced/callahan.fasta ${DATA_DIR}/balanced/bs_callahan_0.97.tax 0.97
#
# READS=bs:${DATA_DIR}/balanced/ERR777695_1_sfd.fastq
# TAX=callahan:${DATA_DIR}/balanced/bs_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/balanced_single/${R} --tax_files ${TAX} --gefast ${GEFAST}
#     for F in ${OUTPUT_DIR}/balanced_single/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/balanced_single/${R}/${R}_${F##*/}; done
# done
#
#
# ## hmp
# python -m scripts.analyses.analysis_callahan reference hmp ${DATA_DIR}/hmp/HMP_MOCK.fasta ${DATA_DIR}/hmp/callahan.fasta
#
# # paired
# python -m scripts.analyses.analysis_callahan prepare hmp ${DATA_DIR}/hmp --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/hmp/Mock1_S1_L001_pfmd.fastq ${DATA_DIR}/hmp/callahan.fasta ${DATA_DIR}/hmp/hp_callahan_0.97.tax 0.97
#
# READS=hp:${DATA_DIR}/hmp/Mock1_S1_L001_pfmd.fastq
# TAX=callahan:${DATA_DIR}/hmp/hp_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/hmp_paired/${R} --tax_files ${TAX} --gefast ${GEFAST}
#     for F in ${OUTPUT_DIR}/hmp_paired/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/hmp_paired/${R}/${R}_${F##*/}; done
# done
#
#
# # single
# python -m scripts.analyses.analysis_callahan prepare hmp ${DATA_DIR}/hmp --single --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/hmp/Mock1_S1_L001_R1_001_sfd.fastq ${DATA_DIR}/hmp/callahan.fasta ${DATA_DIR}/hmp/hs_callahan_0.97.tax 0.97
#
# READS=hs:${DATA_DIR}/hmp/Mock1_S1_L001_R1_001_sfd.fastq
# TAX=callahan:${DATA_DIR}/hmp/hs_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/hmp_single/${R} --tax_files ${TAX} --gefast ${GEFAST}
#     for F in ${OUTPUT_DIR}/hmp_single/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/hmp_single/${R}/${R}_${F##*/}; done
# done

# %% [markdown]
# ## Evaluation

# %% [markdown]
# **Configuration**

# %%
data_sets = ['balanced', 'hmp']
read_types = ['single', 'paired']
ground_truths = ['callahan']

opts = ['as__nf', 'as__f1', 'as__2f', 'as__lsa1', 'as__lsa2', 'as__lsa3', 'as__lsa4', 'as__lsr1', 'as__lsr2', 'as__lsr3', 'as__lsr4', 'as__lss', 
        'as_dada2-c__nf', 'as_dada2-c__f1', 'as_dada2-c__2f', 'as_dada2-c__lsa1', 'as_dada2-c__lsa2', 'as_dada2-c__lsa3', 'as_dada2-c__lsa4', 'as_dada2-c__lsr1', 'as_dada2-c__lsr2', 'as_dada2-c__lsr3', 'as_dada2-c__lsr4', 'as_dada2-c__lss', 
        'dada2-s__nf', 'dada2-s__lsa1', 'dada2-s__lsa2', 'dada2-s__lsa3', 'dada2-s__lsa4', 'dada2-s__lsr1', 'dada2-s__lsr2', 'dada2-s__lsr3', 'dada2-s__lsr4', 'dada2-s__lss', 
        'lev__nf', 'lev__f1', 'lev__2f', 'lev__lsa1', 'lev__lsa2', 'lev__lsa3', 'lev__lsa4', 'lev__lsr1', 'lev__lsr2', 'lev__lsr3', 'lev__lsr4', 'lev__lss', 
        'lev_dada2-c__nf', 'lev_dada2-c__f1', 'lev_dada2-c__2f', 'lev_dada2-c__lsa1', 'lev_dada2-c__lsa2', 'lev_dada2-c__lsa3', 'lev_dada2-c__lsa4', 'lev_dada2-c__lsr1', 'lev_dada2-c__lsr2', 'lev_dada2-c__lsr3', 'lev_dada2-c__lsr4', 'lev_dada2-c__lss']

read_files = {'balanced_single': 'ERR777695_1_sfd.fastq', 'balanced_paired': 'ERR777695_pfmd.fastq',
              'hmp_single': 'Mock1_S1_L001_R1_001_sfd.fastq', 'hmp_paired': 'Mock1_S1_L001_pfmd.fastq'}

data_dir = 'data'
results_dir = 'outputs'
eval_dir = 'evaluation'

# %% [markdown]
# ### Number of clusters and amplicons
#
# Reads the input files and the cluster outputs for all data sets and compares the number of clusters and amplicons.

# %%
# Requires the input and OTU files. Alternatively, the evaluation can use the stored information (see below).
df_columns = ['data_set', 'tool', 'mode', 'refinement', 'threshold', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

rows = []

for rt in read_types:
    for ds in data_sets:
        run_name = '%s_%s' % (ds, rt)
        
        seq_file = '%s/%s/%s' % (data_dir, ds, read_files[run_name]) # the input sequences
        num_input_amplicons = 0
        input_mass = 0
        with open(seq_file, 'r') as in_file:
            for record in SeqIO.parse(in_file, 'fastq'):
                num_input_amplicons += 1
                input_mass += int(record.id.split('_')[-1])
        
        for opt in opts:
            otu_files = [f for f in os.listdir('%s/%s/%s/' % (results_dir, run_name, opt)) if f.endswith('_otus.txt')]

            for f in otu_files:
                otu_file = '%s/%s/%s/%s' % (results_dir, run_name, opt, f)
                                        
                num_output_amplicons = 0
                num_clusters = 0
                output_mass = 0
                with open(otu_file, 'r') as in_file:
                    for line in in_file:
                        num_output_amplicons += len(line.strip().split(' '))
                        num_clusters += 1
                        output_mass += sum([int(m.split('_')[-1]) for m in line.strip().split(' ')])
                        
                tool = 'gefast'
                mode = '_'.join(f.split('__')[0].split('_')[1:])
                refinement = f.split('__')[1].split('_')[0]
                threshold = float(f.split('_')[-2])

                rows.append([run_name, tool, mode, refinement, threshold, num_input_amplicons, input_mass, num_clusters, num_output_amplicons, output_mass, ds, rt])
            
df_counts = pd.DataFrame(rows, columns = df_columns)
df_counts.sort_values(by = ['data_set', 'tool', 'mode', 'refinement', 'threshold'], inplace = True)

# %% [markdown]
# *Column descriptions:*
# `num_input_amplicons`: The number of entries in the corresponding input file.
# `input_mass`: The sum of the abundances of all entries in the input file.
# `num_clusters`: The number of computed clusters.
# `num_output_amplicons`: The number of amplicons contained in the clusters.
# `output_mass`: The sum of the abundances of all amplicons contained in the clusters.

# %%
df_counts[['data_set', 'mode', 'refinement', 'threshold', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass']]
# Out:
#              data_set         mode refinement  threshold  num_input_amplicons  \
# 1005  balanced_paired           as         2f       20.0                21808
# 1007  balanced_paired           as         2f       40.0                21808
# 1008  balanced_paired           as         2f       60.0                21808
# 1009  balanced_paired           as         2f       80.0                21808
# 1000  balanced_paired           as         2f      100.0                21808
# 1001  balanced_paired           as         2f      120.0                21808
# 1002  balanced_paired           as         2f      140.0                21808
# 1003  balanced_paired           as         2f      160.0                21808
# 1004  balanced_paired           as         2f      180.0                21808
# 1006  balanced_paired           as         2f      200.0                21808
# 995   balanced_paired           as         f1       20.0                21808
# 997   balanced_paired           as         f1       40.0                21808
# 998   balanced_paired           as         f1       60.0                21808
# 999   balanced_paired           as         f1       80.0                21808
# 990   balanced_paired           as         f1      100.0                21808
# 991   balanced_paired           as         f1      120.0                21808
# 992   balanced_paired           as         f1      140.0                21808
# 993   balanced_paired           as         f1      160.0                21808
# 994   balanced_paired           as         f1      180.0                21808
# 996   balanced_paired           as         f1      200.0                21808
# 1015  balanced_paired           as       lsa1       20.0                21808
# 1017  balanced_paired           as       lsa1       40.0                21808
# 1018  balanced_paired           as       lsa1       60.0                21808
# 1019  balanced_paired           as       lsa1       80.0                21808
# 1010  balanced_paired           as       lsa1      100.0                21808
# 1011  balanced_paired           as       lsa1      120.0                21808
# 1012  balanced_paired           as       lsa1      140.0                21808
# 1013  balanced_paired           as       lsa1      160.0                21808
# 1014  balanced_paired           as       lsa1      180.0                21808
# 1016  balanced_paired           as       lsa1      200.0                21808
# 1025  balanced_paired           as       lsa2       20.0                21808
# 1027  balanced_paired           as       lsa2       40.0                21808
# 1028  balanced_paired           as       lsa2       60.0                21808
# 1029  balanced_paired           as       lsa2       80.0                21808
# 1020  balanced_paired           as       lsa2      100.0                21808
# 1021  balanced_paired           as       lsa2      120.0                21808
# 1022  balanced_paired           as       lsa2      140.0                21808
# 1023  balanced_paired           as       lsa2      160.0                21808
# 1024  balanced_paired           as       lsa2      180.0                21808
# 1026  balanced_paired           as       lsa2      200.0                21808
# 1035  balanced_paired           as       lsa3       20.0                21808
# 1037  balanced_paired           as       lsa3       40.0                21808
# 1038  balanced_paired           as       lsa3       60.0                21808
# 1039  balanced_paired           as       lsa3       80.0                21808
# 1030  balanced_paired           as       lsa3      100.0                21808
# 1031  balanced_paired           as       lsa3      120.0                21808
# 1032  balanced_paired           as       lsa3      140.0                21808
# 1033  balanced_paired           as       lsa3      160.0                21808
# 1034  balanced_paired           as       lsa3      180.0                21808
# 1036  balanced_paired           as       lsa3      200.0                21808
# 1045  balanced_paired           as       lsa4       20.0                21808
# 1047  balanced_paired           as       lsa4       40.0                21808
# 1048  balanced_paired           as       lsa4       60.0                21808
# 1049  balanced_paired           as       lsa4       80.0                21808
# 1040  balanced_paired           as       lsa4      100.0                21808
# 1041  balanced_paired           as       lsa4      120.0                21808
# 1042  balanced_paired           as       lsa4      140.0                21808
# 1043  balanced_paired           as       lsa4      160.0                21808
# 1044  balanced_paired           as       lsa4      180.0                21808
# 1046  balanced_paired           as       lsa4      200.0                21808
# 1055  balanced_paired           as       lsr1       20.0                21808
# 1057  balanced_paired           as       lsr1       40.0                21808
# 1058  balanced_paired           as       lsr1       60.0                21808
# 1059  balanced_paired           as       lsr1       80.0                21808
# 1050  balanced_paired           as       lsr1      100.0                21808
# 1051  balanced_paired           as       lsr1      120.0                21808
# 1052  balanced_paired           as       lsr1      140.0                21808
# 1053  balanced_paired           as       lsr1      160.0                21808
# 1054  balanced_paired           as       lsr1      180.0                21808
# 1056  balanced_paired           as       lsr1      200.0                21808
# 1065  balanced_paired           as       lsr2       20.0                21808
# 1067  balanced_paired           as       lsr2       40.0                21808
# 1068  balanced_paired           as       lsr2       60.0                21808
# 1069  balanced_paired           as       lsr2       80.0                21808
# 1060  balanced_paired           as       lsr2      100.0                21808
# 1061  balanced_paired           as       lsr2      120.0                21808
# 1062  balanced_paired           as       lsr2      140.0                21808
# 1063  balanced_paired           as       lsr2      160.0                21808
# 1064  balanced_paired           as       lsr2      180.0                21808
# 1066  balanced_paired           as       lsr2      200.0                21808
# 1075  balanced_paired           as       lsr3       20.0                21808
# 1077  balanced_paired           as       lsr3       40.0                21808
# 1078  balanced_paired           as       lsr3       60.0                21808
# 1079  balanced_paired           as       lsr3       80.0                21808
# 1070  balanced_paired           as       lsr3      100.0                21808
# 1071  balanced_paired           as       lsr3      120.0                21808
# 1072  balanced_paired           as       lsr3      140.0                21808
# 1073  balanced_paired           as       lsr3      160.0                21808
# 1074  balanced_paired           as       lsr3      180.0                21808
# 1076  balanced_paired           as       lsr3      200.0                21808
# 1085  balanced_paired           as       lsr4       20.0                21808
# 1087  balanced_paired           as       lsr4       40.0                21808
# 1088  balanced_paired           as       lsr4       60.0                21808
# 1089  balanced_paired           as       lsr4       80.0                21808
# 1080  balanced_paired           as       lsr4      100.0                21808
# 1081  balanced_paired           as       lsr4      120.0                21808
# 1082  balanced_paired           as       lsr4      140.0                21808
# 1083  balanced_paired           as       lsr4      160.0                21808
# 1084  balanced_paired           as       lsr4      180.0                21808
# 1086  balanced_paired           as       lsr4      200.0                21808
# 1095  balanced_paired           as        lss       20.0                21808
# 1097  balanced_paired           as        lss       40.0                21808
# 1098  balanced_paired           as        lss       60.0                21808
# 1099  balanced_paired           as        lss       80.0                21808
# 1090  balanced_paired           as        lss      100.0                21808
# 1091  balanced_paired           as        lss      120.0                21808
# 1092  balanced_paired           as        lss      140.0                21808
# 1093  balanced_paired           as        lss      160.0                21808
# 1094  balanced_paired           as        lss      180.0                21808
# 1096  balanced_paired           as        lss      200.0                21808
# 985   balanced_paired           as         nf       20.0                21808
# 987   balanced_paired           as         nf       40.0                21808
# 988   balanced_paired           as         nf       60.0                21808
# 989   balanced_paired           as         nf       80.0                21808
# 980   balanced_paired           as         nf      100.0                21808
# 981   balanced_paired           as         nf      120.0                21808
# 982   balanced_paired           as         nf      140.0                21808
# 983   balanced_paired           as         nf      160.0                21808
# 984   balanced_paired           as         nf      180.0                21808
# 986   balanced_paired           as         nf      200.0                21808
# 1125  balanced_paired   as_dada2-c         2f       20.0                21808
# 1127  balanced_paired   as_dada2-c         2f       40.0                21808
# 1128  balanced_paired   as_dada2-c         2f       60.0                21808
# 1129  balanced_paired   as_dada2-c         2f       80.0                21808
# 1120  balanced_paired   as_dada2-c         2f      100.0                21808
# 1121  balanced_paired   as_dada2-c         2f      120.0                21808
# 1122  balanced_paired   as_dada2-c         2f      140.0                21808
# 1123  balanced_paired   as_dada2-c         2f      160.0                21808
# 1124  balanced_paired   as_dada2-c         2f      180.0                21808
# 1126  balanced_paired   as_dada2-c         2f      200.0                21808
# 1115  balanced_paired   as_dada2-c         f1       20.0                21808
# 1117  balanced_paired   as_dada2-c         f1       40.0                21808
# 1118  balanced_paired   as_dada2-c         f1       60.0                21808
# 1119  balanced_paired   as_dada2-c         f1       80.0                21808
# 1110  balanced_paired   as_dada2-c         f1      100.0                21808
# 1111  balanced_paired   as_dada2-c         f1      120.0                21808
# 1112  balanced_paired   as_dada2-c         f1      140.0                21808
# 1113  balanced_paired   as_dada2-c         f1      160.0                21808
# 1114  balanced_paired   as_dada2-c         f1      180.0                21808
# 1116  balanced_paired   as_dada2-c         f1      200.0                21808
# 1135  balanced_paired   as_dada2-c       lsa1       20.0                21808
# 1137  balanced_paired   as_dada2-c       lsa1       40.0                21808
# 1138  balanced_paired   as_dada2-c       lsa1       60.0                21808
# 1139  balanced_paired   as_dada2-c       lsa1       80.0                21808
# 1130  balanced_paired   as_dada2-c       lsa1      100.0                21808
# 1131  balanced_paired   as_dada2-c       lsa1      120.0                21808
# 1132  balanced_paired   as_dada2-c       lsa1      140.0                21808
# 1133  balanced_paired   as_dada2-c       lsa1      160.0                21808
# 1134  balanced_paired   as_dada2-c       lsa1      180.0                21808
# 1136  balanced_paired   as_dada2-c       lsa1      200.0                21808
# 1145  balanced_paired   as_dada2-c       lsa2       20.0                21808
# 1147  balanced_paired   as_dada2-c       lsa2       40.0                21808
# 1148  balanced_paired   as_dada2-c       lsa2       60.0                21808
# 1149  balanced_paired   as_dada2-c       lsa2       80.0                21808
# 1140  balanced_paired   as_dada2-c       lsa2      100.0                21808
# 1141  balanced_paired   as_dada2-c       lsa2      120.0                21808
# 1142  balanced_paired   as_dada2-c       lsa2      140.0                21808
# 1143  balanced_paired   as_dada2-c       lsa2      160.0                21808
# 1144  balanced_paired   as_dada2-c       lsa2      180.0                21808
# 1146  balanced_paired   as_dada2-c       lsa2      200.0                21808
# 1155  balanced_paired   as_dada2-c       lsa3       20.0                21808
# 1157  balanced_paired   as_dada2-c       lsa3       40.0                21808
# 1158  balanced_paired   as_dada2-c       lsa3       60.0                21808
# 1159  balanced_paired   as_dada2-c       lsa3       80.0                21808
# 1150  balanced_paired   as_dada2-c       lsa3      100.0                21808
# 1151  balanced_paired   as_dada2-c       lsa3      120.0                21808
# 1152  balanced_paired   as_dada2-c       lsa3      140.0                21808
# 1153  balanced_paired   as_dada2-c       lsa3      160.0                21808
# 1154  balanced_paired   as_dada2-c       lsa3      180.0                21808
# 1156  balanced_paired   as_dada2-c       lsa3      200.0                21808
# 1165  balanced_paired   as_dada2-c       lsa4       20.0                21808
# 1167  balanced_paired   as_dada2-c       lsa4       40.0                21808
# 1168  balanced_paired   as_dada2-c       lsa4       60.0                21808
# 1169  balanced_paired   as_dada2-c       lsa4       80.0                21808
# 1160  balanced_paired   as_dada2-c       lsa4      100.0                21808
# 1161  balanced_paired   as_dada2-c       lsa4      120.0                21808
# 1162  balanced_paired   as_dada2-c       lsa4      140.0                21808
# 1163  balanced_paired   as_dada2-c       lsa4      160.0                21808
# 1164  balanced_paired   as_dada2-c       lsa4      180.0                21808
# 1166  balanced_paired   as_dada2-c       lsa4      200.0                21808
# 1175  balanced_paired   as_dada2-c       lsr1       20.0                21808
# 1177  balanced_paired   as_dada2-c       lsr1       40.0                21808
# 1178  balanced_paired   as_dada2-c       lsr1       60.0                21808
# 1179  balanced_paired   as_dada2-c       lsr1       80.0                21808
# 1170  balanced_paired   as_dada2-c       lsr1      100.0                21808
# 1171  balanced_paired   as_dada2-c       lsr1      120.0                21808
# 1172  balanced_paired   as_dada2-c       lsr1      140.0                21808
# 1173  balanced_paired   as_dada2-c       lsr1      160.0                21808
# 1174  balanced_paired   as_dada2-c       lsr1      180.0                21808
# 1176  balanced_paired   as_dada2-c       lsr1      200.0                21808
# 1185  balanced_paired   as_dada2-c       lsr2       20.0                21808
# 1187  balanced_paired   as_dada2-c       lsr2       40.0                21808
# 1188  balanced_paired   as_dada2-c       lsr2       60.0                21808
# 1189  balanced_paired   as_dada2-c       lsr2       80.0                21808
# 1180  balanced_paired   as_dada2-c       lsr2      100.0                21808
# 1181  balanced_paired   as_dada2-c       lsr2      120.0                21808
# 1182  balanced_paired   as_dada2-c       lsr2      140.0                21808
# 1183  balanced_paired   as_dada2-c       lsr2      160.0                21808
# 1184  balanced_paired   as_dada2-c       lsr2      180.0                21808
# 1186  balanced_paired   as_dada2-c       lsr2      200.0                21808
# 1195  balanced_paired   as_dada2-c       lsr3       20.0                21808
# 1197  balanced_paired   as_dada2-c       lsr3       40.0                21808
# 1198  balanced_paired   as_dada2-c       lsr3       60.0                21808
# 1199  balanced_paired   as_dada2-c       lsr3       80.0                21808
# 1190  balanced_paired   as_dada2-c       lsr3      100.0                21808
# 1191  balanced_paired   as_dada2-c       lsr3      120.0                21808
# 1192  balanced_paired   as_dada2-c       lsr3      140.0                21808
# 1193  balanced_paired   as_dada2-c       lsr3      160.0                21808
# 1194  balanced_paired   as_dada2-c       lsr3      180.0                21808
# 1196  balanced_paired   as_dada2-c       lsr3      200.0                21808
# 1205  balanced_paired   as_dada2-c       lsr4       20.0                21808
# 1207  balanced_paired   as_dada2-c       lsr4       40.0                21808
# 1208  balanced_paired   as_dada2-c       lsr4       60.0                21808
# 1209  balanced_paired   as_dada2-c       lsr4       80.0                21808
# 1200  balanced_paired   as_dada2-c       lsr4      100.0                21808
# 1201  balanced_paired   as_dada2-c       lsr4      120.0                21808
# 1202  balanced_paired   as_dada2-c       lsr4      140.0                21808
# 1203  balanced_paired   as_dada2-c       lsr4      160.0                21808
# 1204  balanced_paired   as_dada2-c       lsr4      180.0                21808
# 1206  balanced_paired   as_dada2-c       lsr4      200.0                21808
# 1215  balanced_paired   as_dada2-c        lss       20.0                21808
# 1217  balanced_paired   as_dada2-c        lss       40.0                21808
# 1218  balanced_paired   as_dada2-c        lss       60.0                21808
# 1219  balanced_paired   as_dada2-c        lss       80.0                21808
# 1210  balanced_paired   as_dada2-c        lss      100.0                21808
# 1211  balanced_paired   as_dada2-c        lss      120.0                21808
# 1212  balanced_paired   as_dada2-c        lss      140.0                21808
# 1213  balanced_paired   as_dada2-c        lss      160.0                21808
# 1214  balanced_paired   as_dada2-c        lss      180.0                21808
# 1216  balanced_paired   as_dada2-c        lss      200.0                21808
# 1105  balanced_paired   as_dada2-c         nf       20.0                21808
# 1107  balanced_paired   as_dada2-c         nf       40.0                21808
# 1108  balanced_paired   as_dada2-c         nf       60.0                21808
# 1109  balanced_paired   as_dada2-c         nf       80.0                21808
# 1100  balanced_paired   as_dada2-c         nf      100.0                21808
# 1101  balanced_paired   as_dada2-c         nf      120.0                21808
# 1102  balanced_paired   as_dada2-c         nf      140.0                21808
# 1103  balanced_paired   as_dada2-c         nf      160.0                21808
# 1104  balanced_paired   as_dada2-c         nf      180.0                21808
# 1106  balanced_paired   as_dada2-c         nf      200.0                21808
# 1221  balanced_paired      dada2-s       lsa1       20.0                21808
# 1222  balanced_paired      dada2-s       lsa2       20.0                21808
# 1223  balanced_paired      dada2-s       lsa3       20.0                21808
# 1224  balanced_paired      dada2-s       lsa4       20.0                21808
# 1225  balanced_paired      dada2-s       lsr1       20.0                21808
# 1226  balanced_paired      dada2-s       lsr2       20.0                21808
# 1227  balanced_paired      dada2-s       lsr3       20.0                21808
# 1228  balanced_paired      dada2-s       lsr4       20.0                21808
# 1229  balanced_paired      dada2-s        lss       20.0                21808
# 1220  balanced_paired      dada2-s         nf       20.0                21808
# 1250  balanced_paired          lev         2f        1.0                21808
# 1252  balanced_paired          lev         2f        2.0                21808
# 1253  balanced_paired          lev         2f        3.0                21808
# 1254  balanced_paired          lev         2f        4.0                21808
# 1255  balanced_paired          lev         2f        5.0                21808
# 1256  balanced_paired          lev         2f        6.0                21808
# 1257  balanced_paired          lev         2f        7.0                21808
# 1258  balanced_paired          lev         2f        8.0                21808
# 1259  balanced_paired          lev         2f        9.0                21808
# 1251  balanced_paired          lev         2f       10.0                21808
# 1240  balanced_paired          lev         f1        1.0                21808
# 1242  balanced_paired          lev         f1        2.0                21808
# 1243  balanced_paired          lev         f1        3.0                21808
# 1244  balanced_paired          lev         f1        4.0                21808
# 1245  balanced_paired          lev         f1        5.0                21808
# 1246  balanced_paired          lev         f1        6.0                21808
# 1247  balanced_paired          lev         f1        7.0                21808
# 1248  balanced_paired          lev         f1        8.0                21808
# 1249  balanced_paired          lev         f1        9.0                21808
# 1241  balanced_paired          lev         f1       10.0                21808
# 1260  balanced_paired          lev       lsa1        1.0                21808
# 1262  balanced_paired          lev       lsa1        2.0                21808
# 1263  balanced_paired          lev       lsa1        3.0                21808
# 1264  balanced_paired          lev       lsa1        4.0                21808
# 1265  balanced_paired          lev       lsa1        5.0                21808
# 1266  balanced_paired          lev       lsa1        6.0                21808
# 1267  balanced_paired          lev       lsa1        7.0                21808
# 1268  balanced_paired          lev       lsa1        8.0                21808
# 1269  balanced_paired          lev       lsa1        9.0                21808
# 1261  balanced_paired          lev       lsa1       10.0                21808
# 1270  balanced_paired          lev       lsa2        1.0                21808
# 1272  balanced_paired          lev       lsa2        2.0                21808
# 1273  balanced_paired          lev       lsa2        3.0                21808
# 1274  balanced_paired          lev       lsa2        4.0                21808
# 1275  balanced_paired          lev       lsa2        5.0                21808
# 1276  balanced_paired          lev       lsa2        6.0                21808
# 1277  balanced_paired          lev       lsa2        7.0                21808
# 1278  balanced_paired          lev       lsa2        8.0                21808
# 1279  balanced_paired          lev       lsa2        9.0                21808
# 1271  balanced_paired          lev       lsa2       10.0                21808
# 1280  balanced_paired          lev       lsa3        1.0                21808
# 1282  balanced_paired          lev       lsa3        2.0                21808
# 1283  balanced_paired          lev       lsa3        3.0                21808
# 1284  balanced_paired          lev       lsa3        4.0                21808
# 1285  balanced_paired          lev       lsa3        5.0                21808
# 1286  balanced_paired          lev       lsa3        6.0                21808
# 1287  balanced_paired          lev       lsa3        7.0                21808
# 1288  balanced_paired          lev       lsa3        8.0                21808
# 1289  balanced_paired          lev       lsa3        9.0                21808
# 1281  balanced_paired          lev       lsa3       10.0                21808
# 1290  balanced_paired          lev       lsa4        1.0                21808
# 1292  balanced_paired          lev       lsa4        2.0                21808
# 1293  balanced_paired          lev       lsa4        3.0                21808
# 1294  balanced_paired          lev       lsa4        4.0                21808
# 1295  balanced_paired          lev       lsa4        5.0                21808
# 1296  balanced_paired          lev       lsa4        6.0                21808
# 1297  balanced_paired          lev       lsa4        7.0                21808
# 1298  balanced_paired          lev       lsa4        8.0                21808
# 1299  balanced_paired          lev       lsa4        9.0                21808
# 1291  balanced_paired          lev       lsa4       10.0                21808
# 1300  balanced_paired          lev       lsr1        1.0                21808
# 1302  balanced_paired          lev       lsr1        2.0                21808
# 1303  balanced_paired          lev       lsr1        3.0                21808
# 1304  balanced_paired          lev       lsr1        4.0                21808
# 1305  balanced_paired          lev       lsr1        5.0                21808
# 1306  balanced_paired          lev       lsr1        6.0                21808
# 1307  balanced_paired          lev       lsr1        7.0                21808
# 1308  balanced_paired          lev       lsr1        8.0                21808
# 1309  balanced_paired          lev       lsr1        9.0                21808
# 1301  balanced_paired          lev       lsr1       10.0                21808
# 1310  balanced_paired          lev       lsr2        1.0                21808
# 1312  balanced_paired          lev       lsr2        2.0                21808
# 1313  balanced_paired          lev       lsr2        3.0                21808
# 1314  balanced_paired          lev       lsr2        4.0                21808
# 1315  balanced_paired          lev       lsr2        5.0                21808
# 1316  balanced_paired          lev       lsr2        6.0                21808
# 1317  balanced_paired          lev       lsr2        7.0                21808
# 1318  balanced_paired          lev       lsr2        8.0                21808
# 1319  balanced_paired          lev       lsr2        9.0                21808
# 1311  balanced_paired          lev       lsr2       10.0                21808
# 1320  balanced_paired          lev       lsr3        1.0                21808
# 1322  balanced_paired          lev       lsr3        2.0                21808
# 1323  balanced_paired          lev       lsr3        3.0                21808
# 1324  balanced_paired          lev       lsr3        4.0                21808
# 1325  balanced_paired          lev       lsr3        5.0                21808
# 1326  balanced_paired          lev       lsr3        6.0                21808
# 1327  balanced_paired          lev       lsr3        7.0                21808
# 1328  balanced_paired          lev       lsr3        8.0                21808
# 1329  balanced_paired          lev       lsr3        9.0                21808
# 1321  balanced_paired          lev       lsr3       10.0                21808
# 1330  balanced_paired          lev       lsr4        1.0                21808
# 1332  balanced_paired          lev       lsr4        2.0                21808
# 1333  balanced_paired          lev       lsr4        3.0                21808
# 1334  balanced_paired          lev       lsr4        4.0                21808
# 1335  balanced_paired          lev       lsr4        5.0                21808
# 1336  balanced_paired          lev       lsr4        6.0                21808
# 1337  balanced_paired          lev       lsr4        7.0                21808
# 1338  balanced_paired          lev       lsr4        8.0                21808
# 1339  balanced_paired          lev       lsr4        9.0                21808
# 1331  balanced_paired          lev       lsr4       10.0                21808
# 1340  balanced_paired          lev        lss        1.0                21808
# 1342  balanced_paired          lev        lss        2.0                21808
# 1343  balanced_paired          lev        lss        3.0                21808
# 1344  balanced_paired          lev        lss        4.0                21808
# 1345  balanced_paired          lev        lss        5.0                21808
# 1346  balanced_paired          lev        lss        6.0                21808
# 1347  balanced_paired          lev        lss        7.0                21808
# 1348  balanced_paired          lev        lss        8.0                21808
# 1349  balanced_paired          lev        lss        9.0                21808
# 1341  balanced_paired          lev        lss       10.0                21808
# 1230  balanced_paired          lev         nf        1.0                21808
# 1232  balanced_paired          lev         nf        2.0                21808
# 1233  balanced_paired          lev         nf        3.0                21808
# 1234  balanced_paired          lev         nf        4.0                21808
# 1235  balanced_paired          lev         nf        5.0                21808
# 1236  balanced_paired          lev         nf        6.0                21808
# 1237  balanced_paired          lev         nf        7.0                21808
# 1238  balanced_paired          lev         nf        8.0                21808
# 1239  balanced_paired          lev         nf        9.0                21808
# 1231  balanced_paired          lev         nf       10.0                21808
# 1370  balanced_paired  lev_dada2-c         2f        1.0                21808
# 1372  balanced_paired  lev_dada2-c         2f        2.0                21808
# 1373  balanced_paired  lev_dada2-c         2f        3.0                21808
# 1374  balanced_paired  lev_dada2-c         2f        4.0                21808
# 1375  balanced_paired  lev_dada2-c         2f        5.0                21808
# 1376  balanced_paired  lev_dada2-c         2f        6.0                21808
# 1377  balanced_paired  lev_dada2-c         2f        7.0                21808
# 1378  balanced_paired  lev_dada2-c         2f        8.0                21808
# 1379  balanced_paired  lev_dada2-c         2f        9.0                21808
# 1371  balanced_paired  lev_dada2-c         2f       10.0                21808
# 1360  balanced_paired  lev_dada2-c         f1        1.0                21808
# 1362  balanced_paired  lev_dada2-c         f1        2.0                21808
# 1363  balanced_paired  lev_dada2-c         f1        3.0                21808
# 1364  balanced_paired  lev_dada2-c         f1        4.0                21808
# 1365  balanced_paired  lev_dada2-c         f1        5.0                21808
# 1366  balanced_paired  lev_dada2-c         f1        6.0                21808
# 1367  balanced_paired  lev_dada2-c         f1        7.0                21808
# 1368  balanced_paired  lev_dada2-c         f1        8.0                21808
# 1369  balanced_paired  lev_dada2-c         f1        9.0                21808
# 1361  balanced_paired  lev_dada2-c         f1       10.0                21808
# 1380  balanced_paired  lev_dada2-c       lsa1        1.0                21808
# 1382  balanced_paired  lev_dada2-c       lsa1        2.0                21808
# 1383  balanced_paired  lev_dada2-c       lsa1        3.0                21808
# 1384  balanced_paired  lev_dada2-c       lsa1        4.0                21808
# 1385  balanced_paired  lev_dada2-c       lsa1        5.0                21808
# 1386  balanced_paired  lev_dada2-c       lsa1        6.0                21808
# 1387  balanced_paired  lev_dada2-c       lsa1        7.0                21808
# 1388  balanced_paired  lev_dada2-c       lsa1        8.0                21808
# 1389  balanced_paired  lev_dada2-c       lsa1        9.0                21808
# 1381  balanced_paired  lev_dada2-c       lsa1       10.0                21808
# 1390  balanced_paired  lev_dada2-c       lsa2        1.0                21808
# 1392  balanced_paired  lev_dada2-c       lsa2        2.0                21808
# 1393  balanced_paired  lev_dada2-c       lsa2        3.0                21808
# 1394  balanced_paired  lev_dada2-c       lsa2        4.0                21808
# 1395  balanced_paired  lev_dada2-c       lsa2        5.0                21808
# 1396  balanced_paired  lev_dada2-c       lsa2        6.0                21808
# 1397  balanced_paired  lev_dada2-c       lsa2        7.0                21808
# 1398  balanced_paired  lev_dada2-c       lsa2        8.0                21808
# 1399  balanced_paired  lev_dada2-c       lsa2        9.0                21808
# 1391  balanced_paired  lev_dada2-c       lsa2       10.0                21808
# 1400  balanced_paired  lev_dada2-c       lsa3        1.0                21808
# 1402  balanced_paired  lev_dada2-c       lsa3        2.0                21808
# 1403  balanced_paired  lev_dada2-c       lsa3        3.0                21808
# 1404  balanced_paired  lev_dada2-c       lsa3        4.0                21808
# 1405  balanced_paired  lev_dada2-c       lsa3        5.0                21808
# 1406  balanced_paired  lev_dada2-c       lsa3        6.0                21808
# 1407  balanced_paired  lev_dada2-c       lsa3        7.0                21808
# 1408  balanced_paired  lev_dada2-c       lsa3        8.0                21808
# 1409  balanced_paired  lev_dada2-c       lsa3        9.0                21808
# 1401  balanced_paired  lev_dada2-c       lsa3       10.0                21808
# 1410  balanced_paired  lev_dada2-c       lsa4        1.0                21808
# 1412  balanced_paired  lev_dada2-c       lsa4        2.0                21808
# 1413  balanced_paired  lev_dada2-c       lsa4        3.0                21808
# 1414  balanced_paired  lev_dada2-c       lsa4        4.0                21808
# 1415  balanced_paired  lev_dada2-c       lsa4        5.0                21808
# 1416  balanced_paired  lev_dada2-c       lsa4        6.0                21808
# 1417  balanced_paired  lev_dada2-c       lsa4        7.0                21808
# 1418  balanced_paired  lev_dada2-c       lsa4        8.0                21808
# 1419  balanced_paired  lev_dada2-c       lsa4        9.0                21808
# 1411  balanced_paired  lev_dada2-c       lsa4       10.0                21808
# 1420  balanced_paired  lev_dada2-c       lsr1        1.0                21808
# 1422  balanced_paired  lev_dada2-c       lsr1        2.0                21808
# 1423  balanced_paired  lev_dada2-c       lsr1        3.0                21808
# 1424  balanced_paired  lev_dada2-c       lsr1        4.0                21808
# 1425  balanced_paired  lev_dada2-c       lsr1        5.0                21808
# 1426  balanced_paired  lev_dada2-c       lsr1        6.0                21808
# 1427  balanced_paired  lev_dada2-c       lsr1        7.0                21808
# 1428  balanced_paired  lev_dada2-c       lsr1        8.0                21808
# 1429  balanced_paired  lev_dada2-c       lsr1        9.0                21808
# 1421  balanced_paired  lev_dada2-c       lsr1       10.0                21808
# 1430  balanced_paired  lev_dada2-c       lsr2        1.0                21808
# 1432  balanced_paired  lev_dada2-c       lsr2        2.0                21808
# 1433  balanced_paired  lev_dada2-c       lsr2        3.0                21808
# 1434  balanced_paired  lev_dada2-c       lsr2        4.0                21808
# 1435  balanced_paired  lev_dada2-c       lsr2        5.0                21808
# 1436  balanced_paired  lev_dada2-c       lsr2        6.0                21808
# 1437  balanced_paired  lev_dada2-c       lsr2        7.0                21808
# 1438  balanced_paired  lev_dada2-c       lsr2        8.0                21808
# 1439  balanced_paired  lev_dada2-c       lsr2        9.0                21808
# 1431  balanced_paired  lev_dada2-c       lsr2       10.0                21808
# 1440  balanced_paired  lev_dada2-c       lsr3        1.0                21808
# 1442  balanced_paired  lev_dada2-c       lsr3        2.0                21808
# 1443  balanced_paired  lev_dada2-c       lsr3        3.0                21808
# 1444  balanced_paired  lev_dada2-c       lsr3        4.0                21808
# 1445  balanced_paired  lev_dada2-c       lsr3        5.0                21808
# 1446  balanced_paired  lev_dada2-c       lsr3        6.0                21808
# 1447  balanced_paired  lev_dada2-c       lsr3        7.0                21808
# 1448  balanced_paired  lev_dada2-c       lsr3        8.0                21808
# 1449  balanced_paired  lev_dada2-c       lsr3        9.0                21808
# 1441  balanced_paired  lev_dada2-c       lsr3       10.0                21808
# 1450  balanced_paired  lev_dada2-c       lsr4        1.0                21808
# 1452  balanced_paired  lev_dada2-c       lsr4        2.0                21808
# 1453  balanced_paired  lev_dada2-c       lsr4        3.0                21808
# 1454  balanced_paired  lev_dada2-c       lsr4        4.0                21808
# 1455  balanced_paired  lev_dada2-c       lsr4        5.0                21808
# 1456  balanced_paired  lev_dada2-c       lsr4        6.0                21808
# 1457  balanced_paired  lev_dada2-c       lsr4        7.0                21808
# 1458  balanced_paired  lev_dada2-c       lsr4        8.0                21808
# 1459  balanced_paired  lev_dada2-c       lsr4        9.0                21808
# 1451  balanced_paired  lev_dada2-c       lsr4       10.0                21808
# 1460  balanced_paired  lev_dada2-c        lss        1.0                21808
# 1462  balanced_paired  lev_dada2-c        lss        2.0                21808
# 1463  balanced_paired  lev_dada2-c        lss        3.0                21808
# 1464  balanced_paired  lev_dada2-c        lss        4.0                21808
# 1465  balanced_paired  lev_dada2-c        lss        5.0                21808
# 1466  balanced_paired  lev_dada2-c        lss        6.0                21808
# 1467  balanced_paired  lev_dada2-c        lss        7.0                21808
# 1468  balanced_paired  lev_dada2-c        lss        8.0                21808
# 1469  balanced_paired  lev_dada2-c        lss        9.0                21808
# 1461  balanced_paired  lev_dada2-c        lss       10.0                21808
# 1350  balanced_paired  lev_dada2-c         nf        1.0                21808
# 1352  balanced_paired  lev_dada2-c         nf        2.0                21808
# 1353  balanced_paired  lev_dada2-c         nf        3.0                21808
# 1354  balanced_paired  lev_dada2-c         nf        4.0                21808
# 1355  balanced_paired  lev_dada2-c         nf        5.0                21808
# 1356  balanced_paired  lev_dada2-c         nf        6.0                21808
# 1357  balanced_paired  lev_dada2-c         nf        7.0                21808
# 1358  balanced_paired  lev_dada2-c         nf        8.0                21808
# 1359  balanced_paired  lev_dada2-c         nf        9.0                21808
# 1351  balanced_paired  lev_dada2-c         nf       10.0                21808
# 25    balanced_single           as         2f       20.0                33523
# 27    balanced_single           as         2f       40.0                33523
# 28    balanced_single           as         2f       60.0                33523
# 29    balanced_single           as         2f       80.0                33523
# 20    balanced_single           as         2f      100.0                33523
# 21    balanced_single           as         2f      120.0                33523
# 22    balanced_single           as         2f      140.0                33523
# 23    balanced_single           as         2f      160.0                33523
# 24    balanced_single           as         2f      180.0                33523
# 26    balanced_single           as         2f      200.0                33523
# 15    balanced_single           as         f1       20.0                33523
# 17    balanced_single           as         f1       40.0                33523
# 18    balanced_single           as         f1       60.0                33523
# 19    balanced_single           as         f1       80.0                33523
# 10    balanced_single           as         f1      100.0                33523
# 11    balanced_single           as         f1      120.0                33523
# 12    balanced_single           as         f1      140.0                33523
# 13    balanced_single           as         f1      160.0                33523
# 14    balanced_single           as         f1      180.0                33523
# 16    balanced_single           as         f1      200.0                33523
# 35    balanced_single           as       lsa1       20.0                33523
# 37    balanced_single           as       lsa1       40.0                33523
# 38    balanced_single           as       lsa1       60.0                33523
# 39    balanced_single           as       lsa1       80.0                33523
# 30    balanced_single           as       lsa1      100.0                33523
# 31    balanced_single           as       lsa1      120.0                33523
# 32    balanced_single           as       lsa1      140.0                33523
# 33    balanced_single           as       lsa1      160.0                33523
# 34    balanced_single           as       lsa1      180.0                33523
# 36    balanced_single           as       lsa1      200.0                33523
# 45    balanced_single           as       lsa2       20.0                33523
# 47    balanced_single           as       lsa2       40.0                33523
# 48    balanced_single           as       lsa2       60.0                33523
# 49    balanced_single           as       lsa2       80.0                33523
# 40    balanced_single           as       lsa2      100.0                33523
# 41    balanced_single           as       lsa2      120.0                33523
# 42    balanced_single           as       lsa2      140.0                33523
# 43    balanced_single           as       lsa2      160.0                33523
# 44    balanced_single           as       lsa2      180.0                33523
# 46    balanced_single           as       lsa2      200.0                33523
# 55    balanced_single           as       lsa3       20.0                33523
# 57    balanced_single           as       lsa3       40.0                33523
# 58    balanced_single           as       lsa3       60.0                33523
# 59    balanced_single           as       lsa3       80.0                33523
# 50    balanced_single           as       lsa3      100.0                33523
# 51    balanced_single           as       lsa3      120.0                33523
# 52    balanced_single           as       lsa3      140.0                33523
# 53    balanced_single           as       lsa3      160.0                33523
# 54    balanced_single           as       lsa3      180.0                33523
# 56    balanced_single           as       lsa3      200.0                33523
# 65    balanced_single           as       lsa4       20.0                33523
# 67    balanced_single           as       lsa4       40.0                33523
# 68    balanced_single           as       lsa4       60.0                33523
# 69    balanced_single           as       lsa4       80.0                33523
# 60    balanced_single           as       lsa4      100.0                33523
# 61    balanced_single           as       lsa4      120.0                33523
# 62    balanced_single           as       lsa4      140.0                33523
# 63    balanced_single           as       lsa4      160.0                33523
# 64    balanced_single           as       lsa4      180.0                33523
# 66    balanced_single           as       lsa4      200.0                33523
# 75    balanced_single           as       lsr1       20.0                33523
# 77    balanced_single           as       lsr1       40.0                33523
# 78    balanced_single           as       lsr1       60.0                33523
# 79    balanced_single           as       lsr1       80.0                33523
# 70    balanced_single           as       lsr1      100.0                33523
# 71    balanced_single           as       lsr1      120.0                33523
# 72    balanced_single           as       lsr1      140.0                33523
# 73    balanced_single           as       lsr1      160.0                33523
# 74    balanced_single           as       lsr1      180.0                33523
# 76    balanced_single           as       lsr1      200.0                33523
# 85    balanced_single           as       lsr2       20.0                33523
# 87    balanced_single           as       lsr2       40.0                33523
# 88    balanced_single           as       lsr2       60.0                33523
# 89    balanced_single           as       lsr2       80.0                33523
# 80    balanced_single           as       lsr2      100.0                33523
# 81    balanced_single           as       lsr2      120.0                33523
# 82    balanced_single           as       lsr2      140.0                33523
# 83    balanced_single           as       lsr2      160.0                33523
# 84    balanced_single           as       lsr2      180.0                33523
# 86    balanced_single           as       lsr2      200.0                33523
# 95    balanced_single           as       lsr3       20.0                33523
# 97    balanced_single           as       lsr3       40.0                33523
# 98    balanced_single           as       lsr3       60.0                33523
# 99    balanced_single           as       lsr3       80.0                33523
# 90    balanced_single           as       lsr3      100.0                33523
# 91    balanced_single           as       lsr3      120.0                33523
# 92    balanced_single           as       lsr3      140.0                33523
# 93    balanced_single           as       lsr3      160.0                33523
# 94    balanced_single           as       lsr3      180.0                33523
# 924       449409          2514                 73071       449409
# 925       449409          2522                 73071       449409
# 926       449409          2524                 73071       449409
# 927       449409          2520                 73071       449409
# 928       449409          2514                 73071       449409
# 929       449409          2510                 73071       449409
# 921       449409          2502                 73071       449409
# 930       449409          3051                 73071       449409
# 932       449409          2865                 73071       449409
# 933       449409          2810                 73071       449409
# 934       449409          2874                 73071       449409
# 935       449409          2867                 73071       449409
# 936       449409          2820                 73071       449409
# 937       449409          2788                 73071       449409
# 938       449409          2780                 73071       449409
# 939       449409          2779                 73071       449409
# 931       449409          2730                 73071       449409
# 940       449409          2385                 72405       448558
# 942       449409          2353                 72559       448726
# 943       449409          2339                 72600       448766
# 944       449409          2315                 72512       448651
# 945       449409          2318                 72522       448656
# 946       449409          2313                 72564       448691
# 947       449409          2300                 72583       448701
# 948       449409          2284                 72575       448683
# 949       449409          2277                 72569       448674
# 941       449409          2266                 72607       448708
# 950       449409          2386                 73071       449409
# 952       449409          2354                 73071       449409
# 953       449409          2340                 73071       449409
# 954       449409          2316                 73071       449409
# 955       449409          2319                 73071       449409
# 956       449409          2314                 73071       449409
# 957       449409          2301                 73071       449409
# 958       449409          2285                 73071       449409
# 959       449409          2278                 73071       449409
# 951       449409          2267                 73071       449409
# 960       449409          2570                 73071       449409
# 962       449409          2524                 73071       449409
# 963       449409          2511                 73071       449409
# 964       449409          2514                 73071       449409
# 965       449409          2522                 73071       449409
# 966       449409          2524                 73071       449409
# 967       449409          2519                 73071       449409
# 968       449409          2514                 73071       449409
# 969       449409          2509                 73071       449409
# 961       449409          2503                 73071       449409
# 970       449409          3032                 73071       449409
# 972       449409          2839                 73071       449409
# 973       449409          2779                 73071       449409
# 974       449409          2846                 73071       449409
# 975       449409          2833                 73071       449409
# 976       449409          2793                 73071       449409
# 977       449409          2760                 73071       449409
# 978       449409          2752                 73071       449409
# 979       449409          2747                 73071       449409
# 971       449409          2706                 73071       449409
# 860       449409         27868                 73071       449409
# 862       449409         15076                 73071       449409
# 863       449409          9734                 73071       449409
# 864       449409          7280                 73071       449409
# 865       449409          5856                 73071       449409
# 866       449409          5024                 73071       449409
# 867       449409          4472                 73071       449409
# 868       449409          4116                 73071       449409
# 869       449409          3805                 73071       449409
# 861       449409          3524                 73071       449409

# %%
df_counts.to_csv('%s/df_counts.csv' % eval_dir, sep = ';', index = False)
#df_counts = pd.read_csv('%s/df_counts.csv' % eval_dir, sep = ';')

# %% [markdown]
# ### Clustering quality

# %%
# Requires the metrics files. Alternatively, the evaluation can use the stored information (see below).
dfs = []
for ds in data_sets:
    for rt in read_types:
        run_name = '%s_%s' % (ds, rt)

        for opt in opts:
            for gt in ground_truths:
                df = pd.read_csv('%s/%s/%s/%s_%s_%s__metrics.csv' % (results_dir, run_name, opt, opt, ds[0] + rt[0], gt), sep = ';')

                df['reads'] = '%s_%s' % (ds, rt)
                df['gt'] = gt
                df['mode'] = ['_'.join(m.split('__')[0].split('_')[1:]) for m in df['task']]
                df['refinement'] = [m.split('__')[1] for m in df['task']]
                df['ds'] = ds
                df['rt'] = rt

                dfs.append(df)
                    
df_quality = pd.concat(dfs, ignore_index = True)
df_quality.rename(columns = {'task': 'run', 'reads': 'data_set'}, inplace = True)
df_quality.sort_values(by = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'threshold'], inplace = True)

# %% [markdown]
# *Column descriptions:*
# `precision`: Quantifies the extent to which amplicons in a cluster are also from the same species.
# `recall`: Measures the proportion of amplicons from the same species that are grouped in the same cluster.
# `adjrandindex`: Measures the agreement between the clusters and the taxonomic assignment and corrects for chance.

# %%
df_quality[['data_set', 'gt', 'mode', 'refinement', 'threshold', 'precision', 'recall', 'adjrandindex']]
# Out:
#              data_set        gt         mode refinement  threshold  precision  \
# 510   balanced_paired  callahan           as         2f       20.0   0.996647
# 511   balanced_paired  callahan           as         2f       40.0   0.975262
# 512   balanced_paired  callahan           as         2f       60.0   0.972507
# 513   balanced_paired  callahan           as         2f       80.0   0.958458
# 514   balanced_paired  callahan           as         2f      100.0   0.956968
# 515   balanced_paired  callahan           as         2f      120.0   0.953080
# 516   balanced_paired  callahan           as         2f      140.0   0.934381
# 517   balanced_paired  callahan           as         2f      160.0   0.931156
# 518   balanced_paired  callahan           as         2f      180.0   0.901399
# 519   balanced_paired  callahan           as         2f      200.0   0.897903
# 500   balanced_paired  callahan           as         f1       20.0   0.996647
# 501   balanced_paired  callahan           as         f1       40.0   0.975379
# 502   balanced_paired  callahan           as         f1       60.0   0.972676
# 503   balanced_paired  callahan           as         f1       80.0   0.958777
# 504   balanced_paired  callahan           as         f1      100.0   0.957479
# 505   balanced_paired  callahan           as         f1      120.0   0.953609
# 506   balanced_paired  callahan           as         f1      140.0   0.935046
# 507   balanced_paired  callahan           as         f1      160.0   0.931684
# 508   balanced_paired  callahan           as         f1      180.0   0.901874
# 509   balanced_paired  callahan           as         f1      200.0   0.898292
# 520   balanced_paired  callahan           as       lsa1       20.0   0.995482
# 521   balanced_paired  callahan           as       lsa1       40.0   0.974629
# 522   balanced_paired  callahan           as       lsa1       60.0   0.972152
# 523   balanced_paired  callahan           as       lsa1       80.0   0.958349
# 524   balanced_paired  callahan           as       lsa1      100.0   0.957212
# 525   balanced_paired  callahan           as       lsa1      120.0   0.953386
# 526   balanced_paired  callahan           as       lsa1      140.0   0.934851
# 527   balanced_paired  callahan           as       lsa1      160.0   0.931659
# 528   balanced_paired  callahan           as       lsa1      180.0   0.901835
# 529   balanced_paired  callahan           as       lsa1      200.0   0.898253
# 530   balanced_paired  callahan           as       lsa2       20.0   0.995496
# 531   balanced_paired  callahan           as       lsa2       40.0   0.974612
# 532   balanced_paired  callahan           as       lsa2       60.0   0.972130
# 533   balanced_paired  callahan           as       lsa2       80.0   0.958306
# 534   balanced_paired  callahan           as       lsa2      100.0   0.957168
# 535   balanced_paired  callahan           as       lsa2      120.0   0.953346
# 536   balanced_paired  callahan           as       lsa2      140.0   0.934802
# 537   balanced_paired  callahan           as       lsa2      160.0   0.931615
# 538   balanced_paired  callahan           as       lsa2      180.0   0.901787
# 539   balanced_paired  callahan           as       lsa2      200.0   0.898216
# 540   balanced_paired  callahan           as       lsa3       20.0   0.994757
# 541   balanced_paired  callahan           as       lsa3       40.0   0.974212
# 542   balanced_paired  callahan           as       lsa3       60.0   0.972005
# 543   balanced_paired  callahan           as       lsa3       80.0   0.958277
# 544   balanced_paired  callahan           as       lsa3      100.0   0.957165
# 545   balanced_paired  callahan           as       lsa3      120.0   0.953382
# 546   balanced_paired  callahan           as       lsa3      140.0   0.934851
# 547   balanced_paired  callahan           as       lsa3      160.0   0.931659
# 548   balanced_paired  callahan           as       lsa3      180.0   0.901835
# 549   balanced_paired  callahan           as       lsa3      200.0   0.898253
# 550   balanced_paired  callahan           as       lsa4       20.0   0.995180
# 551   balanced_paired  callahan           as       lsa4       40.0   0.974428
# 552   balanced_paired  callahan           as       lsa4       60.0   0.972063
# 553   balanced_paired  callahan           as       lsa4       80.0   0.958307
# 554   balanced_paired  callahan           as       lsa4      100.0   0.957182
# 555   balanced_paired  callahan           as       lsa4      120.0   0.953382
# 556   balanced_paired  callahan           as       lsa4      140.0   0.934851
# 557   balanced_paired  callahan           as       lsa4      160.0   0.931659
# 558   balanced_paired  callahan           as       lsa4      180.0   0.901835
# 559   balanced_paired  callahan           as       lsa4      200.0   0.898253
# 560   balanced_paired  callahan           as       lsr1       20.0   0.995334
# 561   balanced_paired  callahan           as       lsr1       40.0   0.974464
# 562   balanced_paired  callahan           as       lsr1       60.0   0.972011
# 563   balanced_paired  callahan           as       lsr1       80.0   0.958213
# 564   balanced_paired  callahan           as       lsr1      100.0   0.957071
# 565   balanced_paired  callahan           as       lsr1      120.0   0.953281
# 566   balanced_paired  callahan           as       lsr1      140.0   0.934768
# 567   balanced_paired  callahan           as       lsr1      160.0   0.931560
# 568   balanced_paired  callahan           as       lsr1      180.0   0.901737
# 569   balanced_paired  callahan           as       lsr1      200.0   0.898174
# 570   balanced_paired  callahan           as       lsr2       20.0   0.995324
# 571   balanced_paired  callahan           as       lsr2       40.0   0.974427
# 572   balanced_paired  callahan           as       lsr2       60.0   0.971982
# 573   balanced_paired  callahan           as       lsr2       80.0   0.958180
# 574   balanced_paired  callahan           as       lsr2      100.0   0.957041
# 575   balanced_paired  callahan           as       lsr2      120.0   0.953256
# 576   balanced_paired  callahan           as       lsr2      140.0   0.934734
# 577   balanced_paired  callahan           as       lsr2      160.0   0.931531
# 578   balanced_paired  callahan           as       lsr2      180.0   0.901706
# 579   balanced_paired  callahan           as       lsr2      200.0   0.898149
# 580   balanced_paired  callahan           as       lsr3       20.0   0.994755
# 581   balanced_paired  callahan           as       lsr3       40.0   0.974158
# 582   balanced_paired  callahan           as       lsr3       60.0   0.971894
# 583   balanced_paired  callahan           as       lsr3       80.0   0.958144
# 584   balanced_paired  callahan           as       lsr3      100.0   0.957028
# 585   balanced_paired  callahan           as       lsr3      120.0   0.953277
# 586   balanced_paired  callahan           as       lsr3      140.0   0.934768
# 587   balanced_paired  callahan           as       lsr3      160.0   0.931560
# 588   balanced_paired  callahan           as       lsr3      180.0   0.901737
# 589   balanced_paired  callahan           as       lsr3      200.0   0.898174
# 590   balanced_paired  callahan           as       lsr4       20.0   0.995131
# 591   balanced_paired  callahan           as       lsr4       40.0   0.974361
# 592   balanced_paired  callahan           as       lsr4       60.0   0.971971
# 593   balanced_paired  callahan           as       lsr4       80.0   0.958189
# 594   balanced_paired  callahan           as       lsr4      100.0   0.957062
# 595   balanced_paired  callahan           as       lsr4      120.0   0.953279
# 596   balanced_paired  callahan           as       lsr4      140.0   0.934768
# 597   balanced_paired  callahan           as       lsr4      160.0   0.931560
# 598   balanced_paired  callahan           as       lsr4      180.0   0.901737
# 599   balanced_paired  callahan           as       lsr4      200.0   0.898174
# 600   balanced_paired  callahan           as        lss       20.0   0.995328
# 601   balanced_paired  callahan           as        lss       40.0   0.974460
# 602   balanced_paired  callahan           as        lss       60.0   0.972011
# 603   balanced_paired  callahan           as        lss       80.0   0.958217
# 604   balanced_paired  callahan           as        lss      100.0   0.957073
# 605   balanced_paired  callahan           as        lss      120.0   0.953284
# 606   balanced_paired  callahan           as        lss      140.0   0.934770
# 607   balanced_paired  callahan           as        lss      160.0   0.931564
# 608   balanced_paired  callahan           as        lss      180.0   0.901737
# 609   balanced_paired  callahan           as        lss      200.0   0.898174
# 490   balanced_paired  callahan           as         nf       20.0   0.996773
# 491   balanced_paired  callahan           as         nf       40.0   0.975503
# 492   balanced_paired  callahan           as         nf       60.0   0.972856
# 493   balanced_paired  callahan           as         nf       80.0   0.958944
# 494   balanced_paired  callahan           as         nf      100.0   0.957706
# 495   balanced_paired  callahan           as         nf      120.0   0.953825
# 496   balanced_paired  callahan           as         nf      140.0   0.935251
# 497   balanced_paired  callahan           as         nf      160.0   0.932009
# 498   balanced_paired  callahan           as         nf      180.0   0.902124
# 499   balanced_paired  callahan           as         nf      200.0   0.898529
# 630   balanced_paired  callahan   as_dada2-c         2f       20.0   0.999395
# 631   balanced_paired  callahan   as_dada2-c         2f       40.0   0.998095
# 632   balanced_paired  callahan   as_dada2-c         2f       60.0   0.996737
# 633   balanced_paired  callahan   as_dada2-c         2f       80.0   0.995522
# 634   balanced_paired  callahan   as_dada2-c         2f      100.0   0.994750
# 635   balanced_paired  callahan   as_dada2-c         2f      120.0   0.993360
# 636   balanced_paired  callahan   as_dada2-c         2f      140.0   0.991545
# 637   balanced_paired  callahan   as_dada2-c         2f      160.0   0.989593
# 638   balanced_paired  callahan   as_dada2-c         2f      180.0   0.987104
# 639   balanced_paired  callahan   as_dada2-c         2f      200.0   0.985739
# 620   balanced_paired  callahan   as_dada2-c         f1       20.0   0.999395
# 621   balanced_paired  callahan   as_dada2-c         f1       40.0   0.998214
# 622   balanced_paired  callahan   as_dada2-c         f1       60.0   0.996889
# 623   balanced_paired  callahan   as_dada2-c         f1       80.0   0.995899
# 624   balanced_paired  callahan   as_dada2-c         f1      100.0   0.995356
# 625   balanced_paired  callahan   as_dada2-c         f1      120.0   0.994045
# 626   balanced_paired  callahan   as_dada2-c         f1      140.0   0.992402
# 627   balanced_paired  callahan   as_dada2-c         f1      160.0   0.990386
# 628   balanced_paired  callahan   as_dada2-c         f1      180.0   0.987863
# 629   balanced_paired  callahan   as_dada2-c         f1      200.0   0.986417
# 640   balanced_paired  callahan   as_dada2-c       lsa1       20.0   0.998174
# 641   balanced_paired  callahan   as_dada2-c       lsa1       40.0   0.997378
# 642   balanced_paired  callahan   as_dada2-c       lsa1       60.0   0.996260
# 643   balanced_paired  callahan   as_dada2-c       lsa1       80.0   0.995405
# 644   balanced_paired  callahan   as_dada2-c       lsa1      100.0   0.995033
# 645   balanced_paired  callahan   as_dada2-c       lsa1      120.0   0.993901
# 646   balanced_paired  callahan   as_dada2-c       lsa1      140.0   0.992400
# 647   balanced_paired  callahan   as_dada2-c       lsa1      160.0   0.990606
# 648   balanced_paired  callahan   as_dada2-c       lsa1      180.0   0.988239
# 649   balanced_paired  callahan   as_dada2-c       lsa1      200.0   0.986909
# 650   balanced_paired  callahan   as_dada2-c       lsa2       20.0   0.998195
# 651   balanced_paired  callahan   as_dada2-c       lsa2       40.0   0.997407
# 652   balanced_paired  callahan   as_dada2-c       lsa2       60.0   0.996271
# 653   balanced_paired  callahan   as_dada2-c       lsa2       80.0   0.995402
# 654   balanced_paired  callahan   as_dada2-c       lsa2      100.0   0.995025
# 655   balanced_paired  callahan   as_dada2-c       lsa2      120.0   0.993890
# 656   balanced_paired  callahan   as_dada2-c       lsa2      140.0   0.992386
# 657   balanced_paired  callahan   as_dada2-c       lsa2      160.0   0.990589
# 658   balanced_paired  callahan   as_dada2-c       lsa2      180.0   0.988219
# 659   balanced_paired  callahan   as_dada2-c       lsa2      200.0   0.986886
# 660   balanced_paired  callahan   as_dada2-c       lsa3       20.0   0.997438
# 661   balanced_paired  callahan   as_dada2-c       lsa3       40.0   0.996812
# 662   balanced_paired  callahan   as_dada2-c       lsa3       60.0   0.995783
# 663   balanced_paired  callahan   as_dada2-c       lsa3       80.0   0.994943
# 664   balanced_paired  callahan   as_dada2-c       lsa3      100.0   0.994537
# 665   balanced_paired  callahan   as_dada2-c       lsa3      120.0   0.993405
# 666   balanced_paired  callahan   as_dada2-c       lsa3      140.0   0.991874
# 667   balanced_paired  callahan   as_dada2-c       lsa3      160.0   0.990080
# 668   balanced_paired  callahan   as_dada2-c       lsa3      180.0   0.987709
# 669   balanced_paired  callahan   as_dada2-c       lsa3      200.0   0.986374
# 670   balanced_paired  callahan   as_dada2-c       lsa4       20.0   0.997883
# 671   balanced_paired  callahan   as_dada2-c       lsa4       40.0   0.997124
# 672   balanced_paired  callahan   as_dada2-c       lsa4       60.0   0.996078
# 673   balanced_paired  callahan   as_dada2-c       lsa4       80.0   0.995236
# 674   balanced_paired  callahan   as_dada2-c       lsa4      100.0   0.994862
# 675   balanced_paired  callahan   as_dada2-c       lsa4      120.0   0.993758
# 676   balanced_paired  callahan   as_dada2-c       lsa4      140.0   0.992283
# 677   balanced_paired  callahan   as_dada2-c       lsa4      160.0   0.990519
# 678   balanced_paired  callahan   as_dada2-c       lsa4      180.0   0.988171
# 679   balanced_paired  callahan   as_dada2-c       lsa4      200.0   0.986858
# 680   balanced_paired  callahan   as_dada2-c       lsr1       20.0   0.998024
# 681   balanced_paired  callahan   as_dada2-c       lsr1       40.0   0.997231
# 682   balanced_paired  callahan   as_dada2-c       lsr1       60.0   0.996098
# 683   balanced_paired  callahan   as_dada2-c       lsr1       80.0   0.995261
# 684   balanced_paired  callahan   as_dada2-c       lsr1      100.0   0.994883
# 685   balanced_paired  callahan   as_dada2-c       lsr1      120.0   0.993767
# 686   balanced_paired  callahan   as_dada2-c       lsr1      140.0   0.992293
# 687   balanced_paired  callahan   as_dada2-c       lsr1      160.0   0.990514
# 688   balanced_paired  callahan   as_dada2-c       lsr1      180.0   0.988164
# 689   balanced_paired  callahan   as_dada2-c       lsr1      200.0   0.986849
# 690   balanced_paired  callahan   as_dada2-c       lsr2       20.0   0.998020
# 691   balanced_paired  callahan   as_dada2-c       lsr2       40.0   0.997226
# 692   balanced_paired  callahan   as_dada2-c       lsr2       60.0   0.996091
# 693   balanced_paired  callahan   as_dada2-c       lsr2       80.0   0.995254
# 694   balanced_paired  callahan   as_dada2-c       lsr2      100.0   0.994875
# 695   balanced_paired  callahan   as_dada2-c       lsr2      120.0   0.993757
# 696   balanced_paired  callahan   as_dada2-c       lsr2      140.0   0.992281
# 697   balanced_paired  callahan   as_dada2-c       lsr2      160.0   0.990499
# 698   balanced_paired  callahan   as_dada2-c       lsr2      180.0   0.988145
# 699   balanced_paired  callahan   as_dada2-c       lsr2      200.0   0.986828
# 700   balanced_paired  callahan   as_dada2-c       lsr3       20.0   0.997432
# 701   balanced_paired  callahan   as_dada2-c       lsr3       40.0   0.996765
# 702   balanced_paired  callahan   as_dada2-c       lsr3       60.0   0.995644
# 703   balanced_paired  callahan   as_dada2-c       lsr3       80.0   0.994804
# 704   balanced_paired  callahan   as_dada2-c       lsr3      100.0   0.994391
# 705   balanced_paired  callahan   as_dada2-c       lsr3      120.0   0.993271
# 706   balanced_paired  callahan   as_dada2-c       lsr3      140.0   0.991767
# 707   balanced_paired  callahan   as_dada2-c       lsr3      160.0   0.989988
# 708   balanced_paired  callahan   as_dada2-c       lsr3      180.0   0.987634
# 709   balanced_paired  callahan   as_dada2-c       lsr3      200.0   0.986315
# 710   balanced_paired  callahan   as_dada2-c       lsr4       20.0   0.997836
# 711   balanced_paired  callahan   as_dada2-c       lsr4       40.0   0.997066
# 712   balanced_paired  callahan   as_dada2-c       lsr4       60.0   0.995980
# 713   balanced_paired  callahan   as_dada2-c       lsr4       80.0   0.995163
# 714   balanced_paired  callahan   as_dada2-c       lsr4      100.0   0.994789
# 715   balanced_paired  callahan   as_dada2-c       lsr4      120.0   0.993698
# 716   balanced_paired  callahan   as_dada2-c       lsr4      140.0   0.992229
# 717   balanced_paired  callahan   as_dada2-c       lsr4      160.0   0.990476
# 718   balanced_paired  callahan   as_dada2-c       lsr4      180.0   0.988149
# 719   balanced_paired  callahan   as_dada2-c       lsr4      200.0   0.986834
# 720   balanced_paired  callahan   as_dada2-c        lss       20.0   0.998018
# 721   balanced_paired  callahan   as_dada2-c        lss       40.0   0.997229
# 722   balanced_paired  callahan   as_dada2-c        lss       60.0   0.996100
# 723   balanced_paired  callahan   as_dada2-c        lss       80.0   0.995268
# 724   balanced_paired  callahan   as_dada2-c        lss      100.0   0.994887
# 725   balanced_paired  callahan   as_dada2-c        lss      120.0   0.993773
# 726   balanced_paired  callahan   as_dada2-c        lss      140.0   0.992296
# 727   balanced_paired  callahan   as_dada2-c        lss      160.0   0.990516
# 728   balanced_paired  callahan   as_dada2-c        lss      180.0   0.988164
# 729   balanced_paired  callahan   as_dada2-c        lss      200.0   0.986849
# 610   balanced_paired  callahan   as_dada2-c         nf       20.0   0.999510
# 611   balanced_paired  callahan   as_dada2-c         nf       40.0   0.998356
# 612   balanced_paired  callahan   as_dada2-c         nf       60.0   0.997081
# 613   balanced_paired  callahan   as_dada2-c         nf       80.0   0.996119
# 614   balanced_paired  callahan   as_dada2-c         nf      100.0   0.995636
# 615   balanced_paired  callahan   as_dada2-c         nf      120.0   0.994402
# 616   balanced_paired  callahan   as_dada2-c         nf      140.0   0.992839
# 617   balanced_paired  callahan   as_dada2-c         nf      160.0   0.991019
# 618   balanced_paired  callahan   as_dada2-c         nf      180.0   0.988538
# 619   balanced_paired  callahan   as_dada2-c         nf      200.0   0.987164
# 731   balanced_paired  callahan      dada2-s       lsa1       20.0   0.997002
# 732   balanced_paired  callahan      dada2-s       lsa2       20.0   0.996997
# 733   balanced_paired  callahan      dada2-s       lsa3       20.0   0.996440
# 734   balanced_paired  callahan      dada2-s       lsa4       20.0   0.996968
# 735   balanced_paired  callahan      dada2-s       lsr1       20.0   0.997002
# 736   balanced_paired  callahan      dada2-s       lsr2       20.0   0.996997
# 737   balanced_paired  callahan      dada2-s       lsr3       20.0   0.996440
# 738   balanced_paired  callahan      dada2-s       lsr4       20.0   0.996968
# 739   balanced_paired  callahan      dada2-s        lss       20.0   0.997002
# 730   balanced_paired  callahan      dada2-s         nf       20.0   0.999243
# 760   balanced_paired  callahan          lev         2f        1.0   0.996641
# 761   balanced_paired  callahan          lev         2f        2.0   0.975155
# 762   balanced_paired  callahan          lev         2f        3.0   0.972405
# 763   balanced_paired  callahan          lev         2f        4.0   0.957682
# 764   balanced_paired  callahan          lev         2f        5.0   0.956309
# 765   balanced_paired  callahan          lev         2f        6.0   0.952841
# 766   balanced_paired  callahan          lev         2f        7.0   0.933970
# 767   balanced_paired  callahan          lev         2f        8.0   0.918878
# 768   balanced_paired  callahan          lev         2f        9.0   0.902355
# 769   balanced_paired  callahan          lev         2f       10.0   0.899470
# 750   balanced_paired  callahan          lev         f1        1.0   0.996641
# 751   balanced_paired  callahan          lev         f1        2.0   0.975268
# 752   balanced_paired  callahan          lev         f1        3.0   0.972586
# 753   balanced_paired  callahan          lev         f1        4.0   0.958052
# 754   balanced_paired  callahan          lev         f1        5.0   0.956722
# 755   balanced_paired  callahan          lev         f1        6.0   0.953320
# 756   balanced_paired  callahan          lev         f1        7.0   0.934528
# 757   balanced_paired  callahan          lev         f1        8.0   0.919434
# 758   balanced_paired  callahan          lev         f1        9.0   0.902911
# 759   balanced_paired  callahan          lev         f1       10.0   0.899934
# 770   balanced_paired  callahan          lev       lsa1        1.0   0.995557
# 771   balanced_paired  callahan          lev       lsa1        2.0   0.974528
# 772   balanced_paired  callahan          lev       lsa1        3.0   0.972067
# 773   balanced_paired  callahan          lev       lsa1        4.0   0.957665
# 774   balanced_paired  callahan          lev       lsa1        5.0   0.956465
# 775   balanced_paired  callahan          lev       lsa1        6.0   0.953117
# 776   balanced_paired  callahan          lev       lsa1        7.0   0.934374
# 777   balanced_paired  callahan          lev       lsa1        8.0   0.919337
# 778   balanced_paired  callahan          lev       lsa1        9.0   0.902840
# 779   balanced_paired  callahan          lev       lsa1       10.0   0.899898
# 780   balanced_paired  callahan          lev       lsa2        1.0   0.995570
# 781   balanced_paired  callahan          lev       lsa2        2.0   0.974513
# 782   balanced_paired  callahan          lev       lsa2        3.0   0.972045
# 783   balanced_paired  callahan          lev       lsa2        4.0   0.957622
# 784   balanced_paired  callahan          lev       lsa2        5.0   0.956423
# 785   balanced_paired  callahan          lev       lsa2        6.0   0.953077
# 786   balanced_paired  callahan          lev       lsa2        7.0   0.934327
# 787   balanced_paired  callahan          lev       lsa2        8.0   0.919289
# 788   balanced_paired  callahan          lev       lsa2        9.0   0.902788
# 789   balanced_paired  callahan          lev       lsa2       10.0   0.899852
# 790   balanced_paired  callahan          lev       lsa3        1.0   0.994806
# 791   balanced_paired  callahan          lev       lsa3        2.0   0.974130
# 792   balanced_paired  callahan          lev       lsa3        3.0   0.971936
# 793   balanced_paired  callahan          lev       lsa3        4.0   0.957597
# 794   balanced_paired  callahan          lev       lsa3        5.0   0.956427
# 795   balanced_paired  callahan          lev       lsa3        6.0   0.953113
# 796   balanced_paired  callahan          lev       lsa3        7.0   0.934374
# 797   balanced_paired  callahan          lev       lsa3        8.0   0.919337
# 798   balanced_paired  callahan          lev       lsa3        9.0   0.902840
# 799   balanced_paired  callahan          lev       lsa3       10.0   0.899898
# 800   balanced_paired  callahan          lev       lsa4        1.0   0.995240
# 801   balanced_paired  callahan          lev       lsa4        2.0   0.974338
# 802   balanced_paired  callahan          lev       lsa4        3.0   0.971992
# 803   balanced_paired  callahan          lev       lsa4        4.0   0.957616
# 804   balanced_paired  callahan          lev       lsa4        5.0   0.956440
# 805   balanced_paired  callahan          lev       lsa4        6.0   0.953113
# 806   balanced_paired  callahan          lev       lsa4        7.0   0.934374
# 807   balanced_paired  callahan          lev       lsa4        8.0   0.919337
# 808   balanced_paired  callahan          lev       lsa4        9.0   0.902840
# 809   balanced_paired  callahan          lev       lsa4       10.0   0.899898
# 810   balanced_paired  callahan          lev       lsr1        1.0   0.995398
# 811   balanced_paired  callahan          lev       lsr1        2.0   0.974359
# 812   balanced_paired  callahan          lev       lsr1        3.0   0.971921
# 813   balanced_paired  callahan          lev       lsr1        4.0   0.957520
# 814   balanced_paired  callahan          lev       lsr1        5.0   0.956333
# 815   balanced_paired  callahan          lev       lsr1        6.0   0.953014
# 816   balanced_paired  callahan          lev       lsr1        7.0   0.934278
# 817   balanced_paired  callahan          lev       lsr1        8.0   0.919243
# 818   balanced_paired  callahan          lev       lsr1        9.0   0.902740
# 819   balanced_paired  callahan          lev       lsr1       10.0   0.899799
# 820   balanced_paired  callahan          lev       lsr2        1.0   0.995389
# 821   balanced_paired  callahan          lev       lsr2        2.0   0.974324
# 822   balanced_paired  callahan          lev       lsr2        3.0   0.971893
# 823   balanced_paired  callahan          lev       lsr2        4.0   0.957487
# 824   balanced_paired  callahan          lev       lsr2        5.0   0.956303
# 825   balanced_paired  callahan          lev       lsr2        6.0   0.952988
# 826   balanced_paired  callahan          lev       lsr2        7.0   0.934247
# 827   balanced_paired  callahan          lev       lsr2        8.0   0.919210
# 828   balanced_paired  callahan          lev       lsr2        9.0   0.902704
# 829   balanced_paired  callahan          lev       lsr2       10.0   0.899770
# 830   balanced_paired  callahan          lev       lsr3        1.0   0.994810
# 831   balanced_paired  callahan          lev       lsr3        2.0   0.974068
# 832   balanced_paired  callahan          lev       lsr3        3.0   0.971817
# 833   balanced_paired  callahan          lev       lsr3        4.0   0.957456
# 834   balanced_paired  callahan          lev       lsr3        5.0   0.956299
# 835   balanced_paired  callahan          lev       lsr3        6.0   0.953010
# 836   balanced_paired  callahan          lev       lsr3        7.0   0.934278
# 837   balanced_paired  callahan          lev       lsr3        8.0   0.919243
# 838   balanced_paired  callahan          lev       lsr3        9.0   0.902740
# 839   balanced_paired  callahan          lev       lsr3       10.0   0.899799
# 840   balanced_paired  callahan          lev       lsr4        1.0   0.995191
# 841   balanced_paired  callahan          lev       lsr4        2.0   0.974265
# 842   balanced_paired  callahan          lev       lsr4        3.0   0.971889
# 843   balanced_paired  callahan          lev       lsr4        4.0   0.957496
# 844   balanced_paired  callahan          lev       lsr4        5.0   0.956324
# 845   balanced_paired  callahan          lev       lsr4        6.0   0.953012
# 846   balanced_paired  callahan          lev       lsr4        7.0   0.934278
# 847   balanced_paired  callahan          lev       lsr4        8.0   0.919243
# 848   balanced_paired  callahan          lev       lsr4        9.0   0.902740
# 849   balanced_paired  callahan          lev       lsr4       10.0   0.899799
# 850   balanced_paired  callahan          lev        lss        1.0   0.995390
# 851   balanced_paired  callahan          lev        lss        2.0   0.974355
# 852   balanced_paired  callahan          lev        lss        3.0   0.971921
# 853   balanced_paired  callahan          lev        lss        4.0   0.957524
# 854   balanced_paired  callahan          lev        lss        5.0   0.956335
# 855   balanced_paired  callahan          lev        lss        6.0   0.953016
# 856   balanced_paired  callahan          lev        lss        7.0   0.934282
# 857   balanced_paired  callahan          lev        lss        8.0   0.919248
# 858   balanced_paired  callahan          lev        lss        9.0   0.902740
# 859   balanced_paired  callahan          lev        lss       10.0   0.899799
# 740   balanced_paired  callahan          lev         nf        1.0   0.996752
# 741   balanced_paired  callahan          lev         nf        2.0   0.975405
# 742   balanced_paired  callahan          lev         nf        3.0   0.972753
# 743   balanced_paired  callahan          lev         nf        4.0   0.958240
# 744   balanced_paired  callahan          lev         nf        5.0   0.956959
# 745   balanced_paired  callahan          lev         nf        6.0   0.953568
# 746   balanced_paired  callahan          lev         nf        7.0   0.934766
# 747   balanced_paired  callahan          lev         nf        8.0   0.919682
# 748   balanced_paired  callahan          lev         nf        9.0   0.903146
# 749   balanced_paired  callahan          lev         nf       10.0   0.900182
# 880   balanced_paired  callahan  lev_dada2-c         2f        1.0   0.999386
# 881   balanced_paired  callahan  lev_dada2-c         2f        2.0   0.997966
# 882   balanced_paired  callahan  lev_dada2-c         2f        3.0   0.996390
# 883   balanced_paired  callahan  lev_dada2-c         2f        4.0   0.995251
# 884   balanced_paired  callahan  lev_dada2-c         2f        5.0   0.994748
# 885   balanced_paired  callahan  lev_dada2-c         2f        6.0   0.993290
# 886   balanced_paired  callahan  lev_dada2-c         2f        7.0   0.990765
# 887   balanced_paired  callahan  lev_dada2-c         2f        8.0   0.988772
# 888   balanced_paired  callahan  lev_dada2-c         2f        9.0   0.987380
# 889   balanced_paired  callahan  lev_dada2-c         2f       10.0   0.986659
# 870   balanced_paired  callahan  lev_dada2-c         f1        1.0   0.999386
# 871   balanced_paired  callahan  lev_dada2-c         f1        2.0   0.998075
# 872   balanced_paired  callahan  lev_dada2-c         f1        3.0   0.996568
# 873   balanced_paired  callahan  lev_dada2-c         f1        4.0   0.995663
# 874   balanced_paired  callahan  lev_dada2-c         f1        5.0   0.995264
# 875   balanced_paired  callahan  lev_dada2-c         f1        6.0   0.993895
# 876   balanced_paired  callahan  lev_dada2-c         f1        7.0   0.991526
# 877   balanced_paired  callahan  lev_dada2-c         f1        8.0   0.989576
# 878   balanced_paired  callahan  lev_dada2-c         f1        9.0   0.988171
# 879   balanced_paired  callahan  lev_dada2-c         f1       10.0   0.987377
# 890   balanced_paired  callahan  lev_dada2-c       lsa1        1.0   0.998178
# 891   balanced_paired  callahan  lev_dada2-c       lsa1        2.0   0.997227
# 892   balanced_paired  callahan  lev_dada2-c       lsa1        3.0   0.995939
# 893   balanced_paired  callahan  lev_dada2-c       lsa1        4.0   0.995206
# 894   balanced_paired  callahan  lev_dada2-c       lsa1        5.0   0.994966
# 895   balanced_paired  callahan  lev_dada2-c       lsa1        6.0   0.993799
# 896   balanced_paired  callahan  lev_dada2-c       lsa1        7.0   0.991596
# 897   balanced_paired  callahan  lev_dada2-c       lsa1        8.0   0.989766
# 898   balanced_paired  callahan  lev_dada2-c       lsa1        9.0   0.988464
# 899   balanced_paired  callahan  lev_dada2-c       lsa1       10.0   0.987822
# 900   balanced_paired  callahan  lev_dada2-c       lsa2        1.0   0.998199
# 901   balanced_paired  callahan  lev_dada2-c       lsa2        2.0   0.997255
# 902   balanced_paired  callahan  lev_dada2-c       lsa2        3.0   0.995950
# 903   balanced_paired  callahan  lev_dada2-c       lsa2        4.0   0.995203
# 904   balanced_paired  callahan  lev_dada2-c       lsa2        5.0   0.994959
# 905   balanced_paired  callahan  lev_dada2-c       lsa2        6.0   0.993787
# 906   balanced_paired  callahan  lev_dada2-c       lsa2        7.0   0.991581
# 907   balanced_paired  callahan  lev_dada2-c       lsa2        8.0   0.989748
# 908   balanced_paired  callahan  lev_dada2-c       lsa2        9.0   0.988444
# 909   balanced_paired  callahan  lev_dada2-c       lsa2       10.0   0.987801
# 910   balanced_paired  callahan  lev_dada2-c       lsa3        1.0   0.997440
# 911   balanced_paired  callahan  lev_dada2-c       lsa3        2.0   0.996692
# 912   balanced_paired  callahan  lev_dada2-c       lsa3        3.0   0.995475
# 913   balanced_paired  callahan  lev_dada2-c       lsa3        4.0   0.994746
# 914   balanced_paired  callahan  lev_dada2-c       lsa3        5.0   0.994479
# 915   balanced_paired  callahan  lev_dada2-c       lsa3        6.0   0.993303
# 916   balanced_paired  callahan  lev_dada2-c       lsa3        7.0   0.991070
# 917   balanced_paired  callahan  lev_dada2-c       lsa3        8.0   0.989244
# 918   balanced_paired  callahan  lev_dada2-c       lsa3        9.0   0.987942
# 919   balanced_paired  callahan  lev_dada2-c       lsa3       10.0   0.987292
# 920   balanced_paired  callahan  lev_dada2-c       lsa4        1.0   0.997887
# 921   balanced_paired  callahan  lev_dada2-c       lsa4        2.0   0.996993
# 922   balanced_paired  callahan  lev_dada2-c       lsa4        3.0   0.995768
# 923   balanced_paired  callahan  lev_dada2-c       lsa4        4.0   0.995037
# 924   balanced_paired  callahan  lev_dada2-c       lsa4        5.0   0.994810
# 925   balanced_paired  callahan  lev_dada2-c       lsa4        6.0   0.993662
# 926   balanced_paired  callahan  lev_dada2-c       lsa4        7.0   0.991487
# 927   balanced_paired  callahan  lev_dada2-c       lsa4        8.0   0.989687
# 928   balanced_paired  callahan  lev_dada2-c       lsa4        9.0   0.988397
# 929   balanced_paired  callahan  lev_dada2-c       lsa4       10.0   0.987760
# 930   balanced_paired  callahan  lev_dada2-c       lsr1        1.0   0.998028
# 931   balanced_paired  callahan  lev_dada2-c       lsr1        2.0   0.997070
# 932   balanced_paired  callahan  lev_dada2-c       lsr1        3.0   0.995772
# 933   balanced_paired  callahan  lev_dada2-c       lsr1        4.0   0.995054
# 934   balanced_paired  callahan  lev_dada2-c       lsr1        5.0   0.994819
# 935   balanced_paired  callahan  lev_dada2-c       lsr1        6.0   0.993668
# 936   balanced_paired  callahan  lev_dada2-c       lsr1        7.0   0.991487
# 937   balanced_paired  callahan  lev_dada2-c       lsr1        8.0   0.989680
# 938   balanced_paired  callahan  lev_dada2-c       lsr1        9.0   0.988385
# 939   balanced_paired  callahan  lev_dada2-c       lsr1       10.0   0.987747
# 940   balanced_paired  callahan  lev_dada2-c       lsr2        1.0   0.998024
# 941   balanced_paired  callahan  lev_dada2-c       lsr2        2.0   0.997065
# 942   balanced_paired  callahan  lev_dada2-c       lsr2        3.0   0.995766
# 943   balanced_paired  callahan  lev_dada2-c       lsr2        4.0   0.995046
# 944   balanced_paired  callahan  lev_dada2-c       lsr2        5.0   0.994811
# 945   balanced_paired  callahan  lev_dada2-c       lsr2        6.0   0.993658
# 946   balanced_paired  callahan  lev_dada2-c       lsr2        7.0   0.991473
# 947   balanced_paired  callahan  lev_dada2-c       lsr2        8.0   0.989664
# 948   balanced_paired  callahan  lev_dada2-c       lsr2        9.0   0.988366
# 949   balanced_paired  callahan  lev_dada2-c       lsr2       10.0   0.987728
# 950   balanced_paired  callahan  lev_dada2-c       lsr3        1.0   0.997434
# 951   balanced_paired  callahan  lev_dada2-c       lsr3        2.0   0.996636
# 952   balanced_paired  callahan  lev_dada2-c       lsr3        3.0   0.995332
# 953   balanced_paired  callahan  lev_dada2-c       lsr3        4.0   0.994599
# 954   balanced_paired  callahan  lev_dada2-c       lsr3        5.0   0.994336
# 955   balanced_paired  callahan  lev_dada2-c       lsr3        6.0   0.993172
# 956   balanced_paired  callahan  lev_dada2-c       lsr3        7.0   0.990961
# 957   balanced_paired  callahan  lev_dada2-c       lsr3        8.0   0.989159
# 958   balanced_paired  callahan  lev_dada2-c       lsr3        9.0   0.987863
# 959   balanced_paired  callahan  lev_dada2-c       lsr3       10.0   0.987217
# 960   balanced_paired  callahan  lev_dada2-c       lsr4        1.0   0.997838
# 961   balanced_paired  callahan  lev_dada2-c       lsr4        2.0   0.996923
# 962   balanced_paired  callahan  lev_dada2-c       lsr4        3.0   0.995668
# 963   balanced_paired  callahan  lev_dada2-c       lsr4        4.0   0.994966
# 964   balanced_paired  callahan  lev_dada2-c       lsr4        5.0   0.994733
# 965   balanced_paired  callahan  lev_dada2-c       lsr4        6.0   0.993606
# 966   balanced_paired  callahan  lev_dada2-c       lsr4        7.0   0.991438
# 967   balanced_paired  callahan  lev_dada2-c       lsr4        8.0   0.989640
# 968   balanced_paired  callahan  lev_dada2-c       lsr4        9.0   0.988365
# 969   balanced_paired  callahan  lev_dada2-c       lsr4       10.0   0.987732
# 970   balanced_paired  callahan  lev_dada2-c        lss        1.0   0.998022
# 971   balanced_paired  callahan  lev_dada2-c        lss        2.0   0.997070
# 972   balanced_paired  callahan  lev_dada2-c        lss        3.0   0.995775
# 973   balanced_paired  callahan  lev_dada2-c        lss        4.0   0.995063
# 974   balanced_paired  callahan  lev_dada2-c        lss        5.0   0.994827
# 975   balanced_paired  callahan  lev_dada2-c        lss        6.0   0.993675
# 976   balanced_paired  callahan  lev_dada2-c        lss        7.0   0.991492
# 977   balanced_paired  callahan  lev_dada2-c        lss        8.0   0.989682
# 978   balanced_paired  callahan  lev_dada2-c        lss        9.0   0.988385
# 979   balanced_paired  callahan  lev_dada2-c        lss       10.0   0.987747
# 860   balanced_paired  callahan  lev_dada2-c         nf        1.0   0.999510
# 861   balanced_paired  callahan  lev_dada2-c         nf        2.0   0.998206
# 862   balanced_paired  callahan  lev_dada2-c         nf        3.0   0.996750
# 863   balanced_paired  callahan  lev_dada2-c         nf        4.0   0.995894
# 864   balanced_paired  callahan  lev_dada2-c         nf        5.0   0.995559
# 865   balanced_paired  callahan  lev_dada2-c         nf        6.0   0.994295
# 866   balanced_paired  callahan  lev_dada2-c         nf        7.0   0.992041
# 867   balanced_paired  callahan  lev_dada2-c         nf        8.0   0.990161
# 868   balanced_paired  callahan  lev_dada2-c         nf        9.0   0.988774
# 869   balanced_paired  callahan  lev_dada2-c         nf       10.0   0.988094
# 20    balanced_single  callahan           as         2f       20.0   0.993092
# 21    balanced_single  callahan           as         2f       40.0   0.972231
# 22    balanced_single  callahan           as         2f       60.0   0.969057
# 23    balanced_single  callahan           as         2f       80.0   0.955136
# 24    balanced_single  callahan           as         2f      100.0   0.951322
# 25    balanced_single  callahan           as         2f      120.0   0.945072
# 26    balanced_single  callahan           as         2f      140.0   0.928022
# 27    balanced_single  callahan           as         2f      160.0   0.926633
# 28    balanced_single  callahan           as         2f      180.0   0.895780
# 29    balanced_single  callahan           as         2f      200.0   0.891845
# 10    balanced_single  callahan           as         f1       20.0   0.993092
# 11    balanced_single  callahan           as         f1       40.0   0.972431
# 12    balanced_single  callahan           as         f1       60.0   0.969693
# 13    balanced_single  callahan           as         f1       80.0   0.956125
# 14    balanced_single  callahan           as         f1      100.0   0.952557
# 15    balanced_single  callahan           as         f1      120.0   0.946248
# 16    balanced_single  callahan           as         f1      140.0   0.929131
# 17    balanced_single  callahan           as         f1      160.0   0.927380
# 18    balanced_single  callahan           as         f1      180.0   0.896386
# 19    balanced_single  callahan           as         f1      200.0   0.892291
# 30    balanced_single  callahan           as       lsa1       20.0   0.990505
# 31    balanced_single  callahan           as       lsa1       40.0   0.970172
# 32    balanced_single  callahan           as       lsa1       60.0   0.967701
# 33    balanced_single  callahan           as       lsa1       80.0   0.954410
# 34    balanced_single  callahan           as       lsa1      100.0   0.951340
# 35    balanced_single  callahan           as       lsa1      120.0   0.945180
# 36    balanced_single  callahan           as       lsa1      140.0   0.928221
# 37    balanced_single  callahan           as       lsa1      160.0   0.926827
# 38    balanced_single  callahan           as       lsa1      180.0   0.895862
# 39    balanced_single  callahan           as       lsa1      200.0   0.891861
# 40    balanced_single  callahan           as       lsa2       20.0   0.990498
# 41    balanced_single  callahan           as       lsa2       40.0   0.970153
# 42    balanced_single  callahan           as       lsa2       60.0   0.967676
# 43    balanced_single  callahan           as       lsa2       80.0   0.954365
# 44    balanced_single  callahan           as       lsa2      100.0   0.951290
# 45    balanced_single  callahan           as       lsa2      120.0   0.945138
# 46    balanced_single  callahan           as       lsa2      140.0   0.928178
# 47    balanced_single  callahan           as       lsa2      160.0   0.926788
# 48    balanced_single  callahan           as       lsa2      180.0   0.895825
# 49    balanced_single  callahan           as       lsa2      200.0   0.891831
# 50    balanced_single  callahan           as       lsa3       20.0   0.990048
# 51    balanced_single  callahan           as       lsa3       40.0   0.969933
# 52    balanced_single  callahan           as       lsa3       60.0   0.967589
# 53    balanced_single  callahan           as       lsa3       80.0   0.954379
# 54    balanced_single  callahan           as       lsa3      100.0   0.951321
# 55    balanced_single  callahan           as       lsa3      120.0   0.945174
# 56    balanced_single  callahan           as       lsa3      140.0   0.928215
# 57    balanced_single  callahan           as       lsa3      160.0   0.926825
# 58    balanced_single  callahan           as       lsa3      180.0   0.895860
# 59    balanced_single  callahan           as       lsa3      200.0   0.891859
# 60    balanced_single  callahan           as       lsa4       20.0   0.990311
# 61    balanced_single  callahan           as       lsa4       40.0   0.970014
# 62    balanced_single  callahan           as       lsa4       60.0   0.967627
# 63    balanced_single  callahan           as       lsa4       80.0   0.954390
# 64    balanced_single  callahan           as       lsa4      100.0   0.951331
# 65    balanced_single  callahan           as       lsa4      120.0   0.945174
# 66    balanced_single  callahan           as       lsa4      140.0   0.928215
# 67    balanced_single  callahan           as       lsa4      160.0   0.926825
# 68    balanced_single  callahan           as       lsa4      180.0   0.895860
# 69    balanced_single  callahan           as       lsa4      200.0   0.891859
# 70    balanced_single  callahan           as       lsr1       20.0   0.990349
# 71    balanced_single  callahan           as       lsr1       40.0   0.970021
# 72    balanced_single  callahan           as       lsr1       60.0   0.967546
# 73    balanced_single  callahan           as       lsr1       80.0   0.954245
# 74    balanced_single  callahan           as       lsr1      100.0   0.951195
# 75    balanced_single  callahan           as       lsr1      120.0   0.945045
# 76    balanced_single  callahan           as       lsr1      140.0   0.928126
# 77    balanced_single  callahan           as       lsr1      160.0   0.926710
# 78    balanced_single  callahan           as       lsr1      180.0   0.895755
# 79    balanced_single  callahan           as       lsr1      200.0   0.891793
# 80    balanced_single  callahan           as       lsr2       20.0   0.990332
# 81    balanced_single  callahan           as       lsr2       40.0   0.969983
# 82    balanced_single  callahan           as       lsr2       60.0   0.967515
# 83    balanced_single  callahan           as       lsr2       80.0   0.954212
# 84    balanced_single  callahan           as       lsr2      100.0   0.951161
# 85    balanced_single  callahan           as       lsr2      120.0   0.945018
# 86    balanced_single  callahan           as       lsr2      140.0   0.928096
# 87    balanced_single  callahan           as       lsr2      160.0   0.926684
# 88    balanced_single  callahan           as       lsr2      180.0   0.895730
# 89    balanced_single  callahan           as       lsr2      200.0   0.891772
# 90    balanced_single  callahan           as       lsr3       20.0   0.989985
# 91    balanced_single  callahan           as       lsr3       40.0   0.969831
# 92    balanced_single  callahan           as       lsr3       60.0   0.967460
# 93    balanced_single  callahan           as       lsr3       80.0   0.954215
# 94    balanced_single  callahan           as       lsr3      100.0   0.951175
# 95    balanced_single  callahan           as       lsr3      120.0   0.945040
# 96    balanced_single  callahan           as       lsr3      140.0   0.928121
# 97    balanced_single  callahan           as       lsr3      160.0   0.926708
# 98    balanced_single  callahan           as       lsr3      180.0   0.895753
# 99    balanced_single  callahan           as       lsr3      200.0   0.891791
# 100   balanced_single  callahan           as       lsr4       20.0   0.990223
# 101   balanced_single  callahan           as       lsr4       40.0   0.969914
# 102   balanced_single  callahan           as       lsr4       60.0   0.967494
# 103   balanced_single  callahan           as       lsr4       80.0   0.954234
# 104   balanced_single  callahan           as       lsr4      100.0   0.951190
# 105   balanced_single  callahan           as       lsr4      120.0   0.945043
# 106   balanced_single  callahan           as       lsr4      140.0   0.928124
# 107   balanced_single  callahan           as       lsr4      160.0   0.926708
# 108   balanced_single  callahan           as       lsr4      180.0   0.895753
# 109   balanced_single  callahan           as       lsr4      200.0   0.891791
# 110   balanced_single  callahan           as        lss       20.0   0.990347
# 1355  0.766431      0.697372
# 1356  0.767005      0.695763
# 1357  0.754173      0.659648
# 1358  0.754466      0.658838
# 1359  0.733739      0.581421

# %%
df_quality.to_csv('%s/df_quality.csv' % eval_dir, sep = ';', index = False)
#df_quality = pd.read_csv('%s/df_quality.csv' % eval_dir, sep = ';')

# %% [markdown]
# Combine counting and quality information:

# %%
df_c, df_q = df_counts.copy(), df_quality.copy()
drop_cols = ['join_col'] + ['%s_counts' % s for s in set(df_q.columns) & set(df_c.columns)]
df_c['join_col'] = df_c['data_set'] + df_c['tool'] + df_c['mode'] + df_c['refinement'] + df_c['threshold'].apply(str)
df_q['join_col'] = df_q['data_set'] + df_q['tool'] + df_q['mode'] + df_q['refinement'] + df_q['threshold'].apply(str)
df_joined = df_q.join(df_c.set_index('join_col'), on = 'join_col', rsuffix = '_counts').drop(drop_cols, axis = 1)

# %%
df_joined.to_csv('%s/df_joined.csv' % eval_dir, sep = ';', index = False)
#df_joined = pd.read_csv('%s/df_joined.csv' % eval_dir, sep = ';')

# %% [markdown]
# Determine the maximum, average and N-best average clustering quality (for N = 5).

# %%
df_columns = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

max_rows = []
mean_rows = []
nbest_rows = []
n = 5

for (d, g, t, m, f, ds, rt), grp in df_joined.groupby(by = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'ds', 'rt']):
    best = grp.nlargest(1, 'adjrandindex')
    max_rows.append([d, g, t, m, f, best['precision'].values[0], best['recall'].values[0], best['adjrandindex'].values[0], best['num_input_amplicons'].values[0], best['input_mass'].values[0], best['num_clusters'].values[0], best['num_output_amplicons'].values[0], best['output_mass'].values[0], ds, rt])
    mean_rows.append([d, g, t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean(), grp['num_input_amplicons'].mean(), grp['input_mass'].mean(), grp['num_clusters'].mean(), grp['num_output_amplicons'].mean(), grp['output_mass'].mean(), ds, rt])
    nbest = grp.nlargest(n, 'adjrandindex')
    nbest_rows.append([d, g, t, m, f, nbest['precision'].mean(), nbest['recall'].mean(), nbest['adjrandindex'].mean(), nbest['num_input_amplicons'].mean(), nbest['input_mass'].mean(), nbest['num_clusters'].mean(), nbest['num_output_amplicons'].mean(), nbest['output_mass'].mean(), ds, rt])
    
df_joined_max = pd.DataFrame(max_rows, columns = df_columns)
df_joined_mean = pd.DataFrame(mean_rows, columns = df_columns)
df_joined_nbest = pd.DataFrame(nbest_rows, columns = df_columns)

# %%
df_joined_max.to_csv('%s/df_joined_max.csv' % eval_dir, sep = ';', index = False)
df_joined_mean.to_csv('%s/df_joined_mean.csv' % eval_dir, sep = ';', index = False)
df_joined_nbest.to_csv('%s/df_joined_nbest.csv' % eval_dir, sep = ';', index = False)
#df_joined_max = pd.read_csv('%s/df_joined_max.csv' % eval_dir, sep = ';')
#df_joined_mean = pd.read_csv('%s/df_joined_mean.csv' % eval_dir, sep = ';')
#df_joined_nbest = pd.read_csv('%s/df_joined_nbest.csv' % eval_dir, sep = ';')

# %%
df_max = df_joined_max.loc[df_joined_max['gt'] == 'callahan']
df_mean = df_joined_mean.loc[df_joined_mean['gt'] == 'callahan']
df_nbest = df_joined_nbest.loc[df_joined_nbest['gt'] == 'callahan']

# %% [markdown]
# For the chosen ground truth, average the maximum, average and N-best average values per data set (e.g. balanced) and read type (e.g. paired).
# Has no effect in this case because there is only one data set per combination of data set and read type .

# %%
df_columns = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

def average_complexity(df):
    rows = []
    for (gt, ds, rt, tool, mode, f), grp in df.groupby(by = ['gt', 'ds', 'rt', 'tool', 'mode', 'refinement']):
        rows.append(['%s_%s' % (ds, rt), gt, tool, mode, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean(), grp['num_input_amplicons'].mean(), grp['input_mass'].mean(), grp['num_clusters'].mean(), grp['num_output_amplicons'].mean(), grp['output_mass'].mean(), ds, rt])
    return pd.DataFrame(rows, columns = df_columns)

# %%
df_joined_max_avg = average_complexity(df_max)
df_joined_mean_avg = average_complexity(df_mean)
df_joined_nbest_avg = average_complexity(df_nbest)

# %%
df_joined_max_avg.to_csv('%s/df_joined_max_avg.csv' % eval_dir, sep = ';', index = False)
df_joined_mean_avg.to_csv('%s/df_joined_mean_avg.csv' % eval_dir, sep = ';', index = False)
df_joined_nbest_avg.to_csv('%s/df_joined_nbest_avg.csv' % eval_dir, sep = ';', index = False)
#df_joined_max_avg = pd.read_csv('%s/df_joined_max_avg.csv' % eval_dir, sep = ';')
#df_joined_mean_avg = pd.read_csv('%s/df_joined_mean_avg.csv' % eval_dir, sep = ';')
#df_joined_nbest_avg = pd.read_csv('%s/df_joined_nbest_avg.csv' % eval_dir, sep = ';')

# %% [markdown]
# **Maximum clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_max_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: balanced_paired / Tool: gefast
#            data_set        gt    tool         mode refinement  precision  \
# 37  balanced_paired  callahan  gefast          lev       lsa2   0.972045
# 41  balanced_paired  callahan  gefast          lev       lsr2   0.971893
# 35  balanced_paired  callahan  gefast          lev         f1   0.972586
# 34  balanced_paired  callahan  gefast          lev         2f   0.972405
# 45  balanced_paired  callahan  gefast          lev         nf   0.972753
# 38  balanced_paired  callahan  gefast          lev       lsa3   0.971936
# 39  balanced_paired  callahan  gefast          lev       lsa4   0.971992
# 36  balanced_paired  callahan  gefast          lev       lsa1   0.972067
# 42  balanced_paired  callahan  gefast          lev       lsr3   0.971817
# 43  balanced_paired  callahan  gefast          lev       lsr4   0.971889
# 44  balanced_paired  callahan  gefast          lev        lss   0.971921
# 40  balanced_paired  callahan  gefast          lev       lsr1   0.971921
# 3   balanced_paired  callahan  gefast           as       lsa2   0.958306
# 7   balanced_paired  callahan  gefast           as       lsr2   0.958180
# 11  balanced_paired  callahan  gefast           as         nf   0.958944
# 1   balanced_paired  callahan  gefast           as         f1   0.958777
# 0   balanced_paired  callahan  gefast           as         2f   0.958458
# 4   balanced_paired  callahan  gefast           as       lsa3   0.958277
# 5   balanced_paired  callahan  gefast           as       lsa4   0.958307
# 2   balanced_paired  callahan  gefast           as       lsa1   0.958349
# 8   balanced_paired  callahan  gefast           as       lsr3   0.958144
# 10  balanced_paired  callahan  gefast           as        lss   0.958217
# 9   balanced_paired  callahan  gefast           as       lsr4   0.958189
# 6   balanced_paired  callahan  gefast           as       lsr1   0.958213
# 49  balanced_paired  callahan  gefast  lev_dada2-c       lsa2   0.995950
# 15  balanced_paired  callahan  gefast   as_dada2-c       lsa2   0.995025
# 53  balanced_paired  callahan  gefast  lev_dada2-c       lsr2   0.995766
# 19  balanced_paired  callahan  gefast   as_dada2-c       lsr2   0.994875
# 29  balanced_paired  callahan  gefast      dada2-s       lsr2   0.996997
# 25  balanced_paired  callahan  gefast      dada2-s       lsa2   0.996997
# 46  balanced_paired  callahan  gefast  lev_dada2-c         2f   0.996390
# 13  balanced_paired  callahan  gefast   as_dada2-c         f1   0.995356
# 47  balanced_paired  callahan  gefast  lev_dada2-c         f1   0.995663
# 50  balanced_paired  callahan  gefast  lev_dada2-c       lsa3   0.994746
# 12  balanced_paired  callahan  gefast   as_dada2-c         2f   0.995522
# 51  balanced_paired  callahan  gefast  lev_dada2-c       lsa4   0.995037
# 48  balanced_paired  callahan  gefast  lev_dada2-c       lsa1   0.995206
# 54  balanced_paired  callahan  gefast  lev_dada2-c       lsr3   0.994599
# 55  balanced_paired  callahan  gefast  lev_dada2-c       lsr4   0.994966
# 56  balanced_paired  callahan  gefast  lev_dada2-c        lss   0.995063
# 52  balanced_paired  callahan  gefast  lev_dada2-c       lsr1   0.995054
# 57  balanced_paired  callahan  gefast  lev_dada2-c         nf   0.995894
# 16  balanced_paired  callahan  gefast   as_dada2-c       lsa3   0.994537
# 17  balanced_paired  callahan  gefast   as_dada2-c       lsa4   0.994862
# 14  balanced_paired  callahan  gefast   as_dada2-c       lsa1   0.995033
# 20  balanced_paired  callahan  gefast   as_dada2-c       lsr3   0.994391
# 21  balanced_paired  callahan  gefast   as_dada2-c       lsr4   0.994789
# 22  balanced_paired  callahan  gefast   as_dada2-c        lss   0.994887
# 18  balanced_paired  callahan  gefast   as_dada2-c       lsr1   0.994883
# 23  balanced_paired  callahan  gefast   as_dada2-c         nf   0.995636
# 30  balanced_paired  callahan  gefast      dada2-s       lsr3   0.996440
# 26  balanced_paired  callahan  gefast      dada2-s       lsa3   0.996440
# 27  balanced_paired  callahan  gefast      dada2-s       lsa4   0.996968
# 31  balanced_paired  callahan  gefast      dada2-s       lsr4   0.996968
# 24  balanced_paired  callahan  gefast      dada2-s       lsa1   0.997002
# 32  balanced_paired  callahan  gefast      dada2-s        lss   0.997002
# 28  balanced_paired  callahan  gefast      dada2-s       lsr1   0.997002
# 33  balanced_paired  callahan  gefast      dada2-s         nf   0.999243
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
#
# 68   balanced_single  callahan  gefast           as        lss   0.990347
# 64   balanced_single  callahan  gefast           as       lsr1   0.990349
# 98   balanced_single  callahan  gefast          lev       lsr1   0.990349
# 96   balanced_single  callahan  gefast          lev       lsa3   0.990048
# 62   balanced_single  callahan  gefast           as       lsa3   0.990048
# 63   balanced_single  callahan  gefast           as       lsa4   0.990311
# 97   balanced_single  callahan  gefast          lev       lsa4   0.990311
# 94   balanced_single  callahan  gefast          lev       lsa1   0.990505
# 60   balanced_single  callahan  gefast           as       lsa1   0.990505
# 93   balanced_single  callahan  gefast          lev         f1   0.993074
# 92   balanced_single  callahan  gefast          lev         2f   0.993074
# 58   balanced_single  callahan  gefast           as         2f   0.993092
# 59   balanced_single  callahan  gefast           as         f1   0.993092
# 103  balanced_single  callahan  gefast          lev         nf   0.993284
# 69   balanced_single  callahan  gefast           as         nf   0.993284
# 107  balanced_single  callahan  gefast  lev_dada2-c       lsa2   0.993825
# 111  balanced_single  callahan  gefast  lev_dada2-c       lsr2   0.993619
# 104  balanced_single  callahan  gefast  lev_dada2-c         2f   0.995165
# 105  balanced_single  callahan  gefast  lev_dada2-c         f1   0.995889
# 87   balanced_single  callahan  gefast      dada2-s       lsr2   0.995326
# 83   balanced_single  callahan  gefast      dada2-s       lsa2   0.995326
# 73   balanced_single  callahan  gefast   as_dada2-c       lsa2   0.995251
# 115  balanced_single  callahan  gefast  lev_dada2-c         nf   0.995117
# 108  balanced_single  callahan  gefast  lev_dada2-c       lsa3   0.993547
# 112  balanced_single  callahan  gefast  lev_dada2-c       lsr3   0.993363
# 109  balanced_single  callahan  gefast  lev_dada2-c       lsa4   0.993716
# 106  balanced_single  callahan  gefast  lev_dada2-c       lsa1   0.993818
# 114  balanced_single  callahan  gefast  lev_dada2-c        lss   0.993635
# 113  balanced_single  callahan  gefast  lev_dada2-c       lsr4   0.993574
# 110  balanced_single  callahan  gefast  lev_dada2-c       lsr1   0.993628
# 77   balanced_single  callahan  gefast   as_dada2-c       lsr2   0.995035
# 84   balanced_single  callahan  gefast      dada2-s       lsa3   0.994979
# 88   balanced_single  callahan  gefast      dada2-s       lsr3   0.994979
# 89   balanced_single  callahan  gefast      dada2-s       lsr4   0.995302
# 85   balanced_single  callahan  gefast      dada2-s       lsa4   0.995302
# 86   balanced_single  callahan  gefast      dada2-s       lsr1   0.995334
# 82   balanced_single  callahan  gefast      dada2-s       lsa1   0.995334
# 90   balanced_single  callahan  gefast      dada2-s        lss   0.995334
# 70   balanced_single  callahan  gefast   as_dada2-c         2f   0.997412
# 78   balanced_single  callahan  gefast   as_dada2-c       lsr3   0.994793
# 74   balanced_single  callahan  gefast   as_dada2-c       lsa3   0.994932
# 79   balanced_single  callahan  gefast   as_dada2-c       lsr4   0.994947
# 76   balanced_single  callahan  gefast   as_dada2-c       lsr1   0.995042
# 80   balanced_single  callahan  gefast   as_dada2-c        lss   0.995040
# 75   balanced_single  callahan  gefast   as_dada2-c       lsa4   0.995076
# 72   balanced_single  callahan  gefast   as_dada2-c       lsa1   0.995230
# 71   balanced_single  callahan  gefast   as_dada2-c         f1   0.996076
# 81   balanced_single  callahan  gefast   as_dada2-c         nf   0.993144
# 91   balanced_single  callahan  gefast      dada2-s         nf   0.999178
#
#        recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
#
# 74   0.885285      0.868347              33523.0    558059.0        1526.0
# 79   0.885351      0.868345              33523.0    558059.0        1750.0
# 76   0.885351      0.868345              33523.0    558059.0        2105.0
# 80   0.885349      0.868344              33523.0    558059.0        2087.0
# 75   0.885285      0.868317              33523.0    558059.0        1750.0
# 72   0.885285      0.868316              33523.0    558059.0        2208.0
# 71   0.884636      0.867801              33523.0    558059.0        3829.0
# 81   0.885397      0.867182              33523.0    558059.0        3329.0
# 91   0.856060      0.840708              33523.0    558059.0       24871.0
#
#      num_output_amplicons  output_mass        ds      rt
# 61                32565.0     556838.0  balanced  single
# 95                32565.0     556838.0  balanced  single
# 99                32802.0     557075.0  balanced  single
# 65                32802.0     557075.0  balanced  single
# 100               33523.0     558059.0  balanced  single
# 66                33523.0     558059.0  balanced  single
# 67                33523.0     558059.0  balanced  single
# 101               33523.0     558059.0  balanced  single
# 102               33523.0     558059.0  balanced  single
# 68                33523.0     558059.0  balanced  single
# 64                33523.0     558059.0  balanced  single
# 98                33523.0     558059.0  balanced  single
# 96                33523.0     558059.0  balanced  single
# 62                33523.0     558059.0  balanced  single
# 63                33523.0     558059.0  balanced  single
# 97                33523.0     558059.0  balanced  single
# 94                33523.0     558059.0  balanced  single
# 60                33523.0     558059.0  balanced  single
# 93                33523.0     558059.0  balanced  single
# 92                33523.0     558059.0  balanced  single
# 58                33523.0     558059.0  balanced  single
# 59                33523.0     558059.0  balanced  single
# 103               33523.0     558059.0  balanced  single
# 69                33523.0     558059.0  balanced  single
# 107               32805.0     557096.0  balanced  single
# 111               33019.0     557310.0  balanced  single
# 104               33523.0     558059.0  balanced  single
# 105               33523.0     558059.0  balanced  single
# 87                33023.0     557176.0  balanced  single
# 83                33023.0     557176.0  balanced  single
# 73                32695.0     557006.0  balanced  single
# 115               33523.0     558059.0  balanced  single
# 108               33523.0     558059.0  balanced  single
# 112               33523.0     558059.0  balanced  single
# 109               33523.0     558059.0  balanced  single
# 106               33523.0     558059.0  balanced  single
# 114               33523.0     558059.0  balanced  single
# 113               33523.0     558059.0  balanced  single
# 110               33523.0     558059.0  balanced  single
# 77                32943.0     557254.0  balanced  single
# 84                33523.0     558059.0  balanced  single
# 88                33523.0     558059.0  balanced  single
# 89                33523.0     558059.0  balanced  single
# 85                33523.0     558059.0  balanced  single
# 86                33523.0     558059.0  balanced  single
# 82                33523.0     558059.0  balanced  single
# 90                33523.0     558059.0  balanced  single
# 70                33523.0     558059.0  balanced  single
# 78                33523.0     558059.0  balanced  single
# 74                33523.0     558059.0  balanced  single
# 79                33523.0     558059.0  balanced  single
# 76                33523.0     558059.0  balanced  single
# 80                33523.0     558059.0  balanced  single
# 75                33523.0     558059.0  balanced  single
# 72                33523.0     558059.0  balanced  single
# 71                33523.0     558059.0  balanced  single
# 81                33523.0     558059.0  balanced  single
# 91                33523.0     558059.0  balanced  single
# Data set: hmp_paired / Tool: gefast
#        data_set        gt    tool         mode refinement  precision  \
# 119  hmp_paired  callahan  gefast           as       lsa2   0.994527
# 153  hmp_paired  callahan  gefast          lev       lsa2   0.994521
# 123  hmp_paired  callahan  gefast           as       lsr2   0.994323
# 157  hmp_paired  callahan  gefast          lev       lsr2   0.994314
# 120  hmp_paired  callahan  gefast           as       lsa3   0.994235
# 116  hmp_paired  callahan  gefast           as         2f   0.995354
# 154  hmp_paired  callahan  gefast          lev       lsa3   0.994226
# 150  hmp_paired  callahan  gefast          lev         2f   0.995321
# 121  hmp_paired  callahan  gefast           as       lsa4   0.994259
# 124  hmp_paired  callahan  gefast           as       lsr3   0.994201
# 118  hmp_paired  callahan  gefast           as       lsa1   0.994523
# 125  hmp_paired  callahan  gefast           as       lsr4   0.994259
# 126  hmp_paired  callahan  gefast           as        lss   0.994341
# 122  hmp_paired  callahan  gefast           as       lsr1   0.994336
# 155  hmp_paired  callahan  gefast          lev       lsa4   0.994245
# 158  hmp_paired  callahan  gefast          lev       lsr3   0.994201
# 152  hmp_paired  callahan  gefast          lev       lsa1   0.994514
# 159  hmp_paired  callahan  gefast          lev       lsr4   0.994250
# 160  hmp_paired  callahan  gefast          lev        lss   0.994331
# 156  hmp_paired  callahan  gefast          lev       lsr1   0.994326
# 117  hmp_paired  callahan  gefast           as         f1   0.995484
# 151  hmp_paired  callahan  gefast          lev         f1   0.995451
# 161  hmp_paired  callahan  gefast          lev         nf   0.995705
# 127  hmp_paired  callahan  gefast           as         nf   0.995744
# 141  hmp_paired  callahan  gefast      dada2-s       lsa2   0.986338
# 145  hmp_paired  callahan  gefast      dada2-s       lsr2   0.986338
# 142  hmp_paired  callahan  gefast      dada2-s       lsa3   0.986159
# 146  hmp_paired  callahan  gefast      dada2-s       lsr3   0.986159
# 143  hmp_paired  callahan  gefast      dada2-s       lsa4   0.986352
# 147  hmp_paired  callahan  gefast      dada2-s       lsr4   0.986352
# 144  hmp_paired  callahan  gefast      dada2-s       lsr1   0.986361
# 140  hmp_paired  callahan  gefast      dada2-s       lsa1   0.986361
# 148  hmp_paired  callahan  gefast      dada2-s        lss   0.986361
# 165  hmp_paired  callahan  gefast  lev_dada2-c       lsa2   0.996530
# 131  hmp_paired  callahan  gefast   as_dada2-c       lsa2   0.996579
# 169  hmp_paired  callahan  gefast  lev_dada2-c       lsr2   0.996305
# 135  hmp_paired  callahan  gefast   as_dada2-c       lsr2   0.996362
# 162  hmp_paired  callahan  gefast  lev_dada2-c         2f   0.997348
# 166  hmp_paired  callahan  gefast  lev_dada2-c       lsa3   0.996147
# 170  hmp_paired  callahan  gefast  lev_dada2-c       lsr3   0.996104
# 163  hmp_paired  callahan  gefast  lev_dada2-c         f1   0.997468
# 167  hmp_paired  callahan  gefast  lev_dada2-c       lsa4   0.996258
# 164  hmp_paired  callahan  gefast  lev_dada2-c       lsa1   0.996522
# 171  hmp_paired  callahan  gefast  lev_dada2-c       lsr4   0.996234
# 172  hmp_paired  callahan  gefast  lev_dada2-c        lss   0.996320
# 168  hmp_paired  callahan  gefast  lev_dada2-c       lsr1   0.996315
# 173  hmp_paired  callahan  gefast  lev_dada2-c         nf   0.997757
# 163  0.702369      0.699156              19882.0    208157.0        2727.0
# 167  0.702407      0.699149              19882.0    208157.0        1453.0
# 164  0.702407      0.699148              19882.0    208157.0        1832.0
# 171  0.702417      0.699144              19882.0    208157.0        1451.0
# 172  0.702417      0.699143              19882.0    208157.0        1673.0
# 168  0.702417      0.699143              19882.0    208157.0        1699.0
# 173  0.702225      0.698913              19882.0    208157.0        3395.0
# 128  0.702057      0.698865              19882.0    208157.0        2513.0
# 132  0.701970      0.698749              19882.0    208157.0        1305.0
# 136  0.701994      0.698705              19882.0    208157.0        1305.0
# 129  0.701946      0.698692              19882.0    208157.0        2772.0
# 137  0.701994      0.698663              19882.0    208157.0        1477.0
# 138  0.701994      0.698662              19882.0    208157.0        1705.0
# 134  0.701994      0.698662              19882.0    208157.0        1734.0
# 133  0.701970      0.698654              19882.0    208157.0        1479.0
# 130  0.701970      0.698653              19882.0    208157.0        1858.0
# 139  0.701120      0.697464              19882.0    208157.0        3690.0
# 149  0.705890      0.694222              19882.0    208157.0       15886.0
#
#      num_output_amplicons  output_mass   ds      rt
# 119               19217.0     207363.0  hmp  paired
# 153               19206.0     207354.0  hmp  paired
# 123               19545.0     207691.0  hmp  paired
# 157               19546.0     207694.0  hmp  paired
# 120               19882.0     208157.0  hmp  paired
# 116               19882.0     208157.0  hmp  paired
# 154               19882.0     208157.0  hmp  paired
# 150               19882.0     208157.0  hmp  paired
# 121               19882.0     208157.0  hmp  paired
# 124               19882.0     208157.0  hmp  paired
# 118               19882.0     208157.0  hmp  paired
# 125               19882.0     208157.0  hmp  paired
# 126               19882.0     208157.0  hmp  paired
# 122               19882.0     208157.0  hmp  paired
# 155               19882.0     208157.0  hmp  paired
# 158               19882.0     208157.0  hmp  paired
# 152               19882.0     208157.0  hmp  paired
# 159               19882.0     208157.0  hmp  paired
# 160               19882.0     208157.0  hmp  paired
# 156               19882.0     208157.0  hmp  paired
# 117               19882.0     208157.0  hmp  paired
# 151               19882.0     208157.0  hmp  paired
# 161               19882.0     208157.0  hmp  paired
# 127               19882.0     208157.0  hmp  paired
# 141               19703.0     207803.0  hmp  paired
# 145               19703.0     207803.0  hmp  paired
# 142               19882.0     208157.0  hmp  paired
# 146               19882.0     208157.0  hmp  paired
# 143               19882.0     208157.0  hmp  paired
# 147               19882.0     208157.0  hmp  paired
# 144               19882.0     208157.0  hmp  paired
# 140               19882.0     208157.0  hmp  paired
# 148               19882.0     208157.0  hmp  paired
# 165               19134.0     207234.0  hmp  paired
# 131               19139.0     207238.0  hmp  paired
# 169               19458.0     207558.0  hmp  paired
# 135               19451.0     207550.0  hmp  paired
# 162               19882.0     208157.0  hmp  paired
# 166               19882.0     208157.0  hmp  paired
# 170               19882.0     208157.0  hmp  paired
# 163               19882.0     208157.0  hmp  paired
# 167               19882.0     208157.0  hmp  paired
# 164               19882.0     208157.0  hmp  paired
# 171               19882.0     208157.0  hmp  paired
# 172               19882.0     208157.0  hmp  paired
# 168               19882.0     208157.0  hmp  paired
# 173               19882.0     208157.0  hmp  paired
# 128               19882.0     208157.0  hmp  paired
# 132               19882.0     208157.0  hmp  paired
# 136               19882.0     208157.0  hmp  paired
# 129               19882.0     208157.0  hmp  paired
# 137               19882.0     208157.0  hmp  paired
# 138               19882.0     208157.0  hmp  paired
# 134               19882.0     208157.0  hmp  paired
# 133               19882.0     208157.0  hmp  paired
# 130               19882.0     208157.0  hmp  paired
# 139               19882.0     208157.0  hmp  paired
# 149               19882.0     208157.0  hmp  paired
# Data set: hmp_single / Tool: gefast
#        data_set        gt    tool         mode refinement  precision  \
# 211  hmp_single  callahan  gefast          lev       lsa2   0.987062
# 177  hmp_single  callahan  gefast           as       lsa2   0.987062
# 215  hmp_single  callahan  gefast          lev       lsr2   0.986967
# 181  hmp_single  callahan  gefast           as       lsr2   0.986967
# 216  hmp_single  callahan  gefast          lev       lsr3   0.986696
# 182  hmp_single  callahan  gefast           as       lsr3   0.986696
# 183  hmp_single  callahan  gefast           as       lsr4   0.986800
# 217  hmp_single  callahan  gefast          lev       lsr4   0.986800
# 214  hmp_single  callahan  gefast          lev       lsr1   0.986994
# 180  hmp_single  callahan  gefast           as       lsr1   0.986994
# 218  hmp_single  callahan  gefast          lev        lss   0.986994
# 184  hmp_single  callahan  gefast           as        lss   0.986994
# 178  hmp_single  callahan  gefast           as       lsa3   0.986614
# 212  hmp_single  callahan  gefast          lev       lsa3   0.986614
# 179  hmp_single  callahan  gefast           as       lsa4   0.986749
# 213  hmp_single  callahan  gefast          lev       lsa4   0.986749
# 210  hmp_single  callahan  gefast          lev       lsa1   0.987076
# 176  hmp_single  callahan  gefast           as       lsa1   0.987076
# 209  hmp_single  callahan  gefast          lev         f1   0.996923
# 208  hmp_single  callahan  gefast          lev         2f   0.996923
# 174  hmp_single  callahan  gefast           as         2f   0.996929
# 175  hmp_single  callahan  gefast           as         f1   0.996929
# 185  hmp_single  callahan  gefast           as         nf   0.997724
# 219  hmp_single  callahan  gefast          lev         nf   0.997724
# 199  hmp_single  callahan  gefast      dada2-s       lsa2   0.986186
# 203  hmp_single  callahan  gefast      dada2-s       lsr2   0.986186
# 200  hmp_single  callahan  gefast      dada2-s       lsa3   0.985986
# 204  hmp_single  callahan  gefast      dada2-s       lsr3   0.985986
# 201  hmp_single  callahan  gefast      dada2-s       lsa4   0.986193
# 205  hmp_single  callahan  gefast      dada2-s       lsr4   0.986193
# 202  hmp_single  callahan  gefast      dada2-s       lsr1   0.986206
# 198  hmp_single  callahan  gefast      dada2-s       lsa1   0.986206
# 206  hmp_single  callahan  gefast      dada2-s        lss   0.986206
# 223  hmp_single  callahan  gefast  lev_dada2-c       lsa2   0.988042
# 189  hmp_single  callahan  gefast   as_dada2-c       lsa2   0.988042
# 193  hmp_single  callahan  gefast   as_dada2-c       lsr2   0.987957
# 227  hmp_single  callahan  gefast  lev_dada2-c       lsr2   0.987957
# 194  hmp_single  callahan  gefast   as_dada2-c       lsr3   0.987777
# 228  hmp_single  callahan  gefast  lev_dada2-c       lsr3   0.987777
# 229  hmp_single  callahan  gefast  lev_dada2-c       lsr4   0.987842
# 195  hmp_single  callahan  gefast   as_dada2-c       lsr4   0.987842
# 192  hmp_single  callahan  gefast   as_dada2-c       lsr1   0.987980
# 226  hmp_single  callahan  gefast  lev_dada2-c       lsr1   0.987980
# 196  hmp_single  callahan  gefast   as_dada2-c        lss   0.987982
# 230  hmp_single  callahan  gefast  lev_dada2-c        lss   0.987982
# 190  hmp_single  callahan  gefast   as_dada2-c       lsa3   0.987719
# 224  hmp_single  callahan  gefast  lev_dada2-c       lsa3   0.987719
# 225  hmp_single  callahan  gefast  lev_dada2-c       lsa4   0.987782
# 191  hmp_single  callahan  gefast   as_dada2-c       lsa4   0.987782
# 188  hmp_single  callahan  gefast   as_dada2-c       lsa1   0.988053
# 222  hmp_single  callahan  gefast  lev_dada2-c       lsa1   0.988053
# 220  hmp_single  callahan  gefast  lev_dada2-c         2f   0.976097
# 186  hmp_single  callahan  gefast   as_dada2-c         2f   0.976231
# 221  hmp_single  callahan  gefast  lev_dada2-c         f1   0.977217
# 187  hmp_single  callahan  gefast   as_dada2-c         f1   0.977357
# 231  hmp_single  callahan  gefast  lev_dada2-c         nf   0.972586
# 197  hmp_single  callahan  gefast   as_dada2-c         nf   0.973125
# 207  hmp_single  callahan  gefast      dada2-s         nf   0.998496
#
#        recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 211  0.934598      0.941511              73071.0    449409.0         919.0
# 177  0.934598      0.941511              73071.0    449409.0         919.0
# 215  0.934139      0.941209              73071.0    449409.0         919.0
# 181  0.934139      0.941209              73071.0    449409.0         919.0
# 216  0.932224      0.939958              73071.0    449409.0         920.0
# 182  0.932224      0.939958              73071.0    449409.0         920.0
# 183  0.932224      0.939941              73071.0    449409.0        1113.0
# 217  0.932224      0.939941              73071.0    449409.0        1113.0
# 214  0.932224      0.939941              73071.0    449409.0        1643.0
# 180  0.932224      0.939941              73071.0    449409.0        1643.0
# 218  0.932224      0.939941              73071.0    449409.0        1622.0
# 184  0.932224      0.939941              73071.0    449409.0        1622.0
# 178  0.932113      0.939883              73071.0    449409.0         920.0
# 212  0.932113      0.939883              73071.0    449409.0         920.0
# 179  0.932113      0.939861              73071.0    449409.0        1115.0
# 213  0.932113      0.939861              73071.0    449409.0        1115.0
# 210  0.932113      0.939861              73071.0    449409.0        1755.0
# 176  0.932113      0.939861              73071.0    449409.0        1755.0
# 209  0.920073      0.935352              73071.0    449409.0       13975.0
# 208  0.920073      0.935352              73071.0    449409.0       13975.0
# 174  0.919381      0.934658              73071.0    449409.0       14247.0
# 175  0.919381      0.934658              73071.0    449409.0       14247.0
# 185  0.896259      0.909730              73071.0    449409.0       26402.0
# 219  0.896259      0.909730              73071.0    449409.0       26402.0
# 199  0.751240      0.738386              73071.0    449409.0        2162.0
# 203  0.751240      0.738386              73071.0    449409.0        2162.0
# 200  0.750139      0.737608              73071.0    449409.0        2163.0
# 204  0.750139      0.737608              73071.0    449409.0        2163.0
# 201  0.750139      0.737594              73071.0    449409.0        2452.0
# 205  0.750139      0.737594              73071.0    449409.0        2452.0
# 202  0.750139      0.737594              73071.0    449409.0        2528.0
# 198  0.750139      0.737594              73071.0    449409.0        2528.0
# 206  0.750139      0.737594              73071.0    449409.0        2528.0
# 223  0.746967      0.730108              73071.0    449409.0        2385.0
# 189  0.746967      0.730108              73071.0    449409.0        2385.0
# 193  0.746628      0.729861              73071.0    449409.0        2385.0
# 227  0.746628      0.729861              73071.0    449409.0        2385.0
# 194  0.745214      0.728863              73071.0    449409.0        2386.0
# 228  0.745214      0.728863              73071.0    449409.0        2386.0
# 229  0.745214      0.728835              73071.0    449409.0        2570.0
# 195  0.745214      0.728835              73071.0    449409.0        2570.0
# 192  0.745214      0.728835              73071.0    449409.0        3051.0
# 226  0.745214      0.728835              73071.0    449409.0        3051.0
# 196  0.745214      0.728835              73071.0    449409.0        3032.0
# 230  0.745214      0.728835              73071.0    449409.0        3032.0
# 190  0.745132      0.728803              73071.0    449409.0        2386.0
# 224  0.745132      0.728803              73071.0    449409.0        2386.0
# 225  0.745132      0.728763              73071.0    449409.0        2570.0
# 191  0.745132      0.728763              73071.0    449409.0        2570.0
# 188  0.745132      0.728763              73071.0    449409.0        3154.0
# 222  0.745132      0.728763              73071.0    449409.0        3154.0
# 220  0.765009      0.720647              73071.0    449409.0        7453.0
# 186  0.764695      0.720388              73071.0    449409.0        7644.0
# 221  0.764255      0.720210              73071.0    449409.0        9836.0
# 187  0.763656      0.719684              73071.0    449409.0       10173.0
# 231  0.768400      0.717247              73071.0    449409.0        9734.0
# 197  0.767399      0.717032              73071.0    449409.0       10038.0
# 207  0.683235      0.657849              73071.0    449409.0       63163.0
#
#      num_output_amplicons  output_mass   ds      rt
# 211               72074.0     448214.0  hmp  single
# 177               72074.0     448214.0  hmp  single
# 215               72347.0     448488.0  hmp  single
# 181               72347.0     448488.0  hmp  single
# 216               73071.0     449409.0  hmp  single
# 182               73071.0     449409.0  hmp  single
# 183               73071.0     449409.0  hmp  single
# 217               73071.0     449409.0  hmp  single
# 214               73071.0     449409.0  hmp  single
# 180               73071.0     449409.0  hmp  single
# 218               73071.0     449409.0  hmp  single
# 184               73071.0     449409.0  hmp  single
# 178               73071.0     449409.0  hmp  single
# 212               73071.0     449409.0  hmp  single
# 179               73071.0     449409.0  hmp  single
# 213               73071.0     449409.0  hmp  single
# 210               73071.0     449409.0  hmp  single
# 176               73071.0     449409.0  hmp  single
# 209               73071.0     449409.0  hmp  single
# 208               73071.0     449409.0  hmp  single
# 174               73071.0     449409.0  hmp  single
# 175               73071.0     449409.0  hmp  single
# 185               73071.0     449409.0  hmp  single
# 219               73071.0     449409.0  hmp  single
# 199               72705.0     448750.0  hmp  single
# 203               72705.0     448750.0  hmp  single
# 200               73071.0     449409.0  hmp  single
# 204               73071.0     449409.0  hmp  single
# 201               73071.0     449409.0  hmp  single
# 205               73071.0     449409.0  hmp  single
# 202               73071.0     449409.0  hmp  single
# 198               73071.0     449409.0  hmp  single
# 206               73071.0     449409.0  hmp  single
# 223               72152.0     448305.0  hmp  single
# 189               72152.0     448305.0  hmp  single
# 193               72405.0     448558.0  hmp  single
# 227               72405.0     448558.0  hmp  single
# 194               73071.0     449409.0  hmp  single
# 228               73071.0     449409.0  hmp  single
# 229               73071.0     449409.0  hmp  single
# 195               73071.0     449409.0  hmp  single
# 192               73071.0     449409.0  hmp  single
# 226               73071.0     449409.0  hmp  single
# 196               73071.0     449409.0  hmp  single
# 230               73071.0     449409.0  hmp  single
# 190               73071.0     449409.0  hmp  single
# 224               73071.0     449409.0  hmp  single
# 225               73071.0     449409.0  hmp  single
# 191               73071.0     449409.0  hmp  single
# 188               73071.0     449409.0  hmp  single
# 222               73071.0     449409.0  hmp  single
# 220               73071.0     449409.0  hmp  single
# 186               73071.0     449409.0  hmp  single
# 221               73071.0     449409.0  hmp  single
# 187               73071.0     449409.0  hmp  single
# 231               73071.0     449409.0  hmp  single
# 197               73071.0     449409.0  hmp  single
# 207               73071.0     449409.0  hmp  single

# %% [markdown]
# Average the maximum values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_max_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#       tool         mode refinement  precision    recall  adjrandindex
# 37  gefast          lev       lsa2   0.986032  0.897712      0.900514
# 41  gefast          lev       lsr2   0.985877  0.897118      0.900024
# 42  gefast          lev       lsr3   0.985675  0.895571      0.898768
# 38  gefast          lev       lsa3   0.985706  0.895508      0.898766
# 43  gefast          lev       lsr4   0.985791  0.895571      0.898752
# 40  gefast          lev       lsr1   0.985898  0.895571      0.898752
# 44  gefast          lev        lss   0.985898  0.895571      0.898752
# 39  gefast          lev       lsa4   0.985824  0.895508      0.898734
# 36  gefast          lev       lsa1   0.986040  0.895508      0.898734
# 3   gefast           as       lsa2   0.982598  0.897969      0.898400
# 7   gefast           as       lsr2   0.982450  0.897393      0.897925
# 34  gefast          lev         2f   0.989431  0.891967      0.897566
# 35  gefast          lev         f1   0.989508  0.891910      0.897541
# 4   gefast           as       lsa3   0.982293  0.895840      0.896729
# 8   gefast           as       lsr3   0.982257  0.895894      0.896725
# 10  gefast           as        lss   0.982475  0.895894      0.896710
# 9   gefast           as       lsr4   0.982368  0.895894      0.896710
# 6   gefast           as       lsr1   0.982473  0.895894      0.896710
# 5   gefast           as       lsa4   0.982407  0.895840      0.896698
# 2   gefast           as       lsa1   0.982613  0.895840      0.896697
# 0   gefast           as         2f   0.985959  0.891884      0.895139
# 1   gefast           as         f1   0.986071  0.891844      0.895137
# 45  gefast          lev         nf   0.989866  0.884666      0.889805
# 11  gefast           as         nf   0.986424  0.885019      0.887767
# 25  gefast      dada2-s       lsa2   0.991212  0.823678      0.815591
# 29  gefast      dada2-s       lsr2   0.991212  0.823678      0.815591
# 26  gefast      dada2-s       lsa3   0.990891  0.822322      0.814373
# 30  gefast      dada2-s       lsr3   0.990891  0.822322      0.814373
# 27  gefast      dada2-s       lsa4   0.991204  0.822322      0.814360
# 31  gefast      dada2-s       lsr4   0.991204  0.822322      0.814360
# 28  gefast      dada2-s       lsr1   0.991226  0.822322      0.814360
# 24  gefast      dada2-s       lsa1   0.991226  0.822322      0.814360
# 32  gefast      dada2-s        lss   0.991226  0.822322      0.814360
# 49  gefast  lev_dada2-c       lsa2   0.993587  0.811517      0.804091
# 53  gefast  lev_dada2-c       lsr2   0.993412  0.810988      0.803644
# 15  gefast   as_dada2-c       lsa2   0.993724  0.811109      0.803547
# 19  gefast   as_dada2-c       lsr2   0.993557  0.810609      0.803130
# 50  gefast  lev_dada2-c       lsa3   0.993040  0.809512      0.802349
# 54  gefast  lev_dada2-c       lsr3   0.992961  0.809542      0.802341
# 55  gefast  lev_dada2-c       lsr4   0.993154  0.809542      0.802320
# 56  gefast  lev_dada2-c        lss   0.993250  0.809542      0.802320
# 52  gefast  lev_dada2-c       lsr1   0.993244  0.809542      0.802320
# 51  gefast  lev_dada2-c       lsa4   0.993198  0.809512      0.802306
# 48  gefast  lev_dada2-c       lsa1   0.993400  0.809512      0.802306
# 20  gefast   as_dada2-c       lsr3   0.993281  0.809065      0.801820
# 16  gefast   as_dada2-c       lsa3   0.993348  0.809021      0.801818
# 21  gefast   as_dada2-c       lsr4   0.993470  0.809065      0.801798
# 18  gefast   as_dada2-c       lsr1   0.993569  0.809065      0.801797
# 22  gefast   as_dada2-c        lss   0.993572  0.809064      0.801797
# 17  gefast   as_dada2-c       lsa4   0.993509  0.809021      0.801774
# 14  gefast   as_dada2-c       lsa1   0.993721  0.809021      0.801773
# 46  gefast  lev_dada2-c         2f   0.991250  0.814595      0.800596
# 47  gefast  lev_dada2-c         f1   0.991559  0.814290      0.800355
# 12  gefast   as_dada2-c         2f   0.991642  0.813804      0.799827
# 13  gefast   as_dada2-c         f1   0.991577  0.813591      0.799449
# 57  gefast  lev_dada2-c         nf   0.990339  0.815264      0.799434
# 23  gefast   as_dada2-c         nf   0.989931  0.814376      0.798255
# 33  gefast      dada2-s         nf   0.998278  0.781501      0.771782

# %% [markdown]
# **Average clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_mean_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: balanced_paired / Tool: gefast
#            data_set        gt    tool         mode refinement  precision  \
# 37  balanced_paired  callahan  gefast          lev       lsa2   0.946551
# 41  balanced_paired  callahan  gefast          lev       lsr2   0.946432
# 45  balanced_paired  callahan  gefast          lev         nf   0.947145
# 35  balanced_paired  callahan  gefast          lev         f1   0.946940
# 38  balanced_paired  callahan  gefast          lev       lsa3   0.946446
# 39  balanced_paired  callahan  gefast          lev       lsa4   0.946519
# 36  balanced_paired  callahan  gefast          lev       lsa1   0.946585
# 42  balanced_paired  callahan  gefast          lev       lsr3   0.946352
# 44  balanced_paired  callahan  gefast          lev        lss   0.946461
# 43  balanced_paired  callahan  gefast          lev       lsr4   0.946424
# 40  balanced_paired  callahan  gefast          lev       lsr1   0.946461
# 34  balanced_paired  callahan  gefast          lev         2f   0.946571
# 3   balanced_paired  callahan  gefast           as       lsa2   0.947748
# 7   balanced_paired  callahan  gefast           as       lsr2   0.947633
# 4   balanced_paired  callahan  gefast           as       lsa3   0.947639
# 5   balanced_paired  callahan  gefast           as       lsa4   0.947714
# 2   balanced_paired  callahan  gefast           as       lsa1   0.947781
# 8   balanced_paired  callahan  gefast           as       lsr3   0.947549
# 1   balanced_paired  callahan  gefast           as         f1   0.948146
# 10  balanced_paired  callahan  gefast           as        lss   0.947662
# 9   balanced_paired  callahan  gefast           as       lsr4   0.947623
# 6   balanced_paired  callahan  gefast           as       lsr1   0.947661
# 11  balanced_paired  callahan  gefast           as         nf   0.948352
# 0   balanced_paired  callahan  gefast           as         2f   0.947776
# 25  balanced_paired  callahan  gefast      dada2-s       lsa2   0.996997
# 29  balanced_paired  callahan  gefast      dada2-s       lsr2   0.996997
# 26  balanced_paired  callahan  gefast      dada2-s       lsa3   0.996440
# 30  balanced_paired  callahan  gefast      dada2-s       lsr3   0.996440
# 27  balanced_paired  callahan  gefast      dada2-s       lsa4   0.996968
# 31  balanced_paired  callahan  gefast      dada2-s       lsr4   0.996968
# 28  balanced_paired  callahan  gefast      dada2-s       lsr1   0.997002
# 24  balanced_paired  callahan  gefast      dada2-s       lsa1   0.997002
# 32  balanced_paired  callahan  gefast      dada2-s        lss   0.997002
# 49  balanced_paired  callahan  gefast  lev_dada2-c       lsa2   0.993293
# 53  balanced_paired  callahan  gefast  lev_dada2-c       lsr2   0.993160
# 15  balanced_paired  callahan  gefast   as_dada2-c       lsa2   0.993427
# 19  balanced_paired  callahan  gefast   as_dada2-c       lsr2   0.993298
# 47  balanced_paired  callahan  gefast  lev_dada2-c         f1   0.993550
# 50  balanced_paired  callahan  gefast  lev_dada2-c       lsa3   0.992768
# 54  balanced_paired  callahan  gefast  lev_dada2-c       lsr3   0.992671
# 51  balanced_paired  callahan  gefast  lev_dada2-c       lsa4   0.993149
# 48  balanced_paired  callahan  gefast  lev_dada2-c       lsa1   0.993296
# 55  balanced_paired  callahan  gefast  lev_dada2-c       lsr4   0.993091
# 56  balanced_paired  callahan  gefast  lev_dada2-c        lss   0.993174
# 52  balanced_paired  callahan  gefast  lev_dada2-c       lsr1   0.993171
# 46  balanced_paired  callahan  gefast  lev_dada2-c         2f   0.993061
# 57  balanced_paired  callahan  gefast  lev_dada2-c         nf   0.993928
# 16  balanced_paired  callahan  gefast   as_dada2-c       lsa3   0.992896
# 20  balanced_paired  callahan  gefast   as_dada2-c       lsr3   0.992801
# 17  balanced_paired  callahan  gefast   as_dada2-c       lsa4   0.993277
# 14  balanced_paired  callahan  gefast   as_dada2-c       lsa1   0.993431
# 21  balanced_paired  callahan  gefast   as_dada2-c       lsr4   0.993222
# 22  balanced_paired  callahan  gefast   as_dada2-c        lss   0.993310
# 18  balanced_paired  callahan  gefast   as_dada2-c       lsr1   0.993308
# 13  balanced_paired  callahan  gefast   as_dada2-c         f1   0.993687
# 12  balanced_paired  callahan  gefast   as_dada2-c         2f   0.993184
# 23  balanced_paired  callahan  gefast   as_dada2-c         nf   0.994066
# 33  balanced_paired  callahan  gefast      dada2-s         nf   0.999243
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
#
# 95   balanced_single  callahan  gefast          lev       lsa2   0.940833
# 93   balanced_single  callahan  gefast          lev         f1   0.942218
# 99   balanced_single  callahan  gefast          lev       lsr2   0.940704
# 103  balanced_single  callahan  gefast          lev         nf   0.942559
# 92   balanced_single  callahan  gefast          lev         2f   0.941508
# 96   balanced_single  callahan  gefast          lev       lsa3   0.940789
# 97   balanced_single  callahan  gefast          lev       lsa4   0.940828
# 94   balanced_single  callahan  gefast          lev       lsa1   0.940867
# 100  balanced_single  callahan  gefast          lev       lsr3   0.940668
# 102  balanced_single  callahan  gefast          lev        lss   0.940733
# 101  balanced_single  callahan  gefast          lev       lsr4   0.940707
# 98   balanced_single  callahan  gefast          lev       lsr1   0.940732
# 61   balanced_single  callahan  gefast           as       lsa2   0.942174
# 65   balanced_single  callahan  gefast           as       lsr2   0.942050
# 59   balanced_single  callahan  gefast           as         f1   0.943533
# 69   balanced_single  callahan  gefast           as         nf   0.943882
# 62   balanced_single  callahan  gefast           as       lsa3   0.942120
# 58   balanced_single  callahan  gefast           as         2f   0.942819
# 63   balanced_single  callahan  gefast           as       lsa4   0.942161
# 60   balanced_single  callahan  gefast           as       lsa1   0.942208
# 66   balanced_single  callahan  gefast           as       lsr3   0.942008
# 68   balanced_single  callahan  gefast           as        lss   0.942078
# 67   balanced_single  callahan  gefast           as       lsr4   0.942048
# 64   balanced_single  callahan  gefast           as       lsr1   0.942079
# 83   balanced_single  callahan  gefast      dada2-s       lsa2   0.995326
# 87   balanced_single  callahan  gefast      dada2-s       lsr2   0.995326
# 84   balanced_single  callahan  gefast      dada2-s       lsa3   0.994979
# 88   balanced_single  callahan  gefast      dada2-s       lsr3   0.994979
# 85   balanced_single  callahan  gefast      dada2-s       lsa4   0.995302
# 89   balanced_single  callahan  gefast      dada2-s       lsr4   0.995302
# 86   balanced_single  callahan  gefast      dada2-s       lsr1   0.995334
# 82   balanced_single  callahan  gefast      dada2-s       lsa1   0.995334
# 90   balanced_single  callahan  gefast      dada2-s        lss   0.995334
# 107  balanced_single  callahan  gefast  lev_dada2-c       lsa2   0.989476
# 111  balanced_single  callahan  gefast  lev_dada2-c       lsr2   0.989332
# 73   balanced_single  callahan  gefast   as_dada2-c       lsa2   0.989775
# 77   balanced_single  callahan  gefast   as_dada2-c       lsr2   0.989635
# 108  balanced_single  callahan  gefast  lev_dada2-c       lsa3   0.989172
# 112  balanced_single  callahan  gefast  lev_dada2-c       lsr3   0.989046
# 109  balanced_single  callahan  gefast  lev_dada2-c       lsa4   0.989400
# 106  balanced_single  callahan  gefast  lev_dada2-c       lsa1   0.989487
# 113  balanced_single  callahan  gefast  lev_dada2-c       lsr4   0.989297
# 110  balanced_single  callahan  gefast  lev_dada2-c       lsr1   0.989347
# 114  balanced_single  callahan  gefast  lev_dada2-c        lss   0.989349
# 105  balanced_single  callahan  gefast  lev_dada2-c         f1   0.990567
# 74   balanced_single  callahan  gefast   as_dada2-c       lsa3   0.989463
# 78   balanced_single  callahan  gefast   as_dada2-c       lsr3   0.989346
# 106  0.884132      0.860504              33523.0    558059.0        1874.2
# 113  0.884150      0.860497              33523.0    558059.0        1610.0
# 110  0.884150      0.860497              33523.0    558059.0        1816.5
# 114  0.884149      0.860497              33523.0    558059.0        1803.4
# 105  0.883869      0.860458              33523.0    558059.0        2928.9
# 74   0.883745      0.860207              33523.0    558059.0        1343.9
# 78   0.883767      0.860201              33523.0    558059.0        1343.9
# 79   0.883767      0.860187              33523.0    558059.0        1639.7
# 76   0.883767      0.860187              33523.0    558059.0        1858.0
# 80   0.883767      0.860186              33523.0    558059.0        1843.1
# 75   0.883745      0.860185              33523.0    558059.0        1639.7
# 72   0.883745      0.860184              33523.0    558059.0        1914.4
# 115  0.883080      0.860166              33523.0    558059.0        3785.1
# 104  0.884068      0.860038              33523.0    558059.0        2426.6
# 71   0.883282      0.859951              33523.0    558059.0        3068.6
# 81   0.882503      0.859672              33523.0    558059.0        3920.1
# 70   0.883573      0.859612              33523.0    558059.0        2510.2
# 91   0.856060      0.840708              33523.0    558059.0       24871.0
#
#      num_output_amplicons  output_mass        ds      rt
# 95                33089.5     557527.5  balanced  single
# 93                33523.0     558059.0  balanced  single
# 99                33244.4     557682.4  balanced  single
# 103               33523.0     558059.0  balanced  single
# 92                33523.0     558059.0  balanced  single
# 96                33523.0     558059.0  balanced  single
# 97                33523.0     558059.0  balanced  single
# 94                33523.0     558059.0  balanced  single
# 100               33523.0     558059.0  balanced  single
# 102               33523.0     558059.0  balanced  single
# 101               33523.0     558059.0  balanced  single
# 98                33523.0     558059.0  balanced  single
# 61                33070.7     557507.6  balanced  single
# 65                33225.3     557662.2  balanced  single
# 59                33523.0     558059.0  balanced  single
# 69                33523.0     558059.0  balanced  single
# 62                33523.0     558059.0  balanced  single
# 58                33523.0     558059.0  balanced  single
# 63                33523.0     558059.0  balanced  single
# 60                33523.0     558059.0  balanced  single
# 66                33523.0     558059.0  balanced  single
# 68                33523.0     558059.0  balanced  single
# 67                33523.0     558059.0  balanced  single
# 64                33523.0     558059.0  balanced  single
# 83                33023.0     557176.0  balanced  single
# 87                33023.0     557176.0  balanced  single
# 84                33523.0     558059.0  balanced  single
# 88                33523.0     558059.0  balanced  single
# 85                33523.0     558059.0  balanced  single
# 89                33523.0     558059.0  balanced  single
# 86                33523.0     558059.0  balanced  single
# 82                33523.0     558059.0  balanced  single
# 90                33523.0     558059.0  balanced  single
# 107               32873.1     557112.4  balanced  single
# 111               33020.1     557259.4  balanced  single
# 73                32859.9     557098.7  balanced  single
# 77                33007.9     557246.7  balanced  single
# 108               33523.0     558059.0  balanced  single
# 112               33523.0     558059.0  balanced  single
# 109               33523.0     558059.0  balanced  single
# 106               33523.0     558059.0  balanced  single
# 113               33523.0     558059.0  balanced  single
# 110               33523.0     558059.0  balanced  single
# 114               33523.0     558059.0  balanced  single
# 105               33523.0     558059.0  balanced  single
# 74                33523.0     558059.0  balanced  single
# 78                33523.0     558059.0  balanced  single
# 79                33523.0     558059.0  balanced  single
# 76                33523.0     558059.0  balanced  single
# 80                33523.0     558059.0  balanced  single
# 75                33523.0     558059.0  balanced  single
# 72                33523.0     558059.0  balanced  single
# 115               33523.0     558059.0  balanced  single
# 104               33523.0     558059.0  balanced  single
# 71                33523.0     558059.0  balanced  single
# 81                33523.0     558059.0  balanced  single
# 70                33523.0     558059.0  balanced  single
# 91                33523.0     558059.0  balanced  single
# Data set: hmp_paired / Tool: gefast
#        data_set        gt    tool         mode refinement  precision  \
# 145  hmp_paired  callahan  gefast      dada2-s       lsr2   0.986338
# 141  hmp_paired  callahan  gefast      dada2-s       lsa2   0.986338
# 142  hmp_paired  callahan  gefast      dada2-s       lsa3   0.986159
# 146  hmp_paired  callahan  gefast      dada2-s       lsr3   0.986159
# 143  hmp_paired  callahan  gefast      dada2-s       lsa4   0.986352
# 147  hmp_paired  callahan  gefast      dada2-s       lsr4   0.986352
# 140  hmp_paired  callahan  gefast      dada2-s       lsa1   0.986361
# 144  hmp_paired  callahan  gefast      dada2-s       lsr1   0.986361
# 148  hmp_paired  callahan  gefast      dada2-s        lss   0.986361
# 153  hmp_paired  callahan  gefast          lev       lsa2   0.951734
# 157  hmp_paired  callahan  gefast          lev       lsr2   0.951606
# 154  hmp_paired  callahan  gefast          lev       lsa3   0.951679
# 155  hmp_paired  callahan  gefast          lev       lsa4   0.951707
# 152  hmp_paired  callahan  gefast          lev       lsa1   0.951795
# 158  hmp_paired  callahan  gefast          lev       lsr3   0.951584
# 159  hmp_paired  callahan  gefast          lev       lsr4   0.951614
# 160  hmp_paired  callahan  gefast          lev        lss   0.951650
# 156  hmp_paired  callahan  gefast          lev       lsr1   0.951649
# 151  hmp_paired  callahan  gefast          lev         f1   0.952290
# 150  hmp_paired  callahan  gefast          lev         2f   0.952078
# 161  hmp_paired  callahan  gefast          lev         nf   0.952473
# 149  hmp_paired  callahan  gefast      dada2-s         nf   0.996195
# 119  hmp_paired  callahan  gefast           as       lsa2   0.947917
# 123  hmp_paired  callahan  gefast           as       lsr2   0.947791
# 165  hmp_paired  callahan  gefast  lev_dada2-c       lsa2   0.985635
# 117  hmp_paired  callahan  gefast           as         f1   0.948865
# 116  hmp_paired  callahan  gefast           as         2f   0.948651
# 120  hmp_paired  callahan  gefast           as       lsa3   0.947848
# 121  hmp_paired  callahan  gefast           as       lsa4   0.947877
# 118  hmp_paired  callahan  gefast           as       lsa1   0.947961
# 124  hmp_paired  callahan  gefast           as       lsr3   0.947756
# 125  hmp_paired  callahan  gefast           as       lsr4   0.947791
# 126  hmp_paired  callahan  gefast           as        lss   0.947822
# 122  hmp_paired  callahan  gefast           as       lsr1   0.947820
# 169  hmp_paired  callahan  gefast  lev_dada2-c       lsr2   0.985486
# 127  hmp_paired  callahan  gefast           as         nf   0.949046
# 131  hmp_paired  callahan  gefast   as_dada2-c       lsa2   0.984664
# 135  hmp_paired  callahan  gefast   as_dada2-c       lsr2   0.984540
# 166  hmp_paired  callahan  gefast  lev_dada2-c       lsa3   0.985270
# 163  hmp_paired  callahan  gefast  lev_dada2-c         f1   0.986018
# 170  hmp_paired  callahan  gefast  lev_dada2-c       lsr3   0.985172
# 167  hmp_paired  callahan  gefast  lev_dada2-c       lsa4   0.985490
# 164  hmp_paired  callahan  gefast  lev_dada2-c       lsa1   0.985676
# 171  hmp_paired  callahan  gefast  lev_dada2-c       lsr4   0.985447
# 172  hmp_paired  callahan  gefast  lev_dada2-c        lss   0.985529
# 168  hmp_paired  callahan  gefast  lev_dada2-c       lsr1   0.985527
# 162  hmp_paired  callahan  gefast  lev_dada2-c         2f   0.985607
# 173  hmp_paired  callahan  gefast  lev_dada2-c         nf   0.986396
# 129  hmp_paired  callahan  gefast   as_dada2-c         f1   0.985728
# 128  hmp_paired  callahan  gefast   as_dada2-c         2f   0.985298
# 132  hmp_paired  callahan  gefast   as_dada2-c       lsa3   0.984397
# 136  hmp_paired  callahan  gefast   as_dada2-c       lsr3   0.984320
# 133  hmp_paired  callahan  gefast   as_dada2-c       lsa4   0.984542
# 130  hmp_paired  callahan  gefast   as_dada2-c       lsa1   0.984690
# 137  hmp_paired  callahan  gefast   as_dada2-c       lsr4   0.984495
# 138  hmp_paired  callahan  gefast   as_dada2-c        lss   0.984566
# 134  hmp_paired  callahan  gefast   as_dada2-c       lsr1   0.984565
# 139  hmp_paired  callahan  gefast   as_dada2-c         nf   0.986116
#
#        recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 145  0.754205      0.741601              19882.0    208157.0         913.0
# 141  0.754205      0.741601              19882.0    208157.0         913.0
# 142  0.752922      0.740803              19882.0    208157.0         914.0
# 146  0.752922      0.740803              19882.0    208157.0         914.0
# 143  0.752922      0.740782              19882.0    208157.0        1079.0
# 147  0.752922      0.740782              19882.0    208157.0        1079.0
# 140  0.752922      0.740782              19882.0    208157.0        1092.0
# 144  0.752922      0.740782              19882.0    208157.0        1092.0
# 148  0.752922      0.740782              19882.0    208157.0        1092.0
# 153  0.727037      0.699770              19882.0    208157.0         491.9
# 157  0.726406      0.699376              19882.0    208157.0         491.9
# 154  0.725402      0.698830              19882.0    208157.0         498.1
# 155  0.725402      0.698801              19882.0    208157.0         572.5
# 152  0.725402      0.698800              19882.0    208157.0         775.8
# 158  0.725418      0.698794              19882.0    208157.0         497.5
# 159  0.725418      0.698783              19882.0    208157.0         571.9
# 160  0.725418      0.698783              19882.0    208157.0         685.1
# 156  0.725418      0.698782              19882.0    208157.0         697.8
# 151  0.725334      0.698748              19882.0    208157.0        1325.0
# 150  0.725361      0.698717              19882.0    208157.0        1152.5
# 161  0.725116      0.698473              19882.0    208157.0        1650.9
# 149  0.705890      0.694222              19882.0    208157.0       15886.0
# 119  0.726843      0.693227              19882.0    208157.0         492.6
# 123  0.726310      0.692871              19882.0    208157.0         492.6
# 165  0.704010      0.692687              19882.0    208157.0        1255.0
# 117  0.725341      0.692513              19882.0    208157.0        1329.7
# 116  0.725369      0.692490              19882.0    208157.0        1154.3
# 120  0.725476      0.692436              19882.0    208157.0         494.0
# 121  0.725476      0.692409              19882.0    208157.0         560.7
# 118  0.725476      0.692408              19882.0    208157.0         727.0
# 124  0.725496      0.692389              19882.0    208157.0         494.0
# 125  0.725496      0.692378              19882.0    208157.0         560.7
# 126  0.725496      0.692378              19882.0    208157.0         649.1
# 122  0.725496      0.692378              19882.0    208157.0         657.3
# 169  0.703439      0.692335              19882.0    208157.0        1255.0
# 127  0.725050      0.692135              19882.0    208157.0        1679.8
# 131  0.703227      0.691474              19882.0    208157.0        1257.2
# 135  0.702725      0.691151              19882.0    208157.0        1257.2
# 166  0.701409      0.691087              19882.0    208157.0        1261.2
# 163  0.701520      0.691064              19882.0    208157.0        2096.0
# 170  0.701418      0.691058              19882.0    208157.0        1260.6
# 167  0.701409      0.691028              19882.0    208157.0        1470.8
# 164  0.701409      0.691027              19882.0    208157.0        1704.0
# 171  0.701418      0.691025              19882.0    208157.0        1469.2
# 172  0.701418      0.691024              19882.0    208157.0        1619.8
# 168  0.701418      0.691024              19882.0    208157.0        1639.1
# 162  0.701556      0.690930              19882.0    208157.0        1921.3
# 173  0.701241      0.690822              19882.0    208157.0        2581.1
# 129  0.701342      0.690471              19882.0    208157.0        2101.0
# 128  0.701377      0.690322              19882.0    208157.0        1923.3
# 132  0.701320      0.690294              19882.0    208157.0        1258.6
# 136  0.701333      0.690264              19882.0    208157.0        1258.6
# 133  0.701320      0.690246              19882.0    208157.0        1401.6
# 130  0.701320      0.690246              19882.0    208157.0        1587.5
# 137  0.701333      0.690240              19882.0    208157.0        1401.5
# 138  0.701333      0.690240              19882.0    208157.0        1512.4
# 134  0.701333      0.690240              19882.0    208157.0        1521.5
# 139  0.700993      0.690137              19882.0    208157.0        2610.5
#
#      num_output_amplicons  output_mass   ds      rt
# 145               19703.0     207803.0  hmp  paired
# 141               19703.0     207803.0  hmp  paired
# 142               19882.0     208157.0  hmp  paired
# 146               19882.0     208157.0  hmp  paired
# 143               19882.0     208157.0  hmp  paired
# 147               19882.0     208157.0  hmp  paired
# 140               19882.0     208157.0  hmp  paired
# 144               19882.0     208157.0  hmp  paired
# 148               19882.0     208157.0  hmp  paired
# 153               19491.6     207689.7  hmp  paired
# 157               19676.1     207874.2  hmp  paired
# 154               19882.0     208157.0  hmp  paired
# 155               19882.0     208157.0  hmp  paired
# 152               19882.0     208157.0  hmp  paired
# 158               19882.0     208157.0  hmp  paired
# 159               19882.0     208157.0  hmp  paired
# 160               19882.0     208157.0  hmp  paired
# 156               19882.0     208157.0  hmp  paired
# 151               19882.0     208157.0  hmp  paired
# 150               19882.0     208157.0  hmp  paired
# 161               19882.0     208157.0  hmp  paired
# 149               19882.0     208157.0  hmp  paired
# 119               19559.5     207766.3  hmp  paired
# 123               19717.3     207924.1  hmp  paired
# 165               19326.8     207387.8  hmp  paired
# 117               19882.0     208157.0  hmp  paired
# 116               19882.0     208157.0  hmp  paired
# 120               19882.0     208157.0  hmp  paired
# 121               19882.0     208157.0  hmp  paired
# 118               19882.0     208157.0  hmp  paired
# 124               19882.0     208157.0  hmp  paired
# 125               19882.0     208157.0  hmp  paired
# 126               19882.0     208157.0  hmp  paired
# 122               19882.0     208157.0  hmp  paired
# 169               19497.9     207558.9  hmp  paired
# 127               19882.0     208157.0  hmp  paired
# 131               19465.5     207592.7  hmp  paired
# 135               19617.7     207744.9  hmp  paired
# 166               19882.0     208157.0  hmp  paired
# 163               19882.0     208157.0  hmp  paired
# 170               19882.0     208157.0  hmp  paired
# 167               19882.0     208157.0  hmp  paired
# 164               19882.0     208157.0  hmp  paired
# 171               19882.0     208157.0  hmp  paired
# 172               19882.0     208157.0  hmp  paired
# 168               19882.0     208157.0  hmp  paired
# 162               19882.0     208157.0  hmp  paired
# 173               19882.0     208157.0  hmp  paired
# 129               19882.0     208157.0  hmp  paired
# 128               19882.0     208157.0  hmp  paired
# 132               19882.0     208157.0  hmp  paired
# 136               19882.0     208157.0  hmp  paired
# 133               19882.0     208157.0  hmp  paired
# 130               19882.0     208157.0  hmp  paired
# 137               19882.0     208157.0  hmp  paired
# 138               19882.0     208157.0  hmp  paired
# 134               19882.0     208157.0  hmp  paired
# 139               19882.0     208157.0  hmp  paired
# Data set: hmp_single / Tool: gefast
#        data_set        gt    tool         mode refinement  precision  \
# 209  hmp_single  callahan  gefast          lev         f1   0.900957
# 211  hmp_single  callahan  gefast          lev       lsa2   0.896731
# 215  hmp_single  callahan  gefast          lev       lsr2   0.896677
# 208  hmp_single  callahan  gefast          lev         2f   0.899183
# 212  hmp_single  callahan  gefast          lev       lsa3   0.896760
# 213  hmp_single  callahan  gefast          lev       lsa4   0.896775
# 210  hmp_single  callahan  gefast          lev       lsa1   0.896830
# 216  hmp_single  callahan  gefast          lev       lsr3   0.896697
# 218  hmp_single  callahan  gefast          lev        lss   0.896744
# 217  hmp_single  callahan  gefast          lev       lsr4   0.896711
# 214  hmp_single  callahan  gefast          lev       lsr1   0.896742
# 219  hmp_single  callahan  gefast          lev         nf   0.902173
# 175  hmp_single  callahan  gefast           as         f1   0.896934
# 177  hmp_single  callahan  gefast           as       lsa2   0.892796
# 181  hmp_single  callahan  gefast           as       lsr2   0.892743
# 174  hmp_single  callahan  gefast           as         2f   0.895185
# 178  hmp_single  callahan  gefast           as       lsa3   0.892806
# 179  hmp_single  callahan  gefast           as       lsa4   0.892822
# 176  hmp_single  callahan  gefast           as       lsa1   0.892894
# 182  hmp_single  callahan  gefast           as       lsr3   0.892759
# 184  hmp_single  callahan  gefast           as        lss   0.892809
# 183  hmp_single  callahan  gefast           as       lsr4   0.892773
# 180  hmp_single  callahan  gefast           as       lsr1   0.892807
# 185  hmp_single  callahan  gefast           as         nf   0.898174
# 199  hmp_single  callahan  gefast      dada2-s       lsa2   0.986186
# 203  hmp_single  callahan  gefast      dada2-s       lsr2   0.986186
# 200  hmp_single  callahan  gefast      dada2-s       lsa3   0.985986
# 204  hmp_single  callahan  gefast      dada2-s       lsr3   0.985986
# 201  hmp_single  callahan  gefast      dada2-s       lsa4   0.986193
# 205  hmp_single  callahan  gefast      dada2-s       lsr4   0.986193
# 202  hmp_single  callahan  gefast      dada2-s       lsr1   0.986206
# 198  hmp_single  callahan  gefast      dada2-s       lsa1   0.986206
# 206  hmp_single  callahan  gefast      dada2-s        lss   0.986206
# 223  hmp_single  callahan  gefast  lev_dada2-c       lsa2   0.951278
# 227  hmp_single  callahan  gefast  lev_dada2-c       lsr2   0.951208
# 224  hmp_single  callahan  gefast  lev_dada2-c       lsa3   0.951185
# 228  hmp_single  callahan  gefast  lev_dada2-c       lsr3   0.951126
# 229  hmp_single  callahan  gefast  lev_dada2-c       lsr4   0.951230
# 230  hmp_single  callahan  gefast  lev_dada2-c        lss   0.951291
# 226  hmp_single  callahan  gefast  lev_dada2-c       lsr1   0.951286
# 225  hmp_single  callahan  gefast  lev_dada2-c       lsa4   0.951261
# 222  hmp_single  callahan  gefast  lev_dada2-c       lsa1   0.951368
# 189  hmp_single  callahan  gefast   as_dada2-c       lsa2   0.950850
# 193  hmp_single  callahan  gefast   as_dada2-c       lsr2   0.950780
# 221  hmp_single  callahan  gefast  lev_dada2-c         f1   0.954981
# 194  hmp_single  callahan  gefast   as_dada2-c       lsr3   0.950696
# 190  hmp_single  callahan  gefast   as_dada2-c       lsa3   0.950743
# 195  hmp_single  callahan  gefast   as_dada2-c       lsr4   0.950800
# 196  hmp_single  callahan  gefast   as_dada2-c        lss   0.950862
# 192  hmp_single  callahan  gefast   as_dada2-c       lsr1   0.950858
# 191  hmp_single  callahan  gefast   as_dada2-c       lsa4   0.950823
# 188  hmp_single  callahan  gefast   as_dada2-c       lsa1   0.950940
# 220  hmp_single  callahan  gefast  lev_dada2-c         2f   0.953044
# 231  hmp_single  callahan  gefast  lev_dada2-c         nf   0.956280
# 187  hmp_single  callahan  gefast   as_dada2-c         f1   0.954478
# 186  hmp_single  callahan  gefast   as_dada2-c         2f   0.952557
# 197  hmp_single  callahan  gefast   as_dada2-c         nf   0.955805
# 207  hmp_single  callahan  gefast      dada2-s         nf   0.998496
#
#        recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 209  0.899345      0.750519              73071.0    449409.0        4298.5
# 211  0.902435      0.749950              73071.0    449409.0         459.3
# 215  0.902064      0.749741              73071.0    449409.0         459.3
# 208  0.900119      0.749594              73071.0    449409.0        3116.4
# 212  0.901267      0.749398              73071.0    449409.0         460.3
# 213  0.901267      0.749387              73071.0    449409.0         528.8
# 210  0.901267      0.749387              73071.0    449409.0         848.6
# 216  0.901291      0.749368              73071.0    449409.0         460.3
# 218  0.901291      0.749363              73071.0    449409.0         752.6
# 217  0.901291      0.749362              73071.0    449409.0         528.6
# 214  0.901291      0.749362              73071.0    449409.0         771.5
# 219  0.895427      0.748276              73071.0    449409.0        6663.9
# 175  0.899915      0.742863              73071.0    449409.0        4338.0
# 177  0.903115      0.742544              73071.0    449409.0         475.8
# 181  0.902739      0.742336              73071.0    449409.0         475.8
# 174  0.900713      0.742051              73071.0    449409.0        3133.9
# 178  0.901937      0.741977              73071.0    449409.0         476.8
# 179  0.901937      0.741966              73071.0    449409.0         545.2
# 176  0.901937      0.741966              73071.0    449409.0         866.8
# 182  0.901974      0.741964              73071.0    449409.0         476.8
# 184  0.901974      0.741960              73071.0    449409.0         766.6
# 183  0.901974      0.741959              73071.0    449409.0         545.0
# 180  0.901974      0.741959              73071.0    449409.0         784.0
# 185  0.896016      0.740704              73071.0    449409.0        6705.0
# 199  0.751240      0.738386              73071.0    449409.0        2162.0
# 203  0.751240      0.738386              73071.0    449409.0        2162.0
# 200  0.750139      0.737608              73071.0    449409.0        2163.0
# 204  0.750139      0.737608              73071.0    449409.0        2163.0
# 201  0.750139      0.737594              73071.0    449409.0        2452.0
# 205  0.750139      0.737594              73071.0    449409.0        2452.0
# 202  0.750139      0.737594              73071.0    449409.0        2528.0
# 198  0.750139      0.737594              73071.0    449409.0        2528.0
# 206  0.750139      0.737594              73071.0    449409.0        2528.0
# 223  0.761209      0.688405              73071.0    449409.0        2315.0
# 227  0.760925      0.688229              73071.0    449409.0        2315.0
# 224  0.759682      0.687512              73071.0    449409.0        2316.0
# 228  0.759693      0.687505              73071.0    449409.0        2316.0
# 229  0.759693      0.687484              73071.0    449409.0        2521.0
# 230  0.759693      0.687484              73071.0    449409.0        2808.7
# 226  0.759693      0.687484              73071.0    449409.0        2836.4
# 225  0.759682      0.687480              73071.0    449409.0        2521.1
# 222  0.759682      0.687480              73071.0    449409.0        2891.8
# 189  0.760684      0.685768              73071.0    449409.0        2331.0
# 193  0.760403      0.685595              73071.0    449409.0        2331.0
# 221  0.758248      0.685278              73071.0    449409.0        6159.6
# 194  0.759188      0.684880              73071.0    449409.0        2332.0
# 190  0.759164      0.684872              73071.0    449409.0        2332.0
# 195  0.759188      0.684860              73071.0    449409.0        2536.8
# 196  0.759188      0.684860              73071.0    449409.0        2817.1
# 192  0.759188      0.684860              73071.0    449409.0        2843.2
# 191  0.759164      0.684841              73071.0    449409.0        2537.0
# 188  0.759164      0.684841              73071.0    449409.0        2903.4
# 220  0.758612      0.684806              73071.0    449409.0        4974.7
# 231  0.756550      0.684657              73071.0    449409.0        8675.5
# 187  0.757629      0.682498              73071.0    449409.0        6198.7
# 186  0.758050      0.682044              73071.0    449409.0        4991.2
# 197  0.755949      0.681932              73071.0    449409.0        8713.4
# 207  0.683235      0.657849              73071.0    449409.0       63163.0
#
#      num_output_amplicons  output_mass   ds      rt
# 209               73071.0     449409.0  hmp  single
# 211               72562.9     448831.2  hmp  single
# 215               72758.8     449027.2  hmp  single
# 208               73071.0     449409.0  hmp  single
# 212               73071.0     449409.0  hmp  single
# 213               73071.0     449409.0  hmp  single
# 210               73071.0     449409.0  hmp  single
# 216               73071.0     449409.0  hmp  single
# 218               73071.0     449409.0  hmp  single
# 217               73071.0     449409.0  hmp  single
# 214               73071.0     449409.0  hmp  single
# 219               73071.0     449409.0  hmp  single
# 175               73071.0     449409.0  hmp  single
# 177               72558.5     448826.9  hmp  single
# 181               72762.8     449031.3  hmp  single
# 174               73071.0     449409.0  hmp  single
# 178               73071.0     449409.0  hmp  single
# 179               73071.0     449409.0  hmp  single
# 176               73071.0     449409.0  hmp  single
# 182               73071.0     449409.0  hmp  single
# 184               73071.0     449409.0  hmp  single
# 183               73071.0     449409.0  hmp  single
# 180               73071.0     449409.0  hmp  single
# 185               73071.0     449409.0  hmp  single
# 199               72705.0     448750.0  hmp  single
# 203               72705.0     448750.0  hmp  single
# 200               73071.0     449409.0  hmp  single
# 204               73071.0     449409.0  hmp  single
# 201               73071.0     449409.0  hmp  single
# 205               73071.0     449409.0  hmp  single
# 202               73071.0     449409.0  hmp  single
# 198               73071.0     449409.0  hmp  single
# 206               73071.0     449409.0  hmp  single
# 223               72376.2     448508.0  hmp  single
# 227               72549.6     448681.4  hmp  single
# 224               73071.0     449409.0  hmp  single
# 228               73071.0     449409.0  hmp  single
# 229               73071.0     449409.0  hmp  single
# 230               73071.0     449409.0  hmp  single
# 226               73071.0     449409.0  hmp  single
# 225               73071.0     449409.0  hmp  single
# 222               73071.0     449409.0  hmp  single
# 189               72379.3     448511.2  hmp  single
# 193               72558.8     448690.7  hmp  single
# 221               73071.0     449409.0  hmp  single
# 194               73071.0     449409.0  hmp  single
# 190               73071.0     449409.0  hmp  single
# 195               73071.0     449409.0  hmp  single
# 196               73071.0     449409.0  hmp  single
# 192               73071.0     449409.0  hmp  single
# 191               73071.0     449409.0  hmp  single
# 188               73071.0     449409.0  hmp  single
# 220               73071.0     449409.0  hmp  single
# 231               73071.0     449409.0  hmp  single
# 187               73071.0     449409.0  hmp  single
# 186               73071.0     449409.0  hmp  single
# 197               73071.0     449409.0  hmp  single
# 207               73071.0     449409.0  hmp  single

# %% [markdown]
# Average the mean values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_mean_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#       tool         mode refinement  precision    recall  adjrandindex
# 37  gefast          lev       lsa2   0.933962  0.891738      0.824393
# 41  gefast          lev       lsr2   0.933855  0.891349      0.824064
# 35  gefast          lev         f1   0.935601  0.889922      0.823938
# 34  gefast          lev         2f   0.934835  0.890172      0.823531
# 38  gefast          lev       lsa3   0.933918  0.890531      0.823508
# 39  gefast          lev       lsa4   0.933957  0.890531      0.823493
# 36  gefast          lev       lsa1   0.934019  0.890531      0.823492
# 42  gefast          lev       lsr3   0.933825  0.890553      0.823462
# 44  gefast          lev        lss   0.933897  0.890553      0.823456
# 43  gefast          lev       lsr4   0.933864  0.890553      0.823455
# 40  gefast          lev       lsr1   0.933896  0.890553      0.823455
# 45  gefast          lev         nf   0.936087  0.888662      0.823218
# 3   gefast           as       lsa2   0.932659  0.889832      0.819548
# 7   gefast           as       lsr2   0.932554  0.889470      0.819234
# 1   gefast           as         f1   0.934370  0.887964      0.819017
# 4   gefast           as       lsa3   0.932603  0.888685      0.818687
# 5   gefast           as       lsa4   0.932643  0.888685      0.818672
# 2   gefast           as       lsa1   0.932711  0.888684      0.818672
# 0   gefast           as         2f   0.933608  0.888247      0.818664
# 8   gefast           as       lsr3   0.932518  0.888711      0.818647
# 10  gefast           as        lss   0.932593  0.888710      0.818640
# 9   gefast           as       lsr4   0.932559  0.888711      0.818640
# 6   gefast           as       lsr1   0.932592  0.888711      0.818640
# 11  gefast           as         nf   0.934864  0.886670      0.818279
# 25  gefast      dada2-s       lsa2   0.991212  0.823678      0.815591
# 29  gefast      dada2-s       lsr2   0.991212  0.823678      0.815591
# 26  gefast      dada2-s       lsa3   0.990891  0.822322      0.814373
# 30  gefast      dada2-s       lsr3   0.990891  0.822322      0.814373
# 27  gefast      dada2-s       lsa4   0.991204  0.822322      0.814360
# 31  gefast      dada2-s       lsr4   0.991204  0.822322      0.814360
# 28  gefast      dada2-s       lsr1   0.991226  0.822322      0.814360
# 24  gefast      dada2-s       lsa1   0.991226  0.822322      0.814360
# 32  gefast      dada2-s        lss   0.991226  0.822322      0.814360
# 49  gefast  lev_dada2-c       lsa2   0.979920  0.813471      0.787847
# 53  gefast  lev_dada2-c       lsr2   0.979797  0.813138      0.787569
# 15  gefast   as_dada2-c       lsa2   0.979679  0.812982      0.786667
# 19  gefast   as_dada2-c       lsr2   0.979563  0.812668      0.786399
# 50  gefast  lev_dada2-c       lsa3   0.979599  0.811620      0.786336
# 54  gefast  lev_dada2-c       lsr3   0.979504  0.811633      0.786321
# 51  gefast  lev_dada2-c       lsa4   0.979825  0.811620      0.786305
# 48  gefast  lev_dada2-c       lsa1   0.979957  0.811619      0.786305
# 55  gefast  lev_dada2-c       lsr4   0.979766  0.811633      0.786303
# 56  gefast  lev_dada2-c        lss   0.979836  0.811632      0.786303
# 52  gefast  lev_dada2-c       lsr1   0.979833  0.811632      0.786303
# 47  gefast  lev_dada2-c         f1   0.981279  0.811291      0.785767
# 46  gefast  lev_dada2-c         2f   0.980367  0.811464      0.785460
# 57  gefast  lev_dada2-c         nf   0.981948  0.810428      0.785404
# 16  gefast   as_dada2-c       lsa3   0.979375  0.811297      0.785251
# 20  gefast   as_dada2-c       lsr3   0.979291  0.811316      0.785242
# 21  gefast   as_dada2-c       lsr4   0.979528  0.811316      0.785227
# 22  gefast   as_dada2-c        lss   0.979598  0.811316      0.785227
# 18  gefast   as_dada2-c       lsr1   0.979596  0.811316      0.785227
# 17  gefast   as_dada2-c       lsa4   0.979584  0.811297      0.785223
# 14  gefast   as_dada2-c       lsa1   0.979712  0.811297      0.785223
# 13  gefast   as_dada2-c         f1   0.981185  0.810854      0.784633
# 12  gefast   as_dada2-c         2f   0.980267  0.811072      0.784349
# 23  gefast   as_dada2-c         nf   0.981865  0.809954      0.784245
# 33  gefast      dada2-s         nf   0.998278  0.781501      0.771782

# %% [markdown]
# **N-best average clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_nbest_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: balanced_paired / Tool: gefast
#            data_set        gt    tool         mode refinement  precision  \
# 37  balanced_paired  callahan  gefast          lev       lsa2   0.966947
# 41  balanced_paired  callahan  gefast          lev       lsr2   0.966812
# 35  balanced_paired  callahan  gefast          lev         f1   0.967464
# 38  balanced_paired  callahan  gefast          lev       lsa3   0.966776
# 45  balanced_paired  callahan  gefast          lev         nf   0.967655
# 39  balanced_paired  callahan  gefast          lev       lsa4   0.966880
# 36  balanced_paired  callahan  gefast          lev       lsa1   0.966974
# 42  balanced_paired  callahan  gefast          lev       lsr3   0.966678
# 44  balanced_paired  callahan  gefast          lev        lss   0.966837
# 43  balanced_paired  callahan  gefast          lev       lsr4   0.966783
# 40  balanced_paired  callahan  gefast          lev       lsr1   0.966837
# 34  balanced_paired  callahan  gefast          lev         2f   0.967176
# 3   balanced_paired  callahan  gefast           as       lsa2   0.963113
# 7   balanced_paired  callahan  gefast           as       lsr2   0.962977
# 1   balanced_paired  callahan  gefast           as         f1   0.963584
# 11  balanced_paired  callahan  gefast           as         nf   0.963767
# 4   balanced_paired  callahan  gefast           as       lsa3   0.963008
# 5   balanced_paired  callahan  gefast           as       lsa4   0.963072
# 2   balanced_paired  callahan  gefast           as       lsa1   0.963146
# 0   balanced_paired  callahan  gefast           as         2f   0.963255
# 8   balanced_paired  callahan  gefast           as       lsr3   0.962900
# 10  balanced_paired  callahan  gefast           as        lss   0.963009
# 9   balanced_paired  callahan  gefast           as       lsr4   0.962972
# 6   balanced_paired  callahan  gefast           as       lsr1   0.963008
# 49  balanced_paired  callahan  gefast  lev_dada2-c       lsa2   0.995431
# 53  balanced_paired  callahan  gefast  lev_dada2-c       lsr2   0.995269
# 15  balanced_paired  callahan  gefast   as_dada2-c       lsa2   0.995599
# 29  balanced_paired  callahan  gefast      dada2-s       lsr2   0.996997
# 25  balanced_paired  callahan  gefast      dada2-s       lsa2   0.996997
# 19  balanced_paired  callahan  gefast   as_dada2-c       lsr2   0.995440
# 47  balanced_paired  callahan  gefast  lev_dada2-c         f1   0.995893
# 46  balanced_paired  callahan  gefast  lev_dada2-c         2f   0.995529
# 50  balanced_paired  callahan  gefast  lev_dada2-c       lsa3   0.994939
# 54  balanced_paired  callahan  gefast  lev_dada2-c       lsr3   0.994815
# 51  balanced_paired  callahan  gefast  lev_dada2-c       lsa4   0.995254
# 48  balanced_paired  callahan  gefast  lev_dada2-c       lsa1   0.995427
# 55  balanced_paired  callahan  gefast  lev_dada2-c       lsr4   0.995179
# 56  balanced_paired  callahan  gefast  lev_dada2-c        lss   0.995282
# 52  balanced_paired  callahan  gefast  lev_dada2-c       lsr1   0.995277
# 57  balanced_paired  callahan  gefast  lev_dada2-c         nf   0.996141
# 12  balanced_paired  callahan  gefast   as_dada2-c         2f   0.995693
# 13  balanced_paired  callahan  gefast   as_dada2-c         f1   0.996080
# 16  balanced_paired  callahan  gefast   as_dada2-c       lsa3   0.995096
# 20  balanced_paired  callahan  gefast   as_dada2-c       lsr3   0.994975
# 17  balanced_paired  callahan  gefast   as_dada2-c       lsa4   0.995412
# 14  balanced_paired  callahan  gefast   as_dada2-c       lsa1   0.995595
# 21  balanced_paired  callahan  gefast   as_dada2-c       lsr4   0.995339
# 22  balanced_paired  callahan  gefast   as_dada2-c        lss   0.995451
# 18               21808.0     467652.0  balanced  paired
# 26               21808.0     467652.0  balanced  paired
# 30               21808.0     467652.0  balanced  paired
# 27               21808.0     467652.0  balanced  paired
# 31               21808.0     467652.0  balanced  paired
# 24               21808.0     467652.0  balanced  paired
# 32               21808.0     467652.0  balanced  paired
# 28               21808.0     467652.0  balanced  paired
# 23               21808.0     467652.0  balanced  paired
# 33               21808.0     467652.0  balanced  paired
# Data set: balanced_single / Tool: gefast
#             data_set        gt    tool         mode refinement  precision  \
# 95   balanced_single  callahan  gefast          lev       lsa2   0.964540
# 99   balanced_single  callahan  gefast          lev       lsr2   0.964385
# 93   balanced_single  callahan  gefast          lev         f1   0.966394
# 92   balanced_single  callahan  gefast          lev         2f   0.965798
# 96   balanced_single  callahan  gefast          lev       lsa3   0.964420
# 97   balanced_single  callahan  gefast          lev       lsa4   0.964494
# 94   balanced_single  callahan  gefast          lev       lsa1   0.964567
# 100  balanced_single  callahan  gefast          lev       lsr3   0.964293
# 102  balanced_single  callahan  gefast          lev        lss   0.964413
# 101  balanced_single  callahan  gefast          lev       lsr4   0.964366
# 98   balanced_single  callahan  gefast          lev       lsr1   0.964413
# 103  balanced_single  callahan  gefast          lev         nf   0.966748
# 61   balanced_single  callahan  gefast           as       lsa2   0.966797
# 65   balanced_single  callahan  gefast           as       lsr2   0.966641
# 59   balanced_single  callahan  gefast           as         f1   0.968780
# 58   balanced_single  callahan  gefast           as         2f   0.968168
# 62   balanced_single  callahan  gefast           as       lsa3   0.966654
# 63   balanced_single  callahan  gefast           as       lsa4   0.966735
# 60   balanced_single  callahan  gefast           as       lsa1   0.966825
# 66   balanced_single  callahan  gefast           as       lsr3   0.966533
# 67   balanced_single  callahan  gefast           as       lsr4   0.966611
# 64   balanced_single  callahan  gefast           as       lsr1   0.966671
# 68   balanced_single  callahan  gefast           as        lss   0.966669
# 69   balanced_single  callahan  gefast           as         nf   0.969098
# 83   balanced_single  callahan  gefast      dada2-s       lsa2   0.995326
# 87   balanced_single  callahan  gefast      dada2-s       lsr2   0.995326
# 107  balanced_single  callahan  gefast  lev_dada2-c       lsa2   0.993781
# 111  balanced_single  callahan  gefast  lev_dada2-c       lsr2   0.993590
# 84   balanced_single  callahan  gefast      dada2-s       lsa3   0.994979
# 88   balanced_single  callahan  gefast      dada2-s       lsr3   0.994979
# 85   balanced_single  callahan  gefast      dada2-s       lsa4   0.995302
# 89   balanced_single  callahan  gefast      dada2-s       lsr4   0.995302
# 86   balanced_single  callahan  gefast      dada2-s       lsr1   0.995334
# 82   balanced_single  callahan  gefast      dada2-s       lsa1   0.995334
# 90   balanced_single  callahan  gefast      dada2-s        lss   0.995334
# 73   balanced_single  callahan  gefast   as_dada2-c       lsa2   0.993968
# 77   balanced_single  callahan  gefast   as_dada2-c       lsr2   0.993780
# 108  balanced_single  callahan  gefast  lev_dada2-c       lsa3   0.993473
# 112  balanced_single  callahan  gefast  lev_dada2-c       lsr3   0.993322
# 113  balanced_single  callahan  gefast  lev_dada2-c       lsr4   0.993529
# 110  balanced_single  callahan  gefast  lev_dada2-c       lsr1   0.993599
# 114  balanced_single  callahan  gefast  lev_dada2-c        lss   0.993602
# 109  balanced_single  callahan  gefast  lev_dada2-c       lsa4   0.993654
# 106  balanced_single  callahan  gefast  lev_dada2-c       lsa1   0.993779
# 105  balanced_single  callahan  gefast  lev_dada2-c         f1   0.995748
# 104  balanced_single  callahan  gefast  lev_dada2-c         2f   0.995097
# 115  balanced_single  callahan  gefast  lev_dada2-c         nf   0.994252
# 78   balanced_single  callahan  gefast   as_dada2-c       lsr3   0.993508
# 74   balanced_single  callahan  gefast   as_dada2-c       lsa3   0.993649
# 79   balanced_single  callahan  gefast   as_dada2-c       lsr4   0.993712
# 76   balanced_single  callahan  gefast   as_dada2-c       lsr1   0.993789
# 80   balanced_single  callahan  gefast   as_dada2-c        lss   0.993792
# 75   balanced_single  callahan  gefast   as_dada2-c       lsa4   0.993833
# 72   balanced_single  callahan  gefast   as_dada2-c       lsa1   0.993966
# 70   balanced_single  callahan  gefast   as_dada2-c         2f   0.995288
# 71   balanced_single  callahan  gefast   as_dada2-c         f1   0.995952
# 81   balanced_single  callahan  gefast   as_dada2-c         nf   0.994471
# 91   balanced_single  callahan  gefast      dada2-s         nf   0.999178
#
#        recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 95   0.961127      0.940269              33523.0    558059.0         546.2
# 99   0.960815      0.939844              33523.0    558059.0         546.2
# 93   0.959105      0.939624              33523.0    558059.0        2881.6
# 92   0.959347      0.939299              33523.0    558059.0        2371.4
# 96   0.959849      0.938924              33523.0    558059.0         547.2
# 97   0.959849      0.938908              33523.0    558059.0         692.0
# 94   0.959849      0.938907              33523.0    558059.0        1027.2
# 100  0.959883      0.938861              33523.0    558059.0         547.2
# 102  0.959883      0.938852              33523.0    558059.0         929.4
# 101  0.959883      0.938852              33523.0    558059.0         692.0
# 98   0.959883      0.938852              33523.0    558059.0         943.6
# 103  0.957779      0.938556              33523.0    558059.0        3892.2
# 61   0.953355      0.935307              33523.0    558059.0         695.8
# 65   0.953025      0.934877              33523.0    558059.0         695.8
# 59   0.950795      0.934156              33523.0    558059.0        3409.6
# 58   0.951229      0.933976              33523.0    558059.0        2771.4
# 62   0.951952      0.933826              33523.0    558059.0         696.8
# 63   0.951952      0.933807              33523.0    558059.0         848.8
# 60   0.951952      0.933806              33523.0    558059.0        1235.4
# 66   0.951997      0.933793              33523.0    558059.0         696.8
# 67   0.951997      0.933782              33523.0    558059.0         848.8
# 64   0.951997      0.933782              33523.0    558059.0        1145.2
# 68   0.951996      0.933782              33523.0    558059.0        1128.6
# 69   0.949460      0.933077              33523.0    558059.0        4423.2
# 83   0.886533      0.870426              33523.0    558059.0        1136.0
# 87   0.886533      0.870426              33523.0    558059.0        1136.0
# 107  0.887450      0.869891              33523.0    558059.0        1415.2
# 111  0.887150      0.869505              33523.0    558059.0        1415.2
# 84   0.885130      0.868859              33523.0    558059.0        1137.0
# 88   0.885130      0.868859              33523.0    558059.0        1137.0
# 85   0.885130      0.868845              33523.0    558059.0        1519.0
# 108               33523.0     558059.0  balanced  single
# 112               33523.0     558059.0  balanced  single
# 113               33523.0     558059.0  balanced  single
# 110               33523.0     558059.0  balanced  single
# 114               33523.0     558059.0  balanced  single
# 109               33523.0     558059.0  balanced  single
# 106               33523.0     558059.0  balanced  single
# 105               33523.0     558059.0  balanced  single
# 104               33523.0     558059.0  balanced  single
# 115               33523.0     558059.0  balanced  single
# 78                33523.0     558059.0  balanced  single
# 74                33523.0     558059.0  balanced  single
# 79                33523.0     558059.0  balanced  single
# 76                33523.0     558059.0  balanced  single
# 80                33523.0     558059.0  balanced  single
# 75                33523.0     558059.0  balanced  single
# 72                33523.0     558059.0  balanced  single
# 70                33523.0     558059.0  balanced  single
# 71                33523.0     558059.0  balanced  single
# 81                33523.0     558059.0  balanced  single
# 91                33523.0     558059.0  balanced  single
# Data set: hmp_paired / Tool: gefast
#        data_set        gt    tool         mode refinement  precision  \
# 145  hmp_paired  callahan  gefast      dada2-s       lsr2   0.986338
# 141  hmp_paired  callahan  gefast      dada2-s       lsa2   0.986338
# 146  hmp_paired  callahan  gefast      dada2-s       lsr3   0.986159
# 142  hmp_paired  callahan  gefast      dada2-s       lsa3   0.986159
# 143  hmp_paired  callahan  gefast      dada2-s       lsa4   0.986352
# 147  hmp_paired  callahan  gefast      dada2-s       lsr4   0.986352
# 140  hmp_paired  callahan  gefast      dada2-s       lsa1   0.986361
# 144  hmp_paired  callahan  gefast      dada2-s       lsr1   0.986361
# 148  hmp_paired  callahan  gefast      dada2-s        lss   0.986361
# 153  hmp_paired  callahan  gefast          lev       lsa2   0.981075
# 119  hmp_paired  callahan  gefast           as       lsa2   0.980792
# 157  hmp_paired  callahan  gefast          lev       lsr2   0.980900
# 123  hmp_paired  callahan  gefast           as       lsr2   0.980628
# 154  hmp_paired  callahan  gefast          lev       lsa3   0.980878
# 158  hmp_paired  callahan  gefast          lev       lsr3   0.980803
# 155  hmp_paired  callahan  gefast          lev       lsa4   0.980934
# 152  hmp_paired  callahan  gefast          lev       lsa1   0.981105
# 159  hmp_paired  callahan  gefast          lev       lsr4   0.980861
# 160  hmp_paired  callahan  gefast          lev        lss   0.980929
# 156  hmp_paired  callahan  gefast          lev       lsr1   0.980926
# 150  hmp_paired  callahan  gefast          lev         2f   0.981680
# 151  hmp_paired  callahan  gefast          lev         f1   0.981847
# 120  hmp_paired  callahan  gefast           as       lsa3   0.980596
# 121  hmp_paired  callahan  gefast           as       lsa4   0.980655
# 124  hmp_paired  callahan  gefast           as       lsr3   0.980527
# 118  hmp_paired  callahan  gefast           as       lsa1   0.980815
# 116  hmp_paired  callahan  gefast           as         2f   0.981704
# 126  hmp_paired  callahan  gefast           as        lss   0.980651
# 125  hmp_paired  callahan  gefast           as       lsr4   0.980591
# 122  hmp_paired  callahan  gefast           as       lsr1   0.980648
# 117  hmp_paired  callahan  gefast           as         f1   0.981876
# 161  hmp_paired  callahan  gefast          lev         nf   0.982059
# 127  hmp_paired  callahan  gefast           as         nf   0.982091
# 165  hmp_paired  callahan  gefast  lev_dada2-c       lsa2   0.990502
# 131  hmp_paired  callahan  gefast   as_dada2-c       lsa2   0.990071
# 169  hmp_paired  callahan  gefast  lev_dada2-c       lsr2   0.990309
# 135  hmp_paired  callahan  gefast   as_dada2-c       lsr2   0.989902
# 149  hmp_paired  callahan  gefast      dada2-s         nf   0.996195
# 162  hmp_paired  callahan  gefast  lev_dada2-c         2f   0.991059
# 166  hmp_paired  callahan  gefast  lev_dada2-c       lsa3   0.990084
# 163  hmp_paired  callahan  gefast  lev_dada2-c         f1   0.991268
# 170  hmp_paired  callahan  gefast  lev_dada2-c       lsr3   0.989999
# 171  hmp_paired  callahan  gefast  lev_dada2-c       lsr4   0.990235
# 172  hmp_paired  callahan  gefast  lev_dada2-c        lss   0.990339
# 168  hmp_paired  callahan  gefast  lev_dada2-c       lsr1   0.990335
# 167  hmp_paired  callahan  gefast  lev_dada2-c       lsa4   0.990273
# 164  hmp_paired  callahan  gefast  lev_dada2-c       lsa1   0.990523
# 128  hmp_paired  callahan  gefast   as_dada2-c         2f   0.991087
# 129  hmp_paired  callahan  gefast   as_dada2-c         f1   0.991307
# 132  hmp_paired  callahan  gefast   as_dada2-c       lsa3   0.989696
# 136  hmp_paired  callahan  gefast   as_dada2-c       lsr3   0.989628
# 137  hmp_paired  callahan  gefast   as_dada2-c       lsr4   0.989829
# 138  hmp_paired  callahan  gefast   as_dada2-c        lss   0.989924
# 134  hmp_paired  callahan  gefast   as_dada2-c       lsr1   0.989922
# 133  hmp_paired  callahan  gefast   as_dada2-c       lsa4   0.989865
# 130  hmp_paired  callahan  gefast   as_dada2-c       lsa1   0.990086
# 173  hmp_paired  callahan  gefast  lev_dada2-c         nf   0.991539
# 139  hmp_paired  callahan  gefast   as_dada2-c         nf   0.991572
#
#        recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 145  0.754205      0.741601              19882.0    208157.0         913.0
# 141  0.754205      0.741601              19882.0    208157.0         913.0
# 146  0.752922      0.740803              19882.0    208157.0         914.0
# 142  0.752922      0.740803              19882.0    208157.0         914.0
# 143  0.752922      0.740782              19882.0    208157.0        1079.0
# 147  0.752922      0.740782              19882.0    208157.0        1079.0
# 140  0.752922      0.740782              19882.0    208157.0        1092.0
# 144  0.752922      0.740782              19882.0    208157.0        1092.0
# 148  0.752922      0.740782              19882.0    208157.0        1092.0
# 153  0.728161      0.731974              19882.0    208157.0         610.0
# 119  0.727920      0.731631              19882.0    208157.0         616.6
# 157  0.727263      0.731397              19882.0    208157.0         610.0
# 123  0.727117      0.731098              19882.0    208157.0         616.6
# 154  0.725842      0.730574              19882.0    208157.0         617.2
# 158  0.725865      0.730530              19882.0    208157.0         617.0
# 155  0.725842      0.730526              19882.0    208157.0         722.6
# 152  0.725842      0.730525              19882.0    208157.0        1015.2
# 159  0.725865      0.730510              19882.0    208157.0         722.4
# 160  0.725865      0.730510              19882.0    208157.0         886.0
# 156  0.725865      0.730510              19882.0    208157.0         901.4
# 150  0.725755      0.730431              19882.0    208157.0        1675.8
# 151  0.725712      0.730409              19882.0    208157.0        1851.2
# 120  0.725815      0.730360              19882.0    208157.0         618.4
# 121  0.725815      0.730312              19882.0    208157.0         719.4
# 124  0.725844      0.730312              19882.0    208157.0         618.4
# 118  0.725815      0.730311              19882.0    208157.0         981.0
# 116  0.725625      0.730293              19882.0    208157.0        1696.4
# 126  0.725844      0.730292              19882.0    208157.0         864.0
# 125  0.725844      0.730292              19882.0    208157.0         719.4
# 122  0.725844      0.730292              19882.0    208157.0         877.4
# 117  0.725580      0.730258              19882.0    208157.0        1878.8
# 161  0.725281      0.729778              19882.0    208157.0        2444.0
# 127  0.725002      0.729426              19882.0    208157.0        2517.4
# 165  0.704404      0.695579              19882.0    208157.0        1283.0
# 131  0.703980      0.695147              19882.0    208157.0        1289.4
# 169  0.703574      0.695063              19882.0    208157.0        1283.0
# 135  0.703226      0.694666              19882.0    208157.0        1289.4
# 149  0.705890      0.694222              19882.0    208157.0       15886.0
# 162  0.701619      0.693805              19882.0    208157.0        2357.6
# 166  0.701497      0.693785              19882.0    208157.0        1290.2
# 163  0.701555      0.693757              19882.0    208157.0        2535.6
# 170  0.701512      0.693748              19882.0    208157.0        1290.0
# 171  0.701512      0.693712              19882.0    208157.0        1477.2
# 172  0.701512      0.693712              19882.0    208157.0        1677.8
# 168  0.701512      0.693712              19882.0    208157.0        1699.6
# 167  0.701497      0.693711              19882.0    208157.0        1478.4
# 164  0.701497      0.693710              19882.0    208157.0        1800.0
# 128  0.701520      0.693699              19882.0    208157.0        2375.8
# 129  0.701452      0.693648              19882.0    208157.0        2560.6
# 132  0.701492      0.693608              19882.0    208157.0        1291.2
# 136  0.701515      0.693574              19882.0    208157.0        1291.2
# 137  0.701515      0.693544              19882.0    208157.0        1447.6
# 138  0.701515      0.693543              19882.0    208157.0        1618.0
# 134  0.701515      0.693543              19882.0    208157.0        1634.2
# 133  0.701492      0.693541              19882.0    208157.0        1448.0
# 130  0.701492      0.693540              19882.0    208157.0        1731.0
# 173  0.701171      0.693267              19882.0    208157.0        3259.6
# 139  0.700928      0.692960              19882.0    208157.0        3329.2
#
#      num_output_amplicons  output_mass   ds      rt
# 145               19703.0     207803.0  hmp  paired
# 141               19703.0     207803.0  hmp  paired
# 146               19882.0     208157.0  hmp  paired
# 142               19882.0     208157.0  hmp  paired
# 143               19882.0     208157.0  hmp  paired
# 147               19882.0     208157.0  hmp  paired
# 140               19882.0     208157.0  hmp  paired
# 144               19882.0     208157.0  hmp  paired
# 148               19882.0     208157.0  hmp  paired
# 153               19328.0     207494.6  hmp  paired
# 119               19384.0     207556.0  hmp  paired
# 157               19590.6     207757.2  hmp  paired
# 123               19621.2     207793.2  hmp  paired
# 154               19882.0     208157.0  hmp  paired
# 158               19882.0     208157.0  hmp  paired
# 155               19882.0     208157.0  hmp  paired
# 152               19882.0     208157.0  hmp  paired
# 159               19882.0     208157.0  hmp  paired
# 160               19882.0     208157.0  hmp  paired
# 156               19882.0     208157.0  hmp  paired
# 150               19882.0     208157.0  hmp  paired
# 151               19882.0     208157.0  hmp  paired
# 120               19882.0     208157.0  hmp  paired
# 121               19882.0     208157.0  hmp  paired
# 124               19882.0     208157.0  hmp  paired
# 118               19882.0     208157.0  hmp  paired
# 116               19882.0     208157.0  hmp  paired
# 126               19882.0     208157.0  hmp  paired
# 125               19882.0     208157.0  hmp  paired
# 122               19882.0     208157.0  hmp  paired
# 117               19882.0     208157.0  hmp  paired
# 161               19882.0     208157.0  hmp  paired
# 127               19882.0     208157.0  hmp  paired
# 165               19216.8     207298.2  hmp  paired
# 131               19308.0     207421.4  hmp  paired
# 169               19465.4     207546.8  hmp  paired
# 135               19537.2     207650.6  hmp  paired
# 149               19882.0     208157.0  hmp  paired
# 162               19882.0     208157.0  hmp  paired
# 166               19882.0     208157.0  hmp  paired
# 163               19882.0     208157.0  hmp  paired
# 170               19882.0     208157.0  hmp  paired
# 171               19882.0     208157.0  hmp  paired
# 172               19882.0     208157.0  hmp  paired
# 168               19882.0     208157.0  hmp  paired
# 167               19882.0     208157.0  hmp  paired
# 164               19882.0     208157.0  hmp  paired
# 128               19882.0     208157.0  hmp  paired
# 129               19882.0     208157.0  hmp  paired
# 132               19882.0     208157.0  hmp  paired
# 136               19882.0     208157.0  hmp  paired
# 137               19882.0     208157.0  hmp  paired
# 138               19882.0     208157.0  hmp  paired
# 134               19882.0     208157.0  hmp  paired
# 133               19882.0     208157.0  hmp  paired
# 130               19882.0     208157.0  hmp  paired
# 173               19882.0     208157.0  hmp  paired
# 139               19882.0     208157.0  hmp  paired
# Data set: hmp_single / Tool: gefast
#        data_set        gt    tool         mode refinement  precision  \
# 209  hmp_single  callahan  gefast          lev         f1   0.949753
# 175  hmp_single  callahan  gefast           as         f1   0.950014
# 177  hmp_single  callahan  gefast           as       lsa2   0.943352
# 211  hmp_single  callahan  gefast          lev       lsa2   0.943099
# 208  hmp_single  callahan  gefast          lev         2f   0.947777
# 181  hmp_single  callahan  gefast           as       lsr2   0.943276
# 215  hmp_single  callahan  gefast          lev       lsr2   0.943025
# 174  hmp_single  callahan  gefast           as         2f   0.947978
# 182  hmp_single  callahan  gefast           as       lsr3   0.943234
# 184  hmp_single  callahan  gefast           as        lss   0.943332
# 183  hmp_single  callahan  gefast           as       lsr4   0.943261
# 180  hmp_single  callahan  gefast           as       lsr1   0.943330
# 178  hmp_single  callahan  gefast           as       lsa3   0.943253
# 212  hmp_single  callahan  gefast          lev       lsa3   0.943036
# 179  hmp_single  callahan  gefast           as       lsa4   0.943285
# 176  hmp_single  callahan  gefast           as       lsa1   0.943429
# 213  hmp_single  callahan  gefast          lev       lsa4   0.943066
# 210  hmp_single  callahan  gefast          lev       lsa1   0.943176
# 216  hmp_single  callahan  gefast          lev       lsr3   0.942990
# 218  hmp_single  callahan  gefast          lev        lss   0.943080
# 217  hmp_single  callahan  gefast          lev       lsr4   0.943018
# 214  hmp_single  callahan  gefast          lev       lsr1   0.943079
# 219  hmp_single  callahan  gefast          lev         nf   0.951551
# 185  hmp_single  callahan  gefast           as         nf   0.951809
# 199  hmp_single  callahan  gefast      dada2-s       lsa2   0.986186
# 203  hmp_single  callahan  gefast      dada2-s       lsr2   0.986186
# 200  hmp_single  callahan  gefast      dada2-s       lsa3   0.985986
# 204  hmp_single  callahan  gefast      dada2-s       lsr3   0.985986
# 201  hmp_single  callahan  gefast      dada2-s       lsa4   0.986193
# 205  hmp_single  callahan  gefast      dada2-s       lsr4   0.986193
# 202  hmp_single  callahan  gefast      dada2-s       lsr1   0.986206
# 198  hmp_single  callahan  gefast      dada2-s       lsa1   0.986206
# 206  hmp_single  callahan  gefast      dada2-s        lss   0.986206
# 189  hmp_single  callahan  gefast   as_dada2-c       lsa2   0.967499
# 193  hmp_single  callahan  gefast   as_dada2-c       lsr2   0.967411
# 223  hmp_single  callahan  gefast  lev_dada2-c       lsa2   0.967177
# 227  hmp_single  callahan  gefast  lev_dada2-c       lsr2   0.967089
# 194  hmp_single  callahan  gefast   as_dada2-c       lsr3   0.967301
# 195  hmp_single  callahan  gefast   as_dada2-c       lsr4   0.967387
# 196  hmp_single  callahan  gefast   as_dada2-c        lss   0.967464
# 192  hmp_single  callahan  gefast   as_dada2-c       lsr1   0.967463
# 190  hmp_single  callahan  gefast   as_dada2-c       lsa3   0.967329
# 191  hmp_single  callahan  gefast   as_dada2-c       lsa4   0.967389
# 188  hmp_single  callahan  gefast   as_dada2-c       lsa1   0.967561
# 224  hmp_single  callahan  gefast  lev_dada2-c       lsa3   0.967034
# 228  hmp_single  callahan  gefast  lev_dada2-c       lsr3   0.966983
# 229  hmp_single  callahan  gefast  lev_dada2-c       lsr4   0.967067
# 230  hmp_single  callahan  gefast  lev_dada2-c        lss   0.967144
# 226  hmp_single  callahan  gefast  lev_dada2-c       lsr1   0.967142
# 225  hmp_single  callahan  gefast  lev_dada2-c       lsa4   0.967086
# 222  hmp_single  callahan  gefast  lev_dada2-c       lsa1   0.967239
# 186  hmp_single  callahan  gefast   as_dada2-c         2f   0.971520
# 220  hmp_single  callahan  gefast  lev_dada2-c         2f   0.971237
# 187  hmp_single  callahan  gefast   as_dada2-c         f1   0.973684
# 221  hmp_single  callahan  gefast  lev_dada2-c         f1   0.973339
# 197  hmp_single  callahan  gefast   as_dada2-c         nf   0.975357
# 231  hmp_single  callahan  gefast  lev_dada2-c         nf   0.975021
# 207  hmp_single  callahan  gefast      dada2-s         nf   0.998496
#
#        recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 209  0.908735      0.837357              73071.0    449409.0        6898.8
# 175  0.908091      0.837050              73071.0    449409.0        7081.4
# 177  0.913725      0.836950              73071.0    449409.0         639.4
# 211  0.914073      0.836905              73071.0    449409.0         602.4
# 208  0.910010      0.836687              73071.0    449409.0        5417.8
# 181  0.913243      0.836659              73071.0    449409.0         639.4
# 215  0.913607      0.836616              73071.0    449409.0         602.4
# 174  0.909492      0.836450              73071.0    449409.0        5515.4
# 182  0.912172      0.836073              73071.0    449409.0         640.4
# 184  0.912172      0.836065              73071.0    449409.0        1036.2
# 183  0.912172      0.836064              73071.0    449409.0         746.6
# 180  0.912172      0.836064              73071.0    449409.0        1056.0
# 184               73071.0     449409.0  hmp  single
# 183               73071.0     449409.0  hmp  single
# 180               73071.0     449409.0  hmp  single
# 178               73071.0     449409.0  hmp  single
# 212               73071.0     449409.0  hmp  single
# 179               73071.0     449409.0  hmp  single
# 176               73071.0     449409.0  hmp  single
# 213               73071.0     449409.0  hmp  single
# 210               73071.0     449409.0  hmp  single
# 216               73071.0     449409.0  hmp  single
# 218               73071.0     449409.0  hmp  single
# 217               73071.0     449409.0  hmp  single
# 214               73071.0     449409.0  hmp  single
# 219               73071.0     449409.0  hmp  single
# 185               73071.0     449409.0  hmp  single
# 199               72705.0     448750.0  hmp  single
# 203               72705.0     448750.0  hmp  single
# 200               73071.0     449409.0  hmp  single
# 204               73071.0     449409.0  hmp  single
# 201               73071.0     449409.0  hmp  single
# 205               73071.0     449409.0  hmp  single
# 202               73071.0     449409.0  hmp  single
# 198               73071.0     449409.0  hmp  single
# 206               73071.0     449409.0  hmp  single
# 189               72281.6     448433.8  hmp  single
# 193               72528.8     448681.0  hmp  single
# 223               72288.2     448440.0  hmp  single
# 227               72519.6     448671.4  hmp  single
# 194               73071.0     449409.0  hmp  single
# 195               73071.0     449409.0  hmp  single
# 196               73071.0     449409.0  hmp  single
# 192               73071.0     449409.0  hmp  single
# 190               73071.0     449409.0  hmp  single
# 191               73071.0     449409.0  hmp  single
# 188               73071.0     449409.0  hmp  single
# 224               73071.0     449409.0  hmp  single
# 228               73071.0     449409.0  hmp  single
# 229               73071.0     449409.0  hmp  single
# 230               73071.0     449409.0  hmp  single
# 226               73071.0     449409.0  hmp  single
# 225               73071.0     449409.0  hmp  single
# 222               73071.0     449409.0  hmp  single
# 186               73071.0     449409.0  hmp  single
# 220               73071.0     449409.0  hmp  single
# 187               73071.0     449409.0  hmp  single
# 221               73071.0     449409.0  hmp  single
# 197               73071.0     449409.0  hmp  single
# 231               73071.0     449409.0  hmp  single
# 207               73071.0     449409.0  hmp  single

# %% [markdown]
# Average the N-best values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_nbest_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#       tool         mode refinement  precision    recall  adjrandindex
# 37  gefast          lev       lsa2   0.963915  0.893757      0.866030
# 41  gefast          lev       lsr2   0.963781  0.893245      0.865595
# 35  gefast          lev         f1   0.966365  0.890936      0.865258
# 34  gefast          lev         2f   0.965608  0.891339      0.864978
# 38  gefast          lev       lsa3   0.963777  0.892114      0.864780
# 39  gefast          lev       lsa4   0.963844  0.892114      0.864756
# 36  gefast          lev       lsa1   0.963955  0.892113      0.864755
# 42  gefast          lev       lsr3   0.963691  0.892148      0.864735
# 44  gefast          lev        lss   0.963815  0.892147      0.864724
# 43  gefast          lev       lsr4   0.963757  0.892148      0.864724
# 40  gefast          lev       lsr1   0.963814  0.892147      0.864724
# 45  gefast          lev         nf   0.967003  0.888527      0.863506
# 3   gefast           as       lsa2   0.963513  0.890568      0.863139
# 7   gefast           as       lsr2   0.963380  0.890070      0.862712
# 1   gefast           as         f1   0.966064  0.887607      0.862235
# 0   gefast           as         2f   0.965276  0.888107      0.862019
# 4   gefast           as       lsa3   0.963378  0.888967      0.861908
# 5   gefast           as       lsa4   0.963437  0.888967      0.861883
# 2   gefast           as       lsa1   0.963554  0.888967      0.861883
# 8   gefast           as       lsr3   0.963299  0.889010      0.861876
# 10  gefast           as        lss   0.963415  0.889010      0.861866
# 9   gefast           as       lsr4   0.963359  0.889010      0.861865
# 6   gefast           as       lsr1   0.963414  0.889010      0.861865
# 11  gefast           as         nf   0.966691  0.885200      0.860467
# 25  gefast      dada2-s       lsa2   0.991212  0.823678      0.815591
# 29  gefast      dada2-s       lsr2   0.991212  0.823678      0.815591
# 26  gefast      dada2-s       lsa3   0.990891  0.822322      0.814373
# 30  gefast      dada2-s       lsr3   0.990891  0.822322      0.814373
# 27  gefast      dada2-s       lsa4   0.991204  0.822322      0.814360
# 31  gefast      dada2-s       lsr4   0.991204  0.822322      0.814360
# 28  gefast      dada2-s       lsr1   0.991226  0.822322      0.814360
# 24  gefast      dada2-s       lsa1   0.991226  0.822322      0.814360
# 32  gefast      dada2-s        lss   0.991226  0.822322      0.814360
# 49  gefast  lev_dada2-c       lsa2   0.986723  0.815650      0.799006
# 53  gefast  lev_dada2-c       lsr2   0.986564  0.815194      0.798625
# 15  gefast   as_dada2-c       lsa2   0.986784  0.815071      0.798528
# 19  gefast   as_dada2-c       lsr2   0.986633  0.814634      0.798159
# 50  gefast  lev_dada2-c       lsa3   0.986382  0.813657      0.797360
# 54  gefast  lev_dada2-c       lsr3   0.986280  0.813679      0.797346
# 55  gefast  lev_dada2-c       lsr4   0.986503  0.813679      0.797327
# 56  gefast  lev_dada2-c        lss   0.986592  0.813679      0.797327
# 52  gefast  lev_dada2-c       lsr1   0.986588  0.813679      0.797327
# 51  gefast  lev_dada2-c       lsa4   0.986567  0.813657      0.797323
# 48  gefast  lev_dada2-c       lsa1   0.986742  0.813657      0.797322
# 16  gefast   as_dada2-c       lsa3   0.986442  0.813167      0.796926
# 20  gefast   as_dada2-c       lsr3   0.986353  0.813200      0.796925
# 21  gefast   as_dada2-c       lsr4   0.986567  0.813200      0.796907
# 22  gefast   as_dada2-c        lss   0.986658  0.813200      0.796907
# 18  gefast   as_dada2-c       lsr1   0.986655  0.813200      0.796907
# 17  gefast   as_dada2-c       lsa4   0.986625  0.813167      0.796890
# 14  gefast   as_dada2-c       lsa1   0.986802  0.813167      0.796890
# 46  gefast  lev_dada2-c         2f   0.988231  0.813025      0.796325
# 47  gefast  lev_dada2-c         f1   0.989062  0.812722      0.796322
# 12  gefast   as_dada2-c         2f   0.988397  0.812427      0.795793
# 13  gefast   as_dada2-c         f1   0.989256  0.812031      0.795741
# 57  gefast  lev_dada2-c         nf   0.989238  0.811811      0.795464
# 23  gefast   as_dada2-c         nf   0.989154  0.811222      0.794817
# 33  gefast      dada2-s         nf   0.998278  0.781501      0.771782
