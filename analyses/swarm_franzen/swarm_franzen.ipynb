# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))


import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import os
import pandas as pd
import seaborn as sb
import statistics as st

from Bio import SeqIO

sb.set()
pd.set_option("display.max_rows", None)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Evaluation of Swarm on Franzén data
#
# The following notebook describes the steps and results of the evaluation.

# %%
# Initial files and directories:
#
# model_supported_franzen
# |- data # will contain the in-silico sequenced data sets
# |
# |- evaluation # will contain the evaluation plots and tables
# |
# |- outputs # will contain the cluster and metric outputs
# |
# |- tasks  # task files for the different runs of Swarm
# |
# \- 40168_2015_105_MOESM9_ESM.csv  # CSV version of Additional file 9 of Franzén et al. (see below)

# %% [markdown]
# ## Analysis workflow
#
# The data sets are prepared as described in Franzén et al., *Improved OTU-picking using long-read 16S rRNA gene amplicon sequencing and generic hierarchical clustering* (https://doi.org/10.1186/s40168-015-0105-6),
# except that there are no Ns between the forward and reverse portion of the reads.
#
# The taxonomic assignment is obtained from the known sources during the creation of the mock communities (simulated sequencing).
#
# Swarm (v3) is executed with and without the fastidious refinement step. Runs without refinement have the suffix `__nf`, while those with refinement end with `__2f`.

# %% [markdown]
# ## Commands
#
# The following commands prepare and cluster the data sets. The results are evaluated below.
#
# In order to execute the workflow as provided here, the `tools` subdirectory of the overall repository has to contain the binaries of Infernal (cmbuild, cmalign) and ART (art_illumina), but the paths can be adjusted.
#
# IMPORTANT: The commands are not intended to be executed from this notebook. They should be executed from the root directory of the overall repository.

# %%
# %%bash
#
# TOOLS_DIR=tools
# ANALYSIS_DIR=analyses/model_supported_franzen
# DATA_DIR=${ANALYSIS_DIR}/data
# OUTPUT_DIR=${ANALYSIS_DIR}/outputs
#
# SWARM=${TOOLS_DIR}/swarm-3.0.0/bin/swarm # adjust to your system
#
# RUNS=( swarm_v3__nf swarm_v3__2f )
#
# # prepare tools and reference data
# CMBUILD_PATH=${TOOLS_DIR}/infernal-1.1.2-linux-intel-gcc/binaries/cmbuild # adjust to your system
# python -m scripts.analyses.analysis_franzen prepare ${DATA_DIR} --cmbuild ${CMBUILD_PATH}
#
# # create list files of mock communities
# python -m scripts.analyses.analysis_franzen lists ${ANALYSIS_DIR}/40168_2015_105_MOESM9_ESM.csv ${DATA_DIR}/list_files
#
# # create mock communities
# GG_DB=${DATA_DIR}/gg_13_5.fasta
# MOCK_LIST=${DATA_DIR}/list_files/list.txt
# MSA_MODEL=${DATA_DIR}/bacteria16S_508_mod5.cmfile
# CMALIGN_PATH=${TOOLS_DIR}/infernal-1.1.2-linux-intel-gcc/binaries/cmalign # adjust to your system
# ART_PATH=${TOOLS_DIR}/art_bin_VanillaIceCream/art_illumina # adjust to your system
# python -m scripts.analyses.analysis_franzen mock ${GG_DB} ${MOCK_LIST} ${MSA_MODEL} ${DATA_DIR} --cmalign ${CMALIGN_PATH} --art ${ART_PATH} --miseq --skip_ambiguous --num_n 0
#
# # run Swarm and determine clustering quality
# DATA=( "LC" "MC" "HC" )
# REGIONS=( "V3-V4" "V4" )
# for D in "${DATA[@]}"; do
#   for ((I=1; I<=10; I++)); do
#     for R in "${REGIONS[@]}"; do
#       echo ${D}_${I}_${R}
#       READS=${D}_${I}_${R}:${DATA_DIR}/${D}_${I}/${D}_${I}_${R}_miseq_rs.fastq
#       TAX=franzen:${DATA_DIR}/${D}_${I}/${D}_${I}_${R}_miseq_rs.tax
#       for RUN in "${RUNS[@]}"; do
#         python -m scripts.analyses.analysis_franzen run_swarm ${RUN} ${READS} ${ANALYSIS_DIR}/tasks/${RUN}.txt ${OUTPUT_DIR}/${D}_${I}_${R}/${RUN} --tax_files ${TAX} --swarm ${SWARM}
#         for F in ${OUTPUT_DIR}/${D}_${I}_${R}/${RUN}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/${D}_${I}_${R}/${RUN}/${RUN}_${F##*/}; done
#       done
#     done
#   done
# done

# %% [markdown]
# ## Evaluation

# %% [markdown]
# **Configuration**

# %%
data_sets = ['LC', 'MC', 'HC']
num_samples = 10
regions = ['V3-V4', 'V4']
ground_truths = ['franzen']

opts = ['swarm_v3__nf', 'swarm_v3__2f']

data_dir = 'data'
results_dir = 'outputs'
eval_dir = 'evaluation'

# %% [markdown]
# ### Number of clusters and amplicons
#
# Reads the input files and the cluster outputs for all data sets and compares the number of clusters and amplicons.

# %%
# Requires the input and OTU files. Alternatively, the evaluation can use the stored information (see below).
df_columns = ['data_set', 'tool', 'mode', 'refinement', 'threshold', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

rows = []

for ds in data_sets:
    for rt in regions:
        for s in range(1, num_samples + 1):
            run_name = '%s_%i_%s' % (ds, s, rt)
            
            seq_file = '%s/%s_%i/%s_miseq_rs.fastq' % (data_dir, ds, s, run_name) # the input sequences
            num_input_amplicons = 0
            input_mass = 0
            with open(seq_file, 'r') as in_file:
                for record in SeqIO.parse(in_file, 'fastq'):
                    num_input_amplicons += 1
                    input_mass += int(record.id.split('_')[-1]) if ('_' in record.id) else 1
            
            for opt in opts:
                otu_files = [f for f in os.listdir('%s/%s/%s/' % (results_dir, run_name, opt)) if f.endswith('_otus.txt')]
                
                
                for f in otu_files:
                    otu_file = '%s/%s/%s/%s' % (results_dir, run_name, opt, f)

                    num_output_amplicons = 0
                    num_clusters = 0
                    output_mass = 0
                    with open(otu_file, 'r') as in_file:
                        for line in in_file:
                            num_output_amplicons += len(line.strip().split(' '))
                            num_clusters += 1
                            output_mass += sum([int(m.split('_')[-1]) for m in line.strip().split(' ')])
                            
                    tool = 'swarm'
                    mode = 'swarm'
                    refinement = opt.split('__')[1]
                    threshold = float(f.split('_')[-2])
                            
                    rows.append([run_name, tool, mode, refinement, threshold, num_input_amplicons, input_mass, num_clusters, num_output_amplicons, output_mass, ds, rt])

df_counts = pd.DataFrame(rows, columns = df_columns)
df_counts.sort_values(by = ['data_set', 'tool', 'mode', 'refinement', 'threshold'], inplace = True)

# %% [markdown]
# *Column descriptions:*
# `num_input_amplicons`: The number of entries in the corresponding input file.
# `input_mass`: The sum of the abundances of all entries in the input file.
# `num_clusters`: The number of computed clusters.
# `num_output_amplicons`: The number of amplicons contained in the clusters.
# `output_mass`: The sum of the abundances of all amplicons contained in the clusters.

# %%
df_counts[['data_set', 'tool', 'refinement', 'threshold', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass']]
# Out:
#         data_set   tool refinement  threshold  num_input_amplicons  \
# 549  HC_10_V3-V4  swarm         2f        1.0                 9940
# 539  HC_10_V3-V4  swarm         nf        1.0                 9940
# 541  HC_10_V3-V4  swarm         nf        2.0                 9940
# 542  HC_10_V3-V4  swarm         nf        3.0                 9940
# 543  HC_10_V3-V4  swarm         nf        4.0                 9940
# 544  HC_10_V3-V4  swarm         nf        5.0                 9940
# 545  HC_10_V3-V4  swarm         nf        6.0                 9940
# 546  HC_10_V3-V4  swarm         nf        7.0                 9940
# 547  HC_10_V3-V4  swarm         nf        8.0                 9940
# 548  HC_10_V3-V4  swarm         nf        9.0                 9940
# 540  HC_10_V3-V4  swarm         nf       10.0                 9940
# 659     HC_10_V4  swarm         2f        1.0                 9940
# 649     HC_10_V4  swarm         nf        1.0                 9940
# 651     HC_10_V4  swarm         nf        2.0                 9940
# 652     HC_10_V4  swarm         nf        3.0                 9940
# 653     HC_10_V4  swarm         nf        4.0                 9940
# 654     HC_10_V4  swarm         nf        5.0                 9940
# 655     HC_10_V4  swarm         nf        6.0                 9940
# 656     HC_10_V4  swarm         nf        7.0                 9940
# 657     HC_10_V4  swarm         nf        8.0                 9940
# 658     HC_10_V4  swarm         nf        9.0                 9940
# 650     HC_10_V4  swarm         nf       10.0                 9940
# 450   HC_1_V3-V4  swarm         2f        1.0                 9940
# 440   HC_1_V3-V4  swarm         nf        1.0                 9940
# 442   HC_1_V3-V4  swarm         nf        2.0                 9940
# 443   HC_1_V3-V4  swarm         nf        3.0                 9940
# 444   HC_1_V3-V4  swarm         nf        4.0                 9940
# 445   HC_1_V3-V4  swarm         nf        5.0                 9940
# 446   HC_1_V3-V4  swarm         nf        6.0                 9940
# 447   HC_1_V3-V4  swarm         nf        7.0                 9940
# 448   HC_1_V3-V4  swarm         nf        8.0                 9940
# 449   HC_1_V3-V4  swarm         nf        9.0                 9940
# 441   HC_1_V3-V4  swarm         nf       10.0                 9940
# 560      HC_1_V4  swarm         2f        1.0                 9940
# 550      HC_1_V4  swarm         nf        1.0                 9940
# 552      HC_1_V4  swarm         nf        2.0                 9940
# 553      HC_1_V4  swarm         nf        3.0                 9940
# 554      HC_1_V4  swarm         nf        4.0                 9940
# 555      HC_1_V4  swarm         nf        5.0                 9940
# 556      HC_1_V4  swarm         nf        6.0                 9940
# 557      HC_1_V4  swarm         nf        7.0                 9940
# 558      HC_1_V4  swarm         nf        8.0                 9940
# 559      HC_1_V4  swarm         nf        9.0                 9940
# 551      HC_1_V4  swarm         nf       10.0                 9940
# 461   HC_2_V3-V4  swarm         2f        1.0                 9960
# 451   HC_2_V3-V4  swarm         nf        1.0                 9960
# 453   HC_2_V3-V4  swarm         nf        2.0                 9960
# 454   HC_2_V3-V4  swarm         nf        3.0                 9960
# 455   HC_2_V3-V4  swarm         nf        4.0                 9960
# 456   HC_2_V3-V4  swarm         nf        5.0                 9960
# 457   HC_2_V3-V4  swarm         nf        6.0                 9960
# 458   HC_2_V3-V4  swarm         nf        7.0                 9960
# 459   HC_2_V3-V4  swarm         nf        8.0                 9960
# 460   HC_2_V3-V4  swarm         nf        9.0                 9960
# 452   HC_2_V3-V4  swarm         nf       10.0                 9960
# 571      HC_2_V4  swarm         2f        1.0                 9960
# 561      HC_2_V4  swarm         nf        1.0                 9960
# 563      HC_2_V4  swarm         nf        2.0                 9960
# 564      HC_2_V4  swarm         nf        3.0                 9960
# 565      HC_2_V4  swarm         nf        4.0                 9960
# 566      HC_2_V4  swarm         nf        5.0                 9960
# 567      HC_2_V4  swarm         nf        6.0                 9960
# 568      HC_2_V4  swarm         nf        7.0                 9960
# 569      HC_2_V4  swarm         nf        8.0                 9960
# 570      HC_2_V4  swarm         nf        9.0                 9960
# 562      HC_2_V4  swarm         nf       10.0                 9960
# 472   HC_3_V3-V4  swarm         2f        1.0                 9960
# 462   HC_3_V3-V4  swarm         nf        1.0                 9960
# 464   HC_3_V3-V4  swarm         nf        2.0                 9960
# 465   HC_3_V3-V4  swarm         nf        3.0                 9960
# 466   HC_3_V3-V4  swarm         nf        4.0                 9960
# 467   HC_3_V3-V4  swarm         nf        5.0                 9960
# 468   HC_3_V3-V4  swarm         nf        6.0                 9960
# 469   HC_3_V3-V4  swarm         nf        7.0                 9960
# 470   HC_3_V3-V4  swarm         nf        8.0                 9960
# 471   HC_3_V3-V4  swarm         nf        9.0                 9960
# 463   HC_3_V3-V4  swarm         nf       10.0                 9960
# 582      HC_3_V4  swarm         2f        1.0                 9960
# 572      HC_3_V4  swarm         nf        1.0                 9960
# 574      HC_3_V4  swarm         nf        2.0                 9960
# 575      HC_3_V4  swarm         nf        3.0                 9960
# 576      HC_3_V4  swarm         nf        4.0                 9960
# 577      HC_3_V4  swarm         nf        5.0                 9960
# 578      HC_3_V4  swarm         nf        6.0                 9960
# 579      HC_3_V4  swarm         nf        7.0                 9960
# 580      HC_3_V4  swarm         nf        8.0                 9960
# 581      HC_3_V4  swarm         nf        9.0                 9960
# 573      HC_3_V4  swarm         nf       10.0                 9960
# 483   HC_4_V3-V4  swarm         2f        1.0                 9980
# 473   HC_4_V3-V4  swarm         nf        1.0                 9980
# 475   HC_4_V3-V4  swarm         nf        2.0                 9980
# 476   HC_4_V3-V4  swarm         nf        3.0                 9980
# 477   HC_4_V3-V4  swarm         nf        4.0                 9980
# 478   HC_4_V3-V4  swarm         nf        5.0                 9980
# 479   HC_4_V3-V4  swarm         nf        6.0                 9980
# 480   HC_4_V3-V4  swarm         nf        7.0                 9980
# 481   HC_4_V3-V4  swarm         nf        8.0                 9980
# 482   HC_4_V3-V4  swarm         nf        9.0                 9980
# 474   HC_4_V3-V4  swarm         nf       10.0                 9980
# 593      HC_4_V4  swarm         2f        1.0                 9980
# 583      HC_4_V4  swarm         nf        1.0                 9980
# 585      HC_4_V4  swarm         nf        2.0                 9980
# 586      HC_4_V4  swarm         nf        3.0                 9980
# 587      HC_4_V4  swarm         nf        4.0                 9980
# 588      HC_4_V4  swarm         nf        5.0                 9980
# 589      HC_4_V4  swarm         nf        6.0                 9980
# 590      HC_4_V4  swarm         nf        7.0                 9980
# 591      HC_4_V4  swarm         nf        8.0                 9980
# 592      HC_4_V4  swarm         nf        9.0                 9980
# 584      HC_4_V4  swarm         nf       10.0                 9980
# 494   HC_5_V3-V4  swarm         2f        1.0                 9980
# 484   HC_5_V3-V4  swarm         nf        1.0                 9980
# 486   HC_5_V3-V4  swarm         nf        2.0                 9980
# 487   HC_5_V3-V4  swarm         nf        3.0                 9980
# 488   HC_5_V3-V4  swarm         nf        4.0                 9980
# 489   HC_5_V3-V4  swarm         nf        5.0                 9980
# 490   HC_5_V3-V4  swarm         nf        6.0                 9980
# 491   HC_5_V3-V4  swarm         nf        7.0                 9980
# 492   HC_5_V3-V4  swarm         nf        8.0                 9980
# 493   HC_5_V3-V4  swarm         nf        9.0                 9980
# 485   HC_5_V3-V4  swarm         nf       10.0                 9980
# 604      HC_5_V4  swarm         2f        1.0                 9980
# 594      HC_5_V4  swarm         nf        1.0                 9980
# 596      HC_5_V4  swarm         nf        2.0                 9980
# 597      HC_5_V4  swarm         nf        3.0                 9980
# 598      HC_5_V4  swarm         nf        4.0                 9980
# 599      HC_5_V4  swarm         nf        5.0                 9980
# 600      HC_5_V4  swarm         nf        6.0                 9980
# 601      HC_5_V4  swarm         nf        7.0                 9980
# 602      HC_5_V4  swarm         nf        8.0                 9980
# 603      HC_5_V4  swarm         nf        9.0                 9980
# 595      HC_5_V4  swarm         nf       10.0                 9980
# 505   HC_6_V3-V4  swarm         2f        1.0                 9960
# 495   HC_6_V3-V4  swarm         nf        1.0                 9960
# 497   HC_6_V3-V4  swarm         nf        2.0                 9960
# 498   HC_6_V3-V4  swarm         nf        3.0                 9960
# 499   HC_6_V3-V4  swarm         nf        4.0                 9960
# 500   HC_6_V3-V4  swarm         nf        5.0                 9960
# 501   HC_6_V3-V4  swarm         nf        6.0                 9960
# 502   HC_6_V3-V4  swarm         nf        7.0                 9960
# 503   HC_6_V3-V4  swarm         nf        8.0                 9960
# 504   HC_6_V3-V4  swarm         nf        9.0                 9960
# 496   HC_6_V3-V4  swarm         nf       10.0                 9960
# 615      HC_6_V4  swarm         2f        1.0                 9960
# 605      HC_6_V4  swarm         nf        1.0                 9960
# 607      HC_6_V4  swarm         nf        2.0                 9960
# 608      HC_6_V4  swarm         nf        3.0                 9960
# 609      HC_6_V4  swarm         nf        4.0                 9960
# 610      HC_6_V4  swarm         nf        5.0                 9960
# 611      HC_6_V4  swarm         nf        6.0                 9960
# 612      HC_6_V4  swarm         nf        7.0                 9960
# 613      HC_6_V4  swarm         nf        8.0                 9960
# 614      HC_6_V4  swarm         nf        9.0                 9960
# 606      HC_6_V4  swarm         nf       10.0                 9960
# 516   HC_7_V3-V4  swarm         2f        1.0                 9940
# 506   HC_7_V3-V4  swarm         nf        1.0                 9940
# 508   HC_7_V3-V4  swarm         nf        2.0                 9940
# 509   HC_7_V3-V4  swarm         nf        3.0                 9940
# 510   HC_7_V3-V4  swarm         nf        4.0                 9940
# 511   HC_7_V3-V4  swarm         nf        5.0                 9940
# 512   HC_7_V3-V4  swarm         nf        6.0                 9940
# 513   HC_7_V3-V4  swarm         nf        7.0                 9940
# 514   HC_7_V3-V4  swarm         nf        8.0                 9940
# 515   HC_7_V3-V4  swarm         nf        9.0                 9940
# 507   HC_7_V3-V4  swarm         nf       10.0                 9940
# 626      HC_7_V4  swarm         2f        1.0                 9940
# 616      HC_7_V4  swarm         nf        1.0                 9940
# 618      HC_7_V4  swarm         nf        2.0                 9940
# 619      HC_7_V4  swarm         nf        3.0                 9940
# 620      HC_7_V4  swarm         nf        4.0                 9940
# 621      HC_7_V4  swarm         nf        5.0                 9940
# 622      HC_7_V4  swarm         nf        6.0                 9940
# 623      HC_7_V4  swarm         nf        7.0                 9940
# 624      HC_7_V4  swarm         nf        8.0                 9940
# 625      HC_7_V4  swarm         nf        9.0                 9940
# 617      HC_7_V4  swarm         nf       10.0                 9940
# 527   HC_8_V3-V4  swarm         2f        1.0                 9980
# 517   HC_8_V3-V4  swarm         nf        1.0                 9980
# 519   HC_8_V3-V4  swarm         nf        2.0                 9980
# 520   HC_8_V3-V4  swarm         nf        3.0                 9980
# 521   HC_8_V3-V4  swarm         nf        4.0                 9980
# 522   HC_8_V3-V4  swarm         nf        5.0                 9980
# 523   HC_8_V3-V4  swarm         nf        6.0                 9980
# 524   HC_8_V3-V4  swarm         nf        7.0                 9980
# 525   HC_8_V3-V4  swarm         nf        8.0                 9980
# 526   HC_8_V3-V4  swarm         nf        9.0                 9980
# 518   HC_8_V3-V4  swarm         nf       10.0                 9980
# 637      HC_8_V4  swarm         2f        1.0                 9980
# 627      HC_8_V4  swarm         nf        1.0                 9980
# 629      HC_8_V4  swarm         nf        2.0                 9980
# 630      HC_8_V4  swarm         nf        3.0                 9980
# 631      HC_8_V4  swarm         nf        4.0                 9980
# 632      HC_8_V4  swarm         nf        5.0                 9980
# 633      HC_8_V4  swarm         nf        6.0                 9980
# 634      HC_8_V4  swarm         nf        7.0                 9980
# 635      HC_8_V4  swarm         nf        8.0                 9980
# 636      HC_8_V4  swarm         nf        9.0                 9980
# 628      HC_8_V4  swarm         nf       10.0                 9980
# 538   HC_9_V3-V4  swarm         2f        1.0                 9940
# 528   HC_9_V3-V4  swarm         nf        1.0                 9940
# 530   HC_9_V3-V4  swarm         nf        2.0                 9940
# 531   HC_9_V3-V4  swarm         nf        3.0                 9940
# 532   HC_9_V3-V4  swarm         nf        4.0                 9940
# 533   HC_9_V3-V4  swarm         nf        5.0                 9940
# 534   HC_9_V3-V4  swarm         nf        6.0                 9940
# 535   HC_9_V3-V4  swarm         nf        7.0                 9940
# 536   HC_9_V3-V4  swarm         nf        8.0                 9940
# 537   HC_9_V3-V4  swarm         nf        9.0                 9940
# 529   HC_9_V3-V4  swarm         nf       10.0                 9940
# 648      HC_9_V4  swarm         2f        1.0                 9940
# 638      HC_9_V4  swarm         nf        1.0                 9940
# 640      HC_9_V4  swarm         nf        2.0                 9940
# 641      HC_9_V4  swarm         nf        3.0                 9940
# 642      HC_9_V4  swarm         nf        4.0                 9940
# 643      HC_9_V4  swarm         nf        5.0                 9940
# 644      HC_9_V4  swarm         nf        6.0                 9940
# 645      HC_9_V4  swarm         nf        7.0                 9940
# 646      HC_9_V4  swarm         nf        8.0                 9940
# 647      HC_9_V4  swarm         nf        9.0                 9940
# 639      HC_9_V4  swarm         nf       10.0                 9940
# 109  LC_10_V3-V4  swarm         2f        1.0                 1980
# 99   LC_10_V3-V4  swarm         nf        1.0                 1980
# 101  LC_10_V3-V4  swarm         nf        2.0                 1980
# 102  LC_10_V3-V4  swarm         nf        3.0                 1980
# 103  LC_10_V3-V4  swarm         nf        4.0                 1980
# 104  LC_10_V3-V4  swarm         nf        5.0                 1980
# 105  LC_10_V3-V4  swarm         nf        6.0                 1980
# 106  LC_10_V3-V4  swarm         nf        7.0                 1980
# 107  LC_10_V3-V4  swarm         nf        8.0                 1980
# 108  LC_10_V3-V4  swarm         nf        9.0                 1980
# 100  LC_10_V3-V4  swarm         nf       10.0                 1980
# 219     LC_10_V4  swarm         2f        1.0                 1980
# 209     LC_10_V4  swarm         nf        1.0                 1980
# 211     LC_10_V4  swarm         nf        2.0                 1980
# 212     LC_10_V4  swarm         nf        3.0                 1980
# 213     LC_10_V4  swarm         nf        4.0                 1980
# 214     LC_10_V4  swarm         nf        5.0                 1980
# 215     LC_10_V4  swarm         nf        6.0                 1980
# 216     LC_10_V4  swarm         nf        7.0                 1980
# 217     LC_10_V4  swarm         nf        8.0                 1980
# 218     LC_10_V4  swarm         nf        9.0                 1980
# 210     LC_10_V4  swarm         nf       10.0                 1980
# 10    LC_1_V3-V4  swarm         2f        1.0                 1980
# 0     LC_1_V3-V4  swarm         nf        1.0                 1980
# 2     LC_1_V3-V4  swarm         nf        2.0                 1980
# 3     LC_1_V3-V4  swarm         nf        3.0                 1980
# 4     LC_1_V3-V4  swarm         nf        4.0                 1980
# 5     LC_1_V3-V4  swarm         nf        5.0                 1980
# 6     LC_1_V3-V4  swarm         nf        6.0                 1980
# 7     LC_1_V3-V4  swarm         nf        7.0                 1980
# 8     LC_1_V3-V4  swarm         nf        8.0                 1980
# 9     LC_1_V3-V4  swarm         nf        9.0                 1980
# 1     LC_1_V3-V4  swarm         nf       10.0                 1980
# 120      LC_1_V4  swarm         2f        1.0                 1980
# 110      LC_1_V4  swarm         nf        1.0                 1980
# 112      LC_1_V4  swarm         nf        2.0                 1980
# 113      LC_1_V4  swarm         nf        3.0                 1980
# 114      LC_1_V4  swarm         nf        4.0                 1980
# 115      LC_1_V4  swarm         nf        5.0                 1980
# 116      LC_1_V4  swarm         nf        6.0                 1980
# 117      LC_1_V4  swarm         nf        7.0                 1980
# 118      LC_1_V4  swarm         nf        8.0                 1980
# 119      LC_1_V4  swarm         nf        9.0                 1980
# 111      LC_1_V4  swarm         nf       10.0                 1980
# 21    LC_2_V3-V4  swarm         2f        1.0                 1980
# 11    LC_2_V3-V4  swarm         nf        1.0                 1980
# 13    LC_2_V3-V4  swarm         nf        2.0                 1980
# 14    LC_2_V3-V4  swarm         nf        3.0                 1980
# 15    LC_2_V3-V4  swarm         nf        4.0                 1980
# 16    LC_2_V3-V4  swarm         nf        5.0                 1980
# 17    LC_2_V3-V4  swarm         nf        6.0                 1980
# 18    LC_2_V3-V4  swarm         nf        7.0                 1980
# 19    LC_2_V3-V4  swarm         nf        8.0                 1980
# 20    LC_2_V3-V4  swarm         nf        9.0                 1980
# 12    LC_2_V3-V4  swarm         nf       10.0                 1980
# 131      LC_2_V4  swarm         2f        1.0                 1980
# 121      LC_2_V4  swarm         nf        1.0                 1980
# 123      LC_2_V4  swarm         nf        2.0                 1980
# 124      LC_2_V4  swarm         nf        3.0                 1980
# 125      LC_2_V4  swarm         nf        4.0                 1980
# 126      LC_2_V4  swarm         nf        5.0                 1980
# 127      LC_2_V4  swarm         nf        6.0                 1980
# 128      LC_2_V4  swarm         nf        7.0                 1980
# 129      LC_2_V4  swarm         nf        8.0                 1980
# 130      LC_2_V4  swarm         nf        9.0                 1980
# 122      LC_2_V4  swarm         nf       10.0                 1980
# 32    LC_3_V3-V4  swarm         2f        1.0                 2000
# 22    LC_3_V3-V4  swarm         nf        1.0                 2000
# 24    LC_3_V3-V4  swarm         nf        2.0                 2000
# 25    LC_3_V3-V4  swarm         nf        3.0                 2000
# 26    LC_3_V3-V4  swarm         nf        4.0                 2000
# 27    LC_3_V3-V4  swarm         nf        5.0                 2000
# 28    LC_3_V3-V4  swarm         nf        6.0                 2000
# 29    LC_3_V3-V4  swarm         nf        7.0                 2000
# 30    LC_3_V3-V4  swarm         nf        8.0                 2000
# 31    LC_3_V3-V4  swarm         nf        9.0                 2000
# 23    LC_3_V3-V4  swarm         nf       10.0                 2000
# 142      LC_3_V4  swarm         2f        1.0                 2000
# 132      LC_3_V4  swarm         nf        1.0                 2000
# 134      LC_3_V4  swarm         nf        2.0                 2000
# 135      LC_3_V4  swarm         nf        3.0                 2000
# 136      LC_3_V4  swarm         nf        4.0                 2000
# 137      LC_3_V4  swarm         nf        5.0                 2000
# 138      LC_3_V4  swarm         nf        6.0                 2000
# 139      LC_3_V4  swarm         nf        7.0                 2000
# 140      LC_3_V4  swarm         nf        8.0                 2000
# 141      LC_3_V4  swarm         nf        9.0                 2000
# 133      LC_3_V4  swarm         nf       10.0                 2000
# 43    LC_4_V3-V4  swarm         2f        1.0                 2000
# 33    LC_4_V3-V4  swarm         nf        1.0                 2000
# 35    LC_4_V3-V4  swarm         nf        2.0                 2000
# 36    LC_4_V3-V4  swarm         nf        3.0                 2000
# 37    LC_4_V3-V4  swarm         nf        4.0                 2000
# 38    LC_4_V3-V4  swarm         nf        5.0                 2000
# 39    LC_4_V3-V4  swarm         nf        6.0                 2000
# 40    LC_4_V3-V4  swarm         nf        7.0                 2000
# 41    LC_4_V3-V4  swarm         nf        8.0                 2000
# 42    LC_4_V3-V4  swarm         nf        9.0                 2000
# 34    LC_4_V3-V4  swarm         nf       10.0                 2000
# 153      LC_4_V4  swarm         2f        1.0                 2000
# 143      LC_4_V4  swarm         nf        1.0                 2000
# 145      LC_4_V4  swarm         nf        2.0                 2000
# 146      LC_4_V4  swarm         nf        3.0                 2000
# 147      LC_4_V4  swarm         nf        4.0                 2000
# 148      LC_4_V4  swarm         nf        5.0                 2000
# 149      LC_4_V4  swarm         nf        6.0                 2000
# 150      LC_4_V4  swarm         nf        7.0                 2000
# 151      LC_4_V4  swarm         nf        8.0                 2000
# 152      LC_4_V4  swarm         nf        9.0                 2000
# 144      LC_4_V4  swarm         nf       10.0                 2000
# 54    LC_5_V3-V4  swarm         2f        1.0                 1980
# 44    LC_5_V3-V4  swarm         nf        1.0                 1980
# 46    LC_5_V3-V4  swarm         nf        2.0                 1980
# 47    LC_5_V3-V4  swarm         nf        3.0                 1980
# 48    LC_5_V3-V4  swarm         nf        4.0                 1980
# 49    LC_5_V3-V4  swarm         nf        5.0                 1980
# 50    LC_5_V3-V4  swarm         nf        6.0                 1980
# 51    LC_5_V3-V4  swarm         nf        7.0                 1980
# 52    LC_5_V3-V4  swarm         nf        8.0                 1980
# 53    LC_5_V3-V4  swarm         nf        9.0                 1980
# 45    LC_5_V3-V4  swarm         nf       10.0                 1980
# 164      LC_5_V4  swarm         2f        1.0                 1980
# 154      LC_5_V4  swarm         nf        1.0                 1980
# 156      LC_5_V4  swarm         nf        2.0                 1980
# 157      LC_5_V4  swarm         nf        3.0                 1980
# 158      LC_5_V4  swarm         nf        4.0                 1980
# 159      LC_5_V4  swarm         nf        5.0                 1980
# 160      LC_5_V4  swarm         nf        6.0                 1980
# 161      LC_5_V4  swarm         nf        7.0                 1980
# 162      LC_5_V4  swarm         nf        8.0                 1980
# 163      LC_5_V4  swarm         nf        9.0                 1980
# 155      LC_5_V4  swarm         nf       10.0                 1980
# 65    LC_6_V3-V4  swarm         2f        1.0                 2000
# 55    LC_6_V3-V4  swarm         nf        1.0                 2000
# 57    LC_6_V3-V4  swarm         nf        2.0                 2000
# 58    LC_6_V3-V4  swarm         nf        3.0                 2000
# 59    LC_6_V3-V4  swarm         nf        4.0                 2000
# 60    LC_6_V3-V4  swarm         nf        5.0                 2000
# 61    LC_6_V3-V4  swarm         nf        6.0                 2000
# 62    LC_6_V3-V4  swarm         nf        7.0                 2000
# 63    LC_6_V3-V4  swarm         nf        8.0                 2000
# 64    LC_6_V3-V4  swarm         nf        9.0                 2000
# 56    LC_6_V3-V4  swarm         nf       10.0                 2000
# 175      LC_6_V4  swarm         2f        1.0                 2000
# 165      LC_6_V4  swarm         nf        1.0                 2000
# 167      LC_6_V4  swarm         nf        2.0                 2000
# 168      LC_6_V4  swarm         nf        3.0                 2000
# 169      LC_6_V4  swarm         nf        4.0                 2000
# 170      LC_6_V4  swarm         nf        5.0                 2000
# 171      LC_6_V4  swarm         nf        6.0                 2000
# 172      LC_6_V4  swarm         nf        7.0                 2000
# 173      LC_6_V4  swarm         nf        8.0                 2000
# 174      LC_6_V4  swarm         nf        9.0                 2000
# 166      LC_6_V4  swarm         nf       10.0                 2000
# 76    LC_7_V3-V4  swarm         2f        1.0                 2000
# 66    LC_7_V3-V4  swarm         nf        1.0                 2000
# 68    LC_7_V3-V4  swarm         nf        2.0                 2000
# 69    LC_7_V3-V4  swarm         nf        3.0                 2000
# 70    LC_7_V3-V4  swarm         nf        4.0                 2000
# 71    LC_7_V3-V4  swarm         nf        5.0                 2000
# 72    LC_7_V3-V4  swarm         nf        6.0                 2000
# 73    LC_7_V3-V4  swarm         nf        7.0                 2000
# 74    LC_7_V3-V4  swarm         nf        8.0                 2000
# 75    LC_7_V3-V4  swarm         nf        9.0                 2000
# 67    LC_7_V3-V4  swarm         nf       10.0                 2000
# 186      LC_7_V4  swarm         2f        1.0                 2000
# 176      LC_7_V4  swarm         nf        1.0                 2000
# 178      LC_7_V4  swarm         nf        2.0                 2000
# 179      LC_7_V4  swarm         nf        3.0                 2000
# 180      LC_7_V4  swarm         nf        4.0                 2000
# 181      LC_7_V4  swarm         nf        5.0                 2000
# 182      LC_7_V4  swarm         nf        6.0                 2000
# 183      LC_7_V4  swarm         nf        7.0                 2000
# 184      LC_7_V4  swarm         nf        8.0                 2000
# 185      LC_7_V4  swarm         nf        9.0                 2000
# 177      LC_7_V4  swarm         nf       10.0                 2000
# 87    LC_8_V3-V4  swarm         2f        1.0                 1980
# 77    LC_8_V3-V4  swarm         nf        1.0                 1980
# 79    LC_8_V3-V4  swarm         nf        2.0                 1980
# 80    LC_8_V3-V4  swarm         nf        3.0                 1980
# 81    LC_8_V3-V4  swarm         nf        4.0                 1980
# 82    LC_8_V3-V4  swarm         nf        5.0                 1980
# 83    LC_8_V3-V4  swarm         nf        6.0                 1980
# 84    LC_8_V3-V4  swarm         nf        7.0                 1980
# 85    LC_8_V3-V4  swarm         nf        8.0                 1980
# 86    LC_8_V3-V4  swarm         nf        9.0                 1980
# 78    LC_8_V3-V4  swarm         nf       10.0                 1980
# 197      LC_8_V4  swarm         2f        1.0                 1980
# 187      LC_8_V4  swarm         nf        1.0                 1980
# 189      LC_8_V4  swarm         nf        2.0                 1980
# 190      LC_8_V4  swarm         nf        3.0                 1980
# 191      LC_8_V4  swarm         nf        4.0                 1980
# 192      LC_8_V4  swarm         nf        5.0                 1980
# 193      LC_8_V4  swarm         nf        6.0                 1980
# 194      LC_8_V4  swarm         nf        7.0                 1980
# 195      LC_8_V4  swarm         nf        8.0                 1980
# 196      LC_8_V4  swarm         nf        9.0                 1980
# 188      LC_8_V4  swarm         nf       10.0                 1980
# 98    LC_9_V3-V4  swarm         2f        1.0                 1980
# 88    LC_9_V3-V4  swarm         nf        1.0                 1980
# 90    LC_9_V3-V4  swarm         nf        2.0                 1980
# 91    LC_9_V3-V4  swarm         nf        3.0                 1980
# 92    LC_9_V3-V4  swarm         nf        4.0                 1980
# 93    LC_9_V3-V4  swarm         nf        5.0                 1980
# 94    LC_9_V3-V4  swarm         nf        6.0                 1980
# 95    LC_9_V3-V4  swarm         nf        7.0                 1980
# 96    LC_9_V3-V4  swarm         nf        8.0                 1980
# 97    LC_9_V3-V4  swarm         nf        9.0                 1980
# 89    LC_9_V3-V4  swarm         nf       10.0                 1980
# 208      LC_9_V4  swarm         2f        1.0                 1980
# 198      LC_9_V4  swarm         nf        1.0                 1980
# 200      LC_9_V4  swarm         nf        2.0                 1980
# 201      LC_9_V4  swarm         nf        3.0                 1980
# 202      LC_9_V4  swarm         nf        4.0                 1980
# 203      LC_9_V4  swarm         nf        5.0                 1980
# 204      LC_9_V4  swarm         nf        6.0                 1980
# 205      LC_9_V4  swarm         nf        7.0                 1980
# 206      LC_9_V4  swarm         nf        8.0                 1980
# 207      LC_9_V4  swarm         nf        9.0                 1980
# 199      LC_9_V4  swarm         nf       10.0                 1980
# 329  MC_10_V3-V4  swarm         2f        1.0                 4980
# 319  MC_10_V3-V4  swarm         nf        1.0                 4980
# 321  MC_10_V3-V4  swarm         nf        2.0                 4980
# 322  MC_10_V3-V4  swarm         nf        3.0                 4980
# 323  MC_10_V3-V4  swarm         nf        4.0                 4980
# 324  MC_10_V3-V4  swarm         nf        5.0                 4980
# 325  MC_10_V3-V4  swarm         nf        6.0                 4980
# 326  MC_10_V3-V4  swarm         nf        7.0                 4980
# 327  MC_10_V3-V4  swarm         nf        8.0                 4980
# 328  MC_10_V3-V4  swarm         nf        9.0                 4980
# 320  MC_10_V3-V4  swarm         nf       10.0                 4980
# 439     MC_10_V4  swarm         2f        1.0                 4980
# 429     MC_10_V4  swarm         nf        1.0                 4980
# 431     MC_10_V4  swarm         nf        2.0                 4980
# 432     MC_10_V4  swarm         nf        3.0                 4980
# 433     MC_10_V4  swarm         nf        4.0                 4980
# 434     MC_10_V4  swarm         nf        5.0                 4980
# 435     MC_10_V4  swarm         nf        6.0                 4980
# 436     MC_10_V4  swarm         nf        7.0                 4980
# 437     MC_10_V4  swarm         nf        8.0                 4980
# 438     MC_10_V4  swarm         nf        9.0                 4980
# 430     MC_10_V4  swarm         nf       10.0                 4980
# 230   MC_1_V3-V4  swarm         2f        1.0                 4960
# 220   MC_1_V3-V4  swarm         nf        1.0                 4960
# 222   MC_1_V3-V4  swarm         nf        2.0                 4960
# 223   MC_1_V3-V4  swarm         nf        3.0                 4960
# 224   MC_1_V3-V4  swarm         nf        4.0                 4960
# 225   MC_1_V3-V4  swarm         nf        5.0                 4960
# 226   MC_1_V3-V4  swarm         nf        6.0                 4960
# 227   MC_1_V3-V4  swarm         nf        7.0                 4960
# 228   MC_1_V3-V4  swarm         nf        8.0                 4960
# 229   MC_1_V3-V4  swarm         nf        9.0                 4960
# 221   MC_1_V3-V4  swarm         nf       10.0                 4960
# 340      MC_1_V4  swarm         2f        1.0                 4960
# 330      MC_1_V4  swarm         nf        1.0                 4960
# 332      MC_1_V4  swarm         nf        2.0                 4960
# 333      MC_1_V4  swarm         nf        3.0                 4960
# 334      MC_1_V4  swarm         nf        4.0                 4960
# 335      MC_1_V4  swarm         nf        5.0                 4960
# 336      MC_1_V4  swarm         nf        6.0                 4960
# 337      MC_1_V4  swarm         nf        7.0                 4960
# 338      MC_1_V4  swarm         nf        8.0                 4960
# 339      MC_1_V4  swarm         nf        9.0                 4960
# 331      MC_1_V4  swarm         nf       10.0                 4960
# 241   MC_2_V3-V4  swarm         2f        1.0                 4940
# 231   MC_2_V3-V4  swarm         nf        1.0                 4940
# 233   MC_2_V3-V4  swarm         nf        2.0                 4940
# 234   MC_2_V3-V4  swarm         nf        3.0                 4940
# 235   MC_2_V3-V4  swarm         nf        4.0                 4940
# 236   MC_2_V3-V4  swarm         nf        5.0                 4940
# 237   MC_2_V3-V4  swarm         nf        6.0                 4940
# 238   MC_2_V3-V4  swarm         nf        7.0                 4940
# 239   MC_2_V3-V4  swarm         nf        8.0                 4940
# 240   MC_2_V3-V4  swarm         nf        9.0                 4940
# 232   MC_2_V3-V4  swarm         nf       10.0                 4940
# 351      MC_2_V4  swarm         2f        1.0                 4940
# 341      MC_2_V4  swarm         nf        1.0                 4940
# 343      MC_2_V4  swarm         nf        2.0                 4940
# 344      MC_2_V4  swarm         nf        3.0                 4940
# 345      MC_2_V4  swarm         nf        4.0                 4940
# 346      MC_2_V4  swarm         nf        5.0                 4940
# 347      MC_2_V4  swarm         nf        6.0                 4940
# 348      MC_2_V4  swarm         nf        7.0                 4940
# 349      MC_2_V4  swarm         nf        8.0                 4940
# 350      MC_2_V4  swarm         nf        9.0                 4940
# 342      MC_2_V4  swarm         nf       10.0                 4940
# 252   MC_3_V3-V4  swarm         2f        1.0                 4980
# 242   MC_3_V3-V4  swarm         nf        1.0                 4980
# 244   MC_3_V3-V4  swarm         nf        2.0                 4980
# 245   MC_3_V3-V4  swarm         nf        3.0                 4980
# 246   MC_3_V3-V4  swarm         nf        4.0                 4980
# 247   MC_3_V3-V4  swarm         nf        5.0                 4980
# 248   MC_3_V3-V4  swarm         nf        6.0                 4980
# 249   MC_3_V3-V4  swarm         nf        7.0                 4980
# 250   MC_3_V3-V4  swarm         nf        8.0                 4980
# 251   MC_3_V3-V4  swarm         nf        9.0                 4980
# 243   MC_3_V3-V4  swarm         nf       10.0                 4980
# 362      MC_3_V4  swarm         2f        1.0                 4980
# 352      MC_3_V4  swarm         nf        1.0                 4980
# 354      MC_3_V4  swarm         nf        2.0                 4980
# 355      MC_3_V4  swarm         nf        3.0                 4980
# 356      MC_3_V4  swarm         nf        4.0                 4980
# 357      MC_3_V4  swarm         nf        5.0                 4980
# 358      MC_3_V4  swarm         nf        6.0                 4980
# 359      MC_3_V4  swarm         nf        7.0                 4980
# 360      MC_3_V4  swarm         nf        8.0                 4980
# 361      MC_3_V4  swarm         nf        9.0                 4980
# 353      MC_3_V4  swarm         nf       10.0                 4980
# 263   MC_4_V3-V4  swarm         2f        1.0                 4980
# 253   MC_4_V3-V4  swarm         nf        1.0                 4980
# 255   MC_4_V3-V4  swarm         nf        2.0                 4980
# 256   MC_4_V3-V4  swarm         nf        3.0                 4980
# 257   MC_4_V3-V4  swarm         nf        4.0                 4980
# 258   MC_4_V3-V4  swarm         nf        5.0                 4980
# 259   MC_4_V3-V4  swarm         nf        6.0                 4980
# 260   MC_4_V3-V4  swarm         nf        7.0                 4980
# 261   MC_4_V3-V4  swarm         nf        8.0                 4980
# 262   MC_4_V3-V4  swarm         nf        9.0                 4980
# 254   MC_4_V3-V4  swarm         nf       10.0                 4980
# 373      MC_4_V4  swarm         2f        1.0                 4980
# 363      MC_4_V4  swarm         nf        1.0                 4980
# 365      MC_4_V4  swarm         nf        2.0                 4980
# 366      MC_4_V4  swarm         nf        3.0                 4980
# 367      MC_4_V4  swarm         nf        4.0                 4980
# 368      MC_4_V4  swarm         nf        5.0                 4980
# 369      MC_4_V4  swarm         nf        6.0                 4980
# 370      MC_4_V4  swarm         nf        7.0                 4980
# 371      MC_4_V4  swarm         nf        8.0                 4980
# 372      MC_4_V4  swarm         nf        9.0                 4980
# 364      MC_4_V4  swarm         nf       10.0                 4980
# 274   MC_5_V3-V4  swarm         2f        1.0                 4940
# 264   MC_5_V3-V4  swarm         nf        1.0                 4940
# 266   MC_5_V3-V4  swarm         nf        2.0                 4940
# 267   MC_5_V3-V4  swarm         nf        3.0                 4940
# 268   MC_5_V3-V4  swarm         nf        4.0                 4940
# 269   MC_5_V3-V4  swarm         nf        5.0                 4940
# 270   MC_5_V3-V4  swarm         nf        6.0                 4940
# 271   MC_5_V3-V4  swarm         nf        7.0                 4940
# 272   MC_5_V3-V4  swarm         nf        8.0                 4940
# 273   MC_5_V3-V4  swarm         nf        9.0                 4940
# 265   MC_5_V3-V4  swarm         nf       10.0                 4940
# 384      MC_5_V4  swarm         2f        1.0                 4940
# 374      MC_5_V4  swarm         nf        1.0                 4940
# 376      MC_5_V4  swarm         nf        2.0                 4940
# 377      MC_5_V4  swarm         nf        3.0                 4940
# 378      MC_5_V4  swarm         nf        4.0                 4940
# 379      MC_5_V4  swarm         nf        5.0                 4940
# 380      MC_5_V4  swarm         nf        6.0                 4940
# 381      MC_5_V4  swarm         nf        7.0                 4940
# 382      MC_5_V4  swarm         nf        8.0                 4940
# 383      MC_5_V4  swarm         nf        9.0                 4940
# 375      MC_5_V4  swarm         nf       10.0                 4940
# 285   MC_6_V3-V4  swarm         2f        1.0                 4960
# 275   MC_6_V3-V4  swarm         nf        1.0                 4960
# 277   MC_6_V3-V4  swarm         nf        2.0                 4960
# 278   MC_6_V3-V4  swarm         nf        3.0                 4960
# 279   MC_6_V3-V4  swarm         nf        4.0                 4960
# 280   MC_6_V3-V4  swarm         nf        5.0                 4960
# 281   MC_6_V3-V4  swarm         nf        6.0                 4960
# 282   MC_6_V3-V4  swarm         nf        7.0                 4960
# 283   MC_6_V3-V4  swarm         nf        8.0                 4960
# 284   MC_6_V3-V4  swarm         nf        9.0                 4960
# 276   MC_6_V3-V4  swarm         nf       10.0                 4960
# 395      MC_6_V4  swarm         2f        1.0                 4960
# 385      MC_6_V4  swarm         nf        1.0                 4960
# 387      MC_6_V4  swarm         nf        2.0                 4960
# 388      MC_6_V4  swarm         nf        3.0                 4960
# 389      MC_6_V4  swarm         nf        4.0                 4960
# 390      MC_6_V4  swarm         nf        5.0                 4960
# 391      MC_6_V4  swarm         nf        6.0                 4960
# 392      MC_6_V4  swarm         nf        7.0                 4960
# 393      MC_6_V4  swarm         nf        8.0                 4960
# 394      MC_6_V4  swarm         nf        9.0                 4960
# 386      MC_6_V4  swarm         nf       10.0                 4960
# 296   MC_7_V3-V4  swarm         2f        1.0                 4960
# 286   MC_7_V3-V4  swarm         nf        1.0                 4960
# 288   MC_7_V3-V4  swarm         nf        2.0                 4960
# 289   MC_7_V3-V4  swarm         nf        3.0                 4960
# 290   MC_7_V3-V4  swarm         nf        4.0                 4960
# 291   MC_7_V3-V4  swarm         nf        5.0                 4960
# 292   MC_7_V3-V4  swarm         nf        6.0                 4960
# 293   MC_7_V3-V4  swarm         nf        7.0                 4960
# 294   MC_7_V3-V4  swarm         nf        8.0                 4960
# 295   MC_7_V3-V4  swarm         nf        9.0                 4960
# 287   MC_7_V3-V4  swarm         nf       10.0                 4960
# 406      MC_7_V4  swarm         2f        1.0                 4960
# 396      MC_7_V4  swarm         nf        1.0                 4960
# 398      MC_7_V4  swarm         nf        2.0                 4960
# 399      MC_7_V4  swarm         nf        3.0                 4960
# 400      MC_7_V4  swarm         nf        4.0                 4960
# 401      MC_7_V4  swarm         nf        5.0                 4960
# 402      MC_7_V4  swarm         nf        6.0                 4960
# 403      MC_7_V4  swarm         nf        7.0                 4960
# 404      MC_7_V4  swarm         nf        8.0                 4960
# 405      MC_7_V4  swarm         nf        9.0                 4960
# 397      MC_7_V4  swarm         nf       10.0                 4960
# 307   MC_8_V3-V4  swarm         2f        1.0                 4980
# 297   MC_8_V3-V4  swarm         nf        1.0                 4980
# 299   MC_8_V3-V4  swarm         nf        2.0                 4980
# 300   MC_8_V3-V4  swarm         nf        3.0                 4980
# 301   MC_8_V3-V4  swarm         nf        4.0                 4980
# 302   MC_8_V3-V4  swarm         nf        5.0                 4980
# 303   MC_8_V3-V4  swarm         nf        6.0                 4980
# 304   MC_8_V3-V4  swarm         nf        7.0                 4980
# 305   MC_8_V3-V4  swarm         nf        8.0                 4980
# 306   MC_8_V3-V4  swarm         nf        9.0                 4980
# 298   MC_8_V3-V4  swarm         nf       10.0                 4980
# 417      MC_8_V4  swarm         2f        1.0                 4980
# 407      MC_8_V4  swarm         nf        1.0                 4980
# 409      MC_8_V4  swarm         nf        2.0                 4980
# 410      MC_8_V4  swarm         nf        3.0                 4980
# 411      MC_8_V4  swarm         nf        4.0                 4980
# 412      MC_8_V4  swarm         nf        5.0                 4980
# 413      MC_8_V4  swarm         nf        6.0                 4980
# 414      MC_8_V4  swarm         nf        7.0                 4980
# 415      MC_8_V4  swarm         nf        8.0                 4980
# 416      MC_8_V4  swarm         nf        9.0                 4980
# 408      MC_8_V4  swarm         nf       10.0                 4980
# 318   MC_9_V3-V4  swarm         2f        1.0                 4980
# 308   MC_9_V3-V4  swarm         nf        1.0                 4980
# 310   MC_9_V3-V4  swarm         nf        2.0                 4980
# 311   MC_9_V3-V4  swarm         nf        3.0                 4980
# 312   MC_9_V3-V4  swarm         nf        4.0                 4980
# 313   MC_9_V3-V4  swarm         nf        5.0                 4980
# 314   MC_9_V3-V4  swarm         nf        6.0                 4980
# 315   MC_9_V3-V4  swarm         nf        7.0                 4980
# 316   MC_9_V3-V4  swarm         nf        8.0                 4980
# 317   MC_9_V3-V4  swarm         nf        9.0                 4980
# 309   MC_9_V3-V4  swarm         nf       10.0                 4980
# 428      MC_9_V4  swarm         2f        1.0                 4980
# 418      MC_9_V4  swarm         nf        1.0                 4980
# 420      MC_9_V4  swarm         nf        2.0                 4980
# 421      MC_9_V4  swarm         nf        3.0                 4980
# 422      MC_9_V4  swarm         nf        4.0                 4980
# 423      MC_9_V4  swarm         nf        5.0                 4980
# 424      MC_9_V4  swarm         nf        6.0                 4980
# 425      MC_9_V4  swarm         nf        7.0                 4980
# 426      MC_9_V4  swarm         nf        8.0                 4980
# 427      MC_9_V4  swarm         nf        9.0                 4980
# 419      MC_9_V4  swarm         nf       10.0                 4980
#
#      input_mass  num_clusters  num_output_amplicons  output_mass
# 549        9940          9831                  9935         9940
# 539        9940          9884                  9935         9940
# 541        9940          9651                  9935         9940
# 542        9940          9002                  9935         9940
# 543        9940          7890                  9935         9940
# 544        9940          6234                  9935         9940
# 545        9940          4462                  9935         9940
# 546        9940          2956                  9935         9940
# 547        9940          1799                  9935         9940
# 548        9940          1090                  9935         9940
# 540        9940           702                  9935         9940
# 659        9940          2398                  8266         9940
# 649        9940          4920                  8266         9940
# 651        9940          2339                  8266         9940
# 652        9940          1009                  8266         9940
# 653        9940           514                  8266         9940
# 654        9940           349                  8266         9940
# 655        9940           300                  8266         9940
# 656        9940           275                  8266         9940
# 657        9940           260                  8266         9940
# 658        9940           250                  8266         9940
# 650        9940           234                  8266         9940
# 450        9940          9784                  9936         9940
# 440        9940          9860                  9936         9940
# ...
# 92         1980          1594                  1979         1980
# 93         1980          1249                  1979         1980
# 94         1980           923                  1979         1980
# 95         1980           636                  1979         1980
# 96         1980           409                  1979         1980
# 97         1980           276                  1979         1980
# 89         1980           188                  1979         1980
# 208        1980           488                  1649         1980
# 198        1980           980                  1649         1980
# 200        1980           477                  1649         1980
# 201        1980           205                  1649         1980
# 202        1980           118                  1649         1980
# 203        1980            89                  1649         1980
# 204        1980            83                  1649         1980
# 205        1980            80                  1649         1980
# 206        1980            78                  1649         1980
# 207        1980            78                  1649         1980
# 199        1980            77                  1649         1980
# 329        4980          4942                  4977         4980
# 319        4980          4949                  4977         4980
# 321        4980          4830                  4977         4980
# 322        4980          4489                  4977         4980
# 323        4980          3877                  4977         4980
# 324        4980          3072                  4977         4980
# 325        4980          2220                  4977         4980
# 326        4980          1471                  4977         4980
# 327        4980           913                  4977         4980
# 328        4980           589                  4977         4980
# 320        4980           380                  4977         4980
# 439        4980          1198                  4143         4980
# 429        4980          2488                  4143         4980
# 431        4980          1171                  4143         4980
# 432        4980           511                  4143         4980
# 433        4980           265                  4143         4980
# 434        4980           178                  4143         4980
# 435        4980           151                  4143         4980
# 436        4980           137                  4143         4980
# 437        4980           129                  4143         4980
# 438        4980           125                  4143         4980
# 430        4980           121                  4143         4980
# 230        4960          4924                  4957         4960
# 220        4960          4935                  4957         4960
# 222        4960          4842                  4957         4960
# 223        4960          4532                  4957         4960
# 224        4960          3972                  4957         4960
# 225        4960          3143                  4957         4960
# 226        4960          2286                  4957         4960
# 227        4960          1555                  4957         4960
# 228        4960           976                  4957         4960
# 229        4960           589                  4957         4960
# 221        4960           391                  4957         4960
# 340        4960          1231                  4112         4960
# 330        4960          2500                  4112         4960
# 332        4960          1205                  4112         4960
# 333        4960           510                  4112         4960
# 334        4960           283                  4112         4960
# 335        4960           210                  4112         4960
# 336        4960           179                  4112         4960
# 337        4960           167                  4112         4960
# 338        4960           159                  4112         4960
# 339        4960           157                  4112         4960
# 331        4960           153                  4112         4960
# 241        4940          4889                  4938         4940
# 231        4940          4909                  4938         4940
# 233        4940          4792                  4938         4940
# 234        4940          4451                  4938         4940
# 235        4940          3852                  4938         4940
# 236        4940          3046                  4938         4940
# 237        4940          2180                  4938         4940
# 238        4940          1427                  4938         4940
# 239        4940           896                  4938         4940
# 240        4940           558                  4938         4940
# 232        4940           344                  4938         4940
# 351        4940          1145                  4046         4940
# 341        4940          2384                  4046         4940
# 343        4940          1131                  4046         4940
# 344        4940           512                  4046         4940
# 345        4940           275                  4046         4940
# 346        4940           207                  4046         4940
# 347        4940           185                  4046         4940
# 348        4940           174                  4046         4940
# 349        4940           168                  4046         4940
# 350        4940           161                  4046         4940
# 342        4940           155                  4046         4940
# 252        4980          4948                  4975         4980
# 242        4980          4957                  4975         4980
# 244        4980          4848                  4975         4980
# 245        4980          4546                  4975         4980
# 246        4980          3958                  4975         4980
# 247        4980          3142                  4975         4980
# 248        4980          2298                  4975         4980
# 249        4980          1507                  4975         4980
# 250        4980           971                  4975         4980
# 251        4980           617                  4975         4980
# 243        4980           405                  4975         4980
# 362        4980          1161                  4103         4980
# 352        4980          2425                  4103         4980
# 354        4980          1144                  4103         4980
# 355        4980           528                  4103         4980
# 356        4980           289                  4103         4980
# 357        4980           219                  4103         4980
# 358        4980           197                  4103         4980
# 359        4980           191                  4103         4980
# 360        4980           181                  4103         4980
# 361        4980           177                  4103         4980
# 353        4980           172                  4103         4980
# 263        4980          4917                  4978         4980
# 253        4980          4945                  4978         4980
# 255        4980          4826                  4978         4980
# 256        4980          4554                  4978         4980
# 257        4980          3961                  4978         4980
# 258        4980          3121                  4978         4980
# 259        4980          2256                  4978         4980
# 260        4980          1561                  4978         4980
# 261        4980           986                  4978         4980
# 262        4980           626                  4978         4980
# 254        4980           407                  4978         4980
# 373        4980          1183                  4043         4980
# 363        4980          2387                  4043         4980
# 365        4980          1153                  4043         4980
# 366        4980           527                  4043         4980
# 367        4980           286                  4043         4980
# 368        4980           204                  4043         4980
# 369        4980           186                  4043         4980
# 370        4980           177                  4043         4980
# 371        4980           164                  4043         4980
# 372        4980           159                  4043         4980
# 364        4980           153                  4043         4980
# 274        4940          4896                  4934         4940
# 264        4940          4909                  4934         4940
# 266        4940          4798                  4934         4940
# 267        4940          4456                  4934         4940
# 268        4940          3871                  4934         4940
# 269        4940          3084                  4934         4940
# 270        4940          2234                  4934         4940
# 271        4940          1535                  4934         4940
# 272        4940           952                  4934         4940
# 273        4940           582                  4934         4940
# 265        4940           378                  4934         4940
# 384        4940          1221                  4104         4940
# 374        4940          2457                  4104         4940
# 376        4940          1193                  4104         4940
# 377        4940           546                  4104         4940
# 378        4940           283                  4104         4940
# 379        4940           205                  4104         4940
# 380        4940           182                  4104         4940
# 381        4940           170                  4104         4940
# 382        4940           163                  4104         4940
# 383        4940           159                  4104         4940
# 375        4940           151                  4104         4940
# 285        4960          4910                  4955         4960
# 275        4960          4923                  4955         4960
# 277        4960          4802                  4955         4960
# 278        4960          4459                  4955         4960
# 279        4960          3884                  4955         4960
# 280        4960          3076                  4955         4960
# 281        4960          2248                  4955         4960
# 282        4960          1520                  4955         4960
# 283        4960           965                  4955         4960
# 284        4960           579                  4955         4960
# 276        4960           372                  4955         4960
# 395        4960          1188                  4096         4960
# 385        4960          2450                  4096         4960
# 387        4960          1174                  4096         4960
# 388        4960           539                  4096         4960
# 389        4960           283                  4096         4960
# 390        4960           198                  4096         4960
# 391        4960           173                  4096         4960
# 392        4960           164                  4096         4960
# 393        4960           159                  4096         4960
# 394        4960           157                  4096         4960
# 386        4960           154                  4096         4960
# 296        4960          4927                  4958         4960
# 286        4960          4941                  4958         4960
# 288        4960          4833                  4958         4960
# 289        4960          4502                  4958         4960
# 290        4960          3950                  4958         4960
# 291        4960          3197                  4958         4960
# 292        4960          2289                  4958         4960
# 293        4960          1568                  4958         4960
# 294        4960           990                  4958         4960
# 295        4960           613                  4958         4960
# 287        4960           389                  4958         4960
# 406        4960          1156                  4111         4960
# 396        4960          2417                  4111         4960
# 398        4960          1142                  4111         4960
# 399        4960           511                  4111         4960
# 400        4960           283                  4111         4960
# 401        4960           207                  4111         4960
# 402        4960           184                  4111         4960
# 403        4960           173                  4111         4960
# 404        4960           166                  4111         4960
# 405        4960           159                  4111         4960
# 397        4960           157                  4111         4960
# 307        4980          4933                  4975         4980
# 297        4980          4949                  4975         4980
# 299        4980          4848                  4975         4980
# 300        4980          4487                  4975         4980
# 301        4980          3879                  4975         4980
# 302        4980          3102                  4975         4980
# 303        4980          2256                  4975         4980
# 304        4980          1508                  4975         4980
# 305        4980           932                  4975         4980
# 306        4980           569                  4975         4980
# 298        4980           377                  4975         4980
# 417        4980          1180                  4107         4980
# 407        4980          2459                  4107         4980
# 409        4980          1172                  4107         4980
# 410        4980           512                  4107         4980
# 411        4980           288                  4107         4980
# 412        4980           203                  4107         4980
# 413        4980           173                  4107         4980
# 414        4980           168                  4107         4980
# 415        4980           162                  4107         4980
# 416        4980           159                  4107         4980
# 408        4980           157                  4107         4980
# 318        4980          4955                  4979         4980
# 308        4980          4960                  4979         4980
# 310        4980          4868                  4979         4980
# 311        4980          4590                  4979         4980
# 312        4980          4054                  4979         4980
# 313        4980          3265                  4979         4980
# 314        4980          2393                  4979         4980
# 315        4980          1596                  4979         4980
# 316        4980           993                  4979         4980
# 317        4980           635                  4979         4980
# 309        4980           417                  4979         4980
# 428        4980          1181                  4150         4980
# 418        4980          2423                  4150         4980
# 420        4980          1168                  4150         4980
# 421        4980           522                  4150         4980
# 422        4980           303                  4150         4980
# 423        4980           222                  4150         4980
# 424        4980           195                  4150         4980
# 425        4980           187                  4150         4980
# 426        4980           177                  4150         4980
# 427        4980           166                  4150         4980
# 419        4980           163                  4150         4980

# %%
df_counts.to_csv('%s/df_counts.csv' % eval_dir, sep = ';', index = False)
#df_counts = pd.read_csv('%s/df_counts.csv' % eval_dir, sep = ';')

# %% [markdown]
# ### Clustering quality

# %%
# Requires the metrics files. Alternatively, the evaluation can use the stored information (see below).
dfs = []
for ds in data_sets:
    for rt in regions:
        for s in range(1, num_samples + 1):
            run_name = '%s_%i_%s' % (ds, s, rt)
            
            for opt in opts:
                for gt in ground_truths:
                    df = pd.read_csv('%s/%s/%s/%s_%s_%s__metrics.csv' % (results_dir, run_name, opt, opt, run_name, gt), sep = ';')
                    
                    df['gt'] = gt
                    df['mode'] = 'swarm'
                    df['refinement'] = [m.split('__')[1] for m in df['task']]
                    df['ds'] = ds
                    df['rt'] = rt
                    
                    dfs.append(df)
                    
df_quality = pd.concat(dfs, ignore_index = True)
df_quality.rename(columns = {'task': 'run', 'reads': 'data_set'}, inplace = True)
df_quality.sort_values(by = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'threshold'], inplace = True)

# %% [markdown]
# *Column descriptions:*
# `precision`: Quantifies the extent to which amplicons in a cluster are also from the same species.
# `recall`: Measures the proportion of amplicons from the same species that are grouped in the same cluster.
# `adjrandindex`: Measures the agreement between the clusters and the taxonomic assignment and corrects for chance.

# %%
df_quality[['data_set', 'gt', 'tool', 'refinement', 'threshold', 'precision', 'recall', 'adjrandindex']]
# Out:
#         data_set       gt   tool refinement  threshold  precision    recall  \
# 549  HC_10_V3-V4  franzen  swarm         2f        1.0   0.996980  0.058983
# 539  HC_10_V3-V4  franzen  swarm         nf        1.0   0.998993  0.054454
# 540  HC_10_V3-V4  franzen  swarm         nf        2.0   0.995571  0.075893
# 541  HC_10_V3-V4  franzen  swarm         nf        3.0   0.982788  0.138500
# 542  HC_10_V3-V4  franzen  swarm         nf        4.0   0.963463  0.248012
# 543  HC_10_V3-V4  franzen  swarm         nf        5.0   0.924811  0.412380
# 544  HC_10_V3-V4  franzen  swarm         nf        6.0   0.880624  0.589834
# 545  HC_10_V3-V4  franzen  swarm         nf        7.0   0.825767  0.740312
# 546  HC_10_V3-V4  franzen  swarm         nf        8.0   0.776850  0.855460
# 547  HC_10_V3-V4  franzen  swarm         nf        9.0   0.743634  0.926220
# 548  HC_10_V3-V4  franzen  swarm         nf       10.0   0.713236  0.964368
# 659     HC_10_V4  franzen  swarm         2f        1.0   0.851803  0.757077
# 649     HC_10_V4  franzen  swarm         nf        1.0   0.921244  0.452214
# 650     HC_10_V4  franzen  swarm         nf        2.0   0.806073  0.759981
# 651     HC_10_V4  franzen  swarm         nf        3.0   0.726107  0.918582
# 652     HC_10_V4  franzen  swarm         nf        4.0   0.672272  0.975442
# 653     HC_10_V4  franzen  swarm         nf        5.0   0.635616  0.994677
# 654     HC_10_V4  franzen  swarm         nf        6.0   0.602589  0.998669
# 655     HC_10_V4  franzen  swarm         nf        7.0   0.557948  0.998790
# 656     HC_10_V4  franzen  swarm         nf        8.0   0.522623  0.997822
# 657     HC_10_V4  franzen  swarm         nf        9.0   0.493951  0.997218
# 658     HC_10_V4  franzen  swarm         nf       10.0   0.465279  0.997701
# 450   HC_1_V3-V4  franzen  swarm         2f        1.0   0.994062  0.062802
# 440   HC_1_V3-V4  franzen  swarm         nf        1.0   0.998289  0.056159
# 441   HC_1_V3-V4  franzen  swarm         nf        2.0   0.992250  0.081824
# 442   HC_1_V3-V4  franzen  swarm         nf        3.0   0.976550  0.151067
# 443   HC_1_V3-V4  franzen  swarm         nf        4.0   0.949577  0.261373
# 444   HC_1_V3-V4  franzen  swarm         nf        5.0   0.904891  0.429247
# 445   HC_1_V3-V4  franzen  swarm         nf        6.0   0.856783  0.602456
# 446   HC_1_V3-V4  franzen  swarm         nf        7.0   0.811896  0.741244
# 447   HC_1_V3-V4  franzen  swarm         nf        8.0   0.762077  0.849537
# 448   HC_1_V3-V4  franzen  swarm         nf        9.0   0.727154  0.923510
# 449   HC_1_V3-V4  franzen  swarm         nf       10.0   0.694243  0.961957
# 560      HC_1_V4  franzen  swarm         2f        1.0   0.826921  0.759375
# 550      HC_1_V4  franzen  swarm         nf        1.0   0.898253  0.456211
# 551      HC_1_V4  franzen  swarm         nf        2.0   0.779040  0.761207
# 552      HC_1_V4  franzen  swarm         nf        3.0   0.692073  0.917674
# 553      HC_1_V4  franzen  swarm         nf        4.0   0.629901  0.975937
# 554      HC_1_V4  franzen  swarm         nf        5.0   0.598021  0.992793
# 555      HC_1_V4  franzen  swarm         nf        6.0   0.571027  0.997069
# 556      HC_1_V4  franzen  swarm         nf        7.0   0.534995  0.998290
# 557      HC_1_V4  franzen  swarm         nf        8.0   0.493832  0.998412
# 558      HC_1_V4  franzen  swarm         nf        9.0   0.454501  0.997924
# 559      HC_1_V4  franzen  swarm         nf       10.0   0.423354  0.997679
# 461   HC_2_V3-V4  franzen  swarm         2f        1.0   0.994977  0.058965
# 451   HC_2_V3-V4  franzen  swarm         nf        1.0   0.997991  0.054244
# 452   HC_2_V3-V4  franzen  swarm         nf        2.0   0.992265  0.076745
# 453   HC_2_V3-V4  franzen  swarm         nf        3.0   0.978704  0.141537
# 454   HC_2_V3-V4  franzen  swarm         nf        4.0   0.954093  0.255851
# 455   HC_2_V3-V4  franzen  swarm         nf        5.0   0.918734  0.412958
# 456   HC_2_V3-V4  franzen  swarm         nf        6.0   0.871522  0.585635
# 457   HC_2_V3-V4  franzen  swarm         nf        7.0   0.817278  0.742943
# 458   HC_2_V3-V4  franzen  swarm         nf        8.0   0.772878  0.850527
# 459   HC_2_V3-V4  franzen  swarm         nf        9.0   0.736916  0.924561
# 460   HC_2_V3-V4  franzen  swarm         nf       10.0   0.711703  0.963235
# 571      HC_2_V4  franzen  swarm         2f        1.0   0.830735  0.756720
# 561      HC_2_V4  franzen  swarm         nf        1.0   0.905364  0.447895
# 562      HC_2_V4  franzen  swarm         nf        2.0   0.776973  0.756229
# 563      HC_2_V4  franzen  swarm         nf        3.0   0.672517  0.914693
# 564      HC_2_V4  franzen  swarm         nf        4.0   0.607463  0.974346
# 565      HC_2_V4  franzen  swarm         nf        5.0   0.561065  0.992758
# 566      HC_2_V4  franzen  swarm         nf        6.0   0.523506  0.996195
# 567      HC_2_V4  franzen  swarm         nf        7.0   0.481527  0.996563
# 568      HC_2_V4  franzen  swarm         nf        8.0   0.442862  0.997054
# 569      HC_2_V4  franzen  swarm         nf        9.0   0.411685  0.995827
# 570      HC_2_V4  franzen  swarm         nf       10.0   0.381981  0.994845
# 472   HC_3_V3-V4  franzen  swarm         2f        1.0   0.996685  0.058770
# 462   HC_3_V3-V4  franzen  swarm         nf        1.0   0.998694  0.054852
# 463   HC_3_V3-V4  franzen  swarm         nf        2.0   0.994374  0.076050
# 464   HC_3_V3-V4  franzen  swarm         nf        3.0   0.981214  0.143058
# 465   HC_3_V3-V4  franzen  swarm         nf        4.0   0.953687  0.268736
# 466   HC_3_V3-V4  franzen  swarm         nf        5.0   0.909885  0.440526
# 467   HC_3_V3-V4  franzen  swarm         nf        6.0   0.856841  0.609303
# 468   HC_3_V3-V4  franzen  swarm         nf        7.0   0.813944  0.760699
# 469   HC_3_V3-V4  franzen  swarm         nf        8.0   0.778782  0.864376
# 470   HC_3_V3-V4  franzen  swarm         nf        9.0   0.747237  0.933092
# 471   HC_3_V3-V4  franzen  swarm         nf       10.0   0.712578  0.968154
# 582      HC_3_V4  franzen  swarm         2f        1.0   0.850480  0.756711
# 572      HC_3_V4  franzen  swarm         nf        1.0   0.914855  0.451233
# 573      HC_3_V4  franzen  swarm         nf        2.0   0.806025  0.760476
# 574      HC_3_V4  franzen  swarm         nf        3.0   0.724766  0.914855
# 575      HC_3_V4  franzen  swarm         nf        4.0   0.675088  0.976315
# 576      HC_3_V4  franzen  swarm         nf        5.0   0.637678  0.994899
# 577      HC_3_V4  franzen  swarm         nf        6.0   0.597595  0.998421
# 578      HC_3_V4  franzen  swarm         nf        7.0   0.560549  0.999514
# 579      HC_3_V4  franzen  swarm         nf        8.0   0.528726  0.999028
# 580      HC_3_V4  franzen  swarm         nf        9.0   0.497631  0.998664
# 581      HC_3_V4  franzen  swarm         nf       10.0   0.472003  0.997328
# 483   HC_4_V3-V4  franzen  swarm         2f        1.0   0.994787  0.060345
# 473   HC_4_V3-V4  franzen  swarm         nf        1.0   0.998496  0.055433
# 474   HC_4_V3-V4  franzen  swarm         nf        2.0   0.993284  0.078388
# 475   HC_4_V3-V4  franzen  swarm         nf        3.0   0.978448  0.142041
# 476   HC_4_V3-V4  franzen  swarm         nf        4.0   0.952185  0.258220
# 477   HC_4_V3-V4  franzen  swarm         nf        5.0   0.913893  0.424018
# 478   HC_4_V3-V4  franzen  swarm         nf        6.0   0.870088  0.592422
# 479   HC_4_V3-V4  franzen  swarm         nf        7.0   0.832899  0.744086
# 480   HC_4_V3-V4  franzen  swarm         nf        8.0   0.803929  0.851143
# 481   HC_4_V3-V4  franzen  swarm         nf        9.0   0.769146  0.920008
# 482   HC_4_V3-V4  franzen  swarm         nf       10.0   0.740878  0.965016
# 593      HC_4_V4  franzen  swarm         2f        1.0   0.856137  0.759864
# 583      HC_4_V4  franzen  swarm         nf        1.0   0.917446  0.459269
# 584      HC_4_V4  franzen  swarm         nf        2.0   0.808061  0.760592
# 585      HC_4_V4  franzen  swarm         nf        3.0   0.730242  0.918053
# 586      HC_4_V4  franzen  swarm         nf        4.0   0.683623  0.977055
# 587      HC_4_V4  franzen  swarm         nf        5.0   0.647444  0.994780
# 588      HC_4_V4  franzen  swarm         nf        6.0   0.604225  0.997451
# 589      HC_4_V4  franzen  swarm         nf        7.0   0.576423  0.998543
# 590      HC_4_V4  franzen  swarm         nf        8.0   0.546073  0.996722
# 591      HC_4_V4  franzen  swarm         nf        9.0   0.502974  0.997086
# 592      HC_4_V4  franzen  swarm         nf       10.0   0.478937  0.997086
# 494   HC_5_V3-V4  franzen  swarm         2f        1.0   0.997394  0.057638
# 484   HC_5_V3-V4  franzen  swarm         nf        1.0   0.999298  0.054330
# 485   HC_5_V3-V4  franzen  swarm         nf        2.0   0.995890  0.077887
# 486   HC_5_V3-V4  franzen  swarm         nf        3.0   0.980754  0.144547
# 487   HC_5_V3-V4  franzen  swarm         nf        4.0   0.954892  0.262430
# 488   HC_5_V3-V4  franzen  swarm         nf        5.0   0.909884  0.432237
# 489   HC_5_V3-V4  franzen  swarm         nf        6.0   0.859062  0.599639
# 490   HC_5_V3-V4  franzen  swarm         nf        7.0   0.814054  0.744286
# 491   HC_5_V3-V4  franzen  swarm         nf        8.0   0.765738  0.850541
# 492   HC_5_V3-V4  franzen  swarm         nf        9.0   0.733260  0.922614
# 493   HC_5_V3-V4  franzen  swarm         nf       10.0   0.702285  0.962009
# 604      HC_5_V4  franzen  swarm         2f        1.0   0.799418  0.767504
# 594      HC_5_V4  franzen  swarm         nf        1.0   0.887514  0.454678
# 595      HC_5_V4  franzen  swarm         nf        2.0   0.751608  0.768232
# 596      HC_5_V4  franzen  swarm         nf        3.0   0.647009  0.916272
# 597      HC_5_V4  franzen  swarm         nf        4.0   0.590220  0.976823
# 598      HC_5_V4  franzen  swarm         nf        5.0   0.556243  0.993205
# 599      HC_5_V4  franzen  swarm         nf        6.0   0.529426  0.998180
# 600      HC_5_V4  franzen  swarm         nf        7.0   0.502245  0.999029
# 601      HC_5_V4  franzen  swarm         nf        8.0   0.478461  0.997816
# 602      HC_5_V4  franzen  swarm         nf        9.0   0.466206  0.997937
# 603      HC_5_V4  franzen  swarm         nf       10.0   0.442301  0.998423
# 505   HC_6_V3-V4  franzen  swarm         2f        1.0   0.998594  0.057659
# 495   HC_6_V3-V4  franzen  swarm         nf        1.0   0.999297  0.055550
# 496   HC_6_V3-V4  franzen  swarm         nf        2.0   0.995881  0.075339
# 497   HC_6_V3-V4  franzen  swarm         nf        3.0   0.985133  0.137921
# 498   HC_6_V3-V4  franzen  swarm         nf        4.0   0.963134  0.257358
# 499   HC_6_V3-V4  franzen  swarm         nf        5.0   0.915419  0.422200
# 500   HC_6_V3-V4  franzen  swarm         nf        6.0   0.863285  0.590758
# 501   HC_6_V3-V4  franzen  swarm         nf        7.0   0.809945  0.743345
# 502   HC_6_V3-V4  franzen  swarm         nf        8.0   0.766449  0.847413
# 503   HC_6_V3-V4  franzen  swarm         nf        9.0   0.732998  0.922049
# 504   HC_6_V3-V4  franzen  swarm         nf       10.0   0.709292  0.965043
# 615      HC_6_V4  franzen  swarm         2f        1.0   0.828941  0.755735
# 605      HC_6_V4  franzen  swarm         nf        1.0   0.903245  0.459614
# 606      HC_6_V4  franzen  swarm         nf        2.0   0.771108  0.753660
# 607      HC_6_V4  franzen  swarm         nf        3.0   0.663982  0.910078
# 608      HC_6_V4  franzen  swarm         nf        4.0   0.600781  0.974012
# 609      HC_6_V4  franzen  swarm         nf        5.0   0.559785  0.993533
# 610      HC_6_V4  franzen  swarm         nf        6.0   0.516837  0.998170
# 611      HC_6_V4  franzen  swarm         nf        7.0   0.491581  0.999024
# 612      HC_6_V4  franzen  swarm         nf        8.0   0.456320  0.998902
# 613      HC_6_V4  franzen  swarm         nf        9.0   0.424719  0.998536
# 614      HC_6_V4  franzen  swarm         nf       10.0   0.376159  0.995852
# 516   HC_7_V3-V4  franzen  swarm         2f        1.0   0.997483  0.058995
# 506   HC_7_V3-V4  franzen  swarm         nf        1.0   0.998993  0.055572
# 507   HC_7_V3-V4  franzen  swarm         nf        2.0   0.994765  0.075506
# 508   HC_7_V3-V4  franzen  swarm         nf        3.0   0.980872  0.139535
# 509   HC_7_V3-V4  franzen  swarm         nf        4.0   0.950065  0.251888
# 510   HC_7_V3-V4  franzen  swarm         nf        5.0   0.907480  0.412665
# 511   HC_7_V3-V4  franzen  swarm         nf        6.0   0.859559  0.582704
# 512   HC_7_V3-V4  franzen  swarm         nf        7.0   0.807712  0.728481
# 513   HC_7_V3-V4  franzen  swarm         nf        8.0   0.767039  0.843350
# 514   HC_7_V3-V4  franzen  swarm         nf        9.0   0.731904  0.920165
# 515   HC_7_V3-V4  franzen  swarm         nf       10.0   0.701500  0.962348
# 626      HC_7_V4  franzen  swarm         2f        1.0   0.772683  0.761341
# 616      HC_7_V4  franzen  swarm         nf        1.0   0.873780  0.449878
# 617      HC_7_V4  franzen  swarm         nf        2.0   0.713537  0.762805
# 618      HC_7_V4  franzen  swarm         nf        3.0   0.596220  0.914512
# 619      HC_7_V4  franzen  swarm         nf        4.0   0.517317  0.973293
# 620      HC_7_V4  franzen  swarm         nf        5.0   0.477683  0.992439
# 621      HC_7_V4  franzen  swarm         nf        6.0   0.458293  0.997683
# 622      HC_7_V4  franzen  swarm         nf        7.0   0.417805  0.996707
# 623      HC_7_V4  franzen  swarm         nf        8.0   0.389024  0.997927
# 624      HC_7_V4  franzen  swarm         nf        9.0   0.363049  0.996341
# 625      HC_7_V4  franzen  swarm         nf       10.0   0.325488  0.993415
# 527   HC_8_V3-V4  franzen  swarm         2f        1.0   0.995888  0.059372
# 517   HC_8_V3-V4  franzen  swarm         nf        1.0   0.998897  0.054558
# 518   HC_8_V3-V4  franzen  swarm         nf        2.0   0.994384  0.075619
# 519   HC_8_V3-V4  franzen  swarm         nf        3.0   0.981948  0.141711
# 520   HC_8_V3-V4  franzen  swarm         nf        4.0   0.954669  0.258750
# 521   HC_8_V3-V4  franzen  swarm         nf        5.0   0.916357  0.417310
# 522   HC_8_V3-V4  franzen  swarm         nf        6.0   0.866112  0.586501
# 523   HC_8_V3-V4  franzen  swarm         nf        7.0   0.812657  0.740548
# 524   HC_8_V3-V4  franzen  swarm         nf        8.0   0.760505  0.851168
# 525   HC_8_V3-V4  franzen  swarm         nf        9.0   0.723097  0.924982
# 526   HC_8_V3-V4  franzen  swarm         nf       10.0   0.693210  0.963294
# 637      HC_8_V4  franzen  swarm         2f        1.0   0.814216  0.766667
# 627      HC_8_V4  franzen  swarm         nf        1.0   0.897181  0.456373
# 628      HC_8_V4  franzen  swarm         nf        2.0   0.769608  0.762010
# 629      HC_8_V4  franzen  swarm         nf        3.0   0.659926  0.918260
# 630      HC_8_V4  franzen  swarm         nf        4.0   0.596936  0.976961
# 631      HC_8_V4  franzen  swarm         nf        5.0   0.550858  0.993995
# 632      HC_8_V4  franzen  swarm         nf        6.0   0.502819  0.998162
# 633      HC_8_V4  franzen  swarm         nf        7.0   0.461642  0.997794
# 634      HC_8_V4  franzen  swarm         nf        8.0   0.439828  0.998284
# 635      HC_8_V4  franzen  swarm         nf        9.0   0.411520  0.997917
# 636      HC_8_V4  franzen  swarm         nf       10.0   0.376103  0.996936
# 538   HC_9_V3-V4  franzen  swarm         2f        1.0   0.995369  0.062016
# 528   HC_9_V3-V4  franzen  swarm         nf        1.0   0.998792  0.055874
# 529   HC_9_V3-V4  franzen  swarm         nf        2.0   0.993557  0.079936
# 530   HC_9_V3-V4  franzen  swarm         nf        3.0   0.982181  0.143260
# 531   HC_9_V3-V4  franzen  swarm         nf        4.0   0.959730  0.257022
# 532   HC_9_V3-V4  franzen  swarm         nf        5.0   0.923890  0.416793
# 533   HC_9_V3-V4  franzen  swarm         nf        6.0   0.878083  0.587335
# 534   HC_9_V3-V4  franzen  swarm         nf        7.0   0.840028  0.738750
# 535   HC_9_V3-V4  franzen  swarm         nf        8.0   0.797946  0.849190
# 536   HC_9_V3-V4  franzen  swarm         nf        9.0   0.765227  0.922984
# 537   HC_9_V3-V4  franzen  swarm         nf       10.0   0.732407  0.964764
# 648      HC_9_V4  franzen  swarm         2f        1.0   0.826399  0.767518
# 638      HC_9_V4  franzen  swarm         nf        1.0   0.905474  0.456934
# 639      HC_9_V4  franzen  swarm         nf        2.0   0.777494  0.767397
# 640      HC_9_V4  franzen  swarm         nf        3.0   0.688321  0.919221
# 641      HC_9_V4  franzen  swarm         nf        4.0   0.603893  0.976521
# 642      HC_9_V4  franzen  swarm         nf        5.0   0.558637  0.993066
# 643      HC_9_V4  franzen  swarm         nf        6.0   0.527129  0.996959
# 644      HC_9_V4  franzen  swarm         nf        7.0   0.499392  0.997445
# 645      HC_9_V4  franzen  swarm         nf        8.0   0.456326  0.996715
# 646      HC_9_V4  franzen  swarm         nf        9.0   0.425182  0.996959
# 647      HC_9_V4  franzen  swarm         nf       10.0   0.382603  0.993187
# 109  LC_10_V3-V4  franzen  swarm         2f        1.0   1.000000  0.060606
# 99   LC_10_V3-V4  franzen  swarm         nf        1.0   1.000000  0.057576
# 100  LC_10_V3-V4  franzen  swarm         nf        2.0   0.998990  0.075758
# 101  LC_10_V3-V4  franzen  swarm         nf        3.0   0.996465  0.138384
# 102  LC_10_V3-V4  franzen  swarm         nf        4.0   0.990404  0.251010
# 103  LC_10_V3-V4  franzen  swarm         nf        5.0   0.974242  0.406566
# 104  LC_10_V3-V4  franzen  swarm         nf        6.0   0.950000  0.581313
# 105  LC_10_V3-V4  franzen  swarm         nf        7.0   0.931313  0.740404
# 106  LC_10_V3-V4  franzen  swarm         nf        8.0   0.911111  0.852020
# 107  LC_10_V3-V4  franzen  swarm         nf        9.0   0.902020  0.921717
# 108  LC_10_V3-V4  franzen  swarm         nf       10.0   0.866667  0.967172
# 219     LC_10_V4  franzen  swarm         2f        1.0   0.938862  0.753027
# 209     LC_10_V4  franzen  swarm         nf        1.0   0.966707  0.472760
# 210     LC_10_V4  franzen  swarm         nf        2.0   0.917070  0.753027
# 211     LC_10_V4  franzen  swarm         nf        3.0   0.871671  0.914044
# 212     LC_10_V4  franzen  swarm         nf        4.0   0.839588  0.976392
# 213     LC_10_V4  franzen  swarm         nf        5.0   0.809322  0.993341
# 214     LC_10_V4  franzen  swarm         nf        6.0   0.789952  0.999395
# 215     LC_10_V4  franzen  swarm         nf        7.0   0.770581  1.000000
# 216     LC_10_V4  franzen  swarm         nf        8.0   0.751211  0.998789
# 217     LC_10_V4  franzen  swarm         nf        9.0   0.722155  0.999395
# 218     LC_10_V4  franzen  swarm         nf       10.0   0.721550  1.000000
# 10    LC_1_V3-V4  franzen  swarm         2f        1.0   1.000000  0.055584
# 0     LC_1_V3-V4  franzen  swarm         nf        1.0   1.000000  0.053562
# 1     LC_1_V3-V4  franzen  swarm         nf        2.0   1.000000  0.070743
# 2     LC_1_V3-V4  franzen  swarm         nf        3.0   0.997473  0.132390
# 3     LC_1_V3-V4  franzen  swarm         nf        4.0   0.988378  0.235978
# 4     LC_1_V3-V4  franzen  swarm         nf        5.0   0.978272  0.405760
# 5     LC_1_V3-V4  franzen  swarm         nf        6.0   0.960586  0.575543
# 6     LC_1_V3-V4  franzen  swarm         nf        7.0   0.946943  0.735725
# 7     LC_1_V3-V4  franzen  swarm         nf        8.0   0.923194  0.847398
# 8     LC_1_V3-V4  franzen  swarm         nf        9.0   0.907529  0.916625
# 9     LC_1_V3-V4  franzen  swarm         nf       10.0   0.883780  0.958060
# 120      LC_1_V4  franzen  swarm         2f        1.0   0.942961  0.774272
# 110      LC_1_V4  franzen  swarm         nf        1.0   0.964199  0.472087
# 111      LC_1_V4  franzen  swarm         nf        2.0   0.928398  0.774272
# 112      LC_1_V4  franzen  swarm         nf        3.0   0.912621  0.916262
# 113      LC_1_V4  franzen  swarm         nf        4.0   0.906553  0.970267
# 114      LC_1_V4  franzen  swarm         nf        5.0   0.905340  0.992718
# 115      LC_1_V4  franzen  swarm         nf        6.0   0.893811  0.996966
# 116      LC_1_V4  franzen  swarm         nf        7.0   0.893204  0.998786
# 117      LC_1_V4  franzen  swarm         nf        8.0   0.874393  0.999393
# 118      LC_1_V4  franzen  swarm         nf        9.0   0.874393  1.000000
# 119      LC_1_V4  franzen  swarm         nf       10.0   0.845874  1.000000
# 21    LC_2_V3-V4  franzen  swarm         2f        1.0   1.000000  0.052578
# 11    LC_2_V3-V4  franzen  swarm         nf        1.0   1.000000  0.052578
# 12    LC_2_V3-V4  franzen  swarm         nf        2.0   1.000000  0.071284
# 13    LC_2_V3-V4  franzen  swarm         nf        3.0   0.996967  0.126896
# 14    LC_2_V3-V4  franzen  swarm         nf        4.0   0.995450  0.238625
# 15    LC_2_V3-V4  franzen  swarm         nf        5.0   0.986855  0.386754
# 16    LC_2_V3-V4  franzen  swarm         nf        6.0   0.957027  0.552578
# 17    LC_2_V3-V4  franzen  swarm         nf        7.0   0.936299  0.700202
# 18    LC_2_V3-V4  franzen  swarm         nf        8.0   0.923155  0.825076
# 19    LC_2_V3-V4  franzen  swarm         nf        9.0   0.896866  0.910516
# 20    LC_2_V3-V4  franzen  swarm         nf       10.0   0.865521  0.955005
# 131      LC_2_V4  franzen  swarm         2f        1.0   0.962763  0.750150
# 121      LC_2_V4  franzen  swarm         nf        1.0   0.977778  0.453453
# 122      LC_2_V4  franzen  swarm         nf        2.0   0.954354  0.754354
# 123      LC_2_V4  franzen  swarm         nf        3.0   0.911111  0.918919
# 124      LC_2_V4  franzen  swarm         nf        4.0   0.894294  0.979580
# 125      LC_2_V4  franzen  swarm         nf        5.0   0.885285  0.994595
# 126      LC_2_V4  franzen  swarm         nf        6.0   0.873273  0.998799
# 127      LC_2_V4  franzen  swarm         nf        7.0   0.843844  1.000000
# 128      LC_2_V4  franzen  swarm         nf        8.0   0.822823  1.000000
# 129      LC_2_V4  franzen  swarm         nf        9.0   0.822823  1.000000
# 130      LC_2_V4  franzen  swarm         nf       10.0   0.813213  1.000000
# 32    LC_3_V3-V4  franzen  swarm         2f        1.0   1.000000  0.054000
# 22    LC_3_V3-V4  franzen  swarm         nf        1.0   1.000000  0.053000
# 23    LC_3_V3-V4  franzen  swarm         nf        2.0   0.998500  0.069500
# 24    LC_3_V3-V4  franzen  swarm         nf        3.0   0.996000  0.132000
# 25    LC_3_V3-V4  franzen  swarm         nf        4.0   0.992000  0.251500
# 26    LC_3_V3-V4  franzen  swarm         nf        5.0   0.988000  0.413000
# 27    LC_3_V3-V4  franzen  swarm         nf        6.0   0.976500  0.585500
# 28    LC_3_V3-V4  franzen  swarm         nf        7.0   0.965500  0.740000
# 29    LC_3_V3-V4  franzen  swarm         nf        8.0   0.933000  0.850000
# 30    LC_3_V3-V4  franzen  swarm         nf        9.0   0.930500  0.916000
# 31    LC_3_V3-V4  franzen  swarm         nf       10.0   0.916500  0.954000
# 142      LC_3_V4  franzen  swarm         2f        1.0   0.965538  0.740939
# 132      LC_3_V4  franzen  swarm         nf        1.0   0.980986  0.438503
# 133      LC_3_V4  franzen  swarm         nf        2.0   0.965538  0.745692
# 134      LC_3_V4  franzen  swarm         nf        3.0   0.949495  0.916221
# 135      LC_3_V4  franzen  swarm         nf        4.0   0.945336  0.978610
# 136      LC_3_V4  franzen  swarm         nf        5.0   0.910279  0.994058
# 137      LC_3_V4  franzen  swarm         nf        6.0   0.899584  0.999406
# 138      LC_3_V4  franzen  swarm         nf        7.0   0.890671  1.000000
# 139      LC_3_V4  franzen  swarm         nf        8.0   0.874034  1.000000
# 140      LC_3_V4  franzen  swarm         nf        9.0   0.856803  1.000000
# 141      LC_3_V4  franzen  swarm         nf       10.0   0.845514  1.000000
# 43    LC_4_V3-V4  franzen  swarm         2f        1.0   0.999499  0.055556
# 33    LC_4_V3-V4  franzen  swarm         nf        1.0   0.999499  0.052553
# 34    LC_4_V3-V4  franzen  swarm         nf        2.0   0.998999  0.067067
# 35    LC_4_V3-V4  franzen  swarm         nf        3.0   0.995996  0.117618
# 36    LC_4_V3-V4  franzen  swarm         nf        4.0   0.991992  0.224224
# 37    LC_4_V3-V4  franzen  swarm         nf        5.0   0.978979  0.360861
# 38    LC_4_V3-V4  franzen  swarm         nf        6.0   0.951451  0.540541
# 39    LC_4_V3-V4  franzen  swarm         nf        7.0   0.927427  0.712713
# 40    LC_4_V3-V4  franzen  swarm         nf        8.0   0.913914  0.834835
# 41    LC_4_V3-V4  franzen  swarm         nf        9.0   0.903403  0.913413
# 42    LC_4_V3-V4  franzen  swarm         nf       10.0   0.888388  0.962462
# 153      LC_4_V4  franzen  swarm         2f        1.0   0.926309  0.753959
# 143      LC_4_V4  franzen  swarm         nf        1.0   0.957369  0.465895
# 144      LC_4_V4  franzen  swarm         nf        2.0   0.908648  0.762485
# 145      LC_4_V4  franzen  swarm         nf        3.0   0.875152  0.917783
# 146      LC_4_V4  franzen  swarm         nf        4.0   0.854446  0.975030
# 147      LC_4_V4  franzen  swarm         nf        5.0   0.852619  0.993301
# 148      LC_4_V4  franzen  swarm         nf        6.0   0.831912  0.999391
# 149      LC_4_V4  franzen  swarm         nf        7.0   0.831912  1.000000
# 150      LC_4_V4  franzen  swarm         nf        8.0   0.804507  1.000000
# 151      LC_4_V4  franzen  swarm         nf        9.0   0.804507  1.000000
# 152      LC_4_V4  franzen  swarm         nf       10.0   0.804507  1.000000
# 54    LC_5_V3-V4  franzen  swarm         2f        1.0   1.000000  0.052525
# 44    LC_5_V3-V4  franzen  swarm         nf        1.0   1.000000  0.052525
# 45    LC_5_V3-V4  franzen  swarm         nf        2.0   0.997980  0.068687
# 46    LC_5_V3-V4  franzen  swarm         nf        3.0   0.994444  0.122222
# 47    LC_5_V3-V4  franzen  swarm         nf        4.0   0.988384  0.239394
# 48    LC_5_V3-V4  franzen  swarm         nf        5.0   0.975758  0.395960
# 49    LC_5_V3-V4  franzen  swarm         nf        6.0   0.960606  0.568687
# 50    LC_5_V3-V4  franzen  swarm         nf        7.0   0.931818  0.728788
# 51    LC_5_V3-V4  franzen  swarm         nf        8.0   0.900505  0.842424
# 52    LC_5_V3-V4  franzen  swarm         nf        9.0   0.880808  0.916162
# 53    LC_5_V3-V4  franzen  swarm         nf       10.0   0.836364  0.959596
# 164      LC_5_V4  franzen  swarm         2f        1.0   0.946634  0.750152
# 154      LC_5_V4  franzen  swarm         nf        1.0   0.970891  0.453002
# 155      LC_5_V4  franzen  swarm         nf        2.0   0.939964  0.750152
# 156      LC_5_V4  franzen  swarm         nf        3.0   0.904184  0.913281
# 157      LC_5_V4  franzen  swarm         nf        4.0   0.861734  0.969072
# 158      LC_5_V4  franzen  swarm         nf        5.0   0.844148  0.993329
# 159      LC_5_V4  franzen  swarm         nf        6.0   0.815646  0.998181
# 160      LC_5_V4  franzen  swarm         nf        7.0   0.807762  0.998787
# 161      LC_5_V4  franzen  swarm         nf        8.0   0.798666  1.000000
# 162      LC_5_V4  franzen  swarm         nf        9.0   0.788357  1.000000
# 163      LC_5_V4  franzen  swarm         nf       10.0   0.777441  1.000000
# 65    LC_6_V3-V4  franzen  swarm         2f        1.0   0.998000  0.055500
# 55    LC_6_V3-V4  franzen  swarm         nf        1.0   0.999500  0.053000
# 56    LC_6_V3-V4  franzen  swarm         nf        2.0   0.996000  0.074000
# 57    LC_6_V3-V4  franzen  swarm         nf        3.0   0.984000  0.139500
# 58    LC_6_V3-V4  franzen  swarm         nf        4.0   0.973500  0.250500
# 59    LC_6_V3-V4  franzen  swarm         nf        5.0   0.949500  0.435500
# 60    LC_6_V3-V4  franzen  swarm         nf        6.0   0.927000  0.592000
# 61    LC_6_V3-V4  franzen  swarm         nf        7.0   0.903000  0.738000
# 62    LC_6_V3-V4  franzen  swarm         nf        8.0   0.868000  0.848500
# 63    LC_6_V3-V4  franzen  swarm         nf        9.0   0.833500  0.928500
# 64    LC_6_V3-V4  franzen  swarm         nf       10.0   0.816500  0.966500
# 175      LC_6_V4  franzen  swarm         2f        1.0   0.925948  0.772512
# 165      LC_6_V4  franzen  swarm         nf        1.0   0.959716  0.476303
# 166      LC_6_V4  franzen  swarm         nf        2.0   0.905213  0.772512
# 167      LC_6_V4  franzen  swarm         nf        3.0   0.868483  0.928318
# 168      LC_6_V4  franzen  swarm         nf        4.0   0.861374  0.976303
# 169      LC_6_V4  franzen  swarm         nf        5.0   0.848341  0.997038
# 170      LC_6_V4  franzen  swarm         nf        6.0   0.848341  0.998815
# 171      LC_6_V4  franzen  swarm         nf        7.0   0.847749  1.000000
# 172      LC_6_V4  franzen  swarm         nf        8.0   0.847749  1.000000
# 173      LC_6_V4  franzen  swarm         nf        9.0   0.839455  1.000000
# 174      LC_6_V4  franzen  swarm         nf       10.0   0.811611  1.000000
# 76    LC_7_V3-V4  franzen  swarm         2f        1.0   0.998498  0.059059
# 66    LC_7_V3-V4  franzen  swarm         nf        1.0   0.998999  0.055556
# 67    LC_7_V3-V4  franzen  swarm         nf        2.0   0.998498  0.066066
# 68    LC_7_V3-V4  franzen  swarm         nf        3.0   0.994995  0.108609
# 69    LC_7_V3-V4  franzen  swarm         nf        4.0   0.989990  0.216216
# 70    LC_7_V3-V4  franzen  swarm         nf        5.0   0.981982  0.366366
# 71    LC_7_V3-V4  franzen  swarm         nf        6.0   0.971471  0.543544
# 72    LC_7_V3-V4  franzen  swarm         nf        7.0   0.957457  0.701702
# 73    LC_7_V3-V4  franzen  swarm         nf        8.0   0.950951  0.818819
# 74    LC_7_V3-V4  franzen  swarm         nf        9.0   0.938939  0.908408
# 75    LC_7_V3-V4  franzen  swarm         nf       10.0   0.935435  0.951952
# 186      LC_7_V4  franzen  swarm         2f        1.0   0.970024  0.761990
# 176      LC_7_V4  franzen  swarm         nf        1.0   0.982014  0.437050
# 177      LC_7_V4  franzen  swarm         nf        2.0   0.962230  0.761990
# 178      LC_7_V4  franzen  swarm         nf        3.0   0.937050  0.922662
# 179      LC_7_V4  franzen  swarm         nf        4.0   0.887890  0.979017
# 180      LC_7_V4  franzen  swarm         nf        5.0   0.884293  0.995803
# 181      LC_7_V4  franzen  swarm         nf        6.0   0.854317  1.000000
# 182      LC_7_V4  franzen  swarm         nf        7.0   0.844724  1.000000
# 183      LC_7_V4  franzen  swarm         nf        8.0   0.844724  1.000000
# 184      LC_7_V4  franzen  swarm         nf        9.0   0.835731  1.000000
# 185      LC_7_V4  franzen  swarm         nf       10.0   0.818945  1.000000
# 87    LC_8_V3-V4  franzen  swarm         2f        1.0   0.996463  0.058110
# 77    LC_8_V3-V4  franzen  swarm         nf        1.0   0.998484  0.054573
# 78    LC_8_V3-V4  franzen  swarm         nf        2.0   0.996463  0.074785
# 79    LC_8_V3-V4  franzen  swarm         nf        3.0   0.983325  0.129864
# 80    LC_8_V3-V4  franzen  swarm         nf        4.0   0.970692  0.245579
# 81    LC_8_V3-V4  franzen  swarm         nf        5.0   0.957554  0.388075
# 82    LC_8_V3-V4  franzen  swarm         nf        6.0   0.933805  0.560889
# 83    LC_8_V3-V4  franzen  swarm         nf        7.0   0.915614  0.725114
# 84    LC_8_V3-V4  franzen  swarm         nf        8.0   0.902476  0.846892
# 85    LC_8_V3-V4  franzen  swarm         nf        9.0   0.877211  0.919656
# 86    LC_8_V3-V4  franzen  swarm         nf       10.0   0.846387  0.964123
# 197      LC_8_V4  franzen  swarm         2f        1.0   0.938219  0.763780
# 187      LC_8_V4  franzen  swarm         nf        1.0   0.965475  0.459721
# 188      LC_8_V4  franzen  swarm         nf        2.0   0.938219  0.774076
# 189      LC_8_V4  franzen  swarm         nf        3.0   0.901878  0.915809
# 190      LC_8_V4  franzen  swarm         nf        4.0   0.866747  0.973955
# 191      LC_8_V4  franzen  swarm         nf        5.0   0.864930  0.993337
# 192      LC_8_V4  franzen  swarm         nf        6.0   0.855239  1.000000
# 193      LC_8_V4  franzen  swarm         nf        7.0   0.847365  1.000000
# 194      LC_8_V4  franzen  swarm         nf        8.0   0.847365  1.000000
# 195      LC_8_V4  franzen  swarm         nf        9.0   0.847365  1.000000
# 196      LC_8_V4  franzen  swarm         nf       10.0   0.837068  1.000000
# 98    LC_9_V3-V4  franzen  swarm         2f        1.0   0.999495  0.054068
# 88    LC_9_V3-V4  franzen  swarm         nf        1.0   1.000000  0.053057
# 89    LC_9_V3-V4  franzen  swarm         nf        2.0   0.999495  0.065184
# 90    LC_9_V3-V4  franzen  swarm         nf        3.0   0.994442  0.128348
# 91    LC_9_V3-V4  franzen  swarm         nf        4.0   0.984336  0.241031
# 92    LC_9_V3-V4  franzen  swarm         nf        5.0   0.964629  0.414856
# 93    LC_9_V3-V4  franzen  swarm         nf        6.0   0.943911  0.578575
# 94    LC_9_V3-V4  franzen  swarm         nf        7.0   0.907529  0.722082
# 95    LC_9_V3-V4  franzen  swarm         nf        8.0   0.884285  0.836281
# 96    LC_9_V3-V4  franzen  swarm         nf        9.0   0.853461  0.902476
# 97    LC_9_V3-V4  franzen  swarm         nf       10.0   0.820111  0.945427
# 208      LC_9_V4  franzen  swarm         2f        1.0   0.910855  0.756216
# 198      LC_9_V4  franzen  swarm         nf        1.0   0.947847  0.457247
# 199      LC_9_V4  franzen  swarm         nf        2.0   0.881140  0.760461
# 200      LC_9_V4  franzen  swarm         nf        3.0   0.829594  0.924196
# 201      LC_9_V4  franzen  swarm         nf        4.0   0.818072  0.976956
# 202      LC_9_V4  franzen  swarm         nf        5.0   0.815039  0.994542
# 203      LC_9_V4  franzen  swarm         nf        6.0   0.815039  0.998181
# 204      LC_9_V4  franzen  swarm         nf        7.0   0.804124  0.999394
# 205      LC_9_V4  franzen  swarm         nf        8.0   0.793208  1.000000
# 206      LC_9_V4  franzen  swarm         nf        9.0   0.793208  1.000000
# 207      LC_9_V4  franzen  swarm         nf       10.0   0.784112  1.000000
# 329  MC_10_V3-V4  franzen  swarm         2f        1.0   0.999397  0.056862
# 319  MC_10_V3-V4  franzen  swarm         nf        1.0   0.999799  0.055455
# 320  MC_10_V3-V4  franzen  swarm         nf        2.0   0.996383  0.077758
# 321  MC_10_V3-V4  franzen  swarm         nf        3.0   0.990356  0.145268
# 322  MC_10_V3-V4  franzen  swarm         nf        4.0   0.974884  0.265622
# 323  MC_10_V3-V4  franzen  swarm         nf        5.0   0.942335  0.425156
# 324  MC_10_V3-V4  franzen  swarm         nf        6.0   0.910991  0.595740
# 325  MC_10_V3-V4  franzen  swarm         nf        7.0   0.867792  0.744826
# 326  MC_10_V3-V4  franzen  swarm         nf        8.0   0.826803  0.855937
# 327  MC_10_V3-V4  franzen  swarm         nf        9.0   0.805304  0.920836
# 328  MC_10_V3-V4  franzen  swarm         nf       10.0   0.764115  0.961222
# 439     MC_10_V4  franzen  swarm         2f        1.0   0.843109  0.757181
# 429     MC_10_V4  franzen  swarm         nf        1.0   0.912382  0.445812
# 430     MC_10_V4  franzen  swarm         nf        2.0   0.806903  0.760560
# 431     MC_10_V4  franzen  swarm         nf        3.0   0.741009  0.918417
# 432     MC_10_V4  franzen  swarm         nf        4.0   0.690804  0.975863
# 433     MC_10_V4  franzen  swarm         nf        5.0   0.640599  0.993724
# 434     MC_10_V4  franzen  swarm         nf        6.0   0.599083  0.997586
# 435     MC_10_V4  franzen  swarm         nf        7.0   0.551291  0.997586
# 436     MC_10_V4  franzen  swarm         nf        8.0   0.524258  0.997586
# 437     MC_10_V4  franzen  swarm         nf        9.0   0.495535  0.996621
# 438     MC_10_V4  franzen  swarm         nf       10.0   0.467294  0.996138
# 230   MC_1_V3-V4  franzen  swarm         2f        1.0   0.998790  0.056284
# 220   MC_1_V3-V4  franzen  swarm         nf        1.0   0.999395  0.054065
# 221   MC_1_V3-V4  franzen  swarm         nf        2.0   0.997781  0.072019
# 222   MC_1_V3-V4  franzen  swarm         nf        3.0   0.991931  0.133145
# 223   MC_1_V3-V4  franzen  swarm         nf        4.0   0.975187  0.243292
# 224   MC_1_V3-V4  franzen  swarm         nf        5.0   0.954004  0.410329
# 225   MC_1_V3-V4  franzen  swarm         nf        6.0   0.922130  0.581198
# 226   MC_1_V3-V4  franzen  swarm         nf        7.0   0.895098  0.728868
# 227   MC_1_V3-V4  franzen  swarm         nf        8.0   0.859996  0.844664
# 228   MC_1_V3-V4  franzen  swarm         nf        9.0   0.836998  0.922130
# 229   MC_1_V3-V4  franzen  swarm         nf       10.0   0.815413  0.961469
# 340      MC_1_V4  franzen  swarm         2f        1.0   0.922179  0.754134
# 330      MC_1_V4  franzen  swarm         nf        1.0   0.956712  0.445525
# 331      MC_1_V4  franzen  swarm         nf        2.0   0.885457  0.756323
# 332      MC_1_V4  franzen  swarm         nf        3.0   0.831469  0.923881
# 333      MC_1_V4  franzen  swarm         nf        4.0   0.798395  0.978356
# 334      MC_1_V4  franzen  swarm         nf        5.0   0.761430  0.993920
# 335      MC_1_V4  franzen  swarm         nf        6.0   0.717169  0.998784
# 336      MC_1_V4  franzen  swarm         nf        7.0   0.678259  0.999270
# 337      MC_1_V4  franzen  swarm         nf        8.0   0.654912  0.999757
# 338      MC_1_V4  franzen  swarm         nf        9.0   0.638862  0.999270
# 339      MC_1_V4  franzen  swarm         nf       10.0   0.631080  0.999757
# 241   MC_2_V3-V4  franzen  swarm         2f        1.0   0.998380  0.059336
# 231   MC_2_V3-V4  franzen  swarm         nf        1.0   0.999392  0.055488
# 232   MC_2_V3-V4  franzen  swarm         nf        2.0   0.995747  0.076549
# 233   MC_2_V3-V4  franzen  swarm         nf        3.0   0.984609  0.144998
# 234   MC_2_V3-V4  franzen  swarm         nf        4.0   0.967598  0.264277
# 235   MC_2_V3-V4  franzen  swarm         nf        5.0   0.943499  0.426488
# 236   MC_2_V3-V4  franzen  swarm         nf        6.0   0.908667  0.599635
# 237   MC_2_V3-V4  franzen  swarm         nf        7.0   0.869380  0.751924
# 238   MC_2_V3-V4  franzen  swarm         nf        8.0   0.839409  0.859052
# 239   MC_2_V3-V4  franzen  swarm         nf        9.0   0.813285  0.926691
# 240   MC_2_V3-V4  franzen  swarm         nf       10.0   0.790603  0.969421
# 351      MC_2_V4  franzen  swarm         2f        1.0   0.901631  0.769402
# 341      MC_2_V4  franzen  swarm         nf        1.0   0.945625  0.463174
# 342      MC_2_V4  franzen  swarm         nf        2.0   0.862086  0.769402
# 343      MC_2_V4  franzen  swarm         nf        3.0   0.803757  0.920168
# 344      MC_2_V4  franzen  swarm         nf        4.0   0.763223  0.976520
# 345      MC_2_V4  franzen  swarm         nf        5.0   0.749876  0.993821
# 346      MC_2_V4  franzen  swarm         nf        6.0   0.727632  0.998023
# 347      MC_2_V4  franzen  swarm         nf        7.0   0.711814  0.999753
# 348      MC_2_V4  franzen  swarm         nf        8.0   0.685368  0.999506
# 349      MC_2_V4  franzen  swarm         nf        9.0   0.654721  0.999259
# 350      MC_2_V4  franzen  swarm         nf       10.0   0.632477  0.999259
# 252   MC_3_V3-V4  franzen  swarm         2f        1.0   0.998995  0.054874
# 242   MC_3_V3-V4  franzen  swarm         nf        1.0   0.999799  0.053467
# 243   MC_3_V3-V4  franzen  swarm         nf        2.0   0.997588  0.073769
# 244   MC_3_V3-V4  franzen  swarm         nf        3.0   0.991558  0.133869
# 245   MC_3_V3-V4  franzen  swarm         nf        4.0   0.977889  0.250050
# 246   MC_3_V3-V4  franzen  swarm         nf        5.0   0.958995  0.413266
# 247   MC_3_V3-V4  franzen  swarm         nf        6.0   0.922613  0.580704
# 248   MC_3_V3-V4  franzen  swarm         nf        7.0   0.895276  0.739497
# 249   MC_3_V3-V4  franzen  swarm         nf        8.0   0.874975  0.847035
# 250   MC_3_V3-V4  franzen  swarm         nf        9.0   0.842613  0.917186
# 251   MC_3_V3-V4  franzen  swarm         nf       10.0   0.824724  0.959397
# 362      MC_3_V4  franzen  swarm         2f        1.0   0.919327  0.770412
# 352      MC_3_V4  franzen  swarm         nf        1.0   0.955642  0.462345
# 353      MC_3_V4  franzen  swarm         nf        2.0   0.882769  0.770656
# 354      MC_3_V4  franzen  swarm         nf        3.0   0.840604  0.920302
# 355      MC_3_V4  franzen  swarm         nf        4.0   0.818913  0.978309
# 356      MC_3_V4  franzen  swarm         nf        5.0   0.800146  0.994151
# 357      MC_3_V4  franzen  swarm         nf        6.0   0.780648  0.998538
# 358      MC_3_V4  franzen  swarm         nf        7.0   0.762369  0.998781
# 359      MC_3_V4  franzen  swarm         nf        8.0   0.738240  0.999756
# 360      MC_3_V4  franzen  swarm         nf        9.0   0.723373  0.999513
# 361      MC_3_V4  franzen  swarm         nf       10.0   0.706556  0.999513
# 263   MC_4_V3-V4  franzen  swarm         2f        1.0   0.997389  0.061069
# 253   MC_4_V3-V4  franzen  swarm         nf        1.0   0.999196  0.055846
# 254   MC_4_V3-V4  franzen  swarm         nf        2.0   0.995982  0.078546
# 255   MC_4_V3-V4  franzen  swarm         nf        3.0   0.990759  0.131981
# 256   MC_4_V3-V4  franzen  swarm         nf        4.0   0.974488  0.248694
# 257   MC_4_V3-V4  franzen  swarm         nf        5.0   0.956810  0.417638
# 258   MC_4_V3-V4  franzen  swarm         nf        6.0   0.939534  0.591402
# 259   MC_4_V3-V4  franzen  swarm         nf        7.0   0.907192  0.729811
# 260   MC_4_V3-V4  franzen  swarm         nf        8.0   0.874849  0.844315
# 261   MC_4_V3-V4  franzen  swarm         nf        9.0   0.848333  0.915830
# 262   MC_4_V3-V4  franzen  swarm         nf       10.0   0.835677  0.959622
# 373      MC_4_V4  franzen  swarm         2f        1.0   0.883997  0.758348
# 363      MC_4_V4  franzen  swarm         nf        1.0   0.932971  0.460549
# 364      MC_4_V4  franzen  swarm         nf        2.0   0.851348  0.763295
# 365      MC_4_V4  franzen  swarm         nf        3.0   0.806332  0.917388
# 366      MC_4_V4  franzen  swarm         nf        4.0   0.770467  0.975513
# 367      MC_4_V4  franzen  swarm         nf        5.0   0.747959  0.994558
# 368      MC_4_V4  franzen  swarm         nf        6.0   0.731388  0.997527
# 369      MC_4_V4  franzen  swarm         nf        7.0   0.712095  0.998516
# 370      MC_4_V4  franzen  swarm         nf        8.0   0.664853  0.998516
# 371      MC_4_V4  franzen  swarm         nf        9.0   0.645560  0.999258
# 372      MC_4_V4  franzen  swarm         nf       10.0   0.632451  1.000000
# 274   MC_5_V3-V4  franzen  swarm         2f        1.0   0.998987  0.057154
# 264   MC_5_V3-V4  franzen  swarm         nf        1.0   0.999392  0.054520
# 265   MC_5_V3-V4  franzen  swarm         nf        2.0   0.996960  0.076003
# 266   MC_5_V3-V4  franzen  swarm         nf        3.0   0.988042  0.143089
# 267   MC_5_V3-V4  franzen  swarm         nf        4.0   0.972842  0.259222
# 268   MC_5_V3-V4  franzen  swarm         nf        5.0   0.948926  0.417916
# 269   MC_5_V3-V4  franzen  swarm         nf        6.0   0.923389  0.590191
# 270   MC_5_V3-V4  franzen  swarm         nf        7.0   0.892987  0.731050
# 271   MC_5_V3-V4  franzen  swarm         nf        8.0   0.861167  0.848399
# 272   MC_5_V3-V4  franzen  swarm         nf        9.0   0.827523  0.922375
# 273   MC_5_V3-V4  franzen  swarm         nf       10.0   0.812525  0.963518
# 384      MC_5_V4  franzen  swarm         2f        1.0   0.881092  0.752680
# 374      MC_5_V4  franzen  swarm         nf        1.0   0.938353  0.451511
# 375      MC_5_V4  franzen  swarm         nf        2.0   0.862086  0.757797
# 376      MC_5_V4  franzen  swarm         nf        3.0   0.795322  0.913012
# 377      MC_5_V4  franzen  swarm         nf        4.0   0.755117  0.975390
# 378      MC_5_V4  franzen  swarm         nf        5.0   0.732212  0.993177
# 379      MC_5_V4  franzen  swarm         nf        6.0   0.721004  0.998051
# 380      MC_5_V4  franzen  swarm         nf        7.0   0.696881  0.999513
# 381      MC_5_V4  franzen  swarm         nf        8.0   0.677632  1.000000
# 382      MC_5_V4  franzen  swarm         nf        9.0   0.647661  0.998294
# 383      MC_5_V4  franzen  swarm         nf       10.0   0.624756  0.999025
# 285   MC_6_V3-V4  franzen  swarm         2f        1.0   0.998991  0.058729
# 275   MC_6_V3-V4  franzen  swarm         nf        1.0   0.999395  0.056105
# 276   MC_6_V3-V4  franzen  swarm         nf        2.0   0.997982  0.079717
# 277   MC_6_V3-V4  franzen  swarm         nf        3.0   0.987891  0.146519
# 278   MC_6_V3-V4  franzen  swarm         nf        4.0   0.969324  0.259939
# 279   MC_6_V3-V4  franzen  swarm         nf        5.0   0.940464  0.421796
# 280   MC_6_V3-V4  franzen  swarm         nf        6.0   0.900101  0.587487
# 281   MC_6_V3-V4  franzen  swarm         nf        7.0   0.867608  0.733804
# 282   MC_6_V3-V4  franzen  swarm         nf        8.0   0.832492  0.845005
# 283   MC_6_V3-V4  franzen  swarm         nf        9.0   0.803835  0.922301
# 284   MC_6_V3-V4  franzen  swarm         nf       10.0   0.785873  0.963673
# 395      MC_6_V4  franzen  swarm         2f        1.0   0.889404  0.760986
# 385      MC_6_V4  franzen  swarm         nf        1.0   0.934326  0.452881
# 386      MC_6_V4  franzen  swarm         nf        2.0   0.868652  0.762695
# 387      MC_6_V4  franzen  swarm         nf        3.0   0.812744  0.915283
# 388      MC_6_V4  franzen  swarm         nf        4.0   0.763428  0.975830
# 389      MC_6_V4  franzen  swarm         nf        5.0   0.721191  0.993896
# 390      MC_6_V4  franzen  swarm         nf        6.0   0.698486  0.998779
# 391      MC_6_V4  franzen  swarm         nf        7.0   0.672363  0.999268
# 392      MC_6_V4  franzen  swarm         nf        8.0   0.656738  0.999756
# 393      MC_6_V4  franzen  swarm         nf        9.0   0.649414  0.999268
# 394      MC_6_V4  franzen  swarm         nf       10.0   0.634766  0.999023
# 296   MC_7_V3-V4  franzen  swarm         2f        1.0   0.999193  0.055869
# 286   MC_7_V3-V4  franzen  swarm         nf        1.0   1.000000  0.053449
# 287   MC_7_V3-V4  franzen  swarm         nf        2.0   0.998588  0.074223
# 288   MC_7_V3-V4  franzen  swarm         nf        3.0   0.989714  0.138766
# 289   MC_7_V3-V4  franzen  swarm         nf        4.0   0.972368  0.247277
# 290   MC_7_V3-V4  franzen  swarm         nf        5.0   0.947761  0.398346
# 291   MC_7_V3-V4  franzen  swarm         nf        6.0   0.921138  0.581081
# 292   MC_7_V3-V4  franzen  swarm         nf        7.0   0.878983  0.725292
# 293   MC_7_V3-V4  franzen  swarm         nf        8.0   0.840662  0.840662
# 294   MC_7_V3-V4  franzen  swarm         nf        9.0   0.817063  0.916297
# 295   MC_7_V3-V4  franzen  swarm         nf       10.0   0.796087  0.960871
# 406      MC_7_V4  franzen  swarm         2f        1.0   0.910241  0.771588
# ...
# 305   MC_8_V3-V4  franzen  swarm         nf        9.0   0.791357  0.924221
# 306   MC_8_V3-V4  franzen  swarm         nf       10.0   0.766633  0.962010
# 417      MC_8_V4  franzen  swarm         2f        1.0   0.876065  0.762600
# 407      MC_8_V4  franzen  swarm         nf        1.0   0.935476  0.451424
# 408      MC_8_V4  franzen  swarm         nf        2.0   0.855612  0.763087
# 409      MC_8_V4  franzen  swarm         nf        3.0   0.773801  0.920380
# 410      MC_8_V4  franzen  swarm         nf        4.0   0.743852  0.973703
# 411      MC_8_V4  franzen  swarm         nf        5.0   0.714634  0.992939
# 412      MC_8_V4  franzen  swarm         nf        6.0   0.691259  0.998783
# 413      MC_8_V4  franzen  swarm         nf        7.0   0.687120  0.999757
# 414      MC_8_V4  franzen  swarm         nf        8.0   0.666910  1.000000
# 415      MC_8_V4  franzen  swarm         nf        9.0   0.656197  1.000000
# 416      MC_8_V4  franzen  swarm         nf       10.0   0.636718  0.998539
# 318   MC_9_V3-V4  franzen  swarm         2f        1.0   0.999397  0.054429
# 308   MC_9_V3-V4  franzen  swarm         nf        1.0   0.999397  0.053424
# 309   MC_9_V3-V4  franzen  swarm         nf        2.0   0.998192  0.070898
# 310   MC_9_V3-V4  franzen  swarm         nf        3.0   0.992770  0.125728
# 311   MC_9_V3-V4  franzen  swarm         nf        4.0   0.981322  0.231974
# 312   MC_9_V3-V4  franzen  swarm         nf        5.0   0.957823  0.388833
# 313   MC_9_V3-V4  franzen  swarm         nf        6.0   0.933320  0.562563
# 314   MC_9_V3-V4  franzen  swarm         nf        7.0   0.894155  0.721631
# 315   MC_9_V3-V4  franzen  swarm         nf        8.0   0.866037  0.842539
# 316   MC_9_V3-V4  franzen  swarm         nf        9.0   0.851978  0.914240
# 317   MC_9_V3-V4  franzen  swarm         nf       10.0   0.842137  0.957823
# 428      MC_9_V4  franzen  swarm         2f        1.0   0.897831  0.766506
# 418      MC_9_V4  franzen  swarm         nf        1.0   0.942410  0.467470
# 419      MC_9_V4  franzen  swarm         nf        2.0   0.879518  0.767952
# 420      MC_9_V4  franzen  swarm         nf        3.0   0.847470  0.923614
# 421      MC_9_V4  franzen  swarm         nf        4.0   0.825542  0.974940
# 422      MC_9_V4  franzen  swarm         nf        5.0   0.805783  0.993976
# 423      MC_9_V4  franzen  swarm         nf        6.0   0.782410  0.999036
# 424      MC_9_V4  franzen  swarm         nf        7.0   0.764096  0.999759
# 425      MC_9_V4  franzen  swarm         nf        8.0   0.721446  0.999518
# 426      MC_9_V4  franzen  swarm         nf        9.0   0.682169  0.999759
# 427      MC_9_V4  franzen  swarm         nf       10.0   0.655181  0.998554
#
#      adjrandindex
# 549      0.003869
# 539      0.001077
# 540      0.009880
# 541      0.047334
# 542      0.134872
# 543      0.275227
# 544      0.421022
# 545      0.502953
# 546      0.508718
# 547      0.515905
# 548      0.507837
# 659      0.540204
# 649      0.296884
# 650      0.483004
# 651      0.521999
# 652      0.491924
# 653      0.466424
# 654      0.444103
# 655      0.376963
# 656      0.352167
# 657      0.334322
# 658      0.306649
# 450      0.005273
# 440      0.001646
# 441      0.011833
# 442      0.055421
# 443      0.143305
# 444      0.276686
# 445      0.371053
# 446      0.437627
# 447      0.460821
# 448      0.486122
# 449      0.474921
# 560      0.481495
# 550      0.271130
# 551      0.430218
# 552      0.459332
# 553      0.422398
# 554      0.408078
# 555      0.392233
# 556      0.367731
# 557      0.340396
# 558      0.282346
# 559      0.262783
# 461      0.004189
# 451      0.001197
# 452      0.009536
# 453      0.048676
# 454      0.135869
# 455      0.261402
# 456      0.386874
# 457      0.473998
# 458      0.512264
# 459      0.534104
# 460      0.532443
# 571      0.537603
# 561      0.286292
# 562      0.461044
# 563      0.461720
# 564      0.442095
# 565      0.412125
# 566      0.380101
# 567      0.339002
# 568      0.309502
# 569      0.281143
# 570      0.230182
# 472      0.003404
# 462      0.001286
# 463      0.009157
# 464      0.046871
# 465      0.148329
# 466      0.292500
# 467      0.393814
# 468      0.474605
# 469      0.516800
# 470      0.535220
# 471      0.525689
# 582      0.548506
# 572      0.295135
# 573      0.488684
# 574      0.518455
# 575      0.524039
# 576      0.498557
# 577      0.471340
# 578      0.434997
# 579      0.404493
# 580      0.383036
# 581      0.348212
# 483      0.004281
# 473      0.001533
# 474      0.010594
# 475      0.048119
# 476      0.137282
# 477      0.275844
# 478      0.402780
# 479      0.497538
# 480      0.556144
# 481      0.576401
# 482      0.581456
# 593      0.555742
# 583      0.304736
# 584      0.504236
# 585      0.540136
# 586      0.534530
# 587      0.514119
# 588      0.456139
# 589      0.441629
# 590      0.377144
# 591      0.313289
# 592      0.296057
# 494      0.002808
# 484      0.001095
# 485      0.010159
# 486      0.049279
# 487      0.144198
# 488      0.280828
# 489      0.389615
# 490      0.467440
# 491      0.478246
# 492      0.491368
# 493      0.490376
# 604      0.501057
# 594      0.277403
# 595      0.435164
# 596      0.433775
# 597      0.428524
# 598      0.409308
# 599      0.393783
# 600      0.366559
# 601      0.332622
# 602      0.322314
# 603      0.308001
# 505      0.003095
# 495      0.001476
# 496      0.009849
# 497      0.045730
# 498      0.141970
# 499      0.279074
# 500      0.396518
# 501      0.471727
# 502      0.508107
# 503      0.527742
# 504      0.540582
# 615      0.529145
# 605      0.294333
# 606      0.449968
# 607      0.446352
# 608      0.428707
# 609      0.404605
# 610      0.359338
# 611      0.347148
# 612      0.319484
# 613      0.295793
# 614      0.254431
# 516      0.003580
# 506      0.001500
# 507      0.009719
# 508      0.046091
# 509      0.133284
# 510      0.262846
# 511      0.386233
# 512      0.442514
# 513      0.486039
# 514      0.490626
# 515      0.487761
# 626      0.455507
# 616      0.264057
# 617      0.386049
# 618      0.385726
# 619      0.355151
# 620      0.342895
# 621      0.334061
# 622      0.275830
# 623      0.233393
# 624      0.205380
# 625      0.167157
# 527      0.003824
# 517      0.001221
# 518      0.009018
# 519      0.047271
# 520      0.137919
# 521      0.269145
# 522      0.379450
# 523      0.436495
# 524      0.471066
# 525      0.467339
# 526      0.468364
# 637      0.470594
# 627      0.269206
# 628      0.422828
# 629      0.424478
# 630      0.416862
# 631      0.382587
# 632      0.353298
# 633      0.313672
# 634      0.302251
# 635      0.284225
# 636      0.247367
# 538      0.005704
# 528      0.001796
# 529      0.011896
# 530      0.050578
# 531      0.142329
# 532      0.284029
# 533      0.416375
# 534      0.513261
# 535      0.554791
# 536      0.577280
# 537      0.564101
# 648      0.532326
# 638      0.291553
# 639      0.484723
# 640      0.498563
# 641      0.442862
# 642      0.413547
# 643      0.390848
# 644      0.340967
# 645      0.302342
# 646      0.289258
# 647      0.212476
# 109      0.004308
# 99       0.001999
# 100      0.009010
# 101      0.047608
# 102      0.153926
# 103      0.313367
# 104      0.497407
# 105      0.656522
# 106      0.755019
# 107      0.816253
# 108      0.822496
# 219      0.668239
# 209      0.347741
# 210      0.649056
# 211      0.773405
# 212      0.799272
# 213      0.790964
# 214      0.773710
# 215      0.760066
# 216      0.740606
# 217      0.714372
# 218      0.714262
# 10       0.002527
# 0        0.000948
# 1        0.007143
# 2        0.042566
# 3        0.123879
# 4        0.305961
# 5        0.500107
# 6        0.673939
# 7        0.750921
# 8        0.805908
# 9        0.797123
# 120      0.676168
# 110      0.339220
# 111      0.652072
# 112      0.783230
# 113      0.825485
# 114      0.842723
# 115      0.836272
# 116      0.837578
# 117      0.822254
# 118      0.822856
# 119      0.788299
# 21       0.000527
# 11       0.000527
# 12       0.006626
# 13       0.038330
# 14       0.130947
# 15       0.276370
# 16       0.450208
# 17       0.605676
# 18       0.729292
# 19       0.789406
# 20       0.794426
# 131      0.687915
# 121      0.326897
# 122      0.677774
# 123      0.800729
# 124      0.832287
# 125      0.838618
# 126      0.805003
# 127      0.779019
# 128      0.752653
# 129      0.752653
# 130      0.746454
# 32       0.002083
# 22       0.001250
# 23       0.006641
# 24       0.040824
# 25       0.140410
# 26       0.308289
# 27       0.508116
# 28       0.675781
# 29       0.767318
# 30       0.832488
# 31       0.849115
# 142      0.675756
# 132      0.315901
# 133      0.678236
# 134      0.847963
# 135      0.903798
# 136      0.885974
# 137      0.881647
# 138      0.874704
# 139      0.853395
# 140      0.839452
# 141      0.821607
# 43       0.002399
# 33       0.000730
# 34       0.005513
# 35       0.036635
# 36       0.120989
# 37       0.257682
# 38       0.442049
# 39       0.619556
# 40       0.736906
# 41       0.808491
# 42       0.844106
# 153      0.669465
# 143      0.347683
# 144      0.658294
# 145      0.785970
# 146      0.804768
# 147      0.820576
# 148      0.809738
# 149      0.810308
# 150      0.790525
# 151      0.790525
# 152      0.790525
# 54       0.000526
# 44       0.000526
# 45       0.006175
# 46       0.036321
# 47       0.131088
# 48       0.288558
# 49       0.484737
# 50       0.644587
# 51       0.736641
# 52       0.791382
# 53       0.778857
# 164      0.671042
# 154      0.324244
# 155      0.666910
# 156      0.801487
# 157      0.805266
# 158      0.809844
# 159      0.787340
# 160      0.782875
# 161      0.772265
# 162      0.765197
# 163      0.751035
# 65       0.001753
# 55       0.000623
# 56       0.007542
# 57       0.043190
# 58       0.144266
# 59       0.321504
# 60       0.479295
# 61       0.612818
# 62       0.696702
# 63       0.746719
# 64       0.770263
# 175      0.679666
# 165      0.351108
# 166      0.657503
# 167      0.773160
# 168      0.808787
# 169      0.815088
# 170      0.816829
# 171      0.815937
# 172      0.815937
# 173      0.804173
# 174      0.779956
# 76       0.004464
# 66       0.001664
# 67       0.006333
# 68       0.028429
# 69       0.101271
# 70       0.247632
# 71       0.453073
# 72       0.629456
# 73       0.754226
# 74       0.838463
# 75       0.879115
# 186      0.699330
# 176      0.314703
# 177      0.692622
# 178      0.847951
# 179      0.845007
# 180      0.856981
# 181      0.813546
# 182      0.806259
# 183      0.806259
# 184      0.799541
# 185      0.787961
# 87       0.002686
# 77       0.001045
# 78       0.008334
# 79       0.042071
# 80       0.139435
# 81       0.270266
# 82       0.440021
# 83       0.593940
# 84       0.703006
# 85       0.748780
# 86       0.761861
# 197      0.680062
# 187      0.334336
# 188      0.685282
# 189      0.777990
# 190      0.792891
# 191      0.808512
# 192      0.808079
# 193      0.802193
# 194      0.802193
# 195      0.802193
# 196      0.794620
# 98       0.001261
# 88       0.000738
# 89       0.004519
# 90       0.035535
# 91       0.128385
# 92       0.301661
# 93       0.461856
# 94       0.564213
# 95       0.644899
# 96       0.671765
# 97       0.675765
# 208      0.610243
# 198      0.316098
# 199      0.584410
# 200      0.671588
# 201      0.697280
# 202      0.706184
# 203      0.709691
# 204      0.704553
# 205      0.698538
# 206      0.698538
# 207      0.692826
# 329      0.002103
# 319      0.001348
# 320      0.010087
# 321      0.050419
# 322      0.156023
# 323      0.313741
# 324      0.476285
# 325      0.580889
# 326      0.636104
# 327      0.666021
# 328      0.652536
# 439      0.576563
# 429      0.292072
# 430      0.548094
# 431      0.614172
# 432      0.611006
# 433      0.573292
# 434      0.539251
# 435      0.474179
# 436      0.435480
# 437      0.382841
# 438      0.360818
# 230      0.002193
# 220      0.000972
# 221      0.007157
# 222      0.044631
# 223      0.135924
# 224      0.303026
# 225      0.467632
# 226      0.597894
# 227      0.677563
# 228      0.713557
# 229      0.721941
# 340      0.650216
# 330      0.311553
# 331      0.609584
# 332      0.719564
# 333      0.728909
# 334      0.700737
# 335      0.628630
# 336      0.593658
# 337      0.575380
# 338      0.547296
# 339      0.543529
# 241      0.004102
# 231      0.001527
# 232      0.009445
# 233      0.050172
# 234      0.149187
# 235      0.310385
# 236      0.477930
# 237      0.595085
# 238      0.667502
# 239      0.693034
# 240      0.695551
# 351      0.651245
# 341      0.329542
# 342      0.607662
# 343      0.680594
# 344      0.680941
# 345      0.668350
# 346      0.651122
# 347      0.633117
# 348      0.613557
# 349      0.593267
# 350      0.576895
# 252      0.001683
# 242      0.000843
# 243      0.008557
# 244      0.042235
# 245      0.136917
# 246      0.300625
# 247      0.459653
# 248      0.600032
# 249      0.684856
# 250      0.706668
# 251      0.720718
# 362      0.657862
# 352      0.329588
# 353      0.613076
# 354      0.706971
# 355      0.738172
# 356      0.726084
# 357      0.713507
# 358      0.696618
# 359      0.679003
# 360      0.661998
# 361      0.640616
# 263      0.005152
# 253      0.001557
# 254      0.011649
# 255      0.042246
# 256      0.137117
# 257      0.304022
# 258      0.484951
# 259      0.590824
# 260      0.667604
# 261      0.686105
# 262      0.710673
# 373      0.585742
# 363      0.310686
# 364      0.559535
# 365      0.652203
# 366      0.656300
# 367      0.649346
# 368      0.626866
# 369      0.608345
# 370      0.554185
# 371      0.526261
# 372      0.519489
# 274      0.002631
# 264      0.001063
# 265      0.009421
# 266      0.048315
# 267      0.149720
# 268      0.305521
# 269      0.479702
# 270      0.597546
# 271      0.673731
# 272      0.682047
# 273      0.694534
# 384      0.594439
# 374      0.306321
# 375      0.578738
# 376      0.651642
# 377      0.660107
# 378      0.638591
# 379      0.634287
# 380      0.620206
# 381      0.606356
# 382      0.574003
# 383      0.556911
# 285      0.002916
# 275      0.001481
# 276      0.011068
# 277      0.051193
# 278      0.148337
# 279      0.298063
# 280      0.436112
# 281      0.550798
# 282      0.607496
# 283      0.645196
# 284      0.660152
# 395      0.597231
# 385      0.303037
# 386      0.567810
# 387      0.639476
# 388      0.645781
# 389      0.618097
# 390      0.605864
# 391      0.585652
# 392      0.571629
# 393      0.565675
# 394      0.558648
# 296      0.002700
# 286      0.000931
# 287      0.008922
# 288      0.044648
# 289      0.136114
# 290      0.283788
# 291      0.458160
# 292      0.557698
# 293      0.615625
# 294      0.653994
# 295      0.672462
# 406      0.656986
# 396      0.331755
# 397      0.607945
# 398      0.696539
# 399      0.668059
# 400      0.653779
# 401      0.601511
# 402      0.596478
# 403      0.576098
# 404      0.556657
# 405      0.549588
# 307      0.003393
# 297      0.001264
# 298      0.009203
# 299      0.052229
# 300      0.151616
# 301      0.296847
# 302      0.445310
# 303      0.557087
# 304      0.623278
# 305      0.636087
# 306      0.644483
# 417      0.590701
# 407      0.303102
# 408      0.569918
# 409      0.605649
# 410      0.617067
# 411      0.591907
# 412      0.580310
# 413      0.579408
# 414      0.566067
# 415      0.560815
# 416      0.546589
# 318      0.001430
# 308      0.000799
# 309      0.007212
# 310      0.037132
# 311      0.124673
# 312      0.276578
# 313      0.455923
# 314      0.594851
# 315      0.686164
# 316      0.740646
# 317      0.768060
# 428      0.646284
# 418      0.332749
# 419      0.620929
# 420      0.740807
# 421      0.758174
# 422      0.746391
# 423      0.713516
# 424      0.701971
# 425      0.650364
# 426      0.627140
# 427      0.591764

# %%
df_quality.to_csv('%s/df_quality.csv' % eval_dir, sep = ';', index = False)
#df_quality = pd.read_csv('%s/df_quality.csv' % eval_dir, sep = ';')

# %% [markdown]
# Combine counting and quality information:

# %%
df_c, df_q = df_counts.copy(), df_quality.copy()
drop_cols = ['join_col'] + ['%s_counts' % s for s in set(df_q.columns) & set(df_c.columns)]
df_c['join_col'] = df_c['data_set'] + df_c['tool'] + df_c['mode'] + df_c['refinement'] + df_c['threshold'].apply(str)
df_q['join_col'] = df_q['data_set'] + df_q['tool'] + df_q['mode'] + df_q['refinement'] + df_q['threshold'].apply(str)
df_joined = df_q.join(df_c.set_index('join_col'), on = 'join_col', rsuffix = '_counts').drop(drop_cols, axis = 1)

# %%
df_joined.to_csv('%s/df_joined.csv' % eval_dir, sep = ';', index = False)
#df_joined = pd.read_csv('%s/df_joined.csv' % eval_dir, sep = ';')

# %% [markdown]
# Determine the maximum, average and N-best average clustering quality (for N = 5).

# %%
df_columns = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

max_rows = []
mean_rows = []
nbest_rows = []
n = 5

for (d, g, t, m, f, ds, rt), grp in df_joined.groupby(by = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'ds', 'rt']):
    best = grp.nlargest(1, 'adjrandindex')
    max_rows.append([d, g, t, m, f, best['precision'].values[0], best['recall'].values[0], best['adjrandindex'].values[0], best['num_input_amplicons'].values[0], best['input_mass'].values[0], best['num_clusters'].values[0], best['num_output_amplicons'].values[0], best['output_mass'].values[0], ds, rt])
    mean_rows.append([d, g, t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean(), grp['num_input_amplicons'].mean(), grp['input_mass'].mean(), grp['num_clusters'].mean(), grp['num_output_amplicons'].mean(), grp['output_mass'].mean(), ds, rt])
    nbest = grp.nlargest(n, 'adjrandindex')
    nbest_rows.append([d, g, t, m, f, nbest['precision'].mean(), nbest['recall'].mean(), nbest['adjrandindex'].mean(), nbest['num_input_amplicons'].mean(), nbest['input_mass'].mean(), nbest['num_clusters'].mean(), nbest['num_output_amplicons'].mean(), nbest['output_mass'].mean(), ds, rt])
    
df_joined_max = pd.DataFrame(max_rows, columns = df_columns)
df_joined_mean = pd.DataFrame(mean_rows, columns = df_columns)
df_joined_nbest = pd.DataFrame(nbest_rows, columns = df_columns)

# %%
df_joined_max.to_csv('%s/df_joined_max.csv' % eval_dir, sep = ';', index = False)
df_joined_mean.to_csv('%s/df_joined_mean.csv' % eval_dir, sep = ';', index = False)
df_joined_nbest.to_csv('%s/df_joined_nbest.csv' % eval_dir, sep = ';', index = False)
#df_joined_max = pd.read_csv('%s/df_joined_max.csv' % eval_dir, sep = ';')
#df_joined_mean = pd.read_csv('%s/df_joined_mean.csv' % eval_dir, sep = ';')
#df_joined_nbest = pd.read_csv('%s/df_joined_nbest.csv' % eval_dir, sep = ';')

# %%
df_max = df_joined_max.loc[df_joined_max['gt'] == 'franzen']
df_mean = df_joined_mean.loc[df_joined_mean['gt'] == 'franzen']
df_nbest = df_joined_nbest.loc[df_joined_nbest['gt'] == 'franzen']

# %% [markdown]
# For the chosen ground truth, average the maximum, average and N-best average values per complexity (e.g. LC) and read type (e.g. V3-V4).

# %%
df_columns = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

def average_complexity(df):
    rows = []
    for (gt, ds, rt, tool, mode, f), grp in df.groupby(by = ['gt', 'ds', 'rt', 'tool', 'mode', 'refinement']):
        rows.append(['%s_%s' % (ds, rt), gt, tool, mode, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean(), grp['num_input_amplicons'].mean(), grp['input_mass'].mean(), grp['num_clusters'].mean(), grp['num_output_amplicons'].mean(), grp['output_mass'].mean(), ds, rt])
    return pd.DataFrame(rows, columns = df_columns)

# %%
df_joined_max_avg = average_complexity(df_max)
df_joined_mean_avg = average_complexity(df_mean)
df_joined_nbest_avg = average_complexity(df_nbest)

# %%
df_joined_max_avg.to_csv('%s/df_joined_max_avg.csv' % eval_dir, sep = ';', index = False)
df_joined_mean_avg.to_csv('%s/df_joined_mean_avg.csv' % eval_dir, sep = ';', index = False)
df_joined_nbest_avg.to_csv('%s/df_joined_nbest_avg.csv' % eval_dir, sep = ';', index = False)
#df_joined_max_avg = pd.read_csv('%s/df_joined_max_avg.csv' % eval_dir, sep = ';')
#df_joined_mean_avg = pd.read_csv('%s/df_joined_mean_avg.csv' % eval_dir, sep = ';')
#df_joined_nbest_avg = pd.read_csv('%s/df_joined_nbest_avg.csv' % eval_dir, sep = ';')

# %% [markdown]
# **Maximum clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_max_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: HC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 1  HC_V3-V4  franzen  swarm  swarm         nf   0.739601  0.925437
# 0  HC_V3-V4  franzen  swarm  swarm         2f   0.996222  0.059555
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 1      0.522373               9958.0      9958.0        1098.7
# 0      0.004003               9958.0      9958.0        9840.7
#
#    num_output_amplicons  output_mass  ds     rt
# 1                9952.4       9958.0  HC  V3-V4
# 0                9952.4       9958.0  HC  V3-V4
# Data set: HC_V4 / Tool: swarm
#   data_set       gt   tool   mode refinement  precision    recall  \
# 2    HC_V4  franzen  swarm  swarm         2f   0.825773  0.760851
# 3    HC_V4  franzen  swarm  swarm         nf   0.708053  0.876749
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 2      0.515218               9958.0      9958.0        2334.0
# 3      0.470145               9958.0      9958.0        1325.6
#
#    num_output_amplicons  output_mass  ds  rt
# 2                8208.7       9958.0  HC  V4
# 3                8208.7       9958.0  HC  V4
# Data set: LC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 5  LC_V3-V4  franzen  swarm  swarm         nf   0.874385  0.949943
# 4  LC_V3-V4  franzen  swarm  swarm         2f   0.999196  0.055759
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 5      0.799444               1988.0      1988.0         185.5
# 4      0.002253               1988.0      1988.0        1975.0
#
#    num_output_amplicons  output_mass  ds     rt
# 5                1987.1       1988.0  LC  V3-V4
# 4                1987.1       1988.0  LC  V3-V4
# Data set: LC_V4 / Tool: swarm
#   data_set       gt   tool   mode refinement  precision    recall  \
# 7    LC_V4  franzen  swarm  swarm         nf   0.868492  0.991508
# 6    LC_V4  franzen  swarm  swarm         2f   0.942811  0.757700
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 7      0.820684               1988.0      1988.0          99.7
# 6      0.671789               1988.0      1988.0         493.2
#
#    num_output_amplicons  output_mass  ds  rt
# 7                1659.5       1988.0  LC  V4
# 6                1659.5       1988.0  LC  V4
# Data set: MC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 9  MC_V3-V4  franzen  swarm  swarm         nf   0.807498  0.957864
# 8  MC_V3-V4  franzen  swarm  swarm         2f   0.998791  0.057249
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 9      0.695459               4966.0      4966.0         406.9
# 8      0.002830               4966.0      4966.0        4924.1
#
#    num_output_amplicons  output_mass  ds     rt
# 9                4962.6       4966.0  MC  V3-V4
# 8                4962.6       4966.0  MC  V3-V4
# Data set: MC_V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 11    MC_V4  franzen  swarm  swarm         nf   0.781186  0.965133
# 10    MC_V4  franzen  swarm  swarm         2f   0.892488  0.762384
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 11      0.679616               4966.0      4966.0         331.2
# 10      0.620727               4966.0      4966.0        1184.4
#
#     num_output_amplicons  output_mass  ds  rt
# 11                4101.5       4966.0  MC  V4
# 10                4101.5       4966.0  MC  V4

# %% [markdown]
# Average maximum values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_max_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#     tool   mode refinement  precision    recall  adjrandindex
# 1  swarm  swarm         nf   0.796536  0.944439      0.664620
# 0  swarm  swarm         2f   0.942547  0.408916      0.302803

# %% [markdown]
# **Average clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_mean_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: HC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 1  HC_V3-V4  franzen  swarm  swarm         nf   0.875615  0.502917
# 0  HC_V3-V4  franzen  swarm  swarm         2f   0.996222  0.059555
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 1      0.288483               9958.0      9958.0       5349.75
# 0      0.004003               9958.0      9958.0       9840.70
#
#    num_output_amplicons  output_mass  ds     rt
# 1                9952.4       9958.0  HC  V3-V4
# 0                9952.4       9958.0  HC  V3-V4
# Data set: HC_V4 / Tool: swarm
#   data_set       gt   tool   mode refinement  precision    recall  \
# 2    HC_V4  franzen  swarm  swarm         2f   0.825773  0.760851
# 3    HC_V4  franzen  swarm  swarm         nf   0.593928  0.908861
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 2      0.515218               9958.0      9958.0        2334.0
# 3      0.373045               9958.0      9958.0        1014.2
#
#    num_output_amplicons  output_mass  ds  rt
# 2                8208.7       9958.0  HC  V4
# 3                8208.7       9958.0  HC  V4
# Data set: LC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 5  LC_V3-V4  franzen  swarm  swarm         nf   0.950822  0.489486
# 4  LC_V3-V4  franzen  swarm  swarm         2f   0.999196  0.055759
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 5      0.387664               1988.0      1988.0       1106.33
# 4      0.002253               1988.0      1988.0       1975.00
#
#    num_output_amplicons  output_mass  ds     rt
# 5                1987.1       1988.0  LC  V3-V4
# 4                1987.1       1988.0  LC  V3-V4
# Data set: LC_V4 / Tool: swarm
#   data_set       gt   tool   mode refinement  precision    recall  \
# 7    LC_V4  franzen  swarm  swarm         nf   0.866530  0.910635
# 6    LC_V4  franzen  swarm  swarm         2f   0.942811  0.757700
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 7      0.734009               1988.0      1988.0        232.75
# 6      0.671789               1988.0      1988.0        493.20
#
#    num_output_amplicons  output_mass  ds  rt
# 7                1659.5       1988.0  LC  V4
# 6                1659.5       1988.0  LC  V4
# Data set: MC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 9  MC_V3-V4  franzen  swarm  swarm         nf   0.918595  0.498619
# 8  MC_V3-V4  franzen  swarm  swarm         2f   0.998791  0.057249
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 9      0.357547               4966.0      4966.0       2705.35
# 8      0.002830               4966.0      4966.0       4924.10
#
#    num_output_amplicons  output_mass  ds     rt
# 9                4962.6       4966.0  MC  V3-V4
# 8                4962.6       4966.0  MC  V3-V4
# Data set: MC_V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 10    MC_V4  franzen  swarm  swarm         2f   0.892488  0.762384
# 11    MC_V4  franzen  swarm  swarm         nf   0.747419  0.910547
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 10      0.620727               4966.0      4966.0       1184.40
# 11      0.583258               4966.0      4966.0        544.08
#
#     num_output_amplicons  output_mass  ds  rt
# 10                4101.5       4966.0  MC  V4
# 11                4101.5       4966.0  MC  V4

# %% [markdown]
# Average mean values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_mean_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#     tool   mode refinement  precision    recall  adjrandindex
# 1  swarm  swarm         nf   0.825485  0.703511      0.454001
# 0  swarm  swarm         2f   0.942547  0.408916      0.302803

# %% [markdown]
# **N-best average clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_nbest_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: HC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 1  HC_V3-V4  franzen  swarm  swarm         nf   0.782445  0.814887
# 0  HC_V3-V4  franzen  swarm  swarm         2f   0.996222  0.059555
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 1      0.481810               9958.0      9958.0       2207.44
# 0      0.004003               9958.0      9958.0       9840.70
#
#    num_output_amplicons  output_mass  ds     rt
# 1                9952.4       9958.0  HC  V3-V4
# 0                9952.4       9958.0  HC  V3-V4
# Data set: HC_V4 / Tool: swarm
#   data_set       gt   tool   mode refinement  precision    recall  \
# 2    HC_V4  franzen  swarm  swarm         2f   0.825773  0.760851
# 3    HC_V4  franzen  swarm  swarm         nf   0.639093  0.928892
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 2      0.515218               9958.0      9958.0       2334.00
# 3      0.439021               9958.0      9958.0        873.68
#
#    num_output_amplicons  output_mass  ds  rt
# 2                8208.7       9958.0  HC  V4
# 3                8208.7       9958.0  HC  V4
# Data set: LC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 5  LC_V3-V4  franzen  swarm  swarm         nf   0.911315  0.801278
# 4  LC_V3-V4  franzen  swarm  swarm         2f   0.999196  0.055759
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 5      0.681821               1988.0      1988.0        483.16
# 4      0.002253               1988.0      1988.0       1975.00
#
#    num_output_amplicons  output_mass  ds     rt
# 5                1987.1       1988.0  LC  V3-V4
# 4                1987.1       1988.0  LC  V3-V4
# Data set: LC_V4 / Tool: swarm
#   data_set       gt   tool   mode refinement  precision    recall  \
# 7    LC_V4  franzen  swarm  swarm         nf   0.856714  0.988027
# 6    LC_V4  franzen  swarm  swarm         2f   0.942811  0.757700
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 7      0.806465               1988.0      1988.0        104.08
# 6      0.671789               1988.0      1988.0        493.20
#
#    num_output_amplicons  output_mass  ds  rt
# 7                1659.5       1988.0  LC  V4
# 6                1659.5       1988.0  LC  V4
# Data set: MC_V3-V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 9  MC_V3-V4  franzen  swarm  swarm         nf   0.855711  0.810055
# 8  MC_V3-V4  franzen  swarm  swarm         2f   0.998791  0.057249
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 9      0.615375               4966.0      4966.0       1145.98
# 8      0.002830               4966.0      4966.0       4924.10
#
#    num_output_amplicons  output_mass  ds     rt
# 9                4962.6       4966.0  MC  V3-V4
# 8                4962.6       4966.0  MC  V3-V4
# Data set: MC_V4 / Tool: swarm
#    data_set       gt   tool   mode refinement  precision    recall  \
# 11    MC_V4  franzen  swarm  swarm         nf   0.759424  0.963268
# 10    MC_V4  franzen  swarm  swarm         2f   0.892488  0.762384
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 11      0.650490               4966.0      4966.0        333.26
# 10      0.620727               4966.0      4966.0       1184.40
#
#     num_output_amplicons  output_mass  ds  rt
# 11                4101.5       4966.0  MC  V4
# 10                4101.5       4966.0  MC  V4

# %% [markdown]
# Average mean values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_nbest_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#     tool   mode refinement  precision    recall  adjrandindex
# 1  swarm  swarm         nf   0.800784  0.884401      0.612497
# 0  swarm  swarm         2f   0.942547  0.408916      0.302803
