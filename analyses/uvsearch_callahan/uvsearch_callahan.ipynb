# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))


import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import os
import pandas as pd
import seaborn as sb
import statistics as st

from Bio import SeqIO

sb.set()
pd.set_option("display.max_rows", None)
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Evaluation of USEARCH and VSEARCH on Callahan data
#
# The following notebook describes the steps and results of the evaluation.

# %%
# Initial files and directories:
#
# uvsearch_callahan
# |- data
# |  |- balanced
# |  |  \- BalancedRefSeqs.fasta  # provided reference sequences of 'balanced' data set
# |  |
# |  \- hmp
# |     \- HMP_MOCK.fasta  # provided reference sequences of 'hmp' data set
# |
# |- evaluation # will contain the evaluation plots and tables
# |
# |- outputs # will contain the cluster and metric outputs
# |
# \- tasks  # task files for the different runs of U/VSEARCH

# %% [markdown]
# The provided reference sequences are part of the [Supplementary Software](https://static-content.springer.com/esm/art%3A10.1038%2Fnmeth.3869/MediaObjects/41592_2016_BFnmeth3869_MOESM270_ESM.zip) of the DADA2 paper.

# %% [markdown]
# ## Analysis workflow
#
# The data sets are preprocessed as described in Callahan et al., *DADA2: High-resolution sample inference from Illumina amplicon data* (https://doi.org/10.1038/nmeth.3869),
# except that the minimum sequence abundance is set to 1 (not 2) for the sake of a fair comparison with other data sets and tools.
#
# The taxonomic assignment is obtained by merging (using `USEARCH -fastq_mergepairs`) and dereplicating (using `USEARCH -derep_fulllength`) the reads,
# and then matching them with the respective reference sequences (using `VSEARCH --usearch_global`).
#
# Both tools are run with several clustering options:
#  - USEARCH: `-cluster_fast`, `-cluster_smallmem`, `-cluster_otus`
#  - VSEARCH: `--cluster_fast`, `--cluster_size`, `--cluster_smallmem`

# %% [markdown]
# ## Commands
#
# The following commands prepare and cluster the data sets. The results are evaluated below.
#
# In order to execute the workflow as provided here, the `tools` subdirectory of the overall repository should contain a VSEARCH binary and the USEARCH binaries `usearch8.0.1623_i86linux32`, `usearch10.0.240_i86linux32` (both for data preparation) and `usearch11.0.667_i86linux32` (for clustering), but the paths can be adjusted.
#
# IMPORTANT: The commands are not intended to be executed from this notebook. They should be executed from the root directory of the overall repository.

# %%
# %%bash
#
# TOOLS_DIR=tools
# ANALYSIS_DIR=analyses/uvsearch_callahan
# DATA_DIR=${ANALYSIS_DIR}/data
# OUTPUT_DIR=${ANALYSIS_DIR}/outputs
#
# USEARCH8_PATH=${TOOLS_DIR}/usearch8.0.1623_i86linux32 # adjust to your system
# USEARCH10_PATH=${TOOLS_DIR}/usearch10.0.240_i86linux32 # adjust to your system
#
# USEARCH=${TOOLS_DIR}/usearch11.0.667_i86linux32 # adjust to your system
# VSEARCH=${TOOLS_DIR}/vsearch-2.14.2-linux-x86_64/bin/vsearch # adjust to your system
#
# RUNS=( uparse_otus usearch_fast_length  usearch_fast_size  usearch_smallmem_length  usearch_smallmem_size  vsearch_fast  vsearch_size  vsearch_smallmem_length  vsearch_smallmem_size )
#
# ## balanced
# python -m scripts.analyses.analysis_callahan reference balanced ${DATA_DIR}/balanced/BalancedRefSeqs.fasta ${DATA_DIR}/balanced/callahan.fasta
#
# # paired
# python -m scripts.analyses.analysis_callahan prepare balanced ${DATA_DIR}/balanced --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/balanced/ERR777695_pfmd.fastq ${DATA_DIR}/balanced/callahan.fasta ${DATA_DIR}/balanced/bp_callahan_0.97.tax 0.97
# READS=bp:${DATA_DIR}/balanced/ERR777695_pfmd.fastq
# TAX=callahan:${DATA_DIR}/balanced/bp_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run_uvsearch ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/balanced_paired/${R} --tax_files ${TAX} --usearch ${USEARCH} --vsearch ${VSEARCH}
#     for F in ${OUTPUT_DIR}/balanced_paired/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/balanced_paired/${R}/${R}_${F##*/}; done
# done
#
# # single
# python -m scripts.analyses.analysis_callahan prepare balanced ${DATA_DIR}/balanced --single --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/balanced/ERR777695_1_sfd.fastq ${DATA_DIR}/balanced/callahan.fasta ${DATA_DIR}/balanced/bs_callahan_0.97.tax 0.97
# READS=bs:${DATA_DIR}/balanced/ERR777695_1_sfd.fastq
# TAX=callahan:${DATA_DIR}/balanced/bs_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run_uvsearch ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/balanced_single/${R} --tax_files ${TAX} --usearch ${USEARCH} --vsearch ${VSEARCH}
#     for F in ${OUTPUT_DIR}/balanced_single/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/balanced_single/${R}/${R}_${F##*/}; done
# done
#
# ## hmp
# python -m scripts.analyses.analysis_callahan reference hmp ${DATA_DIR}/hmp/HMP_MOCK.fasta ${DATA_DIR}/hmp/callahan.fasta
#
# # paired
# python -m scripts.analyses.analysis_callahan prepare hmp ${DATA_DIR}/hmp --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/hmp/Mock1_S1_L001_pfmd.fastq ${DATA_DIR}/hmp/callahan.fasta ${DATA_DIR}/hmp/hp_callahan_0.97.tax 0.97
# READS=hp:${DATA_DIR}/hmp/Mock1_S1_L001_pfmd.fastq
# TAX=callahan:${DATA_DIR}/hmp/hp_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run_uvsearch ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/hmp_paired/${R} --tax_files ${TAX} --usearch ${USEARCH} --vsearch ${VSEARCH}
#     for F in ${OUTPUT_DIR}/hmp_paired/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/hmp_paired/${R}/${R}_${F##*/}; done
# done
#
# # single
# python -m scripts.analyses.analysis_callahan prepare hmp ${DATA_DIR}/hmp --single --min_size 1 --usearch8 ${USEARCH8_PATH} --usearch10 ${USEARCH10_PATH}
# python -m scripts.analyses.analysis_callahan taxonomy ${DATA_DIR}/hmp/Mock1_S1_L001_R1_001_sfd.fastq ${DATA_DIR}/hmp/callahan.fasta ${DATA_DIR}/hmp/hs_callahan_0.97.tax 0.97
# READS=hs:${DATA_DIR}/hmp/Mock1_S1_L001_R1_001_sfd.fastq
# TAX=callahan:${DATA_DIR}/hmp/hs_callahan_0.97.tax
# for R in "${RUNS[@]}"; do
#     python -m scripts.analyses.analysis_callahan run_uvsearch ${R} ${READS} ${ANALYSIS_DIR}/tasks/${R}.txt ${OUTPUT_DIR}/hmp_single/${R} --tax_files ${TAX} --usearch ${USEARCH} --vsearch ${VSEARCH}
#     for F in ${OUTPUT_DIR}/hmp_single/${R}/*__metrics.csv; do mv ${F} ${OUTPUT_DIR}/hmp_single/${R}/${R}_${F##*/}; done
# done

# %% [markdown]
# ## Evaluation

# %% [markdown]
# **Configuration**

# %%
data_sets = ['balanced', 'hmp']
read_types = ['single', 'paired']
ground_truths = ['callahan']

opts = ['uparse_otus', 'usearch_fast_length', 'usearch_fast_size', 'usearch_smallmem_length', 'usearch_smallmem_size', 'vsearch_fast', 'vsearch_size', 'vsearch_smallmem_length', 'vsearch_smallmem_size']

read_files = {'balanced_single': 'ERR777695_1_sfd.fastq', 'balanced_paired': 'ERR777695_pfmd.fastq',
              'hmp_single': 'Mock1_S1_L001_R1_001_sfd.fastq', 'hmp_paired': 'Mock1_S1_L001_pfmd.fastq'}

data_dir = 'data'
results_dir = 'outputs'
eval_dir = 'evaluation'

# %% [markdown]
# ### Number of clusters and amplicons
#
# Reads the input files and the cluster outputs for all data sets and compares the number of clusters and amplicons.

# %%
# Requires the input and OTU files. Alternatively, the evaluation can use the stored information (see below).
df_columns = ['data_set', 'tool', 'mode', 'refinement', 'threshold', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

rows = []

for rt in read_types:
    for ds in data_sets:
        run_name = '%s_%s' % (ds, rt)
        
        seq_file = '%s/%s/%s' % (data_dir, ds, read_files[run_name]) # the input sequences
        num_input_amplicons = 0
        input_mass = 0
        with open(seq_file, 'r') as in_file:
            for record in SeqIO.parse(in_file, 'fastq'):
                num_input_amplicons += 1
                input_mass += int(record.id.split('_')[-1])
        
        for opt in opts:
            otu_files = [f for f in os.listdir('%s/%s/%s/' % (results_dir, run_name, opt)) if f.endswith('_otus.txt')]

            for f in otu_files:
                otu_file = '%s/%s/%s/%s' % (results_dir, run_name, opt, f)
                        
                num_output_amplicons = 0
                num_clusters = 0
                output_mass = 0
                with open(otu_file, 'r') as in_file:
                    for line in in_file:
                        num_output_amplicons += len(line.strip().split(' '))
                        num_clusters += 1
                        output_mass += sum([int(m.split('_')[-1]) for m in line.strip().split(' ')])
                        
                tool, mode = f.split('__')
                mode = mode.split('_0')[0]
                refinement = 'nf'
                threshold = float(f.split('_')[-2])
                        
                rows.append([run_name, tool, mode, refinement, threshold, num_input_amplicons, input_mass, num_clusters, num_output_amplicons, output_mass, ds, rt])
            
df_counts = pd.DataFrame(rows, columns = df_columns)

# %% [markdown]
# *Column descriptions:*
# `num_input_amplicons`: The number of entries in the corresponding input file.
# `input_mass`: The sum of the abundances of all entries in the input file.
# `num_clusters`: The number of computed clusters.
# `num_output_amplicons`: The number of amplicons contained in the clusters.
# `output_mass`: The sum of the abundances of all amplicons contained in the clusters.

# %%
df_counts[['data_set', 'tool', 'mode', 'threshold', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass']]
# Out:
#             data_set     tool             mode  threshold  \
# 0    balanced_single   uparse             otus       0.97
# 1    balanced_single  usearch      fast_length       0.90
# 2    balanced_single  usearch      fast_length       0.91
# 3    balanced_single  usearch      fast_length       0.92
# 4    balanced_single  usearch      fast_length       0.93
# 5    balanced_single  usearch      fast_length       0.94
# 6    balanced_single  usearch      fast_length       0.95
# 7    balanced_single  usearch      fast_length       0.96
# 8    balanced_single  usearch      fast_length       0.97
# 9    balanced_single  usearch      fast_length       0.98
# 10   balanced_single  usearch      fast_length       0.99
# 11   balanced_single  usearch        fast_size       0.90
# 12   balanced_single  usearch        fast_size       0.91
# 13   balanced_single  usearch        fast_size       0.92
# 14   balanced_single  usearch        fast_size       0.93
# 15   balanced_single  usearch        fast_size       0.94
# 16   balanced_single  usearch        fast_size       0.95
# 17   balanced_single  usearch        fast_size       0.96
# 18   balanced_single  usearch        fast_size       0.97
# 19   balanced_single  usearch        fast_size       0.98
# 20   balanced_single  usearch        fast_size       0.99
# 21   balanced_single  usearch  smallmem_length       0.90
# 22   balanced_single  usearch  smallmem_length       0.91
# 23   balanced_single  usearch  smallmem_length       0.92
# 24   balanced_single  usearch  smallmem_length       0.93
# 25   balanced_single  usearch  smallmem_length       0.94
# 26   balanced_single  usearch  smallmem_length       0.95
# 27   balanced_single  usearch  smallmem_length       0.96
# 28   balanced_single  usearch  smallmem_length       0.97
# 29   balanced_single  usearch  smallmem_length       0.98
# 30   balanced_single  usearch  smallmem_length       0.99
# 31   balanced_single  usearch    smallmem_size       0.90
# 32   balanced_single  usearch    smallmem_size       0.91
# 33   balanced_single  usearch    smallmem_size       0.92
# 34   balanced_single  usearch    smallmem_size       0.93
# 35   balanced_single  usearch    smallmem_size       0.94
# 36   balanced_single  usearch    smallmem_size       0.95
# 37   balanced_single  usearch    smallmem_size       0.96
# 38   balanced_single  usearch    smallmem_size       0.97
# 39   balanced_single  usearch    smallmem_size       0.98
# 40   balanced_single  usearch    smallmem_size       0.99
# 41   balanced_single  vsearch             fast       0.90
# 42   balanced_single  vsearch             fast       0.91
# 43   balanced_single  vsearch             fast       0.92
# 44   balanced_single  vsearch             fast       0.93
# 45   balanced_single  vsearch             fast       0.94
# 46   balanced_single  vsearch             fast       0.95
# 47   balanced_single  vsearch             fast       0.96
# 48   balanced_single  vsearch             fast       0.97
# 49   balanced_single  vsearch             fast       0.98
# 50   balanced_single  vsearch             fast       0.99
# 51   balanced_single  vsearch             size       0.90
# 52   balanced_single  vsearch             size       0.91
# 53   balanced_single  vsearch             size       0.92
# 54   balanced_single  vsearch             size       0.93
# 55   balanced_single  vsearch             size       0.94
# 56   balanced_single  vsearch             size       0.95
# 57   balanced_single  vsearch             size       0.96
# 58   balanced_single  vsearch             size       0.97
# 59   balanced_single  vsearch             size       0.98
# 60   balanced_single  vsearch             size       0.99
# 61   balanced_single  vsearch  smallmem_length       0.90
# 62   balanced_single  vsearch  smallmem_length       0.91
# 63   balanced_single  vsearch  smallmem_length       0.92
# 64   balanced_single  vsearch  smallmem_length       0.93
# 65   balanced_single  vsearch  smallmem_length       0.94
# 66   balanced_single  vsearch  smallmem_length       0.95
# 67   balanced_single  vsearch  smallmem_length       0.96
# 68   balanced_single  vsearch  smallmem_length       0.97
# 69   balanced_single  vsearch  smallmem_length       0.98
# 70   balanced_single  vsearch  smallmem_length       0.99
# 71   balanced_single  vsearch    smallmem_size       0.90
# 72   balanced_single  vsearch    smallmem_size       0.91
# 73   balanced_single  vsearch    smallmem_size       0.92
# 74   balanced_single  vsearch    smallmem_size       0.93
# 75   balanced_single  vsearch    smallmem_size       0.94
# 76   balanced_single  vsearch    smallmem_size       0.95
# 77   balanced_single  vsearch    smallmem_size       0.96
# 78   balanced_single  vsearch    smallmem_size       0.97
# 79   balanced_single  vsearch    smallmem_size       0.98
# 80   balanced_single  vsearch    smallmem_size       0.99
# 81        hmp_single   uparse             otus       0.97
# 82        hmp_single  usearch      fast_length       0.90
# 83        hmp_single  usearch      fast_length       0.91
# 84        hmp_single  usearch      fast_length       0.92
# 85        hmp_single  usearch      fast_length       0.93
# 86        hmp_single  usearch      fast_length       0.94
# 87        hmp_single  usearch      fast_length       0.95
# 88        hmp_single  usearch      fast_length       0.96
# 89        hmp_single  usearch      fast_length       0.97
# 90        hmp_single  usearch      fast_length       0.98
# 91        hmp_single  usearch      fast_length       0.99
# 92        hmp_single  usearch        fast_size       0.90
# 93        hmp_single  usearch        fast_size       0.91
# 94        hmp_single  usearch        fast_size       0.92
# 95        hmp_single  usearch        fast_size       0.93
# 96        hmp_single  usearch        fast_size       0.94
# 97        hmp_single  usearch        fast_size       0.95
# 98        hmp_single  usearch        fast_size       0.96
# 99        hmp_single  usearch        fast_size       0.97
# 100       hmp_single  usearch        fast_size       0.98
# 101       hmp_single  usearch        fast_size       0.99
# 102       hmp_single  usearch  smallmem_length       0.90
# 103       hmp_single  usearch  smallmem_length       0.91
# 104       hmp_single  usearch  smallmem_length       0.92
# 105       hmp_single  usearch  smallmem_length       0.93
# 106       hmp_single  usearch  smallmem_length       0.94
# 107       hmp_single  usearch  smallmem_length       0.95
# 108       hmp_single  usearch  smallmem_length       0.96
# 109       hmp_single  usearch  smallmem_length       0.97
# 110       hmp_single  usearch  smallmem_length       0.98
# 111       hmp_single  usearch  smallmem_length       0.99
# 112       hmp_single  usearch    smallmem_size       0.90
# 113       hmp_single  usearch    smallmem_size       0.91
# 114       hmp_single  usearch    smallmem_size       0.92
# 115       hmp_single  usearch    smallmem_size       0.93
# 116       hmp_single  usearch    smallmem_size       0.94
# 117       hmp_single  usearch    smallmem_size       0.95
# 118       hmp_single  usearch    smallmem_size       0.96
# 119       hmp_single  usearch    smallmem_size       0.97
# 120       hmp_single  usearch    smallmem_size       0.98
# 121       hmp_single  usearch    smallmem_size       0.99
# 122       hmp_single  vsearch             fast       0.90
# 123       hmp_single  vsearch             fast       0.91
# 124       hmp_single  vsearch             fast       0.92
# 125       hmp_single  vsearch             fast       0.93
# 126       hmp_single  vsearch             fast       0.94
# 127       hmp_single  vsearch             fast       0.95
# 128       hmp_single  vsearch             fast       0.96
# 129       hmp_single  vsearch             fast       0.97
# 130       hmp_single  vsearch             fast       0.98
# 131       hmp_single  vsearch             fast       0.99
# 132       hmp_single  vsearch             size       0.90
# 133       hmp_single  vsearch             size       0.91
# 134       hmp_single  vsearch             size       0.92
# 135       hmp_single  vsearch             size       0.93
# 136       hmp_single  vsearch             size       0.94
# 137       hmp_single  vsearch             size       0.95
# 138       hmp_single  vsearch             size       0.96
# 139       hmp_single  vsearch             size       0.97
# 140       hmp_single  vsearch             size       0.98
# 141       hmp_single  vsearch             size       0.99
# 142       hmp_single  vsearch  smallmem_length       0.90
# 143       hmp_single  vsearch  smallmem_length       0.91
# 144       hmp_single  vsearch  smallmem_length       0.92
# 145       hmp_single  vsearch  smallmem_length       0.93
# 146       hmp_single  vsearch  smallmem_length       0.94
# 147       hmp_single  vsearch  smallmem_length       0.95
# 148       hmp_single  vsearch  smallmem_length       0.96
# 149       hmp_single  vsearch  smallmem_length       0.97
# 150       hmp_single  vsearch  smallmem_length       0.98
# 151       hmp_single  vsearch  smallmem_length       0.99
# 152       hmp_single  vsearch    smallmem_size       0.90
# 153       hmp_single  vsearch    smallmem_size       0.91
# 154       hmp_single  vsearch    smallmem_size       0.92
# 155       hmp_single  vsearch    smallmem_size       0.93
# 156       hmp_single  vsearch    smallmem_size       0.94
# 157       hmp_single  vsearch    smallmem_size       0.95
# 158       hmp_single  vsearch    smallmem_size       0.96
# 159       hmp_single  vsearch    smallmem_size       0.97
# 160       hmp_single  vsearch    smallmem_size       0.98
# 161       hmp_single  vsearch    smallmem_size       0.99
# 162  balanced_paired   uparse             otus       0.97
# 163  balanced_paired  usearch      fast_length       0.90
# 164  balanced_paired  usearch      fast_length       0.91
# 165  balanced_paired  usearch      fast_length       0.92
# 166  balanced_paired  usearch      fast_length       0.93
# 167  balanced_paired  usearch      fast_length       0.94
# 168  balanced_paired  usearch      fast_length       0.95
# 169  balanced_paired  usearch      fast_length       0.96
# 170  balanced_paired  usearch      fast_length       0.97
# 171  balanced_paired  usearch      fast_length       0.98
# 172  balanced_paired  usearch      fast_length       0.99
# 173  balanced_paired  usearch        fast_size       0.90
# 174  balanced_paired  usearch        fast_size       0.91
# 175  balanced_paired  usearch        fast_size       0.92
# 176  balanced_paired  usearch        fast_size       0.93
# 177  balanced_paired  usearch        fast_size       0.94
# 178  balanced_paired  usearch        fast_size       0.95
# 179  balanced_paired  usearch        fast_size       0.96
# 180  balanced_paired  usearch        fast_size       0.97
# 181  balanced_paired  usearch        fast_size       0.98
# 182  balanced_paired  usearch        fast_size       0.99
# 183  balanced_paired  usearch  smallmem_length       0.90
# 184  balanced_paired  usearch  smallmem_length       0.91
# 185  balanced_paired  usearch  smallmem_length       0.92
# 186  balanced_paired  usearch  smallmem_length       0.93
# 187  balanced_paired  usearch  smallmem_length       0.94
# 188  balanced_paired  usearch  smallmem_length       0.95
# 189  balanced_paired  usearch  smallmem_length       0.96
# 190  balanced_paired  usearch  smallmem_length       0.97
# 191  balanced_paired  usearch  smallmem_length       0.98
# 192  balanced_paired  usearch  smallmem_length       0.99
# 193  balanced_paired  usearch    smallmem_size       0.90
# 194  balanced_paired  usearch    smallmem_size       0.91
# 195  balanced_paired  usearch    smallmem_size       0.92
# 196  balanced_paired  usearch    smallmem_size       0.93
# 197  balanced_paired  usearch    smallmem_size       0.94
# 198  balanced_paired  usearch    smallmem_size       0.95
# 199  balanced_paired  usearch    smallmem_size       0.96
# 200  balanced_paired  usearch    smallmem_size       0.97
# 201  balanced_paired  usearch    smallmem_size       0.98
# 202  balanced_paired  usearch    smallmem_size       0.99
# 203  balanced_paired  vsearch             fast       0.90
# 204  balanced_paired  vsearch             fast       0.91
# 205  balanced_paired  vsearch             fast       0.92
# 206  balanced_paired  vsearch             fast       0.93
# 207  balanced_paired  vsearch             fast       0.94
# 208  balanced_paired  vsearch             fast       0.95
# 209  balanced_paired  vsearch             fast       0.96
# 210  balanced_paired  vsearch             fast       0.97
# 211  balanced_paired  vsearch             fast       0.98
# 212  balanced_paired  vsearch             fast       0.99
# 213  balanced_paired  vsearch             size       0.90
# 214  balanced_paired  vsearch             size       0.91
# 215  balanced_paired  vsearch             size       0.92
# 216  balanced_paired  vsearch             size       0.93
# 217  balanced_paired  vsearch             size       0.94
# 218  balanced_paired  vsearch             size       0.95
# 219  balanced_paired  vsearch             size       0.96
# 220  balanced_paired  vsearch             size       0.97
# 221  balanced_paired  vsearch             size       0.98
# 222  balanced_paired  vsearch             size       0.99
# 223  balanced_paired  vsearch  smallmem_length       0.90
# 224  balanced_paired  vsearch  smallmem_length       0.91
# 225  balanced_paired  vsearch  smallmem_length       0.92
# 226  balanced_paired  vsearch  smallmem_length       0.93
# 227  balanced_paired  vsearch  smallmem_length       0.94
# 228  balanced_paired  vsearch  smallmem_length       0.95
# 229  balanced_paired  vsearch  smallmem_length       0.96
# 230  balanced_paired  vsearch  smallmem_length       0.97
# 231  balanced_paired  vsearch  smallmem_length       0.98
# 232  balanced_paired  vsearch  smallmem_length       0.99
# 233  balanced_paired  vsearch    smallmem_size       0.90
# 234  balanced_paired  vsearch    smallmem_size       0.91
# 235  balanced_paired  vsearch    smallmem_size       0.92
# 236  balanced_paired  vsearch    smallmem_size       0.93
# 237  balanced_paired  vsearch    smallmem_size       0.94
# 238  balanced_paired  vsearch    smallmem_size       0.95
# 239  balanced_paired  vsearch    smallmem_size       0.96
# 240  balanced_paired  vsearch    smallmem_size       0.97
# 241  balanced_paired  vsearch    smallmem_size       0.98
# 242  balanced_paired  vsearch    smallmem_size       0.99
# 243       hmp_paired   uparse             otus       0.97
# 244       hmp_paired  usearch      fast_length       0.90
# 245       hmp_paired  usearch      fast_length       0.91
# 246       hmp_paired  usearch      fast_length       0.92
# 247       hmp_paired  usearch      fast_length       0.93
# 248       hmp_paired  usearch      fast_length       0.94
# 249       hmp_paired  usearch      fast_length       0.95
# 250       hmp_paired  usearch      fast_length       0.96
# 251       hmp_paired  usearch      fast_length       0.97
# 252       hmp_paired  usearch      fast_length       0.98
# 253       hmp_paired  usearch      fast_length       0.99
# 254       hmp_paired  usearch        fast_size       0.90
# 255       hmp_paired  usearch        fast_size       0.91
# 256       hmp_paired  usearch        fast_size       0.92
# 257       hmp_paired  usearch        fast_size       0.93
# 258       hmp_paired  usearch        fast_size       0.94
# 259       hmp_paired  usearch        fast_size       0.95
# 260       hmp_paired  usearch        fast_size       0.96
# 261       hmp_paired  usearch        fast_size       0.97
# 262       hmp_paired  usearch        fast_size       0.98
# 263       hmp_paired  usearch        fast_size       0.99
# 264       hmp_paired  usearch  smallmem_length       0.90
# 265       hmp_paired  usearch  smallmem_length       0.91
# 266       hmp_paired  usearch  smallmem_length       0.92
# 267       hmp_paired  usearch  smallmem_length       0.93
# 268       hmp_paired  usearch  smallmem_length       0.94
# 269       hmp_paired  usearch  smallmem_length       0.95
# 270       hmp_paired  usearch  smallmem_length       0.96
# 271       hmp_paired  usearch  smallmem_length       0.97
# 272       hmp_paired  usearch  smallmem_length       0.98
# 273       hmp_paired  usearch  smallmem_length       0.99
# 274       hmp_paired  usearch    smallmem_size       0.90
# 275       hmp_paired  usearch    smallmem_size       0.91
# 276       hmp_paired  usearch    smallmem_size       0.92
# 277       hmp_paired  usearch    smallmem_size       0.93
# 278       hmp_paired  usearch    smallmem_size       0.94
# 279       hmp_paired  usearch    smallmem_size       0.95
# 280       hmp_paired  usearch    smallmem_size       0.96
# 281       hmp_paired  usearch    smallmem_size       0.97
# 282       hmp_paired  usearch    smallmem_size       0.98
# 283       hmp_paired  usearch    smallmem_size       0.99
# 284       hmp_paired  vsearch             fast       0.90
# 285       hmp_paired  vsearch             fast       0.91
# 286       hmp_paired  vsearch             fast       0.92
# 287       hmp_paired  vsearch             fast       0.93
# 288       hmp_paired  vsearch             fast       0.94
# 289       hmp_paired  vsearch             fast       0.95
# 290       hmp_paired  vsearch             fast       0.96
# 291       hmp_paired  vsearch             fast       0.97
# 292       hmp_paired  vsearch             fast       0.98
# 293       hmp_paired  vsearch             fast       0.99
# 294       hmp_paired  vsearch             size       0.90
# 295       hmp_paired  vsearch             size       0.91
# 296       hmp_paired  vsearch             size       0.92
# 297       hmp_paired  vsearch             size       0.93
# 298       hmp_paired  vsearch             size       0.94
# 299       hmp_paired  vsearch             size       0.95
# 300       hmp_paired  vsearch             size       0.96
# 301       hmp_paired  vsearch             size       0.97
# 302       hmp_paired  vsearch             size       0.98
# 303       hmp_paired  vsearch             size       0.99
# 304       hmp_paired  vsearch  smallmem_length       0.90
# 305       hmp_paired  vsearch  smallmem_length       0.91
# 306       hmp_paired  vsearch  smallmem_length       0.92
# 307       hmp_paired  vsearch  smallmem_length       0.93
# 308       hmp_paired  vsearch  smallmem_length       0.94
# 309       hmp_paired  vsearch  smallmem_length       0.95
# 310       hmp_paired  vsearch  smallmem_length       0.96
# 311       hmp_paired  vsearch  smallmem_length       0.97
# 312       hmp_paired  vsearch  smallmem_length       0.98
# 313       hmp_paired  vsearch  smallmem_length       0.99
# 314       hmp_paired  vsearch    smallmem_size       0.90
# 315       hmp_paired  vsearch    smallmem_size       0.91
# 316       hmp_paired  vsearch    smallmem_size       0.92
# 317       hmp_paired  vsearch    smallmem_size       0.93
# 318       hmp_paired  vsearch    smallmem_size       0.94
# 319       hmp_paired  vsearch    smallmem_size       0.95
# 320       hmp_paired  vsearch    smallmem_size       0.96
# 321       hmp_paired  vsearch    smallmem_size       0.97
# 322       hmp_paired  vsearch    smallmem_size       0.98
# 323       hmp_paired  vsearch    smallmem_size       0.99
#
#      num_input_amplicons  input_mass  num_clusters  num_output_amplicons  \
# 0                  33523      558059           591                 30452
# 1                  33523      558059           421                 33523
# 2                  33523      558059           521                 33523
# 3                  33523      558059           640                 33523
# 4                  33523      558059           811                 33523
# 5                  33523      558059          1044                 33523
# 6                  33523      558059          1351                 33523
# 7                  33523      558059          2170                 33523
# 8                  33523      558059          3095                 33523
# 9                  33523      558059          5600                 33523
# 10                 33523      558059         15254                 33523
# 11                 33523      558059           294                 33523
# 12                 33523      558059           381                 33523
# 13                 33523      558059           493                 33523
# 14                 33523      558059           644                 33523
# 15                 33523      558059           839                 33523
# 16                 33523      558059          1144                 33523
# 17                 33523      558059          1753                 33523
# 18                 33523      558059          2432                 33523
# 19                 33523      558059          3579                 33523
# 20                 33523      558059          7522                 33523
# 21                 33523      558059           301                 33523
# 22                 33523      558059           378                 33523
# 23                 33523      558059           495                 33523
# 24                 33523      558059           642                 33523
# 25                 33523      558059           835                 33523
# 26                 33523      558059          1132                 33523
# 27                 33523      558059          1738                 33523
# 28                 33523      558059          2383                 33523
# 29                 33523      558059          3469                 33523
# 30                 33523      558059          7009                 33523
# 31                 33523      558059           301                 33523
# 32                 33523      558059           378                 33523
# 33                 33523      558059           495                 33523
# 34                 33523      558059           642                 33523
# 35                 33523      558059           835                 33523
# 36                 33523      558059          1132                 33523
# 37                 33523      558059          1738                 33523
# 38                 33523      558059          2383                 33523
# 39                 33523      558059          3469                 33523
# 40                 33523      558059          7009                 33523
# 41                 33523      558059           285                 33523
# 42                 33523      558059           381                 33523
# 43                 33523      558059           497                 33523
# 44                 33523      558059           644                 33523
# 45                 33523      558059           837                 33523
# 46                 33523      558059          1136                 33523
# 47                 33523      558059          1741                 33523
# 48                 33523      558059          2383                 33523
# 49                 33523      558059          3464                 33523
# 50                 33523      558059          6816                 33523
# 51                 33523      558059           284                 33523
# 52                 33523      558059           380                 33523
# 53                 33523      558059           496                 33523
# 54                 33523      558059           643                 33523
# 55                 33523      558059           836                 33523
# 56                 33523      558059          1134                 33523
# 57                 33523      558059          1739                 33523
# 58                 33523      558059          2380                 33523
# 59                 33523      558059          3458                 33523
# 60                 33523      558059          6809                 33523
# 61                 33523      558059           284                 33523
# 62                 33523      558059           380                 33523
# 63                 33523      558059           496                 33523
# 64                 33523      558059           643                 33523
# 65                 33523      558059           836                 33523
# 66                 33523      558059          1134                 33523
# 67                 33523      558059          1739                 33523
# 68                 33523      558059          2380                 33523
# 69                 33523      558059          3458                 33523
# 70                 33523      558059          6809                 33523
# 71                 33523      558059           284                 33523
# 72                 33523      558059           380                 33523
# 73                 33523      558059           496                 33523
# 74                 33523      558059           643                 33523
# 75                 33523      558059           836                 33523
# 76                 33523      558059          1134                 33523
# 77                 33523      558059          1739                 33523
# 78                 33523      558059          2380                 33523
# 79                 33523      558059          3458                 33523
# 80                 33523      558059          6809                 33523
# 81                 73071      449409          1884                 66339
# 82                 73071      449409           647                 73071
# 83                 73071      449409           839                 73071
# 84                 73071      449409          1057                 73071
# 85                 73071      449409          1356                 73071
# 86                 73071      449409          1895                 73071
# 87                 73071      449409          2713                 73071
# 88                 73071      449409          5230                 73071
# 89                 73071      449409         10674                 73071
# 90                 73071      449409         21306                 73071
# 91                 73071      449409         49606                 73071
# 92                 73071      449409           592                 73071
# 93                 73071      449409           727                 73071
# 94                 73071      449409           941                 73071
# 95                 73071      449409          1227                 73071
# 96                 73071      449409          1630                 73071
# 97                 73071      449409          2234                 73071
# 98                 73071      449409          3670                 73071
# 99                 73071      449409          6560                 73071
# 100                73071      449409         13896                 73071
# 101                73071      449409         35016                 73071
# 102                73071      449409           583                 73071
# 103                73071      449409           695                 73071
# 104                73071      449409           909                 73071
# 105                73071      449409          1179                 73071
# 106                73071      449409          1547                 73071
# 107                73071      449409          2110                 73071
# 108                73071      449409          3535                 73071
# 109                73071      449409          5877                 73071
# 110                73071      449409         11737                 73071
# 111                73071      449409         30957                 73071
# 112                73071      449409           583                 73071
# 113                73071      449409           695                 73071
# 114                73071      449409           909                 73071
# 115                73071      449409          1179                 73071
# 116                73071      449409          1547                 73071
# 117                73071      449409          2110                 73071
# 118                73071      449409          3535                 73071
# 119                73071      449409          5877                 73071
# 120                73071      449409         11737                 73071
# 121                73071      449409         30957                 73071
# 122                73071      449409           546                 73071
# 123                73071      449409           706                 73071
# 124                73071      449409           922                 73071
# 125                73071      449409          1191                 73071
# 126                73071      449409          1578                 73071
# 127                73071      449409          2130                 73071
# 128                73071      449409          3540                 73071
# 129                73071      449409          5765                 73071
# 130                73071      449409         11391                 73071
# 131                73071      449409         27644                 73071
# 132                73071      449409           523                 73071
# 133                73071      449409           687                 73071
# 134                73071      449409           894                 73071
# 135                73071      449409          1167                 73071
# 136                73071      449409          1540                 73071
# 137                73071      449409          2084                 73071
# 138                73071      449409          3485                 73071
# 139                73071      449409          5714                 73071
# 140                73071      449409         11353                 73071
# 141                73071      449409         27593                 73071
# 142                73071      449409           523                 73071
# 143                73071      449409           687                 73071
# 144                73071      449409           894                 73071
# 145                73071      449409          1167                 73071
# 146                73071      449409          1540                 73071
# 147                73071      449409          2084                 73071
# 148                73071      449409          3485                 73071
# 149                73071      449409          5714                 73071
# 150                73071      449409         11353                 73071
# 151                73071      449409         27593                 73071
# 152                73071      449409           523                 73071
# 153                73071      449409           687                 73071
# 154                73071      449409           894                 73071
# 155                73071      449409          1167                 73071
# 156                73071      449409          1540                 73071
# 157                73071      449409          2084                 73071
# 158                73071      449409          3485                 73071
# 159                73071      449409          5714                 73071
# 160                73071      449409         11353                 73071
# 161                73071      449409         27593                 73071
# 162                21808      467652            99                 18891
# 163                21808      467652           143                 21808
# 164                21808      467652           204                 21808
# 165                21808      467652           268                 21808
# 166                21808      467652           399                 21808
# 167                21808      467652           524                 21808
# 168                21808      467652           738                 21808
# 169                21808      467652           921                 21808
# 170                21808      467652          1318                 21808
# 171                21808      467652          1706                 21808
# 172                21808      467652          3764                 21808
# 173                21808      467652           131                 21808
# 174                21808      467652           198                 21808
# 175                21808      467652           252                 21808
# 176                21808      467652           392                 21808
# 177                21808      467652           502                 21808
# 178                21808      467652           731                 21808
# 179                21808      467652           901                 21808
# 180                21808      467652          1285                 21808
# 181                21808      467652          1641                 21808
# 182                21808      467652          3170                 21808
# 183                21808      467652           141                 21808
# 184                21808      467652           204                 21808
# 185                21808      467652           263                 21808
# 186                21808      467652           394                 21808
# 187                21808      467652           512                 21808
# 188                21808      467652           733                 21808
# 189                21808      467652           906                 21808
# 190                21808      467652          1265                 21808
# 191                21808      467652          1646                 21808
# 192                21808      467652          3004                 21808
# 193                21808      467652           134                 21808
# 194                21808      467652           198                 21808
# 195                21808      467652           254                 21808
# 196                21808      467652           391                 21808
# 197                21808      467652           504                 21808
# 198                21808      467652           729                 21808
# 199                21808      467652           902                 21808
# 200                21808      467652          1262                 21808
# 201                21808      467652          1636                 21808
# 202                21808      467652          2965                 21808
# 203                21808      467652           141                 21808
# 204                21808      467652           204                 21808
# 205                21808      467652           263                 21808
# 206                21808      467652           394                 21808
# 207                21808      467652           512                 21808
# 208                21808      467652           733                 21808
# 209                21808      467652           907                 21808
# 210                21808      467652          1265                 21808
# 211                21808      467652          1646                 21808
# 212                21808      467652          2977                 21808
# 213                21808      467652           134                 21808
# 214                21808      467652           198                 21808
# 215                21808      467652           254                 21808
# 216                21808      467652           391                 21808
# 217                21808      467652           504                 21808
# 218                21808      467652           729                 21808
# 219                21808      467652           902                 21808
# 220                21808      467652          1262                 21808
# 221                21808      467652          1636                 21808
# 222                21808      467652          2941                 21808
# 223                21808      467652           141                 21808
# 224                21808      467652           204                 21808
# 225                21808      467652           263                 21808
# 226                21808      467652           394                 21808
# 227                21808      467652           512                 21808
# 228                21808      467652           733                 21808
# 229                21808      467652           906                 21808
# 230                21808      467652          1265                 21808
# 231                21808      467652          1646                 21808
# 232                21808      467652          2973                 21808
# 233                21808      467652           134                 21808
# 234                21808      467652           198                 21808
# 235                21808      467652           254                 21808
# 236                21808      467652           391                 21808
# 237                21808      467652           504                 21808
# 238                21808      467652           729                 21808
# 239                21808      467652           902                 21808
# 240                21808      467652          1262                 21808
# 241                21808      467652          1636                 21808
# 242                21808      467652          2941                 21808
# 243                19882      208157           271                 15710
# 244                19882      208157           201                 19882
# 245                19882      208157           241                 19882
# 246                19882      208157           289                 19882
# 247                19882      208157           378                 19882
# 248                19882      208157           451                 19882
# 249                19882      208157           577                 19882
# 250                19882      208157           742                 19882
# 251                19882      208157           950                 19882
# 252                19882      208157          1629                 19882
# 253                19882      208157          4514                 19882
# 254                19882      208157           172                 19882
# 255                19882      208157           201                 19882
# 256                19882      208157           245                 19882
# 257                19882      208157           325                 19882
# 258                19882      208157           416                 19882
# 259                19882      208157           540                 19882
# 260                19882      208157           722                 19882
# 261                19882      208157           856                 19882
# 262                19882      208157          1516                 19882
# 263                19882      208157          4311                 19882
# 264                19882      208157           192                 19882
# 265                19882      208157           225                 19882
# 266                19882      208157           274                 19882
# 267                19882      208157           346                 19882
# 268                19882      208157           425                 19882
# 269                19882      208157           508                 19882
# 270                19882      208157           630                 19882
# 271                19882      208157           795                 19882
# 272                19882      208157          1192                 19882
# 273                19882      208157          2645                 19882
# 274                19882      208157           170                 19882
# 275                19882      208157           193                 19882
# 276                19882      208157           235                 19882
# 277                19882      208157           304                 19882
# 278                19882      208157           364                 19882
# 279                19882      208157           460                 19882
# 280                19882      208157           562                 19882
# 281                19882      208157           715                 19882
# 282                19882      208157          1027                 19882
# 283                19882      208157          2643                 19882
# 284                19882      208157           198                 19882
# 285                19882      208157           229                 19882
# 286                19882      208157           292                 19882
# 287                19882      208157           372                 19882
# 288                19882      208157           443                 19882
# 289                19882      208157           538                 19882
# 290                19882      208157           688                 19882
# 291                19882      208157           898                 19882
# 292                19882      208157          1352                 19882
# 293                19882      208157          2868                 19882
# 294                19882      208157           170                 19882
# 295                19882      208157           193                 19882
# 296                19882      208157           237                 19882
# 297                19882      208157           301                 19882
# 298                19882      208157           363                 19882
# 299                19882      208157           452                 19882
# 300                19882      208157           547                 19882
# 301                19882      208157           707                 19882
# 302                19882      208157          1147                 19882
# 303                19882      208157          2651                 19882
# 304                19882      208157           192                 19882
# 305                19882      208157           225                 19882
# 306                19882      208157           272                 19882
# 307                19882      208157           346                 19882
# 308                19882      208157           422                 19882
# 309                19882      208157           509                 19882
# 310                19882      208157           619                 19882
# 311                19882      208157           798                 19882
# 312                19882      208157          1213                 19882
# 313                19882      208157          2626                 19882
# 314                19882      208157           170                 19882
# 315                19882      208157           193                 19882
# 316                19882      208157           237                 19882
# 317                19882      208157           301                 19882
# 318                19882      208157           363                 19882
# 319                19882      208157           452                 19882
# 320                19882      208157           547                 19882
# 321                19882      208157           707                 19882
# 322                19882      208157          1147                 19882
# 323                19882      208157          2651                 19882
#
#      output_mass
# 0         553807
# 1         558059
# 2         558059
# 3         558059
# 4         558059
# 5         558059
# 6         558059
# 7         558059
# 8         558059
# 9         558059
# 10        558059
# 11        558059
# 12        558059
# 13        558059
# 14        558059
# 15        558059
# 16        558059
# 17        558059
# 18        558059
# 19        558059
# 20        558059
# 21        558059
# 22        558059
# 23        558059
# 24        558059
# 25        558059
# 26        558059
# 27        558059
# 28        558059
# 29        558059
# 30        558059
# 31        558059
# 32        558059
# 33        558059
# 34        558059
# 35        558059
# 36        558059
# 37        558059
# 38        558059
# 39        558059
# 40        558059
# 41        558059
# 42        558059
# 43        558059
# 44        558059
# 45        558059
# 46        558059
# 47        558059
# 48        558059
# 49        558059
# 50        558059
# 51        558059
# 52        558059
# 53        558059
# 54        558059
# 55        558059
# 56        558059
# 57        558059
# 58        558059
# 59        558059
# 60        558059
# 61        558059
# 62        558059
# 63        558059
# 64        558059
# 65        558059
# 66        558059
# 67        558059
# 68        558059
# 69        558059
# 70        558059
# 71        558059
# 72        558059
# 73        558059
# 74        558059
# 75        558059
# 76        558059
# 77        558059
# 78        558059
# 79        558059
# 80        558059
# 81        437522
# 82        449409
# 83        449409
# 84        449409
# 85        449409
# 86        449409
# 87        449409
# 88        449409
# 89        449409
# 90        449409
# 91        449409
# 92        449409
# 93        449409
# 94        449409
# 95        449409
# 96        449409
# 97        449409
# 98        449409
# 99        449409
# 100       449409
# 101       449409
# 102       449409
# 103       449409
# 104       449409
# 105       449409
# 106       449409
# 107       449409
# 108       449409
# 109       449409
# 110       449409
# 111       449409
# 112       449409
# 113       449409
# 114       449409
# 115       449409
# 116       449409
# 117       449409
# 118       449409
# 119       449409
# 120       449409
# 121       449409
# 122       449409
# 123       449409
# 124       449409
# 125       449409
# 126       449409
# 127       449409
# 128       449409
# 129       449409
# 130       449409
# 131       449409
# 132       449409
# 133       449409
# 134       449409
# 135       449409
# 136       449409
# 137       449409
# 138       449409
# 139       449409
# 140       449409
# 141       449409
# 142       449409
# 143       449409
# 144       449409
# 145       449409
# 146       449409
# 147       449409
# 148       449409
# 149       449409
# 150       449409
# 151       449409
# 152       449409
# 153       449409
# 154       449409
# 155       449409
# 156       449409
# 157       449409
# 158       449409
# 159       449409
# 160       449409
# 161       449409
# 162       463596
# 163       467652
# 164       467652
# 165       467652
# 166       467652
# 167       467652
# 168       467652
# 169       467652
# 170       467652
# 171       467652
# 172       467652
# 173       467652
# 174       467652
# 175       467652
# 176       467652
# 177       467652
# 178       467652
# 179       467652
# 180       467652
# 181       467652
# 182       467652
# 183       467652
# 184       467652
# 185       467652
# 186       467652
# 187       467652
# 188       467652
# 189       467652
# 190       467652
# 191       467652
# 192       467652
# 193       467652
# 194       467652
# 195       467652
# 196       467652
# 197       467652
# 198       467652
# 199       467652
# 200       467652
# 201       467652
# 202       467652
# 203       467652
# 204       467652
# 205       467652
# 206       467652
# 207       467652
# 208       467652
# 209       467652
# 210       467652
# 211       467652
# 212       467652
# 213       467652
# 214       467652
# 215       467652
# 216       467652
# 217       467652
# 218       467652
# 219       467652
# 220       467652
# 221       467652
# 222       467652
# 223       467652
# 224       467652
# 225       467652
# 226       467652
# 227       467652
# 228       467652
# 229       467652
# 230       467652
# 231       467652
# 232       467652
# 233       467652
# 234       467652
# 235       467652
# 236       467652
# 237       467652
# 238       467652
# 239       467652
# 240       467652
# 241       467652
# 242       467652
# 243       201779
# 244       208157
# 245       208157
# 246       208157
# 247       208157
# 248       208157
# 249       208157
# 250       208157
# 251       208157
# 252       208157
# 253       208157
# 254       208157
# 255       208157
# 256       208157
# 257       208157
# 258       208157
# 259       208157
# 260       208157
# 261       208157
# 262       208157
# 263       208157
# 264       208157
# 265       208157
# 266       208157
# 267       208157
# 268       208157
# 269       208157
# 270       208157
# 271       208157
# 272       208157
# 273       208157
# 274       208157
# 275       208157
# 276       208157
# 277       208157
# 278       208157
# 279       208157
# 280       208157
# 281       208157
# 282       208157
# 283       208157
# 284       208157
# 285       208157
# 286       208157
# 287       208157
# 288       208157
# 289       208157
# 290       208157
# 291       208157
# 292       208157
# 293       208157
# 294       208157
# 295       208157
# 296       208157
# 297       208157
# 298       208157
# 299       208157
# 300       208157
# 301       208157
# 302       208157
# 303       208157
# 304       208157
# 305       208157
# 306       208157
# 307       208157
# 308       208157
# 309       208157
# 310       208157
# 311       208157
# 312       208157
# 313       208157
# 314       208157
# 315       208157
# 316       208157
# 317       208157
# 318       208157
# 319       208157
# 320       208157
# 321       208157
# 322       208157
# 323       208157

# %%
df_counts.to_csv('%s/df_counts.csv' % eval_dir, sep = ';', index = False)
#df_counts = pd.read_csv('%s/df_counts.csv' % eval_dir, sep = ';')

# %% [markdown]
# ### Clustering quality

# %%
# Requires the metrics files. Alternatively, the evaluation can use the stored information (see below).
dfs = []
for ds in data_sets:
    for rt in read_types:
        run_name = '%s_%s' % (ds, rt)

        for opt in opts:
            for gt in ground_truths:
                df = pd.read_csv('%s/%s/%s/%s_%s_%s__metrics.csv' % (results_dir, run_name, opt, opt, ds[0] + rt[0], gt), sep = ';')

                df['reads'] = '%s_%s' % (ds, rt)
                df['gt'] = gt
                df['mode'] = [m.split('__')[-1] for m in df['task']]
                df['refinement'] = 'nf'
                df['ds'] = ds
                df['rt'] = rt

                dfs.append(df)
                    
df_quality = pd.concat(dfs, ignore_index = True)
df_quality.rename(columns = {'task': 'run', 'reads': 'data_set'}, inplace = True)

# %% [markdown]
# *Column descriptions:*
# `precision`: Quantifies the extent to which amplicons in a cluster are also from the same species.
# `recall`: Measures the proportion of amplicons from the same species that are grouped in the same cluster.
# `adjrandindex`: Measures the agreement between the clusters and the taxonomic assignment and corrects for chance.

# %%
df_quality[['data_set', 'gt', 'tool', 'mode', 'threshold', 'precision', 'recall', 'adjrandindex']]
# Out:
#             data_set        gt     tool             mode  threshold  \
# 0    balanced_single  callahan   uparse             otus       0.97
# 1    balanced_single  callahan  usearch      fast_length       0.90
# 2    balanced_single  callahan  usearch      fast_length       0.91
# 3    balanced_single  callahan  usearch      fast_length       0.92
# 4    balanced_single  callahan  usearch      fast_length       0.93
# 5    balanced_single  callahan  usearch      fast_length       0.94
# 6    balanced_single  callahan  usearch      fast_length       0.95
# 7    balanced_single  callahan  usearch      fast_length       0.96
# 8    balanced_single  callahan  usearch      fast_length       0.97
# 9    balanced_single  callahan  usearch      fast_length       0.98
# 10   balanced_single  callahan  usearch      fast_length       0.99
# 11   balanced_single  callahan  usearch        fast_size       0.90
# 12   balanced_single  callahan  usearch        fast_size       0.91
# 13   balanced_single  callahan  usearch        fast_size       0.92
# 14   balanced_single  callahan  usearch        fast_size       0.93
# 15   balanced_single  callahan  usearch        fast_size       0.94
# 16   balanced_single  callahan  usearch        fast_size       0.95
# 17   balanced_single  callahan  usearch        fast_size       0.96
# 18   balanced_single  callahan  usearch        fast_size       0.97
# 19   balanced_single  callahan  usearch        fast_size       0.98
# 20   balanced_single  callahan  usearch        fast_size       0.99
# 21   balanced_single  callahan  usearch  smallmem_length       0.90
# 22   balanced_single  callahan  usearch  smallmem_length       0.91
# 23   balanced_single  callahan  usearch  smallmem_length       0.92
# 24   balanced_single  callahan  usearch  smallmem_length       0.93
# 25   balanced_single  callahan  usearch  smallmem_length       0.94
# 26   balanced_single  callahan  usearch  smallmem_length       0.95
# 27   balanced_single  callahan  usearch  smallmem_length       0.96
# 28   balanced_single  callahan  usearch  smallmem_length       0.97
# 29   balanced_single  callahan  usearch  smallmem_length       0.98
# 30   balanced_single  callahan  usearch  smallmem_length       0.99
# 31   balanced_single  callahan  usearch    smallmem_size       0.90
# 32   balanced_single  callahan  usearch    smallmem_size       0.91
# 33   balanced_single  callahan  usearch    smallmem_size       0.92
# 34   balanced_single  callahan  usearch    smallmem_size       0.93
# 35   balanced_single  callahan  usearch    smallmem_size       0.94
# 36   balanced_single  callahan  usearch    smallmem_size       0.95
# 37   balanced_single  callahan  usearch    smallmem_size       0.96
# 38   balanced_single  callahan  usearch    smallmem_size       0.97
# 39   balanced_single  callahan  usearch    smallmem_size       0.98
# 40   balanced_single  callahan  usearch    smallmem_size       0.99
# 41   balanced_single  callahan  vsearch             fast       0.90
# 42   balanced_single  callahan  vsearch             fast       0.91
# 43   balanced_single  callahan  vsearch             fast       0.92
# 44   balanced_single  callahan  vsearch             fast       0.93
# 45   balanced_single  callahan  vsearch             fast       0.94
# 46   balanced_single  callahan  vsearch             fast       0.95
# 47   balanced_single  callahan  vsearch             fast       0.96
# 48   balanced_single  callahan  vsearch             fast       0.97
# 49   balanced_single  callahan  vsearch             fast       0.98
# 50   balanced_single  callahan  vsearch             fast       0.99
# 51   balanced_single  callahan  vsearch             size       0.90
# 52   balanced_single  callahan  vsearch             size       0.91
# 53   balanced_single  callahan  vsearch             size       0.92
# 54   balanced_single  callahan  vsearch             size       0.93
# 55   balanced_single  callahan  vsearch             size       0.94
# 56   balanced_single  callahan  vsearch             size       0.95
# 57   balanced_single  callahan  vsearch             size       0.96
# 58   balanced_single  callahan  vsearch             size       0.97
# 59   balanced_single  callahan  vsearch             size       0.98
# 60   balanced_single  callahan  vsearch             size       0.99
# 61   balanced_single  callahan  vsearch  smallmem_length       0.90
# 62   balanced_single  callahan  vsearch  smallmem_length       0.91
# 63   balanced_single  callahan  vsearch  smallmem_length       0.92
# 64   balanced_single  callahan  vsearch  smallmem_length       0.93
# 65   balanced_single  callahan  vsearch  smallmem_length       0.94
# 66   balanced_single  callahan  vsearch  smallmem_length       0.95
# 67   balanced_single  callahan  vsearch  smallmem_length       0.96
# 68   balanced_single  callahan  vsearch  smallmem_length       0.97
# 69   balanced_single  callahan  vsearch  smallmem_length       0.98
# 70   balanced_single  callahan  vsearch  smallmem_length       0.99
# 71   balanced_single  callahan  vsearch    smallmem_size       0.90
# 72   balanced_single  callahan  vsearch    smallmem_size       0.91
# 73   balanced_single  callahan  vsearch    smallmem_size       0.92
# 74   balanced_single  callahan  vsearch    smallmem_size       0.93
# 75   balanced_single  callahan  vsearch    smallmem_size       0.94
# 76   balanced_single  callahan  vsearch    smallmem_size       0.95
# 77   balanced_single  callahan  vsearch    smallmem_size       0.96
# 78   balanced_single  callahan  vsearch    smallmem_size       0.97
# 79   balanced_single  callahan  vsearch    smallmem_size       0.98
# 80   balanced_single  callahan  vsearch    smallmem_size       0.99
# 81   balanced_paired  callahan   uparse             otus       0.97
# 82   balanced_paired  callahan  usearch      fast_length       0.90
# 83   balanced_paired  callahan  usearch      fast_length       0.91
# 84   balanced_paired  callahan  usearch      fast_length       0.92
# 85   balanced_paired  callahan  usearch      fast_length       0.93
# 86   balanced_paired  callahan  usearch      fast_length       0.94
# 87   balanced_paired  callahan  usearch      fast_length       0.95
# 88   balanced_paired  callahan  usearch      fast_length       0.96
# 89   balanced_paired  callahan  usearch      fast_length       0.97
# 90   balanced_paired  callahan  usearch      fast_length       0.98
# 91   balanced_paired  callahan  usearch      fast_length       0.99
# 92   balanced_paired  callahan  usearch        fast_size       0.90
# 93   balanced_paired  callahan  usearch        fast_size       0.91
# 94   balanced_paired  callahan  usearch        fast_size       0.92
# 95   balanced_paired  callahan  usearch        fast_size       0.93
# 96   balanced_paired  callahan  usearch        fast_size       0.94
# 97   balanced_paired  callahan  usearch        fast_size       0.95
# 98   balanced_paired  callahan  usearch        fast_size       0.96
# 99   balanced_paired  callahan  usearch        fast_size       0.97
# 100  balanced_paired  callahan  usearch        fast_size       0.98
# 101  balanced_paired  callahan  usearch        fast_size       0.99
# 102  balanced_paired  callahan  usearch  smallmem_length       0.90
# 103  balanced_paired  callahan  usearch  smallmem_length       0.91
# 104  balanced_paired  callahan  usearch  smallmem_length       0.92
# 105  balanced_paired  callahan  usearch  smallmem_length       0.93
# 106  balanced_paired  callahan  usearch  smallmem_length       0.94
# 107  balanced_paired  callahan  usearch  smallmem_length       0.95
# 108  balanced_paired  callahan  usearch  smallmem_length       0.96
# 109  balanced_paired  callahan  usearch  smallmem_length       0.97
# 110  balanced_paired  callahan  usearch  smallmem_length       0.98
# 111  balanced_paired  callahan  usearch  smallmem_length       0.99
# 112  balanced_paired  callahan  usearch    smallmem_size       0.90
# 113  balanced_paired  callahan  usearch    smallmem_size       0.91
# 114  balanced_paired  callahan  usearch    smallmem_size       0.92
# 115  balanced_paired  callahan  usearch    smallmem_size       0.93
# 116  balanced_paired  callahan  usearch    smallmem_size       0.94
# 117  balanced_paired  callahan  usearch    smallmem_size       0.95
# 118  balanced_paired  callahan  usearch    smallmem_size       0.96
# 119  balanced_paired  callahan  usearch    smallmem_size       0.97
# 120  balanced_paired  callahan  usearch    smallmem_size       0.98
# 121  balanced_paired  callahan  usearch    smallmem_size       0.99
# 122  balanced_paired  callahan  vsearch             fast       0.90
# 123  balanced_paired  callahan  vsearch             fast       0.91
# 124  balanced_paired  callahan  vsearch             fast       0.92
# 125  balanced_paired  callahan  vsearch             fast       0.93
# 126  balanced_paired  callahan  vsearch             fast       0.94
# 127  balanced_paired  callahan  vsearch             fast       0.95
# 128  balanced_paired  callahan  vsearch             fast       0.96
# 129  balanced_paired  callahan  vsearch             fast       0.97
# 130  balanced_paired  callahan  vsearch             fast       0.98
# 131  balanced_paired  callahan  vsearch             fast       0.99
# 132  balanced_paired  callahan  vsearch             size       0.90
# 133  balanced_paired  callahan  vsearch             size       0.91
# 134  balanced_paired  callahan  vsearch             size       0.92
# 135  balanced_paired  callahan  vsearch             size       0.93
# 136  balanced_paired  callahan  vsearch             size       0.94
# 137  balanced_paired  callahan  vsearch             size       0.95
# 138  balanced_paired  callahan  vsearch             size       0.96
# 139  balanced_paired  callahan  vsearch             size       0.97
# 140  balanced_paired  callahan  vsearch             size       0.98
# 141  balanced_paired  callahan  vsearch             size       0.99
# 142  balanced_paired  callahan  vsearch  smallmem_length       0.90
# 143  balanced_paired  callahan  vsearch  smallmem_length       0.91
# 144  balanced_paired  callahan  vsearch  smallmem_length       0.92
# 145  balanced_paired  callahan  vsearch  smallmem_length       0.93
# 146  balanced_paired  callahan  vsearch  smallmem_length       0.94
# 147  balanced_paired  callahan  vsearch  smallmem_length       0.95
# 148  balanced_paired  callahan  vsearch  smallmem_length       0.96
# 149  balanced_paired  callahan  vsearch  smallmem_length       0.97
# 150  balanced_paired  callahan  vsearch  smallmem_length       0.98
# 151  balanced_paired  callahan  vsearch  smallmem_length       0.99
# 152  balanced_paired  callahan  vsearch    smallmem_size       0.90
# 153  balanced_paired  callahan  vsearch    smallmem_size       0.91
# 154  balanced_paired  callahan  vsearch    smallmem_size       0.92
# 155  balanced_paired  callahan  vsearch    smallmem_size       0.93
# 156  balanced_paired  callahan  vsearch    smallmem_size       0.94
# 157  balanced_paired  callahan  vsearch    smallmem_size       0.95
# 158  balanced_paired  callahan  vsearch    smallmem_size       0.96
# 159  balanced_paired  callahan  vsearch    smallmem_size       0.97
# 160  balanced_paired  callahan  vsearch    smallmem_size       0.98
# 161  balanced_paired  callahan  vsearch    smallmem_size       0.99
# 162       hmp_single  callahan   uparse             otus       0.97
# 163       hmp_single  callahan  usearch      fast_length       0.90
# 164       hmp_single  callahan  usearch      fast_length       0.91
# 165       hmp_single  callahan  usearch      fast_length       0.92
# 166       hmp_single  callahan  usearch      fast_length       0.93
# 167       hmp_single  callahan  usearch      fast_length       0.94
# 168       hmp_single  callahan  usearch      fast_length       0.95
# 169       hmp_single  callahan  usearch      fast_length       0.96
# 170       hmp_single  callahan  usearch      fast_length       0.97
# 171       hmp_single  callahan  usearch      fast_length       0.98
# 172       hmp_single  callahan  usearch      fast_length       0.99
# 173       hmp_single  callahan  usearch        fast_size       0.90
# 174       hmp_single  callahan  usearch        fast_size       0.91
# 175       hmp_single  callahan  usearch        fast_size       0.92
# 176       hmp_single  callahan  usearch        fast_size       0.93
# 177       hmp_single  callahan  usearch        fast_size       0.94
# 178       hmp_single  callahan  usearch        fast_size       0.95
# 179       hmp_single  callahan  usearch        fast_size       0.96
# 180       hmp_single  callahan  usearch        fast_size       0.97
# 181       hmp_single  callahan  usearch        fast_size       0.98
# 182       hmp_single  callahan  usearch        fast_size       0.99
# 183       hmp_single  callahan  usearch  smallmem_length       0.90
# 184       hmp_single  callahan  usearch  smallmem_length       0.91
# 185       hmp_single  callahan  usearch  smallmem_length       0.92
# 186       hmp_single  callahan  usearch  smallmem_length       0.93
# 187       hmp_single  callahan  usearch  smallmem_length       0.94
# 188       hmp_single  callahan  usearch  smallmem_length       0.95
# 189       hmp_single  callahan  usearch  smallmem_length       0.96
# 190       hmp_single  callahan  usearch  smallmem_length       0.97
# 191       hmp_single  callahan  usearch  smallmem_length       0.98
# 192       hmp_single  callahan  usearch  smallmem_length       0.99
# 193       hmp_single  callahan  usearch    smallmem_size       0.90
# 194       hmp_single  callahan  usearch    smallmem_size       0.91
# 195       hmp_single  callahan  usearch    smallmem_size       0.92
# 196       hmp_single  callahan  usearch    smallmem_size       0.93
# 197       hmp_single  callahan  usearch    smallmem_size       0.94
# 198       hmp_single  callahan  usearch    smallmem_size       0.95
# 199       hmp_single  callahan  usearch    smallmem_size       0.96
# 200       hmp_single  callahan  usearch    smallmem_size       0.97
# 201       hmp_single  callahan  usearch    smallmem_size       0.98
# 202       hmp_single  callahan  usearch    smallmem_size       0.99
# 203       hmp_single  callahan  vsearch             fast       0.90
# 204       hmp_single  callahan  vsearch             fast       0.91
# 205       hmp_single  callahan  vsearch             fast       0.92
# 206       hmp_single  callahan  vsearch             fast       0.93
# 207       hmp_single  callahan  vsearch             fast       0.94
# 208       hmp_single  callahan  vsearch             fast       0.95
# 209       hmp_single  callahan  vsearch             fast       0.96
# 210       hmp_single  callahan  vsearch             fast       0.97
# 211       hmp_single  callahan  vsearch             fast       0.98
# 212       hmp_single  callahan  vsearch             fast       0.99
# 213       hmp_single  callahan  vsearch             size       0.90
# 214       hmp_single  callahan  vsearch             size       0.91
# 215       hmp_single  callahan  vsearch             size       0.92
# 216       hmp_single  callahan  vsearch             size       0.93
# 217       hmp_single  callahan  vsearch             size       0.94
# 218       hmp_single  callahan  vsearch             size       0.95
# 219       hmp_single  callahan  vsearch             size       0.96
# 220       hmp_single  callahan  vsearch             size       0.97
# 221       hmp_single  callahan  vsearch             size       0.98
# 222       hmp_single  callahan  vsearch             size       0.99
# 223       hmp_single  callahan  vsearch  smallmem_length       0.90
# 224       hmp_single  callahan  vsearch  smallmem_length       0.91
# 225       hmp_single  callahan  vsearch  smallmem_length       0.92
# 226       hmp_single  callahan  vsearch  smallmem_length       0.93
# 227       hmp_single  callahan  vsearch  smallmem_length       0.94
# 228       hmp_single  callahan  vsearch  smallmem_length       0.95
# 229       hmp_single  callahan  vsearch  smallmem_length       0.96
# 230       hmp_single  callahan  vsearch  smallmem_length       0.97
# 231       hmp_single  callahan  vsearch  smallmem_length       0.98
# 232       hmp_single  callahan  vsearch  smallmem_length       0.99
# 233       hmp_single  callahan  vsearch    smallmem_size       0.90
# 234       hmp_single  callahan  vsearch    smallmem_size       0.91
# 235       hmp_single  callahan  vsearch    smallmem_size       0.92
# 236       hmp_single  callahan  vsearch    smallmem_size       0.93
# 237       hmp_single  callahan  vsearch    smallmem_size       0.94
# 238       hmp_single  callahan  vsearch    smallmem_size       0.95
# 239       hmp_single  callahan  vsearch    smallmem_size       0.96
# 240       hmp_single  callahan  vsearch    smallmem_size       0.97
# 241       hmp_single  callahan  vsearch    smallmem_size       0.98
# 242       hmp_single  callahan  vsearch    smallmem_size       0.99
# 243       hmp_paired  callahan   uparse             otus       0.97
# 244       hmp_paired  callahan  usearch      fast_length       0.90
# 245       hmp_paired  callahan  usearch      fast_length       0.91
# 246       hmp_paired  callahan  usearch      fast_length       0.92
# 247       hmp_paired  callahan  usearch      fast_length       0.93
# 248       hmp_paired  callahan  usearch      fast_length       0.94
# 249       hmp_paired  callahan  usearch      fast_length       0.95
# 250       hmp_paired  callahan  usearch      fast_length       0.96
# 251       hmp_paired  callahan  usearch      fast_length       0.97
# 252       hmp_paired  callahan  usearch      fast_length       0.98
# 253       hmp_paired  callahan  usearch      fast_length       0.99
# 254       hmp_paired  callahan  usearch        fast_size       0.90
# 255       hmp_paired  callahan  usearch        fast_size       0.91
# 256       hmp_paired  callahan  usearch        fast_size       0.92
# 257       hmp_paired  callahan  usearch        fast_size       0.93
# 258       hmp_paired  callahan  usearch        fast_size       0.94
# 259       hmp_paired  callahan  usearch        fast_size       0.95
# 260       hmp_paired  callahan  usearch        fast_size       0.96
# 261       hmp_paired  callahan  usearch        fast_size       0.97
# 262       hmp_paired  callahan  usearch        fast_size       0.98
# 263       hmp_paired  callahan  usearch        fast_size       0.99
# 264       hmp_paired  callahan  usearch  smallmem_length       0.90
# 265       hmp_paired  callahan  usearch  smallmem_length       0.91
# 266       hmp_paired  callahan  usearch  smallmem_length       0.92
# 267       hmp_paired  callahan  usearch  smallmem_length       0.93
# 268       hmp_paired  callahan  usearch  smallmem_length       0.94
# 269       hmp_paired  callahan  usearch  smallmem_length       0.95
# 270       hmp_paired  callahan  usearch  smallmem_length       0.96
# 271       hmp_paired  callahan  usearch  smallmem_length       0.97
# 272       hmp_paired  callahan  usearch  smallmem_length       0.98
# 273       hmp_paired  callahan  usearch  smallmem_length       0.99
# 274       hmp_paired  callahan  usearch    smallmem_size       0.90
# 275       hmp_paired  callahan  usearch    smallmem_size       0.91
# 276       hmp_paired  callahan  usearch    smallmem_size       0.92
# 277       hmp_paired  callahan  usearch    smallmem_size       0.93
# 278       hmp_paired  callahan  usearch    smallmem_size       0.94
# 279       hmp_paired  callahan  usearch    smallmem_size       0.95
# 280       hmp_paired  callahan  usearch    smallmem_size       0.96
# 281       hmp_paired  callahan  usearch    smallmem_size       0.97
# 282       hmp_paired  callahan  usearch    smallmem_size       0.98
# 283       hmp_paired  callahan  usearch    smallmem_size       0.99
# 284       hmp_paired  callahan  vsearch             fast       0.90
# 285       hmp_paired  callahan  vsearch             fast       0.91
# 286       hmp_paired  callahan  vsearch             fast       0.92
# 287       hmp_paired  callahan  vsearch             fast       0.93
# 288       hmp_paired  callahan  vsearch             fast       0.94
# 289       hmp_paired  callahan  vsearch             fast       0.95
# 290       hmp_paired  callahan  vsearch             fast       0.96
# 291       hmp_paired  callahan  vsearch             fast       0.97
# 292       hmp_paired  callahan  vsearch             fast       0.98
# 293       hmp_paired  callahan  vsearch             fast       0.99
# 294       hmp_paired  callahan  vsearch             size       0.90
# 295       hmp_paired  callahan  vsearch             size       0.91
# 296       hmp_paired  callahan  vsearch             size       0.92
# 297       hmp_paired  callahan  vsearch             size       0.93
# 298       hmp_paired  callahan  vsearch             size       0.94
# 299       hmp_paired  callahan  vsearch             size       0.95
# 300       hmp_paired  callahan  vsearch             size       0.96
# 301       hmp_paired  callahan  vsearch             size       0.97
# 302       hmp_paired  callahan  vsearch             size       0.98
# 303       hmp_paired  callahan  vsearch             size       0.99
# 304       hmp_paired  callahan  vsearch  smallmem_length       0.90
# 305       hmp_paired  callahan  vsearch  smallmem_length       0.91
# 306       hmp_paired  callahan  vsearch  smallmem_length       0.92
# 307       hmp_paired  callahan  vsearch  smallmem_length       0.93
# 308       hmp_paired  callahan  vsearch  smallmem_length       0.94
# 309       hmp_paired  callahan  vsearch  smallmem_length       0.95
# 310       hmp_paired  callahan  vsearch  smallmem_length       0.96
# 311       hmp_paired  callahan  vsearch  smallmem_length       0.97
# 312       hmp_paired  callahan  vsearch  smallmem_length       0.98
# 313       hmp_paired  callahan  vsearch  smallmem_length       0.99
# 314       hmp_paired  callahan  vsearch    smallmem_size       0.90
# 315       hmp_paired  callahan  vsearch    smallmem_size       0.91
# 316       hmp_paired  callahan  vsearch    smallmem_size       0.92
# 317       hmp_paired  callahan  vsearch    smallmem_size       0.93
# 318       hmp_paired  callahan  vsearch    smallmem_size       0.94
# 319       hmp_paired  callahan  vsearch    smallmem_size       0.95
# 320       hmp_paired  callahan  vsearch    smallmem_size       0.96
# 321       hmp_paired  callahan  vsearch    smallmem_size       0.97
# 322       hmp_paired  callahan  vsearch    smallmem_size       0.98
# 323       hmp_paired  callahan  vsearch    smallmem_size       0.99
#
#      precision    recall  adjrandindex
# 0     0.961808  0.990367      0.966790
# 1     0.925922  0.959764      0.906474
# 2     0.942952  0.956019      0.899262
# 3     0.928246  0.962289      0.911734
# 4     0.956786  0.959676      0.929876
# 5     0.956562  0.932833      0.868032
# 6     0.988856  0.954912      0.957855
# 7     0.990825  0.929531      0.916237
# 8     0.980088  0.908106      0.886726
# 9     0.998018  0.876117      0.846011
# 10    0.999547  0.862830      0.843779
# 11    0.796177  0.966396      0.751976
# 12    0.871279  0.981855      0.854960
# 13    0.873058  0.980533      0.856192
# 14    0.896106  0.982113      0.876201
# 15    0.911436  0.984149      0.889709
# 16    0.914547  0.982165      0.892927
# 17    0.944943  0.982864      0.944860
# 18    0.962171  0.983018      0.960132
# 19    0.963531  0.969505      0.950979
# 20    0.977320  0.961836      0.949057
# 21    0.796118  0.966496      0.752161
# 22    0.871096  0.982048      0.854855
# 23    0.873096  0.980452      0.856322
# 24    0.896196  0.982009      0.876352
# 25    0.911893  0.983668      0.890221
# 26    0.914665  0.982208      0.893222
# 27    0.944999  0.982774      0.944886
# 28    0.962336  0.982932      0.960173
# 29    0.963427  0.969672      0.951110
# 30    0.977108  0.962144      0.949249
# 31    0.796118  0.966496      0.752161
# 32    0.871096  0.982048      0.854855
# 33    0.873096  0.980452      0.856322
# 34    0.896196  0.982009      0.876352
# 35    0.911893  0.983668      0.890221
# 36    0.914665  0.982208      0.893222
# 37    0.944999  0.982774      0.944886
# 38    0.962336  0.982932      0.960173
# 39    0.963427  0.969672      0.951110
# 40    0.977108  0.962144      0.949249
# 41    0.780679  0.973494      0.740228
# 42    0.871243  0.981988      0.855062
# 43    0.873424  0.980309      0.856821
# 44    0.896416  0.981316      0.876327
# 45    0.912843  0.982161      0.890844
# 46    0.914950  0.981334      0.892791
# 47    0.944970  0.983079      0.944904
# 48    0.962533  0.982747      0.960249
# 49    0.963294  0.970025      0.951346
# 50    0.977174  0.961848      0.948609
# 51    0.780679  0.973494      0.740228
# 52    0.871243  0.981988      0.855062
# 53    0.873424  0.980309      0.856821
# 54    0.896416  0.981316      0.876327
# 55    0.912843  0.982161      0.890844
# 56    0.914950  0.981334      0.892791
# 57    0.944970  0.983079      0.944904
# 58    0.962533  0.982747      0.960249
# 59    0.963291  0.970026      0.951345
# 60    0.977171  0.961855      0.948620
# 61    0.780679  0.973494      0.740228
# 62    0.871243  0.981988      0.855062
# 63    0.873424  0.980309      0.856821
# 64    0.896416  0.981316      0.876327
# 65    0.912843  0.982161      0.890844
# 66    0.914950  0.981334      0.892791
# 67    0.944970  0.983079      0.944904
# 68    0.962533  0.982747      0.960249
# 69    0.963291  0.970026      0.951345
# 70    0.977171  0.961855      0.948620
# 71    0.780679  0.973494      0.740228
# 72    0.871243  0.981988      0.855062
# 73    0.873424  0.980309      0.856821
# 74    0.896416  0.981316      0.876327
# 75    0.912843  0.982161      0.890844
# 76    0.914950  0.981334      0.892791
# 77    0.944970  0.983079      0.944904
# 78    0.962533  0.982747      0.960249
# 79    0.963291  0.970026      0.951345
# 80    0.977171  0.961855      0.948620
# 81    0.948569  0.991342      0.957946
# 82    0.909608  0.978289      0.880969
# 83    0.910577  0.985823      0.900132
# 84    0.928457  0.984403      0.927512
# 85    0.958033  0.982585      0.959409
# 86    0.957704  0.983370      0.959913
# 87    0.975050  0.974797      0.962173
# 88    0.932525  0.984518      0.931487
# 89    0.963413  0.973551      0.956417
# 90    0.976577  0.945025      0.949332
# 91    0.978174  0.943372      0.943325
# 92    0.775044  0.979034      0.739200
# 93    0.844418  0.982865      0.840463
# 94    0.849508  0.980488      0.842194
# 95    0.898042  0.984153      0.889382
# 96    0.899340  0.983595      0.890496
# 97    0.917005  0.982716      0.906404
# 98    0.915561  0.985417      0.905108
# 99    0.948504  0.982872      0.949960
# 100   0.964480  0.972137      0.955888
# 101   0.979669  0.965754      0.956857
# 102   0.865920  0.982513      0.860425
# 103   0.868150  0.983054      0.863540
# 104   0.873870  0.979250      0.867647
# 105   0.899554  0.980796      0.892688
# 106   0.915364  0.981379      0.907115
# 107   0.930743  0.980935      0.928836
# 108   0.932362  0.985111      0.931887
# 109   0.947972  0.973324      0.942980
# 110   0.963368  0.971434      0.954777
# 111   0.978063  0.960986      0.953668
# 112   0.774655  0.979504      0.739234
# 113   0.844393  0.982902      0.840450
# 114   0.849585  0.980398      0.842227
# 115   0.897990  0.984243      0.889375
# 116   0.899645  0.983272      0.890778
# 117   0.916812  0.982865      0.906131
# 118   0.915597  0.985417      0.905131
# 119   0.948481  0.982947      0.949983
# 120   0.964471  0.972075      0.955862
# 121   0.979604  0.965789      0.956898
# 122   0.866180  0.982019      0.860234
# 123   0.883734  0.982181      0.876398
# 124   0.888453  0.978647      0.879837
# 125   0.900257  0.980034      0.891900
# 126   0.916104  0.980169      0.906581
# 127   0.932426  0.980714      0.942535
# 128   0.962438  0.984454      0.962737
# 129   0.948079  0.972661      0.943118
# 130   0.963456  0.969338      0.953736
# 131   0.996442  0.960633      0.966443
# 132   0.774822  0.979346      0.739240
# 133   0.844436  0.982859      0.840508
# 134   0.849997  0.980060      0.842590
# 135   0.898529  0.983881      0.889901
# 136   0.900178  0.982823      0.891277
# 137   0.917111  0.982853      0.906469
# 138   0.918335  0.982104      0.907330
# 139   0.948725  0.982493      0.949964
# 140   0.964559  0.972067      0.955861
# 141   0.979998  0.965057      0.956424
# 142   0.866180  0.982019      0.860234
# 143   0.883734  0.982181      0.876398
# 144   0.888453  0.978647      0.879837
# 145   0.900257  0.980034      0.891900
# 146   0.916104  0.980169      0.906581
# 147   0.932426  0.980714      0.942535
# 148   0.962436  0.984454      0.962735
# 149   0.948079  0.972661      0.943118
# 150   0.963456  0.969338      0.953736
# 151   0.996442  0.960766      0.966456
# 152   0.774822  0.979346      0.739240
# 153   0.844436  0.982859      0.840508
# 154   0.849997  0.980060      0.842590
# 155   0.898529  0.983881      0.889901
# 156   0.900178  0.982823      0.891277
# 157   0.917111  0.982853      0.906469
# 158   0.918335  0.982104      0.907330
# 159   0.948725  0.982493      0.949964
# 160   0.964559  0.972067      0.955861
# 161   0.979998  0.965057      0.956424
# 162   0.993017  0.978726      0.984052
# 163   0.965657  0.922794      0.901927
# 164   0.967415  0.916172      0.883236
# 165   0.978071  0.945484      0.943576
# 166   0.978879  0.933179      0.936580
# 167   0.980666  0.908551      0.928624
# 168   0.983454  0.895914      0.915444
# 169   0.990904  0.869215      0.897317
# 170   0.992001  0.804005      0.810952
# 171   0.996673  0.723092      0.713365
# 172   0.999243  0.636614      0.596181
# 173   0.781985  0.936332      0.579969
# 174   0.800202  0.929472      0.592678
# 175   0.810322  0.919145      0.603285
# 176   0.854763  0.931537      0.752454
# 177   0.861282  0.929699      0.758299
# 178   0.868761  0.924018      0.763633
# 179   0.986843  0.955684      0.964832
# 180   0.989377  0.945034      0.955689
# 181   0.993941  0.920656      0.936629
# 182   0.996015  0.861151      0.868406
# 183   0.781785  0.936508      0.580289
# 184   0.797416  0.932587      0.591960
# 185   0.810524  0.919548      0.603906
# 186   0.854571  0.932053      0.752856
# 187   0.861153  0.929910      0.758079
# 188   0.867673  0.924866      0.763708
# 189   0.986511  0.956049      0.964586
# 190   0.989324  0.947978      0.959925
# 191   0.993654  0.925353      0.942024
# 192   0.995803  0.866534      0.874862
# 193   0.781785  0.936508      0.580289
# 194   0.797416  0.932587      0.591960
# 195   0.810524  0.919548      0.603906
# 196   0.854571  0.932053      0.752856
# 197   0.861153  0.929910      0.758079
# 198   0.867673  0.924866      0.763708
# 199   0.986511  0.956049      0.964586
# 200   0.989324  0.947978      0.959925
# 201   0.993654  0.925353      0.942024
# 202   0.995803  0.866534      0.874862
# 203   0.777061  0.936817      0.576002
# 204   0.794750  0.934307      0.591297
# 205   0.811982  0.917583      0.604371
# 206   0.853888  0.932954      0.754114
# 207   0.862499  0.929234      0.759266
# 208   0.871569  0.917367      0.766968
# 209   0.989081  0.958348      0.970879
# 210   0.992828  0.953775      0.973584
# 211   0.993547  0.929060      0.946480
# 212   0.996424  0.865684      0.874393
# 213   0.773391  0.940878      0.573734
# 214   0.794657  0.934841      0.591556
# 215   0.808704  0.918157      0.603933
# 216   0.853726  0.933377      0.754343
# 217   0.861193  0.930658      0.759406
# 218   0.871062  0.917607      0.767162
# 219   0.988819  0.958548      0.970985
# 220   0.992599  0.953846      0.973610
# 221   0.993429  0.929325      0.946754
# 222   0.996308  0.865750      0.874449
# 223   0.773391  0.940878      0.573734
# 224   0.794657  0.934841      0.591556
# 225   0.808704  0.918157      0.603933
# 226   0.853726  0.933377      0.754343
# 227   0.861193  0.930658      0.759406
# 228   0.871062  0.917607      0.767162
# 229   0.988819  0.958548      0.970985
# 230   0.992599  0.953846      0.973610
# 231   0.993429  0.929325      0.946754
# 232   0.996308  0.865750      0.874449
# 233   0.773391  0.940878      0.573734
# 234   0.794657  0.934841      0.591556
# 235   0.808704  0.918157      0.603933
# 236   0.853726  0.933377      0.754343
# 237   0.861193  0.930658      0.759406
# 238   0.871062  0.917607      0.767162
# 239   0.988819  0.958548      0.970985
# 240   0.992599  0.953846      0.973610
# 241   0.993429  0.929325      0.946754
# 242   0.996308  0.865750      0.874449
# 243   0.999385  0.756362      0.772837
# 244   0.952065  0.839299      0.857109
# 245   0.970196  0.816441      0.846719
# 246   0.967097  0.759970      0.763880
# 247   0.966862  0.754945      0.760026
# 248   0.982167  0.747859      0.763880
# 249   0.984320  0.772513      0.778713
# 250   0.984819  0.758490      0.770134
# 251   0.990598  0.750434      0.757949
# 252   0.993145  0.727547      0.740768
# 253   0.996320  0.711987      0.709592
# 254   0.771591  0.948702      0.578623
# 255   0.787113  0.941928      0.584701
# 256   0.789063  0.935866      0.586007
# 257   0.840918  0.935698      0.750962
# 258   0.850296  0.929049      0.748488
# 259   0.849801  0.926589      0.749847
# 260   0.980798  0.932878      0.931659
# 261   0.983868  0.930264      0.931521
# 262   0.987466  0.926162      0.930915
# 263   0.991391  0.911716      0.915546
# 264   0.865414  0.932671      0.760528
# 265   0.840399  0.892913      0.685118
# 266   0.933344  0.878736      0.815325
# 267   0.950509  0.885548      0.860257
# 268   0.942332  0.886196      0.844407
# 269   0.956634  0.902501      0.878514
# 270   0.979962  0.902208      0.919493
# 271   0.986861  0.845218      0.826720
# 272   0.986794  0.822807      0.822388
# 273   0.990248  0.807741      0.805798
# 274   0.772624  0.948813      0.578462
# 275   0.785907  0.944494      0.586105
# 276   0.784845  0.943274      0.588330
# 277   0.842004  0.936620      0.749038
# 278   0.848504  0.935150      0.749834
# 279   0.849316  0.936793      0.755970
# 280   0.979780  0.948231      0.941444
# 281   0.982235  0.947242      0.947380
# 282   0.984310  0.946166      0.948972
# 283   0.987341  0.933171      0.936187
# 284   0.940564  0.905514      0.865029
# 285   0.924519  0.832554      0.783461
# 286   0.936716  0.856152      0.799279
# 287   0.944547  0.845074      0.809382
# 288   0.946166  0.825761      0.801664
# 289   0.958137  0.806934      0.793153
# 290   0.985155  0.804004      0.793765
# 291   0.989417  0.731746      0.745223
# 292   0.990430  0.746792      0.749260
# 293   0.993274  0.735896      0.731540
# 294   0.772172  0.938618      0.592069
# 295   0.784792  0.944494      0.586248
# 296   0.787242  0.939027      0.588158
# 297   0.839645  0.933300      0.748220
# 298   0.848393  0.934713      0.751047
# 299   0.851473  0.935712      0.756633
# 300   0.982547  0.951767      0.950444
# 301   0.983484  0.943322      0.942246
# 302   0.984790  0.942303      0.944023
# 303   0.987591  0.928107      0.930870
# 304   0.865371  0.917538      0.752201
# 305   0.907993  0.865625      0.787714
# 306   0.934074  0.895468      0.820420
# 307   0.941193  0.878135      0.842974
# 308   0.944340  0.884578      0.854099
# 309   0.956374  0.894656      0.879720
# 310   0.983229  0.885548      0.902090
# 311   0.985540  0.843877      0.838404
# 312   0.986246  0.792541      0.797720
# 313   0.991045  0.781122      0.773541
# 314   0.772172  0.938618      0.592069
# 315   0.784792  0.944494      0.586248
# 316   0.787242  0.939027      0.588158
# 317   0.839645  0.933300      0.748220
# 318   0.848393  0.934713      0.751047
# 319   0.851473  0.935712      0.756633
# 320   0.982547  0.951767      0.950444
# 321   0.983484  0.943322      0.942246
# 322   0.984790  0.942303      0.944023
# 323   0.987591  0.928107      0.930870

# %%
df_quality.to_csv('%s/df_quality.csv' % eval_dir, sep = ';', index = False)
#df_quality = pd.read_csv('%s/df_quality.csv' % eval_dir, sep = ';')

# %% [markdown]
# Combine counting and quality information:

# %%
df_c, df_q = df_counts.copy(), df_quality.copy()
drop_cols = ['join_col'] + ['%s_counts' % s for s in set(df_q.columns) & set(df_c.columns)]
df_c['join_col'] = df_c['data_set'] + df_c['tool'] + df_c['mode'] + df_c['refinement'] + df_c['threshold'].apply(str)
df_q['join_col'] = df_q['data_set'] + df_q['tool'] + df_q['mode'] + df_q['refinement'] + df_q['threshold'].apply(str)
df_joined = df_q.join(df_c.set_index('join_col'), on = 'join_col', rsuffix = '_counts').drop(drop_cols, axis = 1)

# %%
df_joined.to_csv('%s/df_joined.csv' % eval_dir, sep = ';', index = False)
#df_joined = pd.read_csv('%s/df_joined.csv' % eval_dir, sep = ';')

# %% [markdown]
# Determine the maximum, average and N-best average clustering quality (for N = 5).

# %%
df_columns = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

max_rows = []
mean_rows = []
nbest_rows = []
n = 5

for (d, g, t, m, f, ds, rt), grp in df_joined.groupby(by = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'ds', 'rt']):
    best = grp.nlargest(1, 'adjrandindex')
    max_rows.append([d, g, t, m, f, best['precision'].values[0], best['recall'].values[0], best['adjrandindex'].values[0], best['num_input_amplicons'].values[0], best['input_mass'].values[0], best['num_clusters'].values[0], best['num_output_amplicons'].values[0], best['output_mass'].values[0], ds, rt])
    mean_rows.append([d, g, t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean(), grp['num_input_amplicons'].mean(), grp['input_mass'].mean(), grp['num_clusters'].mean(), grp['num_output_amplicons'].mean(), grp['output_mass'].mean(), ds, rt])
    nbest = grp.nlargest(n, 'adjrandindex')
    nbest_rows.append([d, g, t, m, f, nbest['precision'].mean(), nbest['recall'].mean(), nbest['adjrandindex'].mean(), nbest['num_input_amplicons'].mean(), nbest['input_mass'].mean(), nbest['num_clusters'].mean(), nbest['num_output_amplicons'].mean(), nbest['output_mass'].mean(), ds, rt])
    
df_joined_max = pd.DataFrame(max_rows, columns = df_columns)
df_joined_mean = pd.DataFrame(mean_rows, columns = df_columns)
df_joined_nbest = pd.DataFrame(nbest_rows, columns = df_columns)

# %%
df_joined_max.to_csv('%s/df_joined_max.csv' % eval_dir, sep = ';', index = False)
df_joined_mean.to_csv('%s/df_joined_mean.csv' % eval_dir, sep = ';', index = False)
df_joined_nbest.to_csv('%s/df_joined_nbest.csv' % eval_dir, sep = ';', index = False)
#df_joined_max = pd.read_csv('%s/df_joined_max.csv' % eval_dir, sep = ';')
#df_joined_mean = pd.read_csv('%s/df_joined_mean.csv' % eval_dir, sep = ';')
#df_joined_nbest = pd.read_csv('%s/df_joined_nbest.csv' % eval_dir, sep = ';')

# %%
df_max = df_joined_max.loc[df_joined_max['gt'] == 'callahan']
df_mean = df_joined_mean.loc[df_joined_mean['gt'] == 'callahan']
df_nbest = df_joined_nbest.loc[df_joined_nbest['gt'] == 'callahan']

# %% [markdown]
# For the chosen ground truth, average the maximum, average and N-best average values per data set (e.g. balanced) and read type (e.g. paired).
# Has no effect in this case because there is only one data set per combination of data set and read type .

# %%
df_columns = ['data_set', 'gt', 'tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex', 'num_input_amplicons', 'input_mass', 'num_clusters', 'num_output_amplicons', 'output_mass', 'ds', 'rt']

def average_complexity(df):
    rows = []
    for (gt, ds, rt, tool, mode, f), grp in df.groupby(by = ['gt', 'ds', 'rt', 'tool', 'mode', 'refinement']):
        rows.append(['%s_%s' % (ds, rt), gt, tool, mode, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean(), grp['num_input_amplicons'].mean(), grp['input_mass'].mean(), grp['num_clusters'].mean(), grp['num_output_amplicons'].mean(), grp['output_mass'].mean(), ds, rt])
    return pd.DataFrame(rows, columns = df_columns)

# %%
df_joined_max_avg = average_complexity(df_max)
df_joined_mean_avg = average_complexity(df_mean)
df_joined_nbest_avg = average_complexity(df_nbest)

# %%
df_joined_max_avg.to_csv('%s/df_joined_max_avg.csv' % eval_dir, sep = ';', index = False)
df_joined_mean_avg.to_csv('%s/df_joined_mean_avg.csv' % eval_dir, sep = ';', index = False)
df_joined_nbest_avg.to_csv('%s/df_joined_nbest_avg.csv' % eval_dir, sep = ';', index = False)
#df_joined_max_avg = pd.read_csv('%s/df_joined_max_avg.csv' % eval_dir, sep = ';')
#df_joined_mean_avg = pd.read_csv('%s/df_joined_mean_avg.csv' % eval_dir, sep = ';')
#df_joined_nbest_avg = pd.read_csv('%s/df_joined_nbest_avg.csv' % eval_dir, sep = ';')

# %% [markdown]
# **Maximum clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_max_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: balanced_paired / Tool: uparse
#           data_set        gt    tool  mode refinement  precision    recall  \
# 0  balanced_paired  callahan  uparse  otus         nf   0.948569  0.991342
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 0      0.957946              21808.0    467652.0          99.0
#
#    num_output_amplicons  output_mass        ds      rt
# 0               18891.0     463596.0  balanced  paired
# Data set: balanced_paired / Tool: usearch
#           data_set        gt     tool             mode refinement  precision  \
# 1  balanced_paired  callahan  usearch      fast_length         nf   0.975050
# 4  balanced_paired  callahan  usearch    smallmem_size         nf   0.979604
# 2  balanced_paired  callahan  usearch        fast_size         nf   0.979669
# 3  balanced_paired  callahan  usearch  smallmem_length         nf   0.963368
#
#      recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 1  0.974797      0.962173              21808.0    467652.0         738.0
# 4  0.965789      0.956898              21808.0    467652.0        2965.0
# 2  0.965754      0.956857              21808.0    467652.0        3170.0
# 3  0.971434      0.954777              21808.0    467652.0        1646.0
#
#    num_output_amplicons  output_mass        ds      rt
# 1               21808.0     467652.0  balanced  paired
# 4               21808.0     467652.0  balanced  paired
# 2               21808.0     467652.0  balanced  paired
# 3               21808.0     467652.0  balanced  paired
# Data set: balanced_paired / Tool: vsearch
#           data_set        gt     tool             mode refinement  precision  \
# 7  balanced_paired  callahan  vsearch  smallmem_length         nf   0.996442
# 5  balanced_paired  callahan  vsearch             fast         nf   0.996442
# 6  balanced_paired  callahan  vsearch             size         nf   0.979998
# 8  balanced_paired  callahan  vsearch    smallmem_size         nf   0.979998
#
#      recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 7  0.960766      0.966456              21808.0    467652.0        2973.0
# 5  0.960633      0.966443              21808.0    467652.0        2977.0
# 6  0.965057      0.956424              21808.0    467652.0        2941.0
# 8  0.965057      0.956424              21808.0    467652.0        2941.0
#
#    num_output_amplicons  output_mass        ds      rt
# 7               21808.0     467652.0  balanced  paired
# 5               21808.0     467652.0  balanced  paired
# 6               21808.0     467652.0  balanced  paired
# 8               21808.0     467652.0  balanced  paired
# Data set: balanced_single / Tool: uparse
#           data_set        gt    tool  mode refinement  precision    recall  \
# 9  balanced_single  callahan  uparse  otus         nf   0.961808  0.990367
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 9       0.96679              33523.0    558059.0         591.0
#
#    num_output_amplicons  output_mass        ds      rt
# 9               30452.0     553807.0  balanced  single
# Data set: balanced_single / Tool: usearch
#            data_set        gt     tool             mode refinement  precision  \
# 12  balanced_single  callahan  usearch  smallmem_length         nf   0.962336
# 13  balanced_single  callahan  usearch    smallmem_size         nf   0.962336
# 11  balanced_single  callahan  usearch        fast_size         nf   0.962171
# 10  balanced_single  callahan  usearch      fast_length         nf   0.988856
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 12  0.982932      0.960173              33523.0    558059.0        2383.0
# 13  0.982932      0.960173              33523.0    558059.0        2383.0
# 11  0.983018      0.960132              33523.0    558059.0        2432.0
# 10  0.954912      0.957855              33523.0    558059.0        1351.0
#
#     num_output_amplicons  output_mass        ds      rt
# 12               33523.0     558059.0  balanced  single
# 13               33523.0     558059.0  balanced  single
# 11               33523.0     558059.0  balanced  single
# 10               33523.0     558059.0  balanced  single
# Data set: balanced_single / Tool: vsearch
#            data_set        gt     tool             mode refinement  precision  \
# 15  balanced_single  callahan  vsearch             size         nf   0.962533
# 16  balanced_single  callahan  vsearch  smallmem_length         nf   0.962533
# 17  balanced_single  callahan  vsearch    smallmem_size         nf   0.962533
# 14  balanced_single  callahan  vsearch             fast         nf   0.962533
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 15  0.982747      0.960249              33523.0    558059.0        2380.0
# 16  0.982747      0.960249              33523.0    558059.0        2380.0
# 17  0.982747      0.960249              33523.0    558059.0        2380.0
# 14  0.982747      0.960249              33523.0    558059.0        2383.0
#
#     num_output_amplicons  output_mass        ds      rt
# 15               33523.0     558059.0  balanced  single
# 16               33523.0     558059.0  balanced  single
# 17               33523.0     558059.0  balanced  single
# 14               33523.0     558059.0  balanced  single
# Data set: hmp_paired / Tool: uparse
#       data_set        gt    tool  mode refinement  precision    recall  \
# 18  hmp_paired  callahan  uparse  otus         nf   0.999385  0.756362
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 18      0.772837              19882.0    208157.0         271.0
#
#     num_output_amplicons  output_mass   ds      rt
# 18               15710.0     201779.0  hmp  paired
# Data set: hmp_paired / Tool: usearch
#       data_set        gt     tool             mode refinement  precision  \
# 22  hmp_paired  callahan  usearch    smallmem_size         nf   0.984310
# 20  hmp_paired  callahan  usearch        fast_size         nf   0.980798
# 21  hmp_paired  callahan  usearch  smallmem_length         nf   0.979962
# 19  hmp_paired  callahan  usearch      fast_length         nf   0.952065
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 22  0.946166      0.948972              19882.0    208157.0        1027.0
# 20  0.932878      0.931659              19882.0    208157.0         722.0
# 21  0.902208      0.919493              19882.0    208157.0         630.0
# 19  0.839299      0.857109              19882.0    208157.0         201.0
#
#     num_output_amplicons  output_mass   ds      rt
# 22               19882.0     208157.0  hmp  paired
# 20               19882.0     208157.0  hmp  paired
# 21               19882.0     208157.0  hmp  paired
# 19               19882.0     208157.0  hmp  paired
# Data set: hmp_paired / Tool: vsearch
#       data_set        gt     tool             mode refinement  precision  \
# 24  hmp_paired  callahan  vsearch             size         nf   0.982547
# 26  hmp_paired  callahan  vsearch    smallmem_size         nf   0.982547
# 25  hmp_paired  callahan  vsearch  smallmem_length         nf   0.983229
# 23  hmp_paired  callahan  vsearch             fast         nf   0.940564
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 24  0.951767      0.950444              19882.0    208157.0         547.0
# 26  0.951767      0.950444              19882.0    208157.0         547.0
# 25  0.885548      0.902090              19882.0    208157.0         619.0
# 23  0.905514      0.865029              19882.0    208157.0         198.0
#
#     num_output_amplicons  output_mass   ds      rt
# 24               19882.0     208157.0  hmp  paired
# 26               19882.0     208157.0  hmp  paired
# 25               19882.0     208157.0  hmp  paired
# 23               19882.0     208157.0  hmp  paired
# Data set: hmp_single / Tool: uparse
#       data_set        gt    tool  mode refinement  precision    recall  \
# 27  hmp_single  callahan  uparse  otus         nf   0.993017  0.978726
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 27      0.984052              73071.0    449409.0        1884.0
#
#     num_output_amplicons  output_mass   ds      rt
# 27               66339.0     437522.0  hmp  single
# Data set: hmp_single / Tool: usearch
#       data_set        gt     tool             mode refinement  precision  \
# 29  hmp_single  callahan  usearch        fast_size         nf   0.986843
# 30  hmp_single  callahan  usearch  smallmem_length         nf   0.986511
# 31  hmp_single  callahan  usearch    smallmem_size         nf   0.986511
# 28  hmp_single  callahan  usearch      fast_length         nf   0.978071
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 29  0.955684      0.964832              73071.0    449409.0        3670.0
# 30  0.956049      0.964586              73071.0    449409.0        3535.0
# 31  0.956049      0.964586              73071.0    449409.0        3535.0
# 28  0.945484      0.943576              73071.0    449409.0        1057.0
#
#     num_output_amplicons  output_mass   ds      rt
# 29               73071.0     449409.0  hmp  single
# 30               73071.0     449409.0  hmp  single
# 31               73071.0     449409.0  hmp  single
# 28               73071.0     449409.0  hmp  single
# Data set: hmp_single / Tool: vsearch
#       data_set        gt     tool             mode refinement  precision  \
# 33  hmp_single  callahan  vsearch             size         nf   0.992599
# 34  hmp_single  callahan  vsearch  smallmem_length         nf   0.992599
# 35  hmp_single  callahan  vsearch    smallmem_size         nf   0.992599
# 32  hmp_single  callahan  vsearch             fast         nf   0.992828
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 33  0.953846      0.973610              73071.0    449409.0        5714.0
# 34  0.953846      0.973610              73071.0    449409.0        5714.0
# 35  0.953846      0.973610              73071.0    449409.0        5714.0
# 32  0.953775      0.973584              73071.0    449409.0        5765.0
#
#     num_output_amplicons  output_mass   ds      rt
# 33               73071.0     449409.0  hmp  single
# 34               73071.0     449409.0  hmp  single
# 35               73071.0     449409.0  hmp  single
# 32               73071.0     449409.0  hmp  single

# %% [markdown]
# Best option of VSEARCH better than best option of USEARCH on each data set, but difference is rather small.
# UPARSE usually similar to both (sometimes a bit better, sometimes a bit worse), but notably lower on hmp_paired.
# However, the results have to be compared with caution because for UPARSE we only consider those sequences not labelled as chimeric.
#
# Average maximum values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_max_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#       tool             mode refinement  precision    recall  adjrandindex
# 6  vsearch             size         nf   0.979419  0.963354      0.960181
# 8  vsearch    smallmem_size         nf   0.979419  0.963354      0.960181
# 4  usearch    smallmem_size         nf   0.978190  0.962734      0.957657
# 2  usearch        fast_size         nf   0.977370  0.959333      0.953370
# 7  vsearch  smallmem_length         nf   0.983701  0.945727      0.950601
# 3  usearch  smallmem_length         nf   0.973044  0.953156      0.949757
# 5  vsearch             fast         nf   0.973092  0.950667      0.941326
# 1  usearch      fast_length         nf   0.973511  0.928623      0.930178
# 0   uparse             otus         nf   0.975695  0.929199      0.920406

# %% [markdown]
# Options using the abundance (size) as the sorting criterion performed better. Minor differences between normal / fast and smallmem versions.
#
# `USEARCH` pick: `fast_size` = `-cluster_fast -sort size
# `
#
# `VSEARCH` pick: `size` = `--cluster_size`

# %% [markdown]
# **Average clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_mean_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: balanced_paired / Tool: uparse
#           data_set        gt    tool  mode refinement  precision    recall  \
# 0  balanced_paired  callahan  uparse  otus         nf   0.948569  0.991342
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 0      0.957946              21808.0    467652.0          99.0
#
#    num_output_amplicons  output_mass        ds      rt
# 0               18891.0     463596.0  balanced  paired
# Data set: balanced_paired / Tool: usearch
#           data_set        gt     tool             mode refinement  precision  \
# 1  balanced_paired  callahan  usearch      fast_length         nf   0.949012
# 3  balanced_paired  callahan  usearch  smallmem_length         nf   0.917537
# 4  balanced_paired  callahan  usearch    smallmem_size         nf   0.899123
# 2  balanced_paired  callahan  usearch        fast_size         nf   0.899157
#
#      recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 1  0.973574      0.937067              21808.0    467652.0         998.5
# 3  0.977878      0.910356              21808.0    467652.0         906.8
# 4  0.979941      0.887607              21808.0    467652.0         897.5
# 2  0.979903      0.887595              21808.0    467652.0         920.3
#
#    num_output_amplicons  output_mass        ds      rt
# 1               21808.0     467652.0  balanced  paired
# 3               21808.0     467652.0  balanced  paired
# 4               21808.0     467652.0  balanced  paired
# 2               21808.0     467652.0  balanced  paired
# Data set: balanced_paired / Tool: vsearch
#           data_set        gt     tool             mode refinement  precision  \
# 7  balanced_paired  callahan  vsearch  smallmem_length         nf   0.925757
# 5  balanced_paired  callahan  vsearch             fast         nf   0.925757
# 6  balanced_paired  callahan  vsearch             size         nf   0.899669
# 8  balanced_paired  callahan  vsearch    smallmem_size         nf   0.899669
#
#      recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 7  0.977098      0.918353              21808.0    467652.0         903.7
# 5  0.977085      0.918352              21808.0    467652.0         904.2
# 6  0.979354      0.887956              21808.0    467652.0         895.1
# 8  0.979354      0.887956              21808.0    467652.0         895.1
#
#    num_output_amplicons  output_mass        ds      rt
# 7               21808.0     467652.0  balanced  paired
# 5               21808.0     467652.0  balanced  paired
# 6               21808.0     467652.0  balanced  paired
# 8               21808.0     467652.0  balanced  paired
# Data set: balanced_single / Tool: uparse
#           data_set        gt    tool  mode refinement  precision    recall  \
# 9  balanced_single  callahan  uparse  otus         nf   0.961808  0.990367
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 9       0.96679              33523.0    558059.0         591.0
#
#    num_output_amplicons  output_mass        ds      rt
# 9               30452.0     553807.0  balanced  single
# Data set: balanced_single / Tool: usearch
#            data_set        gt     tool             mode refinement  precision  \
# 10  balanced_single  callahan  usearch      fast_length         nf   0.966780
# 12  balanced_single  callahan  usearch  smallmem_length         nf   0.911093
# 13  balanced_single  callahan  usearch    smallmem_size         nf   0.911093
# 11  balanced_single  callahan  usearch        fast_size         nf   0.911057
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 10  0.930208      0.896599              33523.0    558059.0        3090.7
# 12  0.977440      0.892855              33523.0    558059.0        1838.2
# 13  0.977440      0.892855              33523.0    558059.0        1838.2
# 11  0.977443      0.892699              33523.0    558059.0        1908.1
#
#     num_output_amplicons  output_mass        ds      rt
# 10               33523.0     558059.0  balanced  single
# 12               33523.0     558059.0  balanced  single
# 13               33523.0     558059.0  balanced  single
# 11               33523.0     558059.0  balanced  single
# Data set: balanced_single / Tool: vsearch
#            data_set        gt     tool             mode refinement  precision  \
# 15  balanced_single  callahan  vsearch             size         nf   0.909752
# 16  balanced_single  callahan  vsearch  smallmem_length         nf   0.909752
# 17  balanced_single  callahan  vsearch    smallmem_size         nf   0.909752
# 14  balanced_single  callahan  vsearch             fast         nf   0.909753
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 15  0.977831      0.891719              33523.0    558059.0        1815.9
# 16  0.977831      0.891719              33523.0    558059.0        1815.9
# 17  0.977831      0.891719              33523.0    558059.0        1815.9
# 14  0.977830      0.891718              33523.0    558059.0        1818.4
#
#     num_output_amplicons  output_mass        ds      rt
# 15               33523.0     558059.0  balanced  single
# 16               33523.0     558059.0  balanced  single
# 17               33523.0     558059.0  balanced  single
# 14               33523.0     558059.0  balanced  single
# Data set: hmp_paired / Tool: uparse
#       data_set        gt    tool  mode refinement  precision    recall  \
# 18  hmp_paired  callahan  uparse  otus         nf   0.999385  0.756362
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 18      0.772837              19882.0    208157.0         271.0
#
#     num_output_amplicons  output_mass   ds      rt
# 18               15710.0     201779.0  hmp  paired
# Data set: hmp_paired / Tool: usearch
#       data_set        gt     tool             mode refinement  precision  \
# 21  hmp_paired  callahan  usearch  smallmem_length         nf   0.943250
# 22  hmp_paired  callahan  usearch    smallmem_size         nf   0.881686
# 19  hmp_paired  callahan  usearch      fast_length         nf   0.978759
# 20  hmp_paired  callahan  usearch        fast_size         nf   0.883230
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 21  0.875654      0.821855              19882.0    208157.0         723.2
# 22  0.941995      0.778172              19882.0    208157.0         667.3
# 19  0.763948      0.774877              19882.0    208157.0         997.2
# 20  0.931885      0.770827              19882.0    208157.0         930.4
#
#     num_output_amplicons  output_mass   ds      rt
# 21               19882.0     208157.0  hmp  paired
# 22               19882.0     208157.0  hmp  paired
# 19               19882.0     208157.0  hmp  paired
# 20               19882.0     208157.0  hmp  paired
# Data set: hmp_paired / Tool: vsearch
#       data_set        gt     tool             mode refinement  precision  \
# 25  hmp_paired  callahan  vsearch  smallmem_length         nf   0.949540
# 23  hmp_paired  callahan  vsearch             fast         nf   0.960892
# 24  hmp_paired  callahan  vsearch             size         nf   0.882213
# 26  hmp_paired  callahan  vsearch    smallmem_size         nf   0.882213
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 25  0.863909      0.824888              19882.0    208157.0         722.2
# 23  0.809043      0.787176              19882.0    208157.0         787.8
# 24  0.939136      0.778996              19882.0    208157.0         676.8
# 26  0.939136      0.778996              19882.0    208157.0         676.8
#
#     num_output_amplicons  output_mass   ds      rt
# 25               19882.0     208157.0  hmp  paired
# 23               19882.0     208157.0  hmp  paired
# 24               19882.0     208157.0  hmp  paired
# 26               19882.0     208157.0  hmp  paired
# Data set: hmp_single / Tool: uparse
#       data_set        gt    tool  mode refinement  precision    recall  \
# 27  hmp_single  callahan  uparse  otus         nf   0.993017  0.978726
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 27      0.984052              73071.0    449409.0        1884.0
#
#     num_output_amplicons  output_mass   ds      rt
# 27               66339.0     437522.0  hmp  single
# Data set: hmp_single / Tool: usearch
#       data_set        gt     tool             mode refinement  precision  \
# 28  hmp_single  callahan  usearch      fast_length         nf   0.983296
# 30  hmp_single  callahan  usearch  smallmem_length         nf   0.893841
# 31  hmp_single  callahan  usearch    smallmem_size         nf   0.893841
# 29  hmp_single  callahan  usearch        fast_size         nf   0.894349
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 28  0.855502      0.852720              73071.0    449409.0        9532.3
# 30  0.927139      0.779220              73071.0    449409.0        5912.9
# 31  0.927139      0.779220              73071.0    449409.0        5912.9
# 29  0.925273      0.777587              73071.0    449409.0        6649.3
#
#     num_output_amplicons  output_mass   ds      rt
# 28               73071.0     449409.0  hmp  single
# 30               73071.0     449409.0  hmp  single
# 31               73071.0     449409.0  hmp  single
# 29               73071.0     449409.0  hmp  single
# Data set: hmp_single / Tool: vsearch
#       data_set        gt     tool             mode refinement  precision  \
# 32  hmp_single  callahan  vsearch             fast         nf   0.894363
# 33  hmp_single  callahan  vsearch             size         nf   0.893389
# 34  hmp_single  callahan  vsearch  smallmem_length         nf   0.893389
# 35  hmp_single  callahan  vsearch    smallmem_size         nf   0.893389
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 32  0.927513      0.781736              73071.0    449409.0        5541.3
# 33  0.928299      0.781593              73071.0    449409.0        5504.0
# 34  0.928299      0.781593              73071.0    449409.0        5504.0
# 35  0.928299      0.781593              73071.0    449409.0        5504.0
#
#     num_output_amplicons  output_mass   ds      rt
# 32               73071.0     449409.0  hmp  single
# 33               73071.0     449409.0  hmp  single
# 34               73071.0     449409.0  hmp  single
# 35               73071.0     449409.0  hmp  single

# %% [markdown]
# Best option of USEARCH typically (slightly) better than best option of VSEARCH. Larger difference on hmp_single.
#
# Average the mean values over all data sets and sort by adjusted Rand index.

# %%
rows = []
for (t, m, f), grp in df_joined_mean_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#       tool             mode refinement  precision    recall  adjrandindex
# 0   uparse             otus         nf   0.975695  0.929199      0.920406
# 1  usearch      fast_length         nf   0.969462  0.880808      0.865316
# 7  vsearch  smallmem_length         nf   0.919609  0.936784      0.854138
# 3  usearch  smallmem_length         nf   0.916430  0.939528      0.851071
# 5  vsearch             fast         nf   0.922691  0.922868      0.844745
# 6  vsearch             size         nf   0.896256  0.956155      0.835066
# 8  vsearch    smallmem_size         nf   0.896256  0.956155      0.835066
# 4  usearch    smallmem_size         nf   0.896436  0.956629      0.834463
# 2  usearch        fast_size         nf   0.896948  0.953626      0.832177

# %% [markdown]
# Options using the abundance (size) as the sorting criterion performed worse. Minor differences between normal / fast and smallmem versions.
#
# `USEARCH` pick: `fast_length` = `-cluster_fast -sort length
# `
#
# `VSEARCH` pick: `smallmem_length` = `--cluster_smallmem --minsize 1` on length-ordered input FASTA file
#
# Differences between abundance- and length-sorted options relatively small. Use of options with best maximum average probably okay.

# %% [markdown]
# **N-best average clustering quality**
#
# Rank by adjusted Rand index (per data set):

# %%
for (d, t), grp in df_joined_nbest_avg.groupby(by = ['data_set', 'tool']):
    print('Data set: %s / Tool: %s' % (d, t))
    display(grp.sort_values(by = 'adjrandindex', ascending = False))
# Out:
# Data set: balanced_paired / Tool: uparse
#           data_set        gt    tool  mode refinement  precision    recall  \
# 0  balanced_paired  callahan  uparse  otus         nf   0.948569  0.991342
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 0      0.957946              21808.0    467652.0          99.0
#
#    num_output_amplicons  output_mass        ds      rt
# 0               18891.0     463596.0  balanced  paired
# Data set: balanced_paired / Tool: usearch
#           data_set        gt     tool             mode refinement  precision  \
# 1  balanced_paired  callahan  usearch      fast_length         nf   0.966155
# 3  balanced_paired  callahan  usearch  smallmem_length         nf   0.950502
# 2  balanced_paired  callahan  usearch        fast_size         nf   0.945044
# 4  balanced_paired  callahan  usearch    smallmem_size         nf   0.944993
#
#      recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 1  0.971866      0.957449              21808.0    467652.0         937.0
# 3  0.974358      0.942430              21808.0    467652.0        1510.8
# 2  0.977779      0.934843              21808.0    467652.0        1545.6
# 4  0.977819      0.934801              21808.0    467652.0        1498.8
#
#    num_output_amplicons  output_mass        ds      rt
# 1               21808.0     467652.0  balanced  paired
# 3               21808.0     467652.0  balanced  paired
# 2               21808.0     467652.0  balanced  paired
# 4               21808.0     467652.0  balanced  paired
# Data set: balanced_paired / Tool: vsearch
#           data_set        gt     tool             mode refinement  precision  \
# 7  balanced_paired  callahan  vsearch  smallmem_length         nf   0.960568
# 5  balanced_paired  callahan  vsearch             fast         nf   0.960568
# 6  balanced_paired  callahan  vsearch             size         nf   0.945746
# 8  balanced_paired  callahan  vsearch    smallmem_size         nf   0.945746
#
#      recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 7  0.973587      0.953716              21808.0    467652.0        1504.6
# 5  0.973560      0.953714              21808.0    467652.0        1505.6
# 6  0.976915      0.935210              21808.0    467652.0        1494.0
# 8  0.976915      0.935210              21808.0    467652.0        1494.0
#
#    num_output_amplicons  output_mass        ds      rt
# 7               21808.0     467652.0  balanced  paired
# 5               21808.0     467652.0  balanced  paired
# 6               21808.0     467652.0  balanced  paired
# 8               21808.0     467652.0  balanced  paired
# Data set: balanced_single / Tool: uparse
#           data_set        gt    tool  mode refinement  precision    recall  \
# 9  balanced_single  callahan  uparse  otus         nf   0.961808  0.990367
#
#    adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 9       0.96679              33523.0    558059.0         591.0
#
#    num_output_amplicons  output_mass        ds      rt
# 9               30452.0     553807.0  balanced  single
# Data set: balanced_single / Tool: usearch
#            data_set        gt     tool             mode refinement  precision  \
# 12  balanced_single  callahan  usearch  smallmem_length         nf   0.952507
# 13  balanced_single  callahan  usearch    smallmem_size         nf   0.952507
# 11  balanced_single  callahan  usearch        fast_size         nf   0.952502
# 10  balanced_single  callahan  usearch      fast_length         nf   0.958127
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 12  0.975946      0.939728              33523.0    558059.0        3146.2
# 13  0.975946      0.939728              33523.0    558059.0        3146.2
# 11  0.975877      0.939591              33523.0    558059.0        3286.0
# 10  0.953234      0.924435              33523.0    558059.0        1078.6
#
#     num_output_amplicons  output_mass        ds      rt
# 12               33523.0     558059.0  balanced  single
# 13               33523.0     558059.0  balanced  single
# 11               33523.0     558059.0  balanced  single
# 10               33523.0     558059.0  balanced  single
# Data set: balanced_single / Tool: vsearch
#            data_set        gt     tool             mode refinement  precision  \
# 15  balanced_single  callahan  vsearch             size         nf   0.952583
# 16  balanced_single  callahan  vsearch  smallmem_length         nf   0.952583
# 17  balanced_single  callahan  vsearch    smallmem_size         nf   0.952583
# 14  balanced_single  callahan  vsearch             fast         nf   0.952584
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 15  0.975808      0.939582              33523.0    558059.0        3104.0
# 16  0.975808      0.939582              33523.0    558059.0        3104.0
# 17  0.975808      0.939582              33523.0    558059.0        3104.0
# 14  0.975807      0.939580              33523.0    558059.0        3108.0
#
#     num_output_amplicons  output_mass        ds      rt
# 15               33523.0     558059.0  balanced  single
# 16               33523.0     558059.0  balanced  single
# 17               33523.0     558059.0  balanced  single
# 14               33523.0     558059.0  balanced  single
# Data set: hmp_paired / Tool: uparse
#       data_set        gt    tool  mode refinement  precision    recall  \
# 18  hmp_paired  callahan  uparse  otus         nf   0.999385  0.756362
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 18      0.772837              19882.0    208157.0         271.0
#
#     num_output_amplicons  output_mass   ds      rt
# 18               15710.0     201779.0  hmp  paired
# Data set: hmp_paired / Tool: usearch
#       data_set        gt     tool             mode refinement  precision  \
# 22  hmp_paired  callahan  usearch    smallmem_size         nf   0.956596
# 20  hmp_paired  callahan  usearch        fast_size         nf   0.956888
# 21  hmp_paired  callahan  usearch  smallmem_length         nf   0.963259
# 19  hmp_paired  callahan  usearch      fast_length         nf   0.971699
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 22  0.942320      0.905991              19882.0    208157.0        1081.4
# 20  0.927343      0.892120              19882.0    208157.0        1546.0
# 21  0.884334      0.865878              19882.0    208157.0         540.8
# 19  0.789343      0.803311              19882.0    208157.0         410.0
#
#     num_output_amplicons  output_mass   ds      rt
# 22               19882.0     208157.0  hmp  paired
# 20               19882.0     208157.0  hmp  paired
# 21               19882.0     208157.0  hmp  paired
# 19               19882.0     208157.0  hmp  paired
# Data set: hmp_paired / Tool: vsearch
#       data_set        gt     tool             mode refinement  precision  \
# 24  hmp_paired  callahan  vsearch             size         nf   0.957977
# 26  hmp_paired  callahan  vsearch    smallmem_size         nf   0.957977
# 25  hmp_paired  callahan  vsearch  smallmem_length         nf   0.962135
# 23  hmp_paired  callahan  vsearch             fast         nf   0.950630
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 24  0.940242      0.904843              19882.0    208157.0        1100.8
# 26  0.940242      0.904843              19882.0    208157.0        1100.8
# 25  0.877359      0.863458              19882.0    208157.0         538.8
# 23  0.847301      0.813824              19882.0    208157.0         398.6
#
#     num_output_amplicons  output_mass   ds      rt
# 24               19882.0     208157.0  hmp  paired
# 26               19882.0     208157.0  hmp  paired
# 25               19882.0     208157.0  hmp  paired
# 23               19882.0     208157.0  hmp  paired
# Data set: hmp_single / Tool: uparse
#       data_set        gt    tool  mode refinement  precision    recall  \
# 27  hmp_single  callahan  uparse  otus         nf   0.993017  0.978726
#
#     adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 27      0.984052              73071.0    449409.0        1884.0
#
#     num_output_amplicons  output_mass   ds      rt
# 27               66339.0     437522.0  hmp  single
# Data set: hmp_single / Tool: usearch
#       data_set        gt     tool             mode refinement  precision  \
# 28  hmp_single  callahan  usearch      fast_length         nf   0.977345
# 30  hmp_single  callahan  usearch  smallmem_length         nf   0.966593
# 31  hmp_single  callahan  usearch    smallmem_size         nf   0.966593
# 29  hmp_single  callahan  usearch        fast_size         nf   0.966987
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 28  0.921184      0.925230              73071.0    449409.0        1533.6
# 30  0.924156      0.901021              73071.0    449409.0       10843.2
# 31  0.924156      0.901021              73071.0    449409.0       10843.2
# 29  0.921309      0.897838              73071.0    449409.0       12275.2
#
#     num_output_amplicons  output_mass   ds      rt
# 28               73071.0     449409.0  hmp  single
# 30               73071.0     449409.0  hmp  single
# 31               73071.0     449409.0  hmp  single
# 29               73071.0     449409.0  hmp  single
# Data set: hmp_single / Tool: vsearch
#       data_set        gt     tool             mode refinement  precision  \
# 33  hmp_single  callahan  vsearch             size         nf   0.968443
# 34  hmp_single  callahan  vsearch  smallmem_length         nf   0.968443
# 35  hmp_single  callahan  vsearch    smallmem_size         nf   0.968443
# 32  hmp_single  callahan  vsearch             fast         nf   0.968690
#
#       recall  adjrandindex  num_input_amplicons  input_mass  num_clusters  \
# 33  0.925015      0.906592              73071.0    449409.0       10045.8
# 34  0.925015      0.906592              73071.0    449409.0       10045.8
# 35  0.925015      0.906592              73071.0    449409.0       10045.8
# 32  0.924847      0.906461              73071.0    449409.0       10094.0
#
#     num_output_amplicons  output_mass   ds      rt
# 33               73071.0     449409.0  hmp  single
# 34               73071.0     449409.0  hmp  single
# 35               73071.0     449409.0  hmp  single
# 32               73071.0     449409.0  hmp  single

# %% [markdown]
# Mixed tendencies. Usually no large differences.
#
# Average the N-best values over all data sets and sort by adjusted Rand index:

# %%
rows = []
for (t, m, f), grp in df_joined_nbest_avg.groupby(by = ['tool', 'mode', 'refinement']):
    rows.append([t, m, f, grp['precision'].mean(), grp['recall'].mean(), grp['adjrandindex'].mean()])
pd.DataFrame(rows, columns = ['tool', 'mode', 'refinement', 'precision', 'recall', 'adjrandindex']).sort_values(by = 'adjrandindex', ascending = False)
# Out:
#       tool             mode refinement  precision    recall  adjrandindex
# 6  vsearch             size         nf   0.956187  0.954495      0.921557
# 8  vsearch    smallmem_size         nf   0.956187  0.954495      0.921557
# 0   uparse             otus         nf   0.975695  0.929199      0.920406
# 4  usearch    smallmem_size         nf   0.955172  0.955060      0.920385
# 2  usearch        fast_size         nf   0.955355  0.950577      0.916098
# 7  vsearch  smallmem_length         nf   0.960932  0.937942      0.915837
# 3  usearch  smallmem_length         nf   0.958215  0.939699      0.912264
# 5  vsearch             fast         nf   0.958118  0.930379      0.903395
# 1  usearch      fast_length         nf   0.968332  0.908907      0.902606

# %% [markdown]
# Similar to maximum.
